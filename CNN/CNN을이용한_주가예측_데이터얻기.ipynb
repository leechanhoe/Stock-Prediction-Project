# %%
# !pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.10/dist-packages (0.9.50)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from datetime import datetime, timedelta

num_images = 5000
day_num = 32

# %%
def convert_image(data, num_images, day_num, change_std, save = False):
    def alpha_blend(color1, color2, alpha):
        return [
            int((color1[0] * alpha + color2[0] * (1 - alpha))),
            int((color1[1] * alpha + color2[1] * (1 - alpha))),
            int((color1[2] * alpha + color2[2] * (1 - alpha))),
            255,
        ]

    # 데이터수가 너무 적으면 패스
    if len(data) <= 100
        return []


    # 해당 종목의 주가 데이터 - 100이 요구되는 이미지 수보다 적으면(상장직후는 변동이 심할 수있으니 제외)
    if num_images - 100 > len(data):
        num_images = len(data) - 100

    #return_datas는 이미지, 라벨링(상승이면1 하락이면0), 변동률, 날짜를 담고있음
    return_datas = []
    prediction_day_num = 5


    image_idx = 1
    while(image_idx <= num_images):
        prediction_day = data[-image_idx - prediction_day_num : -image_idx]
        predict_mean = prediction_day['Close'].mean()
        now = data.iloc[-image_idx - prediction_day_num - 1]
        change = (predict_mean - now['Close']) / now['Close']

        # change가 너무 높으면 이상치라고 판단하여 패스
        if abs(change) < change_std or change_std * 2 < abs(change): # 향후 prediction_day_num일의 변동률이 기준 이하면
            image_idx += 1
            continue

        stock_data = data[-image_idx - day_num - prediction_day_num : -image_idx - prediction_day_num]

        # 이미지 크기 설정
        width, height = 96, 96

        # High, Low, Close, Volume 데이터 정규화
        high_prices = stock_data['High'].values
        low_prices = stock_data['Low'].values
        close_prices = stock_data['Close'].values
        volume_data = stock_data['Volume'].values

        high_prices_norm = (high_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        low_prices_norm = (low_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        close_prices_norm = (close_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        volume_data_norm = height * (volume_data) / (2 * (np.max(volume_data)))

        # 이동평균선 추가를 위한 stock_data 생성
        stock_data_ma20 = data[-image_idx - day_num - 19: -image_idx]
        stock_data_ma20 = stock_data_ma20.copy()
        stock_data_ma20['MA20'] = stock_data_ma20['Close'].rolling(window=20).mean()
        stock_data_ma20.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma20['MA20_norm'] = (
                (stock_data_ma20['MA20'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        # 96x96 이미지 생성
        img = np.zeros((height, width, 4), dtype=np.uint8)  # 4 channels for RGBA

        for day in range(32):
            high_price = int(high_prices_norm[day] * (height - 1))
            low_price = int(low_prices_norm[day] * (height - 1))
            close_price = int(close_prices_norm[day] * (height - 1))
            open_price = int(
                (
                    (stock_data['Open'].values[day] - np.min(low_prices))
                    / (np.max(high_prices) - np.min(low_prices))
                )
                * (height - 1)
            )
            volume = int(volume_data_norm[day])

            x_start = day * 3

            # 시가, 종가, 고가, 저가 막대그래프
            # 막대 왼쪽, 오른쪽 그리기 (시가, 종가 범위)
            for x in range(x_start, x_start + 3):
                if close_prices[day] > stock_data['Open'].values[day]:
                    color = [255, 0, 0, 255]  # 상승: 빨강
                    tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                else:
                    color = [0, 0, 255, 255]  # 하락: 파랑
                    tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑

                for y in range(min(open_price, close_price), max(open_price, close_price) + 1):
                    img[height - 1 - y, x] = color

            # 꼬리 그리기 (High, Low 범위)
            for x in range(x_start + 1, x_start + 2):
                for y in range(low_price, high_price + 1):
                    if img[height - 1 - y, x][0] != 255 and img[height - 1 - y, x][2] != 255:
                        img[height - 1 - y, x] = tail_color

            # 거래량 그리기
            for x in range(x_start, x_start + 3):
                overlapped = height - volume
                if overlapped >= 0 and overlapped < height:
                    img[overlapped:, x] = [
                        alpha_blend(img[y, x], [128, 128, 128, 255], 0.45)
                        for y in range(overlapped, height)
                    ]

            # 20일 이동평균선 그리기
            ma20_norm = stock_data_ma20.iloc[day]['MA20_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma20_norm):
                    ma20_y = int(ma20_norm * (height - 1))
                    if 0 <= ma20_y < height:
                        for y in range(ma20_y - 1, ma20_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([255, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 노란색으로 변경
                                img[height - 1 - y, x] = new_color
        if save :
            # 이미지 저장
            img = Image.fromarray(img, 'RGBA')
            img.save(f'samsung_stock_data_image_{image_idx}.png')

        if change_std <= change:
            return_datas.append((img, 1))
        elif change <= -change_std :
            return_datas.append((img, 0))

        # 비슷한 이미지를 피하기 위해 기준 예측일만큼 건너뜀
        image_idx += prediction_day_num


    return return_datas

# %%
top_50_tickers = ['005930', '051910', '000660', '207940', '005935', '051915', '006400', '005380', '035420', '363280',
                  '247540', '000270', '086520', '035720', '068270', '012330', '105560', '028260', '055550', '096770',
                  '066570', '047050', '032830', '323410', '003550', '015760', '000810', '033780', '091990', '009150',
                  '086790', '034730', '336370', '352820', '018260', '122630', '017670', '010130', '024880', '003490',
                  '010950', '086280', '259960', '024110', '030200', '316140', '010140', '090430', '028050', '233740']

# %%
def preprocess_data(data):
    # 0 값을 포함하는 행을 찾기 위해 0을 NaN으로 대체
    print('거래량이 0인 데이터수 :', (data['Volume'] == 0).sum())
    print(data[data['Volume'] == 0])

    data = data[data['Volume'] != 0]
    # 0이나 NaN을 포함하는 행 제거
    data = data.dropna(how='any')

    return data

# %%
result = []
for i, ticker in enumerate(top_50_tickers):
    print(f"{i+1}번째 종목 추출중...   ")

    data = preprocess_data(fdr.DataReader(ticker))  # 각 종목의 데이터 가져오기
    images = convert_image(data, num_images, day_num, 0.05)
    print(type(images[0][0]))
    result += images
    print(f"{len(images)}개 추출완료")
# Out:
# 1번째 종목 추출중...
# 거래량이 0인 데이터수 : 3
#             Open  High  Low  Close  Volume  Change
# Date
# 2018-04-30     0     0    0  53000       0     0.0
# 2018-05-02     0     0    0  53000       0     0.0
# 2018-05-03     0     0    0  53000       0     0.0
# <class 'numpy.ndarray'>
# 168개 추출완료
# 2번째 종목 추출중...
# 거래량이 0인 데이터수 : 15
#             Open  High  Low   Close  Volume  Change
# Date
# 2009-03-30     0     0    0  128000       0     0.0
# 2009-03-31     0     0    0  128000       0     0.0
# 2009-04-01     0     0    0  128000       0     0.0
# 2009-04-02     0     0    0  128000       0     0.0
# 2009-04-03     0     0    0  128000       0     0.0
# 2009-04-06     0     0    0  128000       0     0.0
# 2009-04-07     0     0    0  128000       0     0.0
# 2009-04-08     0     0    0  128000       0     0.0
# 2009-04-09     0     0    0  128000       0     0.0
# 2009-04-10     0     0    0  128000       0     0.0
# 2009-04-13     0     0    0  128000       0     0.0
# 2009-04-14     0     0    0  128000       0     0.0
# 2009-04-15     0     0    0  128000       0     0.0
# 2009-04-16     0     0    0  128000       0     0.0
# 2009-04-17     0     0    0  128000       0     0.0
# <class 'numpy.ndarray'>
# 309개 추출완료
# 3번째 종목 추출중...
# 거래량이 0인 데이터수 : 12
#             Open  High   Low  Close  Volume  Change
# Date
# 2003-03-27  2650  2650  2650   2650       0     0.0
# 2003-03-28  2650  2650  2650   2650       0     0.0
# 2003-03-31  2650  2650  2650   2650       0     0.0
# 2003-04-01  2650  2650  2650   2650       0     0.0
# 2003-04-02  2650  2650  2650   2650       0     0.0
# 2003-04-03  2650  2650  2650   2650       0     0.0
# 2003-04-04  2650  2650  2650   2650       0     0.0
# 2003-04-07  2650  2650  2650   2650       0     0.0
# 2003-04-08  2650  2650  2650   2650       0     0.0
# 2003-04-09  2650  2650  2650   2650       0     0.0
# 2003-04-10  2650  2650  2650   2650       0     0.0
# 2003-04-11  2650  2650  2650   2650       0     0.0
# <class 'numpy.ndarray'>
# 372개 추출완료
# 4번째 종목 추출중...
# 거래량이 0인 데이터수 : 18
#             Open  High  Low   Close  Volume  Change
# Date
# 2018-11-15     0     0    0  330585       0     0.0
# 2018-11-16     0     0    0  330585       0     0.0
# 2018-11-19     0     0    0  330585       0     0.0
# 2018-11-20     0     0    0  330585       0     0.0
# 2018-11-21     0     0    0  330585       0     0.0
# 2018-11-22     0     0    0  330585       0     0.0
# 2018-11-23     0     0    0  330585       0     0.0
# 2018-11-26     0     0    0  330585       0     0.0
# 2018-11-27     0     0    0  330585       0     0.0
# 2018-11-28     0     0    0  330585       0     0.0
# 2018-11-29     0     0    0  330585       0     0.0
# 2018-11-30     0     0    0  330585       0     0.0
# 2018-12-03     0     0    0  330585       0     0.0
# 2018-12-04     0     0    0  330585       0     0.0
# 2018-12-05     0     0    0  330585       0     0.0
# 2018-12-06     0     0    0  330585       0     0.0
# 2018-12-07     0     0    0  330585       0     0.0
# 2018-12-10     0     0    0  330585       0     0.0
# <class 'numpy.ndarray'>
# 86개 추출완료
# 5번째 종목 추출중...
# 거래량이 0인 데이터수 : 3
#             Open  High  Low  Close  Volume  Change
# Date
# 2018-04-30     0     0    0  42500       0     0.0
# 2018-05-02     0     0    0  42500       0     0.0
# 2018-05-03     0     0    0  42500       0     0.0
# <class 'numpy.ndarray'>
# 190개 추출완료
# 6번째 종목 추출중...
# 거래량이 0인 데이터수 : 15
#             Open  High  Low  Close  Volume  Change
# Date
# 2009-03-30     0     0    0  43000       0     0.0
# 2009-03-31     0     0    0  43000       0     0.0
# 2009-04-01     0     0    0  43000       0     0.0
# 2009-04-02     0     0    0  43000       0     0.0
# 2009-04-03     0     0    0  43000       0     0.0
# 2009-04-06     0     0    0  43000       0     0.0
# 2009-04-07     0     0    0  43000       0     0.0
# 2009-04-08     0     0    0  43000       0     0.0
# 2009-04-09     0     0    0  43000       0     0.0
# 2009-04-10     0     0    0  43000       0     0.0
# 2009-04-13     0     0    0  43000       0     0.0
# 2009-04-14     0     0    0  43000       0     0.0
# 2009-04-15     0     0    0  43000       0     0.0
# 2009-04-16     0     0    0  43000       0     0.0
# 2009-04-17     0     0    0  43000       0     0.0
# <class 'numpy.ndarray'>
# 311개 추출완료
# 7번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 313개 추출완료
# 8번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 235개 추출완료
# 9번째 종목 추출중...
# 거래량이 0인 데이터수 : 24
#             Open  High  Low   Close  Volume  Change
# Date
# 2013-07-30     0     0    0   92130       0     0.0
# 2013-07-31     0     0    0   92130       0     0.0
# 2013-08-01     0     0    0   92130       0     0.0
# 2013-08-02     0     0    0   92130       0     0.0
# 2013-08-05     0     0    0   92130       0     0.0
# 2013-08-06     0     0    0   92130       0     0.0
# 2013-08-07     0     0    0   92130       0     0.0
# 2013-08-08     0     0    0   92130       0     0.0
# 2013-08-09     0     0    0   92130       0     0.0
# 2013-08-12     0     0    0   92130       0     0.0
# 2013-08-13     0     0    0   92130       0     0.0
# 2013-08-14     0     0    0   92130       0     0.0
# 2013-08-16     0     0    0   92130       0     0.0
# 2013-08-19     0     0    0   92130       0     0.0
# 2013-08-20     0     0    0   92130       0     0.0
# 2013-08-21     0     0    0   92130       0     0.0
# 2013-08-22     0     0    0   92130       0     0.0
# 2013-08-23     0     0    0   92130       0     0.0
# 2013-08-26     0     0    0   92130       0     0.0
# 2013-08-27     0     0    0   92130       0     0.0
# 2013-08-28     0     0    0   92130       0     0.0
# 2018-10-08     0     0    0  141000       0     0.0
# 2018-10-10     0     0    0  141000       0     0.0
# 2018-10-11     0     0    0  141000       0     0.0
# <class 'numpy.ndarray'>
# 341개 추출완료
# 10번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 26개 추출완료
# 11번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 103개 추출완료
# 12번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 250개 추출완료
# 13번째 종목 추출중...
# 거래량이 0인 데이터수 : 19
#             Open  High  Low  Close  Volume  Change
# Date
# 2021-04-29     0     0    0  49341       0     0.0
# 2021-04-30     0     0    0  49341       0     0.0
# 2021-05-03     0     0    0  49341       0     0.0
# 2021-05-04     0     0    0  49341       0     0.0
# 2021-05-06     0     0    0  49341       0     0.0
# 2021-05-07     0     0    0  49341       0     0.0
# 2021-05-10     0     0    0  49341       0     0.0
# 2021-05-11     0     0    0  49341       0     0.0
# 2021-05-12     0     0    0  49341       0     0.0
# 2021-05-13     0     0    0  49341       0     0.0
# 2021-05-14     0     0    0  49341       0     0.0
# 2021-05-17     0     0    0  49341       0     0.0
# 2021-05-18     0     0    0  49341       0     0.0
# 2021-05-20     0     0    0  49341       0     0.0
# 2021-05-21     0     0    0  49341       0     0.0
# 2021-05-24     0     0    0  49341       0     0.0
# 2021-05-25     0     0    0  49341       0     0.0
# 2021-05-26     0     0    0  49341       0     0.0
# 2021-05-27     0     0    0  49341       0     0.0
# <class 'numpy.ndarray'>
# 382개 추출완료
# 14번째 종목 추출중...
# 거래량이 0인 데이터수 : 19
#             Open  High   Low   Close  Volume  Change
# Date
# 2000-12-04  4532  4532  4532    4532       0     0.0
# 2006-04-27  8450  8450  8450    8450       0     0.0
# 2006-04-28  8450  8450  8450    8450       0     0.0
# 2006-05-02  8450  8450  8450    8450       0     0.0
# 2006-05-03  8450  8450  8450    8450       0     0.0
# 2006-05-04  8450  8450  8450    8450       0     0.0
# 2006-05-08  8450  8450  8450    8450       0     0.0
# 2006-05-09  8450  8450  8450    8450       0     0.0
# 2006-05-10  8450  8450  8450    8450       0     0.0
# 2006-05-11  8450  8450  8450    8450       0     0.0
# 2006-05-12  8450  8450  8450    8450       0     0.0
# 2006-05-15  8450  8450  8450    8450       0     0.0
# 2006-05-16  8450  8450  8450    8450       0     0.0
# 2006-05-17  8450  8450  8450    8450       0     0.0
# 2006-05-18  8450  8450  8450    8450       0     0.0
# 2014-05-26     0     0     0   15675       0     0.0
# 2021-04-12     0     0     0  112000       0     0.0
# 2021-04-13     0     0     0  112000       0     0.0
# 2021-04-14     0     0     0  112000       0     0.0
# <class 'numpy.ndarray'>
# 358개 추출완료
# 15번째 종목 추출중...
# 거래량이 0인 데이터수 : 3113
#               Open    High     Low   Close  Volume    Change
# Date
# 2005-07-19    5597    6433    5437    6439       0       NaN
# 2005-07-20    6424    6424    5470    5475       0 -0.149713
# 2005-07-21    5391    5499    4785    4798       0 -0.123653
# 2005-07-22    4884    4884    4617    4664       0 -0.027928
# 2005-07-25    4587    4967    4587    4723       0  0.012650
# ...            ...     ...     ...     ...     ...       ...
# 2018-02-02  276726  282347  267234  277740       0  0.005335
# 2018-02-05  270368  276357  263549  263549       0 -0.051095
# 2018-02-06  254518  268340  250832  261890       0 -0.006295
# 2018-02-07  268432  269078  235904  235904       0 -0.099225
# 2018-02-08  231572  251569  219777  250095       0  0.060156
#
# [3113 rows x 6 columns]
# <class 'numpy.ndarray'>
# 91개 추출완료
# 16번째 종목 추출중...
# 거래량이 0인 데이터수 : 12
#             Open  High   Low  Close  Volume  Change
# Date
# 1999-07-29  8991  8991  8991   8991       0     0.0
# 1999-07-30  8991  8991  8991   8991       0     0.0
# 1999-08-02  8991  8991  8991   8991       0     0.0
# 1999-08-03  8991  8991  8991   8991       0     0.0
# 1999-08-04  8991  8991  8991   8991       0     0.0
# 1999-08-05  8991  8991  8991   8991       0     0.0
# 1999-08-06  8991  8991  8991   8991       0     0.0
# 1999-08-09  8991  8991  8991   8991       0     0.0
# 1999-08-10  8991  8991  8991   8991       0     0.0
# 1999-08-11  8991  8991  8991   8991       0     0.0
# 1999-08-12  8991  8991  8991   8991       0     0.0
# 1999-08-13  8991  8991  8991   8991       0     0.0
# <class 'numpy.ndarray'>
# 267개 추출완료
# 17번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 127개 추출완료
# 18번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 67개 추출완료
# 19번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 201개 추출완료
# 20번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 253개 추출완료
# 21번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 284개 추출완료
# 22번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 344개 추출완료
# 23번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 65개 추출완료
# 24번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 34개 추출완료
# 25번째 종목 추출중...
# 거래량이 0인 데이터수 : 75
#              Open   High    Low   Close  Volume  Change
# Date
# 2001-03-29  14894  14894  14894   14893       0     0.0
# 2001-03-30  14894  14894  14894   14893       0     0.0
# 2001-04-02  14894  14894  14894   14893       0     0.0
# 2001-04-03  14894  14894  14894   14893       0     0.0
# 2001-04-04  14894  14894  14894   14893       0     0.0
# ...           ...    ...    ...     ...     ...     ...
# 2021-05-20      0      0      0  119500       0     0.0
# 2021-05-21      0      0      0  119500       0     0.0
# 2021-05-24      0      0      0  119500       0     0.0
# 2021-05-25      0      0      0  119500       0     0.0
# 2021-05-26      0      0      0  119500       0     0.0
#
# [75 rows x 6 columns]
# <class 'numpy.ndarray'>
# 256개 추출완료
# 26번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 164개 추출완료
# 27번째 종목 추출중...
# 거래량이 0인 데이터수 : 2
#              Open   High    Low  Close  Volume  Change
# Date
# 1999-07-01  71679  71679  71679  71678       0     0.0
# 1999-07-02  71679  71679  71679  71678       0     0.0
# <class 'numpy.ndarray'>
# 177개 추출완료
# 28번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 97개 추출완료
# 29번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 119개 추출완료
# 30번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 317개 추출완료
# 31번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 231개 추출완료
# 32번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 151개 추출완료
# 33번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 97개 추출완료
# 34번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 60개 추출완료
# 35번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 76개 추출완료
# 36번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 129개 추출완료
# 37번째 종목 추출중...
# 거래량이 0인 데이터수 : 26
#              Open   High    Low  Close  Volume  Change
# Date
# 2000-04-20  50725  50725  50725  50726       0     0.0
# 2000-04-21  50725  50725  50725  50726       0     0.0
# 2021-10-26      0      0      0  53400       0     0.0
# 2021-10-27      0      0      0  53400       0     0.0
# 2021-10-28      0      0      0  53400       0     0.0
# 2021-10-29      0      0      0  53400       0     0.0
# 2021-11-01      0      0      0  53400       0     0.0
# 2021-11-02      0      0      0  53400       0     0.0
# 2021-11-03      0      0      0  53400       0     0.0
# 2021-11-04      0      0      0  53400       0     0.0
# 2021-11-05      0      0      0  53400       0     0.0
# 2021-11-08      0      0      0  53400       0     0.0
# 2021-11-09      0      0      0  53400       0     0.0
# 2021-11-10      0      0      0  53400       0     0.0
# 2021-11-11      0      0      0  53400       0     0.0
# 2021-11-12      0      0      0  53400       0     0.0
# 2021-11-15      0      0      0  53400       0     0.0
# 2021-11-16      0      0      0  53400       0     0.0
# 2021-11-17      0      0      0  53400       0     0.0
# 2021-11-18      0      0      0  53400       0     0.0
# 2021-11-19      0      0      0  53400       0     0.0
# 2021-11-22      0      0      0  53400       0     0.0
# 2021-11-23      0      0      0  53400       0     0.0
# 2021-11-24      0      0      0  53400       0     0.0
# 2021-11-25      0      0      0  53400       0     0.0
# 2021-11-26      0      0      0  53400       0     0.0
# <class 'numpy.ndarray'>
# 135개 추출완료
# 38번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 326개 추출완료
# 39번째 종목 추출중...
# 거래량이 0인 데이터수 : 21
#             Open  High   Low  Close  Volume    Change
# Date
# 1999-04-29  3564  3564  3564   3563       0       NaN
# 1999-04-30  3564  3564  3564   3563       0  0.000000
# 1999-05-03  3564  3564  3564   3563       0  0.000000
# 1999-05-04  3564  3564  3564   3563       0  0.000000
# 1999-05-06  3564  3564  3564   3563       0  0.000000
# 1999-05-07  3564  3564  3564   3563       0  0.000000
# 1999-05-10  3564  3564  3564   3563       0  0.000000
# 1999-05-11  3564  3564  3564   3563       0  0.000000
# 1999-05-12  3564  3564  3564   3563       0  0.000000
# 1999-05-14  3991  3991  3991   3991       0  0.000000
# 1999-05-17  3991  3991  3991   3991       0  0.000000
# 1999-05-18  3991  3991  3991   3991       0  0.000000
# 1999-05-19  3991  3991  3991   3991       0  0.000000
# 1999-05-25  4562  4562  4562   4561       0 -0.015328
# 1999-06-01  4633  4633  4633   4632       0 -0.071557
# 1999-06-07  4269  4269  4269   4269       0 -0.001637
# 1999-06-08  4205  4205  4205   4205       0 -0.014992
# 1999-06-09  4134  4134  4134   4133       0 -0.017122
# 1999-06-25  4918  4918  4918   4917       0 -0.014432
# 2000-04-27  3240  3240  3240   3240       0  0.000000
# 2000-04-28  3240  3240  3240   3240       0  0.000000
# <class 'numpy.ndarray'>
# 304개 추출완료
# 40번째 종목 추출중...
# 거래량이 0인 데이터수 : 33
#             Open  High  Low  Close  Volume  Change
# Date
# 2013-07-30     0     0    0  19400       0     0.0
# 2013-07-31     0     0    0  19400       0     0.0
# 2013-08-01     0     0    0  19400       0     0.0
# 2013-08-02     0     0    0  19400       0     0.0
# 2013-08-05     0     0    0  19400       0     0.0
# 2013-08-06     0     0    0  19400       0     0.0
# 2013-08-07     0     0    0  19400       0     0.0
# 2013-08-08     0     0    0  19400       0     0.0
# 2013-08-09     0     0    0  19400       0     0.0
# 2013-08-12     0     0    0  19400       0     0.0
# 2013-08-13     0     0    0  19400       0     0.0
# 2013-08-14     0     0    0  19400       0     0.0
# 2013-08-16     0     0    0  19400       0     0.0
# 2013-08-19     0     0    0  19400       0     0.0
# 2013-08-20     0     0    0  19400       0     0.0
# 2013-08-21     0     0    0  19400       0     0.0
# 2013-08-22     0     0    0  19400       0     0.0
# 2013-08-23     0     0    0  19400       0     0.0
# 2013-08-26     0     0    0  19400       0     0.0
# 2013-08-27     0     0    0  19400       0     0.0
# 2013-08-28     0     0    0  19400       0     0.0
# 2013-08-29     0     0    0  19400       0     0.0
# 2013-08-30     0     0    0  19400       0     0.0
# 2013-09-02     0     0    0  19400       0     0.0
# 2013-09-03     0     0    0  19400       0     0.0
# 2013-09-04     0     0    0  19400       0     0.0
# 2013-09-05     0     0    0  19400       0     0.0
# 2013-09-06     0     0    0  19400       0     0.0
# 2013-09-09     0     0    0  19400       0     0.0
# 2013-09-10     0     0    0  19400       0     0.0
# 2013-09-11     0     0    0  19400       0     0.0
# 2013-09-12     0     0    0  19400       0     0.0
# 2013-09-13     0     0    0  19400       0     0.0
# <class 'numpy.ndarray'>
# 326개 추출완료
# 41번째 종목 추출중...
# 거래량이 0인 데이터수 : 3
#              Open   High    Low  Close  Volume  Change
# Date
# 2001-11-29  21500  21500  21500  21500       0     0.0
# 2001-11-30  21500  21500  21500  21500       0     0.0
# 2004-12-24  65000  65000  65000  65000       0     0.0
# <class 'numpy.ndarray'>
# 251개 추출완료
# 42번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 255개 추출완료
# 43번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 37개 추출완료
# 44번째 종목 추출중...
# 거래량이 0인 데이터수 : 1
#             Open  High  Low  Close  Volume    Change
# Date
# 2003-12-23     0     0    0   6990       0 -0.004274
# <class 'numpy.ndarray'>
# 213개 추출완료
# 45번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 71개 추출완료
# 46번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 36개 추출완료
# 47번째 종목 추출중...
# 거래량이 0인 데이터수 : 12
#             Open  High  Low  Close  Volume  Change
# Date
# 2021-07-23     0     0    0   6173       0     0.0
# 2021-07-26     0     0    0   6173       0     0.0
# 2021-07-27     0     0    0   6173       0     0.0
# 2021-07-28     0     0    0   6173       0     0.0
# 2021-07-29     0     0    0   6173       0     0.0
# 2021-07-30     0     0    0   6173       0     0.0
# 2021-08-02     0     0    0   6173       0     0.0
# 2021-08-03     0     0    0   6173       0     0.0
# 2021-08-04     0     0    0   6173       0     0.0
# 2021-08-05     0     0    0   6173       0     0.0
# 2021-08-06     0     0    0   6173       0     0.0
# 2021-08-09     0     0    0   6173       0     0.0
# <class 'numpy.ndarray'>
# 354개 추출완료
# 48번째 종목 추출중...
# 거래량이 0인 데이터수 : 10
#             Open  High  Low   Close  Volume  Change
# Date
# 2015-04-22     0     0    0  388500       0     0.0
# 2015-04-23     0     0    0  388500       0     0.0
# 2015-04-24     0     0    0  388500       0     0.0
# 2015-04-27     0     0    0  388500       0     0.0
# 2015-04-28     0     0    0  388500       0     0.0
# 2015-04-29     0     0    0  388500       0     0.0
# 2015-04-30     0     0    0  388500       0     0.0
# 2015-05-04     0     0    0  388500       0     0.0
# 2015-05-06     0     0    0  388500       0     0.0
# 2015-05-07     0     0    0  388500       0     0.0
# <class 'numpy.ndarray'>
# 237개 추출완료
# 49번째 종목 추출중...
# 거래량이 0인 데이터수 : 10
#             Open  High  Low  Close  Volume  Change
# Date
# 2016-03-02     0     0    0   9520       0     0.0
# 2016-03-03     0     0    0   9520       0     0.0
# 2016-03-04     0     0    0   9520       0     0.0
# 2016-03-07     0     0    0   9520       0     0.0
# 2016-03-08     0     0    0   9520       0     0.0
# 2016-03-09     0     0    0   9520       0     0.0
# 2016-03-10     0     0    0   9520       0     0.0
# 2016-03-11     0     0    0   9520       0     0.0
# 2016-03-14     0     0    0   9520       0     0.0
# 2016-03-15     0     0    0   9520       0     0.0
# <class 'numpy.ndarray'>
# 391개 추출완료
# 50번째 종목 추출중...
# 거래량이 0인 데이터수 : 0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change]
# Index: []
# <class 'numpy.ndarray'>
# 165개 추출완료

# %%
print(len(result))
# Out:
# 10152

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# 이미지와 라벨 분리
images, labels = zip(*result)

# 이미지와 라벨을 NumPy로 변환
images = np.array([np.array(image) for image in images])
labels = np.array(labels)

# 훈련 데이터와 테스트 데이터로 분리
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# NumPy 배열로 저장
np.save('X_train.npy', X_train)
np.save('X_test.npy', X_test)
np.save('y_train.npy', y_train)
np.save('y_test.npy', y_test)

# %%
# NumPy 배열로부터 데이터 로드
X_train = np.load('X_train.npy')
X_test = np.load('X_test.npy')
y_train = np.load('y_train.npy')
y_test = np.load('y_test.npy')
