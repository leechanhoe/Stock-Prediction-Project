# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.50 requests-file-1.5.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from datetime import datetime, timedelta
import random

num_images = 5000
day_num = 32

# %%
def convert_image(data, num_images, day_num, change_std, save = False, test = False):
    if test:
        change_std = 0

    def alpha_blend(color1, color2, alpha):
        return [
            int((color1[0] * alpha + color2[0] * (1 - alpha))),
            int((color1[1] * alpha + color2[1] * (1 - alpha))),
            int((color1[2] * alpha + color2[2] * (1 - alpha))),
            255,
        ]

    # 데이터수가 너무 적으면 패스
    if len(data) <= 100:
        return []


    # 해당 종목의 주가 데이터 - 100이 요구되는 이미지 수보다 적으면(상장직후는 변동이 심할 수있으니 제외)
    if num_images - 92 > len(data):
        num_images = len(data) - 92

    #return_datas는 이미지, 라벨링(상승이면1 하락이면0), 변동률, 날짜를 담고있음
    return_datas = []
    prediction_day_num = 5


    image_idx = 1
    while(image_idx <= num_images):
        prediction_day5 = data[-image_idx - (prediction_day_num * 2) : -image_idx - prediction_day_num]
        predict_mean5 = prediction_day5['Close'].mean()
        prediction_day5_10 = data[-image_idx - prediction_day_num : -image_idx]
        predict_mean5_10 = prediction_day5_10['Close'].mean()
        prediction_day10 = data[-image_idx - (prediction_day_num * 2) : -image_idx]
        predict_mean10 = prediction_day10['Close'].mean()

        now = data.iloc[-image_idx - (prediction_day_num * 2) - 1]
        change5 = (predict_mean5 - now['Close']) / now['Close']
        after5 = prediction_day5.iloc[-1]
        change5_10 = (predict_mean5_10 - after5['Close']) / after5['Close']
        change10 = (predict_mean10 - now['Close']) / now['Close']

        # change가 너무 높으면 이상치라고 판단하여 패스
        if not test and (abs(change5) < change_std or change_std * 3 < abs(change5)): # 향후 prediction_day_num일의 변동률이 기준 이하면
            image_idx += 1
            continue

        stock_data = data[-image_idx - day_num - (prediction_day_num * 2): -image_idx - (prediction_day_num * 2)]

        # 이미지 크기 설정
        width, height = 96, 96

        # High, Low, Close, Volume 데이터 정규화
        high_prices = stock_data['High'].values
        low_prices = stock_data['Low'].values
        close_prices = stock_data['Close'].values
        volume_data = stock_data['Volume'].values

        high_prices_norm = (high_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        low_prices_norm = (low_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        close_prices_norm = (close_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        volume_data_norm = height * (volume_data) / (2 * (np.max(volume_data)))

        if len(data) <= abs(-image_idx - day_num - 20 - (prediction_day_num * 2)):
            break
        # 이동평균선 추가를 위한 stock_data 생성
        stock_data_ma20 = data[-image_idx - day_num - 20 - (prediction_day_num * 2): -image_idx - (prediction_day_num * 2)]
        stock_data_ma20 = stock_data_ma20.copy()
        stock_data_ma20['MA20'] = stock_data_ma20['Close'].rolling(window=20).mean()
        stock_data_ma20.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma20['MA20_norm'] = (
                (stock_data_ma20['MA20'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        if len(data) <= abs(-image_idx - day_num - 40 - (prediction_day_num * 2)):
            break
        stock_data_ma40 = data[-image_idx - day_num - 40 - (prediction_day_num * 2): -image_idx - (prediction_day_num * 2)]
        stock_data_ma40 = stock_data_ma40.copy()
        stock_data_ma40['MA40'] = stock_data_ma40['Close'].rolling(window=40).mean()
        stock_data_ma40.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma40['MA40_norm'] = (
                (stock_data_ma40['MA40'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )


        if len(data) <= abs(-image_idx - day_num - 60 - (prediction_day_num * 2)):
            break
        stock_data_ma60 = data[-image_idx - day_num - 60 - (prediction_day_num * 2): -image_idx - (prediction_day_num * 2)]
        stock_data_ma60 = stock_data_ma60.copy()
        stock_data_ma60['MA60'] = stock_data_ma60['Close'].rolling(window=60).mean()
        stock_data_ma60.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma60['MA60_norm'] = (
                (stock_data_ma60['MA60'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        # 96x96 이미지 생성
        img = np.zeros((height, width, 4), dtype=np.uint8)  # 4 channels for RGBA

        fail_generate = False
        for day in range(32):
            high_price = int(high_prices_norm[day] * (height - 1))
            low_price = int(low_prices_norm[day] * (height - 1))
            close_price = int(close_prices_norm[day] * (height - 1))
            open_price = int(
                (
                    (stock_data['Open'].values[day] - np.min(low_prices))
                    / (np.max(high_prices) - np.min(low_prices))
                )
                * (height - 1)
            )
            volume = int(volume_data_norm[day])
            if(volume == 0):
                fail_generate = True
                break

            x_start = day * 3

            # 시가, 종가, 고가, 저가 막대그래프
            # 막대 왼쪽, 오른쪽 그리기 (시가, 종가 범위)
            for x in range(x_start, x_start + 3):
                if close_prices[day] > stock_data['Open'].values[day]:
                    color = [255, 0, 0, 255]  # 상승: 빨강
                    tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                elif close_prices[day] < stock_data['Open'].values[day]:
                    color = [0, 0, 255, 255]  # 하락: 파랑
                    tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑
                else: # 시가와 종가가 같을경우 어제보다 같거나 올랐으면 빨강, 아니면 파랑
                    if 0 <= stock_data['Change'].values[day]:
                        color = [255, 0, 0, 255]  # 상승: 빨강
                        tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                    else:
                        color = [0, 0, 255, 255]  # 하락: 파랑
                        tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑

                for y in range(min(open_price, close_price), max(open_price, close_price) + 1):
                    img[height - 1 - y, x] = color

            # 꼬리 그리기 (High, Low 범위)
            for x in range(x_start + 1, x_start + 2):
                for y in range(low_price, high_price + 1):
                    if img[height - 1 - y, x][0] != 255 and img[height - 1 - y, x][2] != 255:
                        img[height - 1 - y, x] = tail_color

            # 거래량 그리기
            for x in range(x_start, x_start + 3):
                overlapped = height - volume
                if overlapped >= 0 and overlapped < height:
                    img[overlapped:, x] = [
                        alpha_blend(img[y, x], [128, 128, 128, 255], 0.45)
                        for y in range(overlapped, height)
                    ]

            # 20일 이동평균선 그리기
            ma20_norm = stock_data_ma20.iloc[day]['MA20_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma20_norm):
                    ma20_y = int(ma20_norm * (height - 1))
                    if 0 <= ma20_y < height:
                        for y in range(ma20_y - 1, ma20_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([255, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 노란색으로 변경
                                img[height - 1 - y, x] = new_color

            # 40일 이동평균선 그리기
            ma40_norm = stock_data_ma40.iloc[day]['MA40_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma40_norm):
                    ma40_y = int(ma40_norm * (height - 1))
                    if 0 <= ma40_y < height:
                        for y in range(ma40_y - 1, ma40_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([128, 0, 128, 255], img[height - 1 - y, x], 0.6)  # 보라색으로 변경
                                img[height - 1 - y, x] = new_color

            # 60일 이동평균선 그리기
            ma60_norm = stock_data_ma60.iloc[day]['MA60_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma60_norm):
                    ma60_y = int(ma60_norm * (height - 1))
                    if 0 <= ma60_y < height:
                        for y in range(ma60_y - 1, ma60_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([0, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 초록색으로 변경
                                img[height - 1 - y, x] = new_color

        #이미지가 day_num(그려지기 원하는 거래일 수)미만으로 그려졌으면
        if fail_generate:
            image_idx += (prediction_day_num * 2)
            continue

        if save :
            # 이미지 저장
            img = Image.fromarray(img, 'RGBA')
            img.save(f'stock_data_image_{image_idx}.png')
        if not test:
            if change_std <= change5 and 0 < change5_10:
                return_datas.append((img, 1))
            elif change5 < -change_std and change5_10 < 0:
                return_datas.append((img, 0))
        else:
            if change_std <= change10:
                return_datas.append((img, 1))
            elif change10 < -change_std:
                return_datas.append((img, 0))

            # 테스트는 촘촘하게 모든 데이터로
        if test:
            image_idx += 1
        else:
            # 비슷한 이미지를 피하기 위해 기준 예측일만큼 건너뜀
            image_idx += random.choice(range(1, 5))


    return return_datas

# %%
def preprocess_data(data):
    # 0이나 NaN을 포함하는 행 제거
    data = data[data['Volume'] != 0]
    data = data.dropna(how='any')

    return data

# %%
stock_codes2 = [
    ["005930", "삼성전자"],
    ["051910", "LG화학"],
    ["000660", "SK하이닉스"],
    ["207940", "삼성바이오로직스"],
    ["005935", "삼성전자우"],
    ["051915", "LG화학우"],
    ["006400", "삼성SDI"],
    ["005380", "현대차"],
    ["363280", "효성화학"],
    ["247540", "에코프로비엠"],
    ["000270", "기아"],
    ["086520", "에코프로"],
    ["035720", "카카오"],
    ["068270", "셀트리온"],
    ["012330", "현대모비스"],
    ["105560", "KB금융"],
    ["028260", "삼성물산"],
    ["055550", "신한지주"],
    ["096770", "SK이노베이션"],
    ["066570", "LG전자"],
    ["047050", "대우조선해양"],
    ["032830", "삼성생명"],
    ["323410", "카카오뱅크"],
    ["003550", "LG"],
    ["015760", "한국전력"],
    ["000810", "삼성화재"],
    ["033780", "KT&G"],
    ["091990", "셀트리온헬스케어"],
    ["009150", "삼성전기"],
    ["086790", "하나금융지주"],
    ["034730", "SK"],
    ["336370", "솔루스첨단소재"],
    ["352820", "하이브"],
    ["018260", "삼성에스디에스"],
    ["122630", "KODEX 레버리지"],
    ["017670", "SK텔레콤"],
    ["010130", "고려아연"],
    ["024880", "케이씨케미칼"],
    ["003490", "대한항공"],
    ["010950", "S-Oil"],
    ["086280", "현대글로비스"],
    ["259960", "크래프톤"],
    ["024110", "기업은행"],
    ["030200", "케이티"],
    ["316140", "우리금융지주"],
    ["010140", "삼성중공업"],
    ["090430", "아모레퍼시픽"],
    ["051900", "LG생활건강"],
    ["028050", "삼성엔지니어링"],
    ["233740", "KODEX 코스닥 150 레버리지"],
    ["011170", "롯데케미칼"],
    ["000100", "유한양행"],
    ["012450", "한화에어로스페이스"],
    ["036570", "엔씨소프트"],
    ["241560", "두산밥캣"],
    ["005830", "DB손해보험"],
    ["018880", "한온시스템"],
    ["034220", "LG디스플레이"],
    ["170030", "HD현대"],
    ["088980", "맥쿼리인프라"],
    ["005070", "코스모신소재"],
    ["271560", "오리온"],
    ["004020", "현대제철"],
    ["097950", "CJ제일제당"],
    ["047810", "한국항공우주"],
    ["042700", "한미반도체"],
    ["032640", "LG유플러스"],
    ["307950", "현대오토에버"],
    ["006800", "미래에셋증권"],
    ["007700", "F&F홀딩스"],
    ["251270", "넷마블"],
    ["128940", "한미약품"],
    ["000720", "현대건설"],
    ["010620", "현대미포조선"],
    ["006260", "LS"],
    ["078930", "GS"],
    ["011780", "금호석유"],
    ["035250", "강원랜드"],
    ["008770", "호텔신라"],
    ["005940", "NH투자증권"],
    ["180640", "한진칼"],
    ["016360", "삼성증권"],
    ["064350", "현대로템"],
    ["021240", "코웨이"],
    ["282330", "BGF리테일"],
    ["112610", "씨에스윈드"],
    ["071050", "한국금융지주"],
    ["002790", "아모레G"],
    ["008930", "한미사이언스"],
    ["004990", "롯데지주"],
    ["010780", "쌍용C&E"],
    ["001450",  "현대해상"],
    ["111770",  "영원무역"],
    ["272210",  "한화시스템"],
    ["052690",  "한전기술"],
    ["267260",  "HD현대일렉트릭"],
    ["007070",  "GS리테일"],
    ["028670",  "팬오션"],
    ["139480",  "이마트"],
    ["035900", "JYP Ent."], # 여기서부터는 코스닥
    ["263750", "펄어비스"],
    ["293490", "카카오게임즈"],
    ["196170", "알테오젠"],
    ["058470", "리노공업"],
    ["214150", "클래시스"],
    ["039030", "이오테크닉스"],
    ["278280", "천보"],
    ["137400", "피엔티"],
    ["237690", "에스티팜"],
    ["214450", "파마리서치"],
    ["240810", "원익IPS"],
    ["145020", "휴젤"],
    ["035760", "CJ ENM"],
    ["056190", "에스에프에이"],
    ["036930", "주성엔지니어링"],
    ["064760", "티씨케이"],
    ["213420", "덕산네오룩스"],
    ["195940", "HK이노엔"],
    ["014130", "레고켐바이오"],
    ["098460", "고영"],
    ["067310", "하나마이크론"],
    ["166090", "하나머티리얼즈"],
    ["348210", "넥스틴"],
    ["003380", "하림지주"],
    ["272290", "이녹스첨단소재"],
    ["085660", "차바이오텍"],
    ["074610", "원익QnC"],
    ["083470", "유진테크"],
    ["046890", "서울반도체"],
    ["086450", "동국제약"],
    ["215000", "골프존"],
    ["215200", "메가스터디교육"],
    ["319660", "피에스케이"],
    ["183300", "코미코"],
    ["200130", "콜마비앤에이치"],
    ["069080", "웹젠"],
    ["036830", "솔브레인홀딩스"],
    ["084850", "아이티엠반도체"],
    ["243070", "휴온스"],
    ["049070", "인탑스"],
    ["131290", "티에스이"],
    ["091700", "파트론"],
    ["064550", "바이오니아"],
    ["019550", "SFA반도체"],
    ["095610", "테스"],
    ["230360", "에코마케팅"],
    ["267980", "매일유업"],
    ['205470', '휴마시스'],
    ['060150', '인선이엔티'],
    ['417010', '나노팀'],
    ['036620', '감성코퍼레이션'],
    ['047920', 'HLB제약'],
    ['243840', '신흥에스이씨'],
    ['217270', '넵튠'],
    ['056080', '유진로봇'],
    ['018290', '브이티'],
    ['108490', '로보티즈'],
    ['059090', '미코'],
    ['348340', '뉴로메카'],
    ['041830', '인바디'],
    ['101360', '에코앤드림'],
    ['013030', '하이록코리아'],
    ['038500', '삼표시멘트'],
    ['307750', '국전약품'],
    ['049950', '미래컴퍼니'],
    ['092040', '아미코젠'],
    ['382840', '원준'],
    ['094360', '칩스앤미디어'],
    ['290670', '대보마그네틱'],
    ['029960', '코엔텍'],
    ['058820', 'CMG제약'],
    ['314930', '바이오다인'],
    ['047310', '파워로직스'],
    ['297090', '씨에스베어링'],
    ['104830', '원익머트리얼즈'],
    ['282880', '코윈테크'],
    ['077360', '덕산하이메탈'],
    ['214610', '미코바이오메드'],
    ['297890', 'HB솔루션'],
    ['122640', '예스티'],
    ['054210', '이랜텍'],
    ['285490', '노바텍'],
    ['025770', '한국정보통신'],
    ['089010', '켐트로닉스'],
    ['053030', '바이넥스'],
    ['030520', '한글과컴퓨터'],
    ['060370', 'KT서브마린'],
    ['126340', '비나텍'],
    ['254490', '미래반도체'],
    ['235980', '메드팩토'],
    ['102940', '코오롱생명과학'],
    ['101730', '위메이드맥스'],
    ['093320', '케이아이엔엑스'],
    ['251970', '펌텍코리아'],
    ['005160', '동국산업'],
    ['051500', 'CJ프레시웨이'],
    ['005090', 'SGC에너지'],
    ['232140', '와이아이케이'],
    ['000210', 'DL'],
    ['053210', '스카이라이프'],
]
print(len(stock_codes2))

def check_duplicate_stock_codes(stock_codes2):
    stock_codes_set = set()

    for code, name in stock_codes2:
        if code in stock_codes_set:
            print(f"중복된 종목코드 발견: {code} ({name})")
        else:
            stock_codes_set.add(code)

    if len(stock_codes_set) == len(stock_codes2):
        print("중복된 종목코드가 없습니다.")

# 종목코드 중복 여부 확인
check_duplicate_stock_codes(stock_codes2)
# Out:
# 200
# 중복된 종목코드가 없습니다.

# %%
# 엑셀 파일 읽기
df = pd.read_csv('drive/MyDrive/Colab Notebooks/kosdaq.csv', usecols=[0, 1], dtype={1: str})
df = df[~df.iloc[:, 0].str.contains("스팩")]
df = df.iloc[:, [1, 0]]
df = df.sample(n=1000, random_state=42)
df = df.iloc[500:]
# 첫 번째 열과 두 번째 열을 Nx2 리스트로 변환
stock_codes = df.values.tolist()

# 결과 출력
print(stock_codes)
# Out:
# [['361390', '제노코'], ['239340', '줌인터넷'], ['146320', '비씨엔씨'], ['238120', '얼라인드'], ['147830', '제룡산업'], ['389260', '대명에너지'], ['900300', '오가닉티코스메틱'], ['950130', '엑세스바이오'], ['033200', '모아텍'], ['353190', '휴럼'], ['009730', '코센'], ['103840', '우양'], ['047920', 'HLB제약'], ['255440', '야스'], ['083450', 'GST'], ['115500', '케이씨에스'], ['290120', '대유에이피'], ['061970', 'LB세미콘'], ['377480', '마음AI'], ['121600', '나노신소재'], ['027050', '코리아나'], ['100790', '미래에셋벤처투자'], ['052420', '오성첨단소재'], ['365590', '하이딥'], ['261780', '차백신연구소'], ['036480', '대성미생물'], ['049520', '유아이엘'], ['083310', '엘오티베큠'], ['054620', 'APS'], ['106520', '노블엠앤비'], ['145020', '휴젤'], ['048260', '오스템임플란트'], ['230980', '에이트원'], ['321370', '센서뷰'], ['138690', '엘아이에스'], ['288330', '브릿지바이오'], ['335890', '비올'], ['225570', '넥슨게임즈'], ['060230', '소니드'], ['290090', '트윔'], ['286750', '나노브릭'], ['046970', '우리로'], ['250060', '모비스'], ['012620', '원일특강'], ['065650', '메디프론'], ['900070', '글로벌에스엠'], ['171010', '램테크놀러지'], ['078350', '한양디지텍'], ['376980', '원티드랩'], ['214310', '에스엘에너지'], ['246690', 'TS인베스트먼트'], ['041590', '플래스크'], ['262840', '아이퀘스트'], ['038500', '삼표시멘트'], ['032500', '케이엠더블유'], ['303030', '지니틱스'], ['148780', '비플라이소프트'], ['215090', '휴센텍'], ['175140', '인포마크'], ['058970', '엠로'], ['080720', '한국유니온제약'], ['192390', '윈하이텍'], ['273060', '와이즈버즈'], ['187220', '디티앤씨'], ['079950', '인베니아'], ['078890', '가온그룹'], ['187870', '디바이스이엔지'], ['024810', '이화전기'], ['059270', '해성티피씨'], ['208340', '파멥신'], ['043200', '파루'], ['114190', '강원에너지'], ['024850', 'HLB이노베이션'], ['080580', '오킨스전자'], ['042600', '새로닉스'], ['198440', '고려시멘트'], ['078940', '코드네이처'], ['054210', '이랜텍'], ['033500', '동성화인텍'], ['060260', '뉴보텍'], ['047560', '이스트소프트'], ['321550', '티움바이오'], ['190510', '나무가'], ['091340', 'S&K폴리텍'], ['328130', '루닛'], ['418550', '제이오'], ['311320', '지오엘리먼트'], ['006050', '국영지앤엠'], ['032960', '동일기연'], ['015710', '코콤'], ['032940', '원익'], ['008370', '원풍'], ['357580', '아모센스'], ['302550', '리메드'], ['025980', '아난티'], ['011320', '유니크'], ['307930', '컴퍼니케이'], ['142210', '유니트론텍'], ['219550', '디와이디'], ['027710', '팜스토리'], ['066790', '씨씨에스'], ['041930', '동아화성'], ['085660', '차바이오텍'], ['143160', '아이디스'], ['265560', '영화테크'], ['307870', '비투엔'], ['317850', '대모'], ['126700', '하이비젼시스템'], ['036690', '코맥스'], ['031330', '에스에이엠티'], ['081150', '티플랙스'], ['037370', 'EG'], ['032750', '삼진'], ['049830', '승일'], ['317330', '덕산테코피아'], ['039310', '세중'], ['320000', '윈텍'], ['041960', '코미팜'], ['035460', '기산텔레콤'], ['376190', 'LB루셈'], ['274400', '이노시뮬레이션'], ['363250', '진시스템'], ['330350', '위더스제약'], ['086890', '이수앱지스'], ['094970', '제이엠티'], ['082920', '비츠로셀'], ['382800', '지앤비에스 에코'], ['208860', '엔지스테크널러지'], ['084650', '랩지노믹스'], ['041020', '폴라리스오피스'], ['115610', '이미지스'], ['144510', '지씨셀'], ['114840', '아이패밀리에스씨'], ['038680', '에스넷'], ['094480', '갤럭시아머니트리'], ['290690', '소룩스'], ['215200', '메가스터디교육'], ['197140', '디지캡'], ['228670', '레이'], ['216080', '제테마'], ['091120', '이엠텍'], ['131400', '이브이첨단소재'], ['035620', '바른손이앤에이'], ['032850', '비트컴퓨터'], ['239890', '피엔에이치테크'], ['014470', '부방'], ['224060', '더코디'], ['264450', '유비쿼스'], ['092870', '엑시콘'], ['119610', '인터로조'], ['025320', '시노펙스'], ['373170', '엠아이큐브솔루션'], ['035600', 'KG이니시스'], ['259630', '엠플러스'], ['195500', '마니커에프앤지'], ['172670', '에이엘티'], ['348150', '고바이오랩'], ['900270', '헝셩그룹'], ['069140', '누리플랜'], ['344860', '이노진'], ['250930', '예선테크'], ['332370', '아이디피'], ['348370', '엔켐'], ['037070', '파세코'], ['001840', '이화공영'], ['065450', '빅텍'], ['005670', '푸드웰'], ['056700', '신화인터텍'], ['123840', '한일진공'], ['025770', '한국정보통신'], ['013310', '아진산업'], ['014200', '광림'], ['204630', '스튜디오산타클로스'], ['101490', '에스앤에스텍'], ['008290', '원풍물산'], ['302430', '이노메트리'], ['332290', '누보'], ['219420', '링크제니시스'], ['256150', '한독크린텍'], ['109860', '동일금속'], ['048410', '현대바이오'], ['046940', '우원개발'], ['289080', 'SV인베스트먼트'], ['071460', '위니아'], ['221980', '케이디켐'], ['088130', '동아엘텍'], ['092040', '아미코젠'], ['009620', '삼보산업'], ['053450', '세코닉스'], ['119500', '포메탈'], ['301300', '바이브컴퍼니'], ['040910', '아이씨디'], ['101680', '한국정밀기계'], ['003100', '선광'], ['006910', '보성파워텍'], ['419120', '산돌'], ['194700',  ...

# %%
train_result = []
stock_codes += stock_codes2[:90]
for i, ticker in enumerate(stock_codes):
    code, name = ticker[0], ticker[1]
    print(f"{i+1}번째 종목 {name} 추출중...   ")

    try:
        cnt = 0
        data = preprocess_data(fdr.DataReader(code, '2014-01-01', '2020-02-20'))  # 각 종목의 데이터 가져오기
        images = convert_image(data, 3000, day_num, 0.07)
        train_result += images
        cnt += len(images)
        data = preprocess_data(fdr.DataReader(code, '2020-03-01', '2022-12-31'))  # 각 종목의 데이터 가져오기
        images = convert_image(data, 1000, day_num, 0.07)
        train_result += images
        cnt += len(images)
        print(f"{cnt}개 추출완료. 누적{len(train_result)}개")
    except IndexError:
        print(f"{name}에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.")
        continue
# Out:
# 1번째 종목 제노코 추출중...
# 27개 추출완료. 누적27개
# 2번째 종목 줌인터넷 추출중...
# 12개 추출완료. 누적39개
# 3번째 종목 비씨엔씨 추출중...
# 0개 추출완료. 누적39개
# 4번째 종목 얼라인드 추출중...
# 12개 추출완료. 누적51개
# 5번째 종목 제룡산업 추출중...
# 37개 추출완료. 누적88개
# 6번째 종목 대명에너지 추출중...
# 3개 추출완료. 누적91개
# 7번째 종목 오가닉티코스메틱 추출중...
# 20개 추출완료. 누적111개
# 8번째 종목 엑세스바이오 추출중...
# 56개 추출완료. 누적167개
# 9번째 종목 모아텍 추출중...
# 12개 추출완료. 누적179개
# 10번째 종목 휴럼 추출중...
# 5개 추출완료. 누적184개
# 11번째 종목 코센 추출중...
# 41개 추출완료. 누적225개
# 12번째 종목 우양 추출중...
# 4개 추출완료. 누적229개
# 13번째 종목 HLB제약 추출중...
# 36개 추출완료. 누적265개
# 14번째 종목 야스 추출중...
# 19개 추출완료. 누적284개
# 15번째 종목 GST 추출중...
# 34개 추출완료. 누적318개
# 16번째 종목 케이씨에스 추출중...
# 17개 추출완료. 누적335개
# 17번째 종목 대유에이피 추출중...
# 14개 추출완료. 누적349개
# 18번째 종목 LB세미콘 추출중...
# 48개 추출완료. 누적397개
# 19번째 종목 마음AI 추출중...
# 5개 추출완료. 누적402개
# 20번째 종목 나노신소재 추출중...
# 61개 추출완료. 누적463개
# 21번째 종목 코리아나 추출중...
# 41개 추출완료. 누적504개
# 22번째 종목 미래에셋벤처투자 추출중...
# 13개 추출완료. 누적517개
# 23번째 종목 오성첨단소재 추출중...
# 41개 추출완료. 누적558개
# 24번째 종목 하이딥 추출중...
# 0개 추출완료. 누적558개
# 25번째 종목 차백신연구소 추출중...
# 1개 추출완료. 누적559개
# 26번째 종목 대성미생물 추출중...
# 29개 추출완료. 누적588개
# 27번째 종목 유아이엘 추출중...
# 18개 추출완료. 누적606개
# 28번째 종목 엘오티베큠 추출중...
# 51개 추출완료. 누적657개
# 29번째 종목 APS 추출중...
# 55개 추출완료. 누적712개
# 30번째 종목 노블엠앤비 추출중...
# 114개 추출완료. 누적826개
# 31번째 종목 휴젤 추출중...
# 39개 추출완료. 누적865개
# 32번째 종목 오스템임플란트 추출중...
# 52개 추출완료. 누적917개
# 33번째 종목 에이트원 추출중...
# 39개 추출완료. 누적956개
# 34번째 종목 센서뷰 추출중...
# 0개 추출완료. 누적956개
# 35번째 종목 엘아이에스 추출중...
# 62개 추출완료. 누적1018개
# 36번째 종목 브릿지바이오 추출중...
# 19개 추출완료. 누적1037개
# 37번째 종목 비올 추출중...
# 6개 추출완료. 누적1043개
# 38번째 종목 넥슨게임즈 추출중...
# 36개 추출완료. 누적1079개
# 39번째 종목 소니드 추출중...
# 35개 추출완료. 누적1114개
# 40번째 종목 트윔 추출중...
# 4개 추출완료. 누적1118개
# 41번째 종목 나노브릭 추출중...
# 14개 추출완료. 누적1132개
# 42번째 종목 우리로 추출중...
# 30개 추출완료. 누적1162개
# 43번째 종목 모비스 추출중...
# 21개 추출완료. 누적1183개
# 44번째 종목 원일특강 추출중...
# 17개 추출완료. 누적1200개
# 45번째 종목 메디프론 추출중...
# 40개 추출완료. 누적1240개
# 46번째 종목 글로벌에스엠 추출중...
# 17개 추출완료. 누적1257개
# 47번째 종목 램테크놀러지 추출중...
# 25개 추출완료. 누적1282개
# 48번째 종목 한양디지텍 추출중...
# 33개 추출완료. 누적1315개
# 49번째 종목 원티드랩 추출중...
# 6개 추출완료. 누적1321개
# 50번째 종목 에스엘에너지 추출중...
# 45개 추출완료. 누적1366개
# 51번째 종목 TS인베스트먼트 추출중...
# 14개 추출완료. 누적1380개
# 52번째 종목 플래스크 추출중...
# 75개 추출완료. 누적1455개
# 53번째 종목 아이퀘스트 추출중...
# 7개 추출완료. 누적1462개
# 54번째 종목 삼표시멘트 추출중...
# 32개 추출완료. 누적1494개
# 55번째 종목 케이엠더블유 추출중...
# 80개 추출완료. 누적1574개
# 56번째 종목 지니틱스 추출중...
# 8개 추출완료. 누적1582개
# 57번째 종목 비플라이소프트 추출중...
# 4개 추출완료. 누적1586개
# 58번째 종목 휴센텍 추출중...
# 20개 추출완료. 누적1606개
# 59번째 종목 인포마크 추출중...
# 22개 추출완료. 누적1628개
# 60번째 종목 엠로 추출중...
# 7개 추출완료. 누적1635개
# 61번째 종목 한국유니온제약 추출중...
# 18개 추출완료. 누적1653개
# 62번째 종목 윈하이텍 추출중...
# 33개 추출완료. 누적1686개
# 63번째 종목 와이즈버즈 추출중...
# 5개 추출완료. 누적1691개
# 64번째 종목 디티앤씨 추출중...
# 26개 추출완료. 누적1717개
# 65번째 종목 인베니아 추출중...
# 41개 추출완료. 누적1758개
# 66번째 종목 가온그룹 추출중...
# 46개 추출완료. 누적1804개
# 67번째 종목 디바이스이엔지 추출중...
# 33개 추출완료. 누적1837개
# 68번째 종목 이화전기 추출중...
# 36개 추출완료. 누적1873개
# 69번째 종목 해성티피씨 추출중...
# 6개 추출완료. 누적1879개
# 70번째 종목 파멥신 추출중...
# 31개 추출완료. 누적1910개
# 71번째 종목 파루 추출중...
# 21개 추출완료. 누적1931개
# 72번째 종목 강원에너지 추출중...
# 13개 추출완료. 누적1944개
# 73번째 종목 HLB이노베이션 추출중...
# 30개 추출완료. 누적1974개
# 74번째 종목 오킨스전자 추출중...
# 39개 추출완료. 누적2013개
# 75번째 종목 새로닉스 추출중...
# 21개 추출완료. 누적2034개
# 76번째 종목 고려시멘트 추출중...
# 10개 추출완료. 누적2044개
# 77번째 종목 코드네이처 추출중...
# 48개 추출완료. 누적2092개
# 78번째 종목 이랜텍 추출중...
# 51개 추출완료. 누적2143개
# 79번째 종목 동성화인텍 추출중...
# 45개 추출완료. 누적2188개
# 80번째 종목 뉴보텍 추출중...
# 42개 추출완료. 누적2230개
# 81번째 종목 이스트소프트 추출중...
# 41개 추출완료. 누적2271개
# 82번째 종목 티움바이오 추출중...
# 13개 추출완료. 누적2284개
# 83번째 종목 나무가 추출중...
# 45개 추출완료. 누적2329개
# 84번째 종목 S&K폴리텍 추출중...
# 19개 추출완료. 누적2348개
# 85번째 종목 루닛 추출중...
# 0개 추출완료. 누적2348개
# 86번째 종목 제이오 추출중...
# 0개 추출완료. 누적2348개
# 87번째 종목 지오엘리먼트 추출중...
# 3개 추출완료. 누적2351개
# 88번째 종목 국영지앤엠 추출중...
# 40개 추출완료. 누적2391개
# 89번째 종목 동일기연 추출중...
# 6개 추출완료. 누적2397개
# 90번째 종목 코콤 추출중...
# 26개 추출완료. 누적2423개
# 91번째 종목 원익 추출중...
# 26개 추출완료. 누적2449개
# 92번째 종목 원풍 추출중...
# 9개 추출완료. 누적2458개
# 93번째 종목 아모센스 추출중...
# 8개 추출완료. 누적2466개
# 94번째 종목 리메드 추출중...
# 15개 추출완료. 누적2481개
# 95번째 종목 아난티 추출중...
# 64개 추출완료. 누적2545개
# 96번째 종목 유니크 추출중...
# 24개 추출완료. 누적2569개
# 97번째 종목 컴퍼니케이 추출중...
# 9개 추출완료. 누적2578개
# 98번째 종목 유니트론텍 추출중...
# 24개 추출완료. 누적2602개
# 99번째 종목 디와이디 추출중...
# 22개 추출완료. 누적2624개
# 100번째 종목 팜스토리 추출중...
# 25개 추출완료. 누적2649개
# 101번째 종목 씨씨에스 추출중...
# 36개 추출완료. 누적2685개
# 102번째 종목 동아화성 추출중...
# 15개 추출완료. 누적2700개
# 103번째 종목 차바이오텍 추출중...
# 48개 추출완료. 누적2748개
# 104번째 종목 아이디스 추출중...
# 28개 추출완료. 누적2776개
# 105번째 종목 영화테크 추출중...
# 33개 추출완료. 누적2809개
# 106번째 종목 비투엔 추출중...
# 4개 추출완료. 누적2813개
# 107번째 종목 대모 추출중...
# 11개 추출완료. 누적2824개
# 108번째 종목 하이비젼시스템 추출중...
# 51개 추출완료. 누적2875개
# 109번째 종목 코맥스 추출중...
# 26개 추출완료. 누적2901개
# 110번째 종목 에스에이엠티 추출중...
# 11개 추출완료. 누적2912개
# 111번째 종목 티플랙스 추출중...
# 17개 추출완료. 누적2929개
# 112번째 종목 EG 추출중...
# 17개 추출완료. 누적2946개
# 113번째 종목 삼진 추출중...
# 27개 추출완료. 누적2973개
# 114번째 종목 승일 추출중...
# 26개 추출완료. 누적2999개
# 115번째 종목 덕산테코피아 추출중...
# 15개 추출완료. 누적3014개
# 116번째 종목 세중 추출중...
# 28개 추출완료. 누적3042개
# 117번째 종목 윈텍 추출중...
# 1개 추출완료. 누적3043개
# 118번째 종목 코미팜 추출중...
# 44개 추출완료. 누적3087개
# 119번째 종목 기산텔레콤 추출중...
# 18개 추출완료. 누적3105개
# 120번째 종목 LB루셈 추출중...
# 4개 추출완료. 누적3109개
# 121번째 종목 이노시뮬레이션 추출중...
# 0개 추출완료. 누적3109개
# 122번째 종목 진시스템 추출중...
# 0개 추출완료. 누적3109개
# 123번째 종목 위더스제약 추출중...
# 6개 추출완료. 누적3115개
# 124번째 종목 이수앱지스 추출중...
# 43개 추출완료. 누적3158개
# 125번째 종목 제이엠티 추출중...
# 27개 추출완료. 누적3185개
# 126번째 종목 비츠로셀 추출중...
# 17개 추출완료. 누적3202개
# 127번째 종목 지앤비에스 에코 추출중...
# 6개 추출완료. 누적3208개
# 128번째 종목 엔지스테크널러지 추출중...
# 22개 추출완료. 누적3230개
# 129번째 종목 랩지노믹스 추출중...
# 53개 추출완료. 누적3283개
# 130번째 종목 폴라리스오피스 추출중...
# 25개 추출완료. 누적3308개
# 131번째 종목 이미지스 추출중...
# 24개 추출완료. 누적3332개
# 132번째 종목 지씨셀 추출중...
# 38개 추출완료. 누적3370개
# 133번째 종목 아이패밀리에스씨 추출중...
# 10개 추출완료. 누적3380개
# 134번째 종목 에스넷 추출중...
# 30개 추출완료. 누적3410개
# 135번째 종목 갤럭시아머니트리 추출중...
# 25개 추출완료. 누적3435개
# 136번째 종목 소룩스 추출중...
# 12개 추출완료. 누적3447개
# 137번째 종목 메가스터디교육 추출중...
# 41개 추출완료. 누적3488개
# 138번째 종목 디지캡 추출중...
# 7개 추출완료. 누적3495개
# 139번째 종목 레이 추출중...
# 15개 추출완료. 누적3510개
# 140번째 종목 제테마 추출중...
# 20개 추출완료. 누적3530개
# 141번째 종목 이엠텍 추출중...
# 58개 추출완료. 누적3588개
# 142번째 종목 이브이첨단소재 추출중...
# 43개 추출완료. 누적3631개
# 143번째 종목 바른손이앤에이 추출중...
# 54개 추출완료. 누적3685개
# 144번째 종목 비트컴퓨터 추출중...
# 25개 추출완료. 누적3710개
# 145번째 종목 피엔에이치테크 추출중...
# 17개 추출완료. 누적3727개
# 146번째 종목 부방 추출중...
# 35개 추출완료. 누적3762개
# 147번째 종목 더코디 추출중...
# 37개 추출완료. 누적3799개
# 148번째 종목 유비쿼스 추출중...
# 30개 추출완료. 누적3829개
# 149번째 종목 엑시콘 추출중...
# 34개 추출완료. 누적3863개
# 150번째 종목 인터로조 추출중...
# 18개 추출완료. 누적3881개
# 151번째 종목 시노펙스 추출중...
# 33개 추출완료. 누적3914개
# 152번째 종목 엠아이큐브솔루션 추출중...
# 0개 추출완료. 누적3914개
# 153번째 종목 KG이니시스 추출중...
# 45개 추출완료. 누적3959개
# 154번째 종목 엠플러스 추출중...
# 36개 추출완료. 누적3995개
# 155번째 종목 마니커에프앤지 추출중...
# 9개 추출완료. 누적4004개
# 156번째 종목 에이엘티 추출중...
# 0개 추출완료. 누적4004개
# 157번째 종목 고바이오랩 추출중...
# 11개 추출완료. 누적4015개
# 158번째 종목 헝셩그룹 추출중...
# 9개 추출완료. 누적4024개
# 159번째 종목 누리플랜 추출중...
# 25개 추출완료. 누적4049개
# 160번째 종목 이노진 추출중...
# 0개 추출완료. 누적4049개
# 161번째 종목 예선테크 추출중...
# 9개 추출완료. 누적4058개
# 162번째 종목 아이디피 추출중...
# 4개 추출완료. 누적4062개
# 163번째 종목 엔켐 추출중...
# 7개 추출완료. 누적4069개
# 164번째 종목 파세코 추출중...
# 33개 추출완료. 누적4102개
# 165번째 종목 이화공영 추출중...
# 35개 추출완료. 누적4137개
# 166번째 종목 빅텍 추출중...
# 27개 추출완료. 누적4164개
# 167번째 종목 푸드웰 추출중...
# 40개 추출완료. 누적4204개
# 168번째 종목 신화인터텍 추출중...
# 45개 추출완료. 누적4249개
# 169번째 종목 한일진공 추출중...
# 41개 추출완료. 누적4290개
# 170번째 종목 한국정보통신 추출중...
# 34개 추출완료. 누적4324개
# 171번째 종목 아진산업 추출중...
# 15개 추출완료. 누적4339개
# 172번째 종목 광림 추출중...
# 44개 추출완료. 누적4383개
# 173번째 종목 스튜디오산타클로스 추출중...
# 36개 추출완료. 누적4419개
# 174번째 종목 에스앤에스텍 추출중...
# 65개 추출완료. 누적4484개
# 175번째 종목 원풍물산 추출중...
# 47개 추출완료. 누적4531개
# 176번째 종목 이노메트리 추출중...
# 16개 추출완료. 누적4547개
# 177번째 종목 누보 추출중...
# 5개 추출완료. 누적4552개
# 178번째 종목 링크제니시스 추출중...
# 21개 추출완료. 누적4573개
# 179번째 종목 한독크린텍 추출중...
# 9개 추출완료. 누적4582개
# 180번째 종목 동일금속 추출중...
# 3개 추출완료. 누적4585개
# 181번째 종목 현대바이오 추출중...
# 68개 추출완료. 누적4653개
# 182번째 종목 우원개발 추출중...
# 43개 추출완료. 누적4696개
# 183번째 종목 SV인베스트먼트 추출중...
# 8개 추출완료. 누적4704개
# 184번째 종목 위니아 추출중...
# 23개 추출완료. 누적4727개
# 185번째 종목 케이디켐 추출중...
# 3개 추출완료. 누적4730개
# 186번째 종목 동아엘텍 추출중...
# 48개 추출완료. 누적4778개
# 187번째 종목 아미코젠 추출중...
# 82개 추출완료. 누적4860개
# 188번째 종목 삼보산업 추출중...
# 37개 추출완료. 누적4897개
# 189번째 종목 세코닉스 추출중...
# 30개 추출완료. 누적4927개
# 190번째 종목 포메탈 추출중...
# 21개 추출완료. 누적4948개
# 191번째 종목 바이브컴퍼니 추출중...
# 28개 추출완료. 누적4976개
# 192번째 종목 아이씨디 추출중...
# 40개 추출완료. 누적5016개
# 193번째 종목 한국정밀기계 추출중...
# 4개 추출완료. 누적5020개
# 194번째 종목 선광 추출중...
# 6개 추출완료. 누적5026개
# 195번째 종목 보성파워텍 추출중...
# 48개 추출완료. 누적5074개
# 196번째 종목 산돌 추출중...
# 0개 추출완료. 누적5074개
# 197번째 종목 노바렉스 추출중...
# 11개 추출완료. 누적5085개
# 198번째 종목 한국맥널티 추출중...
# 16개 추출완료. 누적5101개
# 199번째 종목 씨유박스 추출중...
# 0개 추출완료. 누적5101개
# 200번째 종목 티엘비 추출중...
# 5개 추출완료. 누적5106개
# 201번째 종목 동양에스텍 추출중...
# 12개 추출완료. 누적5118개
# 202번째 종목 아이디스홀딩스 추출중...
# 5개 추출완료. 누적5123개
# 203번째 종목 인텔리안테크 추출중...
# 39개 추출완료. 누적5162개
# 204번째 종목 나이벡 추출중...
# 68개 추출완료. 누적5230개
# 205번째 종목 해성옵틱스 추출중...
# 48개 추출완료. 누적5278개
# 206번째 종목 성일하이텍 추출중...
# 0개 추출완료. 누적5278개
# 207번째 종목 서울전자통신 추출중...
# 16개 추출완료. 누적5294개
# 208번째 종목 제이앤티씨 추출중...
# 0개 추출완료. 누적5294개
# 209번째 종목 루트로닉 추출중...
# 62개 추출완료. 누적5356개
# 210번째 종목 아바텍 추출중...
# 22개 추출완료. 누적5378개
# 211번째 종목 대성창투 추출중...
# 65개 추출완료. 누적5443개
# 212번째 종목 RFHIC 추출중...
# 34개 추출완료. 누적5477개
# 213번째 종목 미래컴퍼니 추출중...
# 71개 추출완료. 누적5548개
# 214번째 종목 뉴인텍 추출중...
# 28개 추출완료. 누적5576개
# 215번째 종목 코미코 추출중...
# 25개 추출완료. 누적5601개
# 216번째 종목 켄코아에어로스페이스 추출중...
# 16개 추출완료. 누적5617개
# 217번째 종목 서진오토모티브 추출중...
# 22개 추출완료. 누적5639개
# 218번째 종목 비피도 추출중...
# 8개 추출완료. 누적5647개
# 219번째 종목 칩스앤미디어 추출중...
# 36개 추출완료. 누적5683개
# 220번째 종목 파두 추출중...
# 0개 추출완료. 누적5683개
# 221번째 종목 파로스아이바이오 추출중...
# 0개 추출완료. 누적5683개
# 222번째 종목 라온피플 추출중...
# 12개 추출완료. 누적5695개
# 223번째 종목 이니텍 추출중...
# 20개 추출완료. 누적5715개
# 224번째 종목 제이엠아이 추출중...
# 26개 추출완료. 누적5741개
# 225번째 종목 휴메딕스 추출중...
# 30개 추출완료. 누적5771개
# 226번째 종목 디케이티 추출중...
# 30개 추출완료. 누적5801개
# 227번째 종목 한국가구 추출중...
# 19개 추출완료. 누적5820개
# 228번째 종목 클리노믹스 추출중...
# 3개 추출완료. 누적5823개
# 229번째 종목 코이즈 추출중...
# 76개 추출완료. 누적5899개
# 230번째 종목 슈어소프트테크 추출중...
# 0개 추출완료. 누적5899개
# 231번째 종목 현대바이오랜드 추출중...
# 33개 추출완료. 누적5932개
# 232번째 종목 옴니시스템 추출중...
# 33개 추출완료. 누적5965개
# 233번째 종목 제이씨현시스템 추출중...
# 23개 추출완료. 누적5988개
# 234번째 종목 골드앤에스 추출중...
# 38개 추출완료. 누적6026개
# 235번째 종목 넵튠 추출중...
# 46개 추출완료. 누적6072개
# 236번째 종목 인화정공 추출중...
# 15개 추출완료. 누적6087개
# 237번째 종목 SGA솔루션즈 추출중...
# 23개 추출완료. 누적6110개
# 238번째 종목 액션스퀘어 추출중...
# 48개 추출완료. 누적6158개
# 239번째 종목 세운메디칼 추출중...
# 29개 추출완료. 누적6187개
# 240번째 종목 아이쓰리시스템 추출중...
# 22개 추출완료. 누적6209개
# 241번째 종목 한국알콜 추출중...
# 21개 추출완료. 누적6230개
# 242번째 종목 티에스아이 추출중...
# 9개 추출완료. 누적6239개
# 243번째 종목 트루엔 추출중...
# 0개 추출완료. 누적6239개
# 244번째 종목 헥토파이낸셜 추출중...
# 3개 추출완료. 누적6242개
# 245번째 종목 크리스탈신소재 추출중...
# 8개 추출완료. 누적6250개
# 246번째 종목 미래반도체 추출중...
# 0개 추출완료. 누적6250개
# 247번째 종목 모아데이타 추출중...
# 2개 추출완료. 누적6252개
# 248번째 종목 피에스케이 추출중...
# 18개 추출완료. 누적6270개
# 249번째 종목 인벤티지랩 추출중...
# 0개 추출완료. 누적6270개
# 250번째 종목 한국기업평가 추출중...
# 1개 추출완료. 누적6271개
# 251번째 종목 엔젠바이오 추출중...
# 15개 추출완료. 누적6286개
# 252번째 종목 애드바이오텍 추출중...
# 3개 추출완료. 누적6289개
# 253번째 종목 빅솔론 추출중...
# 4개 추출완료. 누적6293개
# 254번째 종목 메디콕스 추출중...
# 79개 추출완료. 누적6372개
# 255번째 종목 에스비비테크 추출중...
# 0개 추출완료. 누적6372개
# 256번째 종목 케이바이오 추출중...
# 56개 추출완료. 누적6428개
# 257번째 종목 하이소닉 추출중...
# 17개 추출완료. 누적6445개
# 258번째 종목 피제이메탈 추출중...
# 12개 추출완료. 누적6457개
# 259번째 종목 삼기이브이 추출중...
# 0개 추출완료. 누적6457개
# 260번째 종목 아즈텍WB 추출중...
# 14개 추출완료. 누적6471개
# 261번째 종목 퓨쳐켐 추출중...
# 51개 추출완료. 누적6522개
# 262번째 종목 에스에이티 추출중...
# 16개 추출완료. 누적6538개
# 263번째 종목 셀바스AI 추출중...
# 49개 추출완료. 누적6587개
# 264번째 종목 미래나노텍 추출중...
# 49개 추출완료. 누적6636개
# 265번째 종목 오디텍 추출중...
# 16개 추출완료. 누적6652개
# 266번째 종목 코스메카코리아 추출중...
# 30개 추출완료. 누적6682개
# 267번째 종목 지어소프트 추출중...
# 56개 추출완료. 누적6738개
# 268번째 종목 엔케이맥스 추출중...
# 50개 추출완료. 누적6788개
# 269번째 종목 유티아이 추출중...
# 43개 추출완료. 누적6831개
# 270번째 종목 에이테크솔루션 추출중...
# 18개 추출완료. 누적6849개
# 271번째 종목 서울제약 추출중...
# 38개 추출완료. 누적6887개
# 272번째 종목 삼기 추출중...
# 14개 추출완료. 누적6901개
# 273번째 종목 에너토크 추출중...
# 25개 추출완료. 누적6926개
# 274번째 종목 윤성에프앤씨 추출중...
# 0개 추출완료. 누적6926개
# 275번째 종목 참좋은여행 추출중...
# 30개 추출완료. 누적6956개
# 276번째 종목 넥스트칩 추출중...
# 0개 추출완료. 누적6956개
# 277번째 종목 바이오로그디바이스 추출중...
# 19개 추출완료. 누적6975개
# 278번째 종목 위메이드맥스 추출중...
# 75개 추출완료. 누적7050개
# 279번째 종목 모비데이즈 추출중...
# 4개 추출완료. 누적7054개
# 280번째 종목 RF머트리얼즈 추출중...
# 16개 추출완료. 누적7070개
# 281번째 종목 영우디에스피 추출중...
# 37개 추출완료. 누적7107개
# 282번째 종목 이노테라피 추출중...
# 16개 추출완료. 누적7123개
# 283번째 종목 유니온커뮤니티 추출중...
# 9개 추출완료. 누적7132개
# 284번째 종목 우림피티에스 추출중...
# 22개 추출완료. 누적7154개
# 285번째 종목 파인디지털 추출중...
# 10개 추출완료. 누적7164개
# 286번째 종목 라이프시맨틱스 추출중...
# 8개 추출완료. 누적7172개
# 287번째 종목 에스엔유 추출중...
# 27개 추출완료. 누적7199개
# 288번째 종목 KG모빌리언스 추출중...
# 22개 추출완료. 누적7221개
# 289번째 종목 풍원정밀 추출중...
# 2개 추출완료. 누적7223개
# 290번째 종목 크레버스 추출중...
# 26개 추출완료. 누적7249개
# 291번째 종목 샌즈랩 추출중...
# 0개 추출완료. 누적7249개
# 292번째 종목 한솔아이원스 추출중...
# 53개 추출완료. 누적7302개
# 293번째 종목 팬엔터테인먼트 추출중...
# 60개 추출완료. 누적7362개
# 294번째 종목 블리츠웨이 추출중...
# 9개 추출완료. 누적7371개
# 295번째 종목 대성파인텍 추출중...
# 26개 추출완료. 누적7397개
# 296번째 종목 핑거스토리 추출중...
# 0개 추출완료. 누적7397개
# 297번째 종목 서호전기 추출중...
# 30개 추출완료. 누적7427개
# 298번째 종목 나무기술 추출중...
# 9개 추출완료. 누적7436개
# 299번째 종목 핀텔 추출중...
# 0개 추출완료. 누적7436개
# 300번째 종목 휴온스글로벌 추출중...
# 43개 추출완료. 누적7479개
# 301번째 종목 유신 추출중...
# 26개 추출완료. 누적7505개
# 302번째 종목 현우산업 추출중...
# 20개 추출완료. 누적7525개
# 303번째 종목 SM Life Design 추출중...
# 50개 추출완료. 누적7575개
# 304번째 종목 바이오다인 추출중...
# 7개 추출완료. 누적7582개
# 305번째 종목 리파인 추출중...
# 2개 추출완료. 누적7584개
# 306번째 종목 넥스트아이 추출중...
# 21개 추출완료. 누적7605개
# 307번째 종목 디어유 추출중...
# 16개 추출완료. 누적7621개
# 308번째 종목 오픈엣지테크놀로지 추출중...
# 0개 추출완료. 누적7621개
# 309번째 종목 한국테크놀로지 추출중...
# 68개 추출완료. 누적7689개
# 310번째 종목 유일로보틱스 추출중...
# 4개 추출완료. 누적7693개
# 311번째 종목 제일바이오 추출중...
# 19개 추출완료. 누적7712개
# 312번째 종목 미투온 추출중...
# 32개 추출완료. 누적7744개
# 313번째 종목 대정화금 추출중...
# 18개 추출완료. 누적7762개
# 314번째 종목 지니언스 추출중...
# 11개 추출완료. 누적7773개
# 315번째 종목 이노뎁 추출중...
# 9개 추출완료. 누적7782개
# 316번째 종목 솔브레인 추출중...
# 7개 추출완료. 누적7789개
# 317번째 종목 캐리소프트 추출중...
# 27개 추출완료. 누적7816개
# 318번째 종목 시스웍 추출중...
# 12개 추출완료. 누적7828개
# 319번째 종목 KH 전자 추출중...
# 36개 추출완료. 누적7864개
# 320번째 종목 에이스토리 추출중...
# 37개 추출완료. 누적7901개
# 321번째 종목 에코바이오 추출중...
# 41개 추출완료. 누적7942개
# 322번째 종목 범한퓨얼셀 추출중...
# 0개 추출완료. 누적7942개
# 323번째 종목 엠에스오토텍 추출중...
# 29개 추출완료. 누적7971개
# 324번째 종목 디모아 추출중...
# 35개 추출완료. 누적8006개
# 325번째 종목 GH신소재 추출중...
# 22개 추출완료. 누적8028개
# 326번째 종목 삼아제약 추출중...
# 16개 추출완료. 누적8044개
# 327번째 종목 조이시티 추출중...
# 56개 추출완료. 누적8100개
# 328번째 종목 알로이스 추출중...
# 5개 추출완료. 누적8105개
# 329번째 종목 지투파워 추출중...
# 1개 추출완료. 누적8106개
# 330번째 종목 케어랩스 추출중...
# 14개 추출완료. 누적8120개
# 331번째 종목 모델솔루션 추출중...
# 0개 추출완료. 누적8120개
# 332번째 종목 우리엔터프라이즈 추출중...
# 27개 추출완료. 누적8147개
# 333번째 종목 태웅 추출중...
# 26개 추출완료. 누적8173개
# 334번째 종목 조아제약 추출중...
# 12개 추출완료. 누적8185개
# 335번째 종목 일승 추출중...
# 1개 추출완료. 누적8186개
# 336번째 종목 동진쎄미켐 추출중...
# 70개 추출완료. 누적8256개
# 337번째 종목 이글벳 추출중...
# 14개 추출완료. 누적8270개
# 338번째 종목 대원미디어 추출중...
# 47개 추출완료. 누적8317개
# 339번째 종목 시그네틱스 추출중...
# 32개 추출완료. 누적8349개
# 340번째 종목 빛샘전자 추출중...
# 15개 추출완료. 누적8364개
# 341번째 종목 파수 추출중...
# 24개 추출완료. 누적8388개
# 342번째 종목 싸이토젠 추출중...
# 13개 추출완료. 누적8401개
# 343번째 종목 비비씨 추출중...
# 6개 추출완료. 누적8407개
# 344번째 종목 TPC 추출중...
# 20개 추출완료. 누적8427개
# 345번째 종목 이지바이오 추출중...
# 5개 추출완료. 누적8432개
# 346번째 종목 티라유텍 추출중...
# 4개 추출완료. 누적8436개
# 347번째 종목 나라엠앤디 추출중...
# 22개 추출완료. 누적8458개
# 348번째 종목 아셈스 추출중...
# 4개 추출완료. 누적8462개
# 349번째 종목 JYP Ent. 추출중...
# 38개 추출완료. 누적8500개
# 350번째 종목 녹십자엠에스 추출중...
# 10개 추출완료. 누적8510개
# 351번째 종목 이루다 추출중...
# 6개 추출완료. 누적8516개
# 352번째 종목 에스폴리텍 추출중...
# 21개 추출완료. 누적8537개
# 353번째 종목 휴비츠 추출중...
# 29개 추출완료. 누적8566개
# 354번째 종목 탑머티리얼 추출중...
# 0개 추출완료. 누적8566개
# 355번째 종목 보로노이 추출중...
# 3개 추출완료. 누적8569개
# 356번째 종목 서원인텍 추출중...
# 11개 추출완료. 누적8580개
# 357번째 종목 엑스게이트 추출중...
# 0개 추출완료. 누적8580개
# 358번째 종목 KX 추출중...
# 15개 추출완료. 누적8595개
# 359번째 종목 인터플렉스 추출중...
# 75개 추출완료. 누적8670개
# 360번째 종목 레이크머티리얼즈 추출중...
# 7개 추출완료. 누적8677개
# 361번째 종목 씨앤지하이테크 추출중...
# 9개 추출완료. 누적8686개
# 362번째 종목 서암기계공업 추출중...
# 26개 추출완료. 누적8712개
# 363번째 종목 다산솔루에타 추출중...
# 36개 추출완료. 누적8748개
# 364번째 종목 오로라 추출중...
# 20개 추출완료. 누적8768개
# 365번째 종목 ES큐브 추출중...
# 27개 추출완료. 누적8795개
# 366번째 종목 디스플레이텍 추출중...
# 13개 추출완료. 누적8808개
# 367번째 종목 판타지오 추출중...
# 44개 추출완료. 누적8852개
# 368번째 종목 선바이오 추출중...
# 38개 추출완료. 누적8890개
# 369번째 종목 아이씨에이치 추출중...
# 0개 추출완료. 누적8890개
# 370번째 종목 코세스 추출중...
# 38개 추출완료. 누적8928개
# 371번째 종목 에이치와이티씨 추출중...
# 0개 추출완료. 누적8928개
# 372번째 종목 코오롱티슈진 추출중...
# 8개 추출완료. 누적8936개
# 373번째 종목 DH오토웨어 추출중...
# 19개 추출완료. 누적8955개
# 374번째 종목 정다운 추출중...
# 25개 추출완료. 누적8980개
# 375번째 종목 흥구석유 추출중...
# 14개 추출완료. 누적8994개
# 376번째 종목 하이록코리아 추출중...
# 26개 추출완료. 누적9020개
# 377번째 종목 오스테오닉 추출중...
# 17개 추출완료. 누적9037개
# 378번째 종목 시큐브 추출중...
# 20개 추출완료. 누적9057개
# 379번째 종목 스타플렉스 추출중...
# 33개 추출완료. 누적9090개
# 380번째 종목 제노포커스 추출중...
# 26개 추출완료. 누적9116개
# 381번째 종목 씨케이에이치 추출중...
# 28개 추출완료. 누적9144개
# 382번째 종목 메디톡스 추출중...
# 62개 추출완료. 누적9206개
# 383번째 종목 상지카일룸 추출중...
# 105개 추출완료. 누적9311개
# 384번째 종목 솔브레인홀딩스 추출중...
# 38개 추출완료. 누적9349개
# 385번째 종목 에스아이리소스 추출중...
# 47개 추출완료. 누적9396개
# 386번째 종목 크리스에프앤씨 추출중...
# 12개 추출완료. 누적9408개
# 387번째 종목 위즈코프 추출중...
# 36개 추출완료. 누적9444개
# 388번째 종목 TKG애강 추출중...
# 15개 추출완료. 누적9459개
# 389번째 종목 오픈베이스 추출중...
# 40개 추출완료. 누적9499개
# 390번째 종목 공구우먼 추출중...
# 1개 추출완료. 누적9500개
# 391번째 종목 패션플랫폼 추출중...
# 5개 추출완료. 누적9505개
# 392번째 종목 서울옥션 추출중...
# 70개 추출완료. 누적9575개
# 393번째 종목 지엘팜텍 추출중...
# 32개 추출완료. 누적9607개
# 394번째 종목 제우스 추출중...
# 45개 추출완료. 누적9652개
# 395번째 종목 BGF에코머티리얼즈 추출중...
# 23개 추출완료. 누적9675개
# 396번째 종목 케이피티유 추출중...
# 33개 추출완료. 누적9708개
# 397번째 종목 진바이오텍 추출중...
# 22개 추출완료. 누적9730개
# 398번째 종목 뉴로메카 추출중...
# 0개 추출완료. 누적9730개
# 399번째 종목 아이비김영 추출중...
# 10개 추출완료. 누적9740개
# 400번째 종목 유비벨록스 추출중...
# 34개 추출완료. 누적9774개
# 401번째 종목 스마트솔루션즈 추출중...
# 18개 추출완료. 누적9792개
# 402번째 종목 모두투어 추출중...
# 32개 추출완료. 누적9824개
# 403번째 종목 압타머사이언스 추출중...
# 11개 추출완료. 누적9835개
# 404번째 종목 네패스아크 추출중...
# 8개 추출완료. 누적9843개
# 405번째 종목 원준 추출중...
# 9개 추출완료. 누적9852개
# 406번째 종목 삼일 추출중...
# 25개 추출완료. 누적9877개
# 407번째 종목 전진바이오팜 추출중...
# 16개 추출완료. 누적9893개
# 408번째 종목 리드코프 추출중...
# 26개 추출완료. 누적9919개
# 409번째 종목 스코넥 추출중...
# 10개 추출완료. 누적9929개
# 410번째 종목 서울리거 추출중...
# 54개 추출완료. 누적9983개
# 411번째 종목 파라텍 추출중...
# 15개 추출완료. 누적9998개
# 412번째 종목 와이팜 추출중...
# 10개 추출완료. 누적10008개
# 413번째 종목 풍국주정 추출중...
# 12개 추출완료. 누적10020개
# 414번째 종목 안랩 추출중...
# 28개 추출완료. 누적10048개
# 415번째 종목 켐트로닉스 추출중...
# 58개 추출완료. 누적10106개
# 416번째 종목 와이랩 추출중...
# 0개 추출완료. 누적10106개
# 417번째 종목 씨티케이 추출중...
# 6개 추출완료. 누적10112개
# 418번째 종목 한라IMS 추출중...
# 20개 추출완료. 누적10132개
# 419번째 종목 콜마비앤에이치 추출중...
# 24개 추출완료. 누적10156개
# 420번째 종목 솔트룩스 추출중...
# 7개 추출완료. 누적10163개
# 421번째 종목 휴맥스 추출중...
# 18개 추출완료. 누적10181개
# 422번째 종목 DXVX 추출중...
# 32개 추출완료. 누적10213개
# 423번째 종목 아주IB투자 추출중...
# 8개 추출완료. 누적10221개
# 424번째 종목 오리엔탈정공 추출중...
# 15개 추출완료. 누적10236개
# 425번째 종목 인지디스플레 추출중...
# 19개 추출완료. 누적10255개
# 426번째 종목 에스티팜 추출중...
# 42개 추출완료. 누적10297개
# 427번째 종목 에스티오 추출중...
# 17개 추출완료. 누적10314개
# 428번째 종목 마이크로컨텍솔 추출중...
# 45개 추출완료. 누적10359개
# 429번째 종목 현대에이치티 추출중...
# 36개 추출완료. 누적10395개
# 430번째 종목 엘디티 추출중...
# 26개 추출완료. 누적10421개
# 431번째 종목 상신전자 추출중...
# 7개 추출완료. 누적10428개
# 432번째 종목 엔브이에이치코리아 추출중...
# 8개 추출완료. 누적10436개
# 433번째 종목 오스코텍 추출중...
# 97개 추출완료. 누적10533개
# 434번째 종목 바이온 추출중...
# 49개 추출완료. 누적10582개
# 435번째 종목 아스플로 추출중...
# 5개 추출완료. 누적10587개
# 436번째 종목 유에스티 추출중...
# 33개 추출완료. 누적10620개
# 437번째 종목 이크레더블 추출중...
# 5개 추출완료. 누적10625개
# 438번째 종목 삼화네트웍스 추출중...
# 47개 추출완료. 누적10672개
# 439번째 종목 KG ETS 추출중...
# 28개 추출완료. 누적10700개
# 440번째 종목 엠벤처투자 추출중...
# 31개 추출완료. 누적10731개
# 441번째 종목 모베이스 추출중...
# 49개 추출완료. 누적10780개
# 442번째 종목 내츄럴엔도텍 추출중...
# 40개 추출완료. 누적10820개
# 443번째 종목 앤디포스 추출중...
# 20개 추출완료. 누적10840개
# 444번째 종목 이삭엔지니어링 추출중...
# 6개 추출완료. 누적10846개
# 445번째 종목 대한광통신 추출중...
# 37개 추출완료. 누적10883개
# 446번째 종목 메디아나 추출중...
# 33개 추출완료. 누적10916개
# 447번째 종목 유비케어 추출중...
# 19개 추출완료. 누적10935개
# 448번째 종목 한국경제TV 추출중...
# 19개 추출완료. 누적10954개
# 449번째 종목 컴투스 추출중...
# 68개 추출완료. 누적11022개
# 450번째 종목 휴림로봇 추출중...
# 52개 추출완료. 누적11074개
# 451번째 종목 피에스텍 추출중...
# 17개 추출완료. 누적11091개
# 452번째 종목 버넥트 추출중...
# 0개 추출완료. 누적11091개
# 453번째 종목 네오티스 추출중...
# 9개 추출완료. 누적11100개
# 454번째 종목 서전기전 추출중...
# 23개 추출완료. 누적11123개
# 455번째 종목 백금T&A 추출중...
# 41개 추출완료. 누적11164개
# 456번째 종목 셀리드 추출중...
# 42개 추출완료. 누적11206개
# 457번째 종목 씨엔플러스 추출중...
# 30개 추출완료. 누적11236개
# 458번째 종목 지엔씨에너지 추출중...
# 24개 추출완료. 누적11260개
# 459번째 종목 KBG 추출중...
# 3개 추출완료. 누적11263개
# 460번째 종목 CS 추출중...
# 30개 추출완료. 누적11293개
# 461번째 종목 아이에스이커머스 추출중...
# 39개 추출완료. 누적11332개
# 462번째 종목 케이엘넷 추출중...
# 24개 추출완료. 누적11356개
# 463번째 종목 국보디자인 추출중...
# 45개 추출완료. 누적11401개
# 464번째 종목 소마젠 추출중...
# 1개 추출완료. 누적11402개
# 465번째 종목 동국제약 추출중...
# 27개 추출완료. 누적11429개
# 466번째 종목 에이티넘인베스트 추출중...
# 49개 추출완료. 누적11478개
# 467번째 종목 머큐리 추출중...
# 9개 추출완료. 누적11487개
# 468번째 종목 케이피엠테크 추출중...
# 65개 추출완료. 누적11552개
# 469번째 종목 바이오솔루션 추출중...
# 17개 추출완료. 누적11569개
# 470번째 종목 코닉오토메이션 추출중...
# 5개 추출완료. 누적11574개
# 471번째 종목 엘앤케이바이오 추출중...
# 42개 추출완료. 누적11616개
# 472번째 종목 지엔코 추출중...
# 55개 추출완료. 누적11671개
# 473번째 종목 비나텍 추출중...
# 9개 추출완료. 누적11680개
# 474번째 종목 리노스 추출중...
# 33개 추출완료. 누적11713개
# 475번째 종목 CBI 추출중...
# 48개 추출완료. 누적11761개
# 476번째 종목 알리코제약 추출중...
# 15개 추출완료. 누적11776개
# 477번째 종목 인크로스 추출중...
# 30개 추출완료. 누적11806개
# 478번째 종목 태광 추출중...
# 17개 추출완료. 누적11823개
# 479번째 종목 센코 추출중...
# 2개 추출완료. 누적11825개
# 480번째 종목 케이에스피 추출중...
# 6개 추출완료. 누적11831개
# 481번째 종목 미코바이오메드 추출중...
# 21개 추출완료. 누적11852개
# 482번째 종목 파나진 추출중...
# 32개 추출완료. 누적11884개
# 483번째 종목 TJ미디어 추출중...
# 8개 추출완료. 누적11892개
# 484번째 종목 인바이오 추출중...
# 2개 추출완료. 누적11894개
# 485번째 종목 상상인인더스트리 추출중...
# 29개 추출완료. 누적11923개
# 486번째 종목 알피바이오 추출중...
# 0개 추출완료. 누적11923개
# 487번째 종목 프롬바이오 추출중...
# 4개 추출완료. 누적11927개
# 488번째 종목 커넥트웨이브 추출중...
# 36개 추출완료. 누적11963개
# 489번째 종목 와이오엠 추출중...
# 86개 추출완료. 누적12049개
# 490번째 종목 DMS 추출중...
# 43개 추출완료. 누적12092개
# 491번째 종목 NEW 추출중...
# 82개 추출완료. 누적12174개
# 492번째 종목 피씨디렉트 추출중...
# 20개 추출완료. 누적12194개
# 493번째 종목 피앤씨테크 추출중...
# 10개 추출완료. 누적12204개
# 494번째 종목 KD 추출중...
# 36개 추출완료. 누적12240개
# 495번째 종목 비트나인 추출중...
# 7개 추출완료. 누적12247개
# 496번째 종목 쎌바이오텍 추출중...
# 35개 추출완료. 누적12282개
# 497번째 종목 월덱스 추출중...
# 49개 추출완료. 누적12331개
# 498번째 종목 에쎈테크 추출중...
# 27개 추출완료. 누적12358개
# 499번째 종목 티비씨 추출중...
# 14개 추출완료. 누적12372개
# 500번째 종목 엔피 추출중...
# 15개 추출완료. 누적12387개
# 501번째 종목 삼성전자 추출중...
# 6개 추출완료. 누적12393개
# 502번째 종목 LG화학 추출중...
# 40개 추출완료. 누적12433개
# 503번째 종목 SK하이닉스 추출중...
# 16개 추출완료. 누적12449개
# 504번째 종목 삼성바이오로직스 추출중...
# 18개 추출완료. 누적12467개
# 505번째 종목 삼성전자우 추출중...
# 4개 추출완료. 누적12471개
# 506번째 종목 LG화학우 추출중...
# 25개 추출완료. 누적12496개
# 507번째 종목 삼성SDI 추출중...
# 40개 추출완료. 누적12536개
# 508번째 종목 현대차 추출중...
# 11개 추출완료. 누적12547개
# 509번째 종목 효성화학 추출중...
# 8개 추출완료. 누적12555개
# 510번째 종목 에코프로비엠 추출중...
# 29개 추출완료. 누적12584개
# 511번째 종목 기아 추출중...
# 12개 추출완료. 누적12596개
# 512번째 종목 에코프로 추출중...
# 77개 추출완료. 누적12673개
# 513번째 종목 카카오 추출중...
# 32개 추출완료. 누적12705개
# 514번째 종목 셀트리온 추출중...
# 20개 추출완료. 누적12725개
# 515번째 종목 현대모비스 추출중...
# 14개 추출완료. 누적12739개
# 516번째 종목 KB금융 추출중...
# 3개 추출완료. 누적12742개
# 517번째 종목 삼성물산 추출중...
# 12개 추출완료. 누적12754개
# 518번째 종목 신한지주 추출중...
# 3개 추출완료. 누적12757개
# 519번째 종목 SK이노베이션 추출중...
# 31개 추출완료. 누적12788개
# 520번째 종목 LG전자 추출중...
# 21개 추출완료. 누적12809개
# 521번째 종목 대우조선해양 추출중...
# 26개 추출완료. 누적12835개
# 522번째 종목 삼성생명 추출중...
# 5개 추출완료. 누적12840개
# 523번째 종목 카카오뱅크 추출중...
# 17개 추출완료. 누적12857개
# 524번째 종목 LG 추출중...
# 9개 추출완료. 누적12866개
# 525번째 종목 한국전력 추출중...
# 14개 추출완료. 누적12880개
# 526번째 종목 삼성화재 추출중...
# 5개 추출완료. 누적12885개
# 527번째 종목 KT&G 추출중...
# 2개 추출완료. 누적12887개
# 528번째 종목 셀트리온헬스케어 추출중...
# 24개 추출완료. 누적12911개
# 529번째 종목 삼성전기 추출중...
# 27개 추출완료. 누적12938개
# 530번째 종목 하나금융지주 추출중...
# 11개 추출완료. 누적12949개
# 531번째 종목 SK 추출중...
# 13개 추출완료. 누적12962개
# 532번째 종목 솔루스첨단소재 추출중...
# 25개 추출완료. 누적12987개
# 533번째 종목 하이브 추출중...
# 19개 추출완료. 누적13006개
# 534번째 종목 삼성에스디에스 추출중...
# 10개 추출완료. 누적13016개
# 535번째 종목 KODEX 레버리지 추출중...
# 11개 추출완료. 누적13027개
# 536번째 종목 SK텔레콤 추출중...
# 4개 추출완료. 누적13031개
# 537번째 종목 고려아연 추출중...
# 9개 추출완료. 누적13040개
# 538번째 종목 케이씨케미칼 추출중...
# 19개 추출완료. 누적13059개
# 539번째 종목 대한항공 추출중...
# 19개 추출완료. 누적13078개
# 540번째 종목 S-Oil 추출중...
# 20개 추출완료. 누적13098개
# 541번째 종목 현대글로비스 추출중...
# 23개 추출완료. 누적13121개
# 542번째 종목 크래프톤 추출중...
# 9개 추출완료. 누적13130개
# 543번째 종목 기업은행 추출중...
# 4개 추출완료. 누적13134개
# 544번째 종목 케이티 추출중...
# 2개 추출완료. 누적13136개
# 545번째 종목 우리금융지주 추출중...
# 0개 추출완료. 누적13136개
# 546번째 종목 삼성중공업 추출중...
# 29개 추출완료. 누적13165개
# 547번째 종목 아모레퍼시픽 추출중...
# 47개 추출완료. 누적13212개
# 548번째 종목 LG생활건강 추출중...
# 33개 추출완료. 누적13245개
# 549번째 종목 삼성엔지니어링 추출중...
# 44개 추출완료. 누적13289개
# 550번째 종목 KODEX 코스닥 150 레버리지 추출중...
# 58개 추출완료. 누적13347개
# 551번째 종목 롯데케미칼 추출중...
# 26개 추출완료. 누적13373개
# 552번째 종목 유한양행 추출중...
# 13개 추출완료. 누적13386개
# 553번째 종목 한화에어로스페이스 추출중...
# 47개 추출완료. 누적13433개
# 554번째 종목 엔씨소프트 추출중...
# 27개 추출완료. 누적13460개
# 555번째 종목 두산밥캣 추출중...
# 9개 추출완료. 누적13469개
# 556번째 종목 DB손해보험 추출중...
# 10개 추출완료. 누적13479개
# 557번째 종목 한온시스템 추출중...
# 28개 추출완료. 누적13507개
# 558번째 종목 LG디스플레이 추출중...
# 25개 추출완료. 누적13532개
# 559번째 종목 HD현대 추출중...
# 18개 추출완료. 누적13550개
# 560번째 종목 맥쿼리인프라 추출중...
# 1개 추출완료. 누적13551개
# 561번째 종목 코스모신소재 추출중...
# 76개 추출완료. 누적13627개
# 562번째 종목 오리온 추출중...
# 11개 추출완료. 누적13638개
# 563번째 종목 현대제철 추출중...
# 26개 추출완료. 누적13664개
# 564번째 종목 CJ제일제당 추출중...
# 12개 추출완료. 누적13676개
# 565번째 종목 한국항공우주 추출중...
# 25개 추출완료. 누적13701개
# 566번째 종목 한미반도체 추출중...
# 43개 추출완료. 누적13744개
# 567번째 종목 LG유플러스 추출중...
# 7개 추출완료. 누적13751개
# 568번째 종목 현대오토에버 추출중...
# 17개 추출완료. 누적13768개
# 569번째 종목 미래에셋증권 추출중...
# 20개 추출완료. 누적13788개
# 570번째 종목 F&F홀딩스 추출중...
# 83개 추출완료. 누적13871개
# 571번째 종목 넷마블 추출중...
# 21개 추출완료. 누적13892개
# 572번째 종목 한미약품 추출중...
# 40개 추출완료. 누적13932개
# 573번째 종목 현대건설 추출중...
# 30개 추출완료. 누적13962개
# 574번째 종목 현대미포조선 추출중...
# 53개 추출완료. 누적14015개
# 575번째 종목 LS 추출중...
# 21개 추출완료. 누적14036개
# 576번째 종목 GS 추출중...
# 3개 추출완료. 누적14039개
# 577번째 종목 금호석유 추출중...
# 36개 추출완료. 누적14075개
# 578번째 종목 강원랜드 추출중...
# 7개 추출완료. 누적14082개
# 579번째 종목 호텔신라 추출중...
# 39개 추출완료. 누적14121개
# 580번째 종목 NH투자증권 추출중...
# 14개 추출완료. 누적14135개
# 581번째 종목 한진칼 추출중...
# 41개 추출완료. 누적14176개
# 582번째 종목 삼성증권 추출중...
# 10개 추출완료. 누적14186개
# 583번째 종목 현대로템 추출중...
# 35개 추출완료. 누적14221개
# 584번째 종목 코웨이 추출중...
# 15개 추출완료. 누적14236개
# 585번째 종목 BGF리테일 추출중...
# 11개 추출완료. 누적14247개
# 586번째 종목 씨에스윈드 추출중...
# 54개 추출완료. 누적14301개
# 587번째 종목 한국금융지주 추출중...
# 20개 추출완료. 누적14321개
# 588번째 종목 아모레G 추출중...
# 40개 추출완료. 누적14361개
# 589번째 종목 한미사이언스 추출중...
# 57개 추출완료. 누적14418개
# 590번째 종목 롯데지주 추출중...
# 14개 추출완료. 누적14432개
# 591번째 종목 삼성전자 추출중...
# 6개 추출완료. 누적14438개
# 592번째 종목 LG화학 추출중...
# 41개 추출완료. 누적14479개
# 593번째 종목 SK하이닉스 추출중...
# 15개 추출완료. 누적14494개
# 594번째 종목 삼성바이오로직스 추출중...
# 19개 추출완료. 누적14513개
# 595번째 종목 삼성전자우 추출중...
# 4개 추출완료. 누적14517개
# 596번째 종목 LG화학우 추출중...
# 25개 추출완료. 누적14542개
# 597번째 종목 삼성SDI 추출중...
# 37개 추출완료. 누적14579개
# 598번째 종목 현대차 추출중...
# 11개 추출완료. 누적14590개
# 599번째 종목 효성화학 추출중...
# 8개 추출완료. 누적14598개
# 600번째 종목 에코프로비엠 추출중...
# 28개 추출완료. 누적14626개
# 601번째 종목 기아 추출중...
# 11개 추출완료. 누적14637개
# 602번째 종목 에코프로 추출중...
# 83개 추출완료. 누적14720개
# 603번째 종목 카카오 추출중...
# 31개 추출완료. 누적14751개
# 604번째 종목 셀트리온 추출중...
# 18개 추출완료. 누적14769개
# 605번째 종목 현대모비스 추출중...
# 13개 추출완료. 누적14782개
# 606번째 종목 KB금융 추출중...
# 3개 추출완료. 누적14785개
# 607번째 종목 삼성물산 추출중...
# 12개 추출완료. 누적14797개
# 608번째 종목 신한지주 추출중...
# 3개 추출완료. 누적14800개
# 609번째 종목 SK이노베이션 추출중...
# 26개 추출완료. 누적14826개
# 610번째 종목 LG전자 추출중...
# 22개 추출완료. 누적14848개
# 611번째 종목 대우조선해양 추출중...
# 27개 추출완료. 누적14875개
# 612번째 종목 삼성생명 추출중...
# 5개 추출완료. 누적14880개
# 613번째 종목 카카오뱅크 추출중...
# 16개 추출완료. 누적14896개
# 614번째 종목 LG 추출중...
# 8개 추출완료. 누적14904개
# 615번째 종목 한국전력 추출중...
# 14개 추출완료. 누적14918개
# 616번째 종목 삼성화재 추출중...
# 5개 추출완료. 누적14923개
# 617번째 종목 KT&G 추출중...
# 1개 추출완료. 누적14924개
# 618번째 종목 셀트리온헬스케어 추출중...
# 26개 추출완료. 누적14950개
# 619번째 종목 삼성전기 추출중...
# 27개 추출완료. 누적14977개
# 620번째 종목 하나금융지주 추출중...
# 13개 추출완료. 누적14990개
# 621번째 종목 SK 추출중...
# 17개 추출완료. 누적15007개
# 622번째 종목 솔루스첨단소재 추출중...
# 26개 추출완료. 누적15033개
# 623번째 종목 하이브 추출중...
# 17개 추출완료. 누적15050개
# 624번째 종목 삼성에스디에스 추출중...
# 8개 추출완료. 누적15058개
# 625번째 종목 KODEX 레버리지 추출중...
# 10개 추출완료. 누적15068개
# 626번째 종목 SK텔레콤 추출중...
# 3개 추출완료. 누적15071개
# 627번째 종목 고려아연 추출중...
# 9개 추출완료. 누적15080개
# 628번째 종목 케이씨케미칼 추출중...
# 17개 추출완료. 누적15097개
# 629번째 종목 대한항공 추출중...
# 20개 추출완료. 누적15117개
# 630번째 종목 S-Oil 추출중...
# 20개 추출완료. 누적15137개
# 631번째 종목 현대글로비스 추출중...
# 22개 추출완료. 누적15159개
# 632번째 종목 크래프톤 추출중...
# 11개 추출완료. 누적15170개
# 633번째 종목 기업은행 추출중...
# 4개 추출완료. 누적15174개
# 634번째 종목 케이티 추출중...
# 3개 추출완료. 누적15177개
# 635번째 종목 우리금융지주 추출중...
# 0개 추출완료. 누적15177개
# 636번째 종목 삼성중공업 추출중...
# 29개 추출완료. 누적15206개
# 637번째 종목 아모레퍼시픽 추출중...
# 46개 추출완료. 누적15252개
# 638번째 종목 LG생활건강 추출중...
# 33개 추출완료. 누적15285개
# 639번째 종목 삼성엔지니어링 추출중...
# 45개 추출완료. 누적15330개
# 640번째 종목 KODEX 코스닥 150 레버리지 추출중...
# 58개 추출완료. 누적15388개
# 641번째 종목 롯데케미칼 추출중...
# 30개 추출완료. 누적15418개
# 642번째 종목 유한양행 추출중...
# 16개 추출완료. 누적15434개
# 643번째 종목 한화에어로스페이스 추출중...
# 40개 추출완료. 누적15474개
# 644번째 종목 엔씨소프트 추출중...
# 30개 추출완료. 누적15504개
# 645번째 종목 두산밥캣 추출중...
# 12개 추출완료. 누적15516개
# 646번째 종목 DB손해보험 추출중...
# 10개 추출완료. 누적15526개
# 647번째 종목 한온시스템 추출중...
# 28개 추출완료. 누적15554개
# 648번째 종목 LG디스플레이 추출중...
# 28개 추출완료. 누적15582개
# 649번째 종목 HD현대 추출중...
# 16개 추출완료. 누적15598개
# 650번째 종목 맥쿼리인프라 추출중...
# 1개 추출완료. 누적15599개
# 651번째 종목 코스모신소재 추출중...
# 75개 추출완료. 누적15674개
# 652번째 종목 오리온 추출중...
# 9개 추출완료. 누적15683개
# 653번째 종목 현대제철 추출중...
# 26개 추출완료. 누적15709개
# 654번째 종목 CJ제일제당 추출중...
# 11개 추출완료. 누적15720개
# 655번째 종목 한국항공우주 추출중...
# 25개 추출완료. 누적15745개
# 656번째 종목 한미반도체 추출중...
# 38개 추출완료. 누적15783개
# 657번째 종목 LG유플러스 추출중...
# 8개 추출완료. 누적15791개
# 658번째 종목 현대오토에버 추출중...
# 18개 추출완료. 누적15809개
# 659번째 종목 미래에셋증권 추출중...
# 21개 추출완료. 누적15830개
# 660번째 종목 F&F홀딩스 추출중...
# 81개 추출완료. 누적15911개
# 661번째 종목 넷마블 추출중...
# 23개 추출완료. 누적15934개
# 662번째 종목 한미약품 추출중...
# 41개 추출완료. 누적15975개
# 663번째 종목 현대건설 추출중...
# 32개 추출완료. 누적16007개
# 664번째 종목 현대미포조선 추출중...
# 47개 추출완료. 누적16054개
# 665번째 종목 LS 추출중...
# 23개 추출완료. 누적16077개
# 666번째 종목 GS 추출중...
# 2개 추출완료. 누적16079개
# 667번째 종목 금호석유 추출중...
# 31개 추출완료. 누적16110개
# 668번째 종목 강원랜드 추출중...
# 8개 추출완료. 누적16118개
# 669번째 종목 호텔신라 추출중...
# 43개 추출완료. 누적16161개
# 670번째 종목 NH투자증권 추출중...
# 13개 추출완료. 누적16174개
# 671번째 종목 한진칼 추출중...
# 45개 추출완료. 누적16219개
# 672번째 종목 삼성증권 추출중...
# 9개 추출완료. 누적16228개
# 673번째 종목 현대로템 추출중...
# 38개 추출완료. 누적16266개
# 674번째 종목 코웨이 추출중...
# 14개 추출완료. 누적16280개
# 675번째 종목 BGF리테일 추출중...
# 11개 추출완료. 누적16291개
# 676번째 종목 씨에스윈드 추출중...
# 50개 추출완료. 누적16341개
# 677번째 종목 한국금융지주 추출중...
# 20개 추출완료. 누적16361개
# 678번째 종목 아모레G 추출중...
# 39개 추출완료. 누적16400개
# 679번째 종목 한미사이언스 추출중...
# 59개 추출완료. 누적16459개
# 680번째 종목 롯데지주 추출중...
# 13개 추출완료. 누적16472개

# %%
print(len(train_result))
print(sum([low[1] for low in train_result]))
# Out:
# 14430
# 8148

# %%
train_result = train_result[:14430]

# %%
def get_same_labelnum(result, num):

    # 라벨별로 이미지 데이터 분리
    label0_images = [image_data for image_data, label in result if label == 0]
    label1_images = [image_data for image_data, label in result if label == 1]

    # 각 라벨에서 랜덤하게 5,000개씩 뽑기
    random_label0_images = random.sample(label0_images, num)
    random_label1_images = random.sample(label1_images, num)

    # 뽑은 이미지 데이터와 라벨을 다시 묶기
    new_label0_result = [(image_data, 0) for image_data in random_label0_images]
    new_label1_result = [(image_data, 1) for image_data in random_label1_images]

    # 두 결과를 번갈아가면서 합치기
    result = [t for pair in zip(new_label0_result, new_label1_result) for t in pair]
    return result

# %%
train_result = get_same_labelnum(train_result, 5000)
train_images, train_labels = zip(*train_result)
print(sum(train_labels))
np.save('train_images.npy', train_images)
np.save('train_labels.npy', train_labels)
# Out:
# 5000

# %%
test_result = []
for i, ticker in enumerate(stock_codes):
    code, name = ticker[0], ticker[1]
    print(f"{i+1}번째 종목 {name} 추출중...   ")
    try:
        data = preprocess_data(fdr.DataReader(code, "2022-10-15"))  # 각 종목의 데이터 가져오기
        images = convert_image(data, 300, day_num, 0, test=True)
        test_result += images
        print(f"{len(images)}개 추출완료. 누적{len(test_result)}개")
    except IndexError:
        print(f"{name}에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.")
        continue

# %%
print(len(test_result))
print(sum([low[1] for low in test_result]))
# Out:
# 14205
# 6238

# %%
test_result = get_same_labelnum(test_result, 5000)
test_images, test_labels = zip(*test_result)
print(sum(test_labels))
np.save('test_images.npy', test_images)
np.save('test_labels.npy', test_labels)
# Out:
# 5000

# %%
train_images = np.load('train_images.npy')
train_labels = np.load('train_labels.npy')
# test_images = np.load('test_images.npy')
# test_labels = np.load('test_labels.npy')

train_images = train_images[:, :, :, :3]
# test_images = test_images[:, :, :, :3]

np.save('train_images.npy', train_images)
np.save('train_labels.npy', train_labels)
# np.save('test_images.npy', test_images)
# np.save('test_labels.npy', test_labels)

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# 이미지 개수와 그리드 크기 설정
num_images = len(train_images)
num_to_display = 100
grid_size = int(np.sqrt(num_to_display))

# 랜덤으로 이미지 인덱스 선택
random_indices = np.random.choice(num_images, num_to_display, replace=False)

fig, axes = plt.subplots(grid_size, grid_size, figsize=(16, 16))
for i in range(grid_size):
    for j in range(grid_size):
        img_idx = random_indices[i * grid_size + j]
        img = Image.fromarray(train_images[img_idx])
        axes[i, j].imshow(img)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        axes[i, j].set_xlabel(f'Img {img_idx + 1}', fontsize=9)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10, 10, figsize=(16, 16))
for i in range(10):
    for j in range(10):
        img_idx = i * 10 + j
        img = Image.fromarray(train_images[img_idx])
        axes[i, j].imshow(img)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        axes[i, j].set_xlabel(f'Img {img_idx + 1}', fontsize=9)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.show()
