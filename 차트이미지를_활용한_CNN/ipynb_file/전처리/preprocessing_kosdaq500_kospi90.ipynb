# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.50 requests-file-1.5.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from datetime import datetime, timedelta
import random

num_images = 5000
day_num = 32

# %%
def convert_image(data, num_images, day_num, change_std, save = False, test = False):
    if test:
        change_std = 0

    def alpha_blend(color1, color2, alpha):
        return [
            int((color1[0] * alpha + color2[0] * (1 - alpha))),
            int((color1[1] * alpha + color2[1] * (1 - alpha))),
            int((color1[2] * alpha + color2[2] * (1 - alpha))),
            255,
        ]

    # 데이터수가 너무 적으면 패스
    if len(data) <= 100:
        return []


    # 해당 종목의 주가 데이터 - 100이 요구되는 이미지 수보다 적으면(상장직후는 변동이 심할 수있으니 제외)
    if num_images - 92 > len(data):
        num_images = len(data) - 92

    #return_datas는 이미지, 라벨링(상승이면1 하락이면0), 변동률, 날짜를 담고있음
    return_datas = []
    prediction_day_num = 5


    image_idx = 1
    while(image_idx <= num_images):
        prediction_day = data[-image_idx - prediction_day_num : -image_idx]
        predict_mean = prediction_day['Close'].mean()
        now = data.iloc[-image_idx - prediction_day_num - 1]
        change = (predict_mean - now['Close']) / now['Close']


        # change가 너무 높으면 이상치라고 판단하여 패스
        if not test and (abs(change) < change_std or change_std * 3 < abs(change)): # 향후 prediction_day_num일의 변동률이 기준 이하면
            image_idx += 1
            continue

        stock_data = data[-image_idx - day_num - prediction_day_num : -image_idx - prediction_day_num]

        # 이미지 크기 설정
        width, height = 96, 96

        # High, Low, Close, Volume 데이터 정규화
        high_prices = stock_data['High'].values
        low_prices = stock_data['Low'].values
        close_prices = stock_data['Close'].values
        volume_data = stock_data['Volume'].values

        high_prices_norm = (high_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        low_prices_norm = (low_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        close_prices_norm = (close_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        volume_data_norm = height * (volume_data) / (2 * (np.max(volume_data)))

        # 이동평균선 추가를 위한 stock_data 생성
        stock_data_ma20 = data[-image_idx - day_num - 20 - prediction_day_num: -image_idx - prediction_day_num]
        stock_data_ma20 = stock_data_ma20.copy()
        stock_data_ma20['MA20'] = stock_data_ma20['Close'].rolling(window=20).mean()
        stock_data_ma20.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma20['MA20_norm'] = (
                (stock_data_ma20['MA20'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        stock_data_ma40 = data[-image_idx - day_num - 40 - prediction_day_num: -image_idx - prediction_day_num]
        stock_data_ma40 = stock_data_ma40.copy()
        stock_data_ma40['MA40'] = stock_data_ma40['Close'].rolling(window=40).mean()
        stock_data_ma40.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma40['MA40_norm'] = (
                (stock_data_ma40['MA40'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        stock_data_ma60 = data[-image_idx - day_num - 60 - prediction_day_num: -image_idx - prediction_day_num]
        stock_data_ma60 = stock_data_ma60.copy()
        stock_data_ma60['MA60'] = stock_data_ma60['Close'].rolling(window=60).mean()
        stock_data_ma60.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma60['MA60_norm'] = (
                (stock_data_ma60['MA60'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        # 96x96 이미지 생성
        img = np.zeros((height, width, 4), dtype=np.uint8)  # 4 channels for RGBA

        fail_generate = False
        for day in range(32):
            high_price = int(high_prices_norm[day] * (height - 1))
            low_price = int(low_prices_norm[day] * (height - 1))
            close_price = int(close_prices_norm[day] * (height - 1))
            open_price = int(
                (
                    (stock_data['Open'].values[day] - np.min(low_prices))
                    / (np.max(high_prices) - np.min(low_prices))
                )
                * (height - 1)
            )
            volume = int(volume_data_norm[day])
            if(volume == 0):
                fail_generate = True
                break

            x_start = day * 3

            # 시가, 종가, 고가, 저가 막대그래프
            # 막대 왼쪽, 오른쪽 그리기 (시가, 종가 범위)
            for x in range(x_start, x_start + 3):
                if close_prices[day] > stock_data['Open'].values[day]:
                    color = [255, 0, 0, 255]  # 상승: 빨강
                    tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                elif close_prices[day] < stock_data['Open'].values[day]:
                    color = [0, 0, 255, 255]  # 하락: 파랑
                    tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑
                else: # 시가와 종가가 같을경우 어제보다 같거나 올랐으면 빨강, 아니면 파랑
                    if 0 <= stock_data['Change'].values[day]:
                        color = [255, 0, 0, 255]  # 상승: 빨강
                        tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                    else:
                        color = [0, 0, 255, 255]  # 하락: 파랑
                        tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑

                for y in range(min(open_price, close_price), max(open_price, close_price) + 1):
                    img[height - 1 - y, x] = color

            # 꼬리 그리기 (High, Low 범위)
            for x in range(x_start + 1, x_start + 2):
                for y in range(low_price, high_price + 1):
                    if img[height - 1 - y, x][0] != 255 and img[height - 1 - y, x][2] != 255:
                        img[height - 1 - y, x] = tail_color

            # 거래량 그리기
            for x in range(x_start, x_start + 3):
                overlapped = height - volume
                if overlapped >= 0 and overlapped < height:
                    img[overlapped:, x] = [
                        alpha_blend(img[y, x], [128, 128, 128, 255], 0.45)
                        for y in range(overlapped, height)
                    ]

            # 20일 이동평균선 그리기
            ma20_norm = stock_data_ma20.iloc[day]['MA20_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma20_norm):
                    ma20_y = int(ma20_norm * (height - 1))
                    if 0 <= ma20_y < height:
                        for y in range(ma20_y - 1, ma20_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([255, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 노란색으로 변경
                                img[height - 1 - y, x] = new_color

            # 40일 이동평균선 그리기
            ma40_norm = stock_data_ma40.iloc[day]['MA40_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma40_norm):
                    ma40_y = int(ma40_norm * (height - 1))
                    if 0 <= ma40_y < height:
                        for y in range(ma40_y - 1, ma40_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([128, 0, 128, 255], img[height - 1 - y, x], 0.6)  # 보라색으로 변경
                                img[height - 1 - y, x] = new_color

            # 60일 이동평균선 그리기
            ma60_norm = stock_data_ma60.iloc[day]['MA60_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma60_norm):
                    ma60_y = int(ma60_norm * (height - 1))
                    if 0 <= ma60_y < height:
                        for y in range(ma60_y - 1, ma60_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([0, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 초록색으로 변경
                                img[height - 1 - y, x] = new_color

        #이미지가 day_num(그려지기 원하는 거래일 수)미만으로 그려졌으면
        if fail_generate:
            image_idx += prediction_day_num
            continue

        if save :
            # 이미지 저장
            img = Image.fromarray(img, 'RGBA')
            img.save(f'stock_data_image_{image_idx}.png')

        if change_std <= change:
            return_datas.append((img, 1))
        elif change < -change_std :
            return_datas.append((img, 0))

            # 테스트는 촘촘하게 모든 데이터로
        if test:
            image_idx += random.choice(range(1, 6))
        else:
            # 비슷한 이미지를 피하기 위해 기준 예측일만큼 건너뜀
            image_idx += random.choice(range(1, 10))


    return return_datas

# %%
def preprocess_data(data):
    # 0이나 NaN을 포함하는 행 제거
    data = data[data['Volume'] != 0]
    data = data.dropna(how='any')

    return data

# %%
stock_codes2 = [
    ["005930", "삼성전자"],
    ["051910", "LG화학"],
    ["000660", "SK하이닉스"],
    ["207940", "삼성바이오로직스"],
    ["005935", "삼성전자우"],
    ["051915", "LG화학우"],
    ["006400", "삼성SDI"],
    ["005380", "현대차"],
    ["363280", "효성화학"],
    ["247540", "에코프로비엠"],
    ["000270", "기아"],
    ["086520", "에코프로"],
    ["035720", "카카오"],
    ["068270", "셀트리온"],
    ["012330", "현대모비스"],
    ["105560", "KB금융"],
    ["028260", "삼성물산"],
    ["055550", "신한지주"],
    ["096770", "SK이노베이션"],
    ["066570", "LG전자"],
    ["047050", "대우조선해양"],
    ["032830", "삼성생명"],
    ["323410", "카카오뱅크"],
    ["003550", "LG"],
    ["015760", "한국전력"],
    ["000810", "삼성화재"],
    ["033780", "KT&G"],
    ["091990", "셀트리온헬스케어"],
    ["009150", "삼성전기"],
    ["086790", "하나금융지주"],
    ["034730", "SK"],
    ["336370", "솔루스첨단소재"],
    ["352820", "하이브"],
    ["018260", "삼성에스디에스"],
    ["122630", "KODEX 레버리지"],
    ["017670", "SK텔레콤"],
    ["010130", "고려아연"],
    ["024880", "케이씨케미칼"],
    ["003490", "대한항공"],
    ["010950", "S-Oil"],
    ["086280", "현대글로비스"],
    ["259960", "크래프톤"],
    ["024110", "기업은행"],
    ["030200", "케이티"],
    ["316140", "우리금융지주"],
    ["010140", "삼성중공업"],
    ["090430", "아모레퍼시픽"],
    ["051900", "LG생활건강"],
    ["028050", "삼성엔지니어링"],
    ["233740", "KODEX 코스닥 150 레버리지"],
    ["011170", "롯데케미칼"],
    ["000100", "유한양행"],
    ["012450", "한화에어로스페이스"],
    ["036570", "엔씨소프트"],
    ["241560", "두산밥캣"],
    ["005830", "DB손해보험"],
    ["018880", "한온시스템"],
    ["034220", "LG디스플레이"],
    ["170030", "HD현대"],
    ["088980", "맥쿼리인프라"],
    ["005070", "코스모신소재"],
    ["271560", "오리온"],
    ["004020", "현대제철"],
    ["097950", "CJ제일제당"],
    ["047810", "한국항공우주"],
    ["042700", "한미반도체"],
    ["032640", "LG유플러스"],
    ["307950", "현대오토에버"],
    ["006800", "미래에셋증권"],
    ["007700", "F&F홀딩스"],
    ["251270", "넷마블"],
    ["128940", "한미약품"],
    ["000720", "현대건설"],
    ["010620", "현대미포조선"],
    ["006260", "LS"],
    ["078930", "GS"],
    ["011780", "금호석유"],
    ["035250", "강원랜드"],
    ["008770", "호텔신라"],
    ["005940", "NH투자증권"],
    ["180640", "한진칼"],
    ["016360", "삼성증권"],
    ["064350", "현대로템"],
    ["021240", "코웨이"],
    ["282330", "BGF리테일"],
    ["112610", "씨에스윈드"],
    ["071050", "한국금융지주"],
    ["002790", "아모레G"],
    ["008930", "한미사이언스"],
    ["004990", "롯데지주"],
    ["010780", "쌍용C&E"],
    ["001450",  "현대해상"],
    ["111770",  "영원무역"],
    ["272210",  "한화시스템"],
    ["052690",  "한전기술"],
    ["267260",  "HD현대일렉트릭"],
    ["007070",  "GS리테일"],
    ["028670",  "팬오션"],
    ["139480",  "이마트"],
    ["035900", "JYP Ent."], # 여기서부터는 코스닥
    ["263750", "펄어비스"],
    ["293490", "카카오게임즈"],
    ["196170", "알테오젠"],
    ["058470", "리노공업"],
    ["214150", "클래시스"],
    ["039030", "이오테크닉스"],
    ["278280", "천보"],
    ["137400", "피엔티"],
    ["237690", "에스티팜"],
    ["214450", "파마리서치"],
    ["240810", "원익IPS"],
    ["145020", "휴젤"],
    ["035760", "CJ ENM"],
    ["056190", "에스에프에이"],
    ["036930", "주성엔지니어링"],
    ["064760", "티씨케이"],
    ["213420", "덕산네오룩스"],
    ["195940", "HK이노엔"],
    ["014130", "레고켐바이오"],
    ["098460", "고영"],
    ["067310", "하나마이크론"],
    ["166090", "하나머티리얼즈"],
    ["348210", "넥스틴"],
    ["003380", "하림지주"],
    ["272290", "이녹스첨단소재"],
    ["085660", "차바이오텍"],
    ["074610", "원익QnC"],
    ["083470", "유진테크"],
    ["046890", "서울반도체"],
    ["086450", "동국제약"],
    ["215000", "골프존"],
    ["215200", "메가스터디교육"],
    ["319660", "피에스케이"],
    ["183300", "코미코"],
    ["200130", "콜마비앤에이치"],
    ["069080", "웹젠"],
    ["036830", "솔브레인홀딩스"],
    ["084850", "아이티엠반도체"],
    ["243070", "휴온스"],
    ["049070", "인탑스"],
    ["131290", "티에스이"],
    ["091700", "파트론"],
    ["064550", "바이오니아"],
    ["019550", "SFA반도체"],
    ["095610", "테스"],
    ["230360", "에코마케팅"],
    ["267980", "매일유업"],
    ['205470', '휴마시스'],
    ['060150', '인선이엔티'],
    ['417010', '나노팀'],
    ['036620', '감성코퍼레이션'],
    ['047920', 'HLB제약'],
    ['243840', '신흥에스이씨'],
    ['217270', '넵튠'],
    ['056080', '유진로봇'],
    ['018290', '브이티'],
    ['108490', '로보티즈'],
    ['059090', '미코'],
    ['348340', '뉴로메카'],
    ['041830', '인바디'],
    ['101360', '에코앤드림'],
    ['013030', '하이록코리아'],
    ['038500', '삼표시멘트'],
    ['307750', '국전약품'],
    ['049950', '미래컴퍼니'],
    ['092040', '아미코젠'],
    ['382840', '원준'],
    ['094360', '칩스앤미디어'],
    ['290670', '대보마그네틱'],
    ['029960', '코엔텍'],
    ['058820', 'CMG제약'],
    ['314930', '바이오다인'],
    ['047310', '파워로직스'],
    ['297090', '씨에스베어링'],
    ['104830', '원익머트리얼즈'],
    ['282880', '코윈테크'],
    ['077360', '덕산하이메탈'],
    ['214610', '미코바이오메드'],
    ['297890', 'HB솔루션'],
    ['122640', '예스티'],
    ['054210', '이랜텍'],
    ['285490', '노바텍'],
    ['025770', '한국정보통신'],
    ['089010', '켐트로닉스'],
    ['053030', '바이넥스'],
    ['030520', '한글과컴퓨터'],
    ['060370', 'KT서브마린'],
    ['126340', '비나텍'],
    ['254490', '미래반도체'],
    ['235980', '메드팩토'],
    ['102940', '코오롱생명과학'],
    ['101730', '위메이드맥스'],
    ['093320', '케이아이엔엑스'],
    ['251970', '펌텍코리아'],
    ['005160', '동국산업'],
    ['051500', 'CJ프레시웨이'],
    ['005090', 'SGC에너지'],
    ['232140', '와이아이케이'],
    ['000210', 'DL'],
    ['053210', '스카이라이프'],
]
print(len(stock_codes2))

def check_duplicate_stock_codes(stock_codes2):
    stock_codes_set = set()

    for code, name in stock_codes2:
        if code in stock_codes_set:
            print(f"중복된 종목코드 발견: {code} ({name})")
        else:
            stock_codes_set.add(code)

    if len(stock_codes_set) == len(stock_codes2):
        print("중복된 종목코드가 없습니다.")

# 종목코드 중복 여부 확인
check_duplicate_stock_codes(stock_codes2)
# Out:
# 200
# 중복된 종목코드가 없습니다.

# %%
# 엑셀 파일 읽기
df = pd.read_csv('drive/MyDrive/Colab Notebooks/kosdaq.csv', usecols=[0, 1], dtype={1: str})
df = df[~df.iloc[:, 0].str.contains("스팩")]
df = df.iloc[:, [1, 0]]
df = df.sample(n=500, random_state=42)
# 첫 번째 열과 두 번째 열을 Nx2 리스트로 변환
stock_codes = df.values.tolist()

# 결과 출력
print(stock_codes)
# Out:
# [['068760', '셀트리온제약'], ['317870', '엔바이오니아'], ['037950', '엘컴텍'], ['032190', '다우데이타'], ['200780', '비씨월드제약'], ['023460', 'CNH'], ['208350', '지란지교시큐리티'], ['294630', '서남'], ['166090', '하나머티리얼즈'], ['417840', '저스템'], ['016790', '카나리아바이오'], ['040350', '큐로컴'], ['310200', '애니플러스'], ['080010', '이상네트웍스'], ['066910', '손오공'], ['317240', 'TS트릴리온'], ['228760', '지노믹트리'], ['200470', '에이팩트'], ['424980', '마이크로투나노'], ['318160', '셀바이오휴먼텍'], ['006140', '피제이전자'], ['204020', '그리티'], ['252500', '세화피앤씨'], ['196300', '애니젠'], ['239610', '에이치엘사이언스'], ['115960', '연우'], ['078860', '아이오케이'], ['253590', '네오셈'], ['187790', '나노'], ['142760', '비엘'], ['425420', '티에프이'], ['032820', '우리기술'], ['192440', '슈피겐코리아'], ['064290', '인텍플러스'], ['054050', '농우바이오'], ['038060', '루멘스'], ['104200', 'NHN벅스'], ['900280', '골든센츄리'], ['067160', '아프리카TV'], ['434480', '모니터랩'], ['068330', '일신바이오'], ['309960', 'LB인베스트먼트'], ['206640', '바디텍메드'], ['190650', '코리아에셋투자증권'], ['102120', '어보브반도체'], ['211270', 'AP위성'], ['131220', '대한과학'], ['174900', '앱클론'], ['033340', '좋은사람들'], ['044480', '블레이드 Ent'], ['252990', '샘씨엔에스'], ['036120', 'SCI평가정보'], ['136480', '하림'], ['053300', '한국정보인증'], ['093520', '매커스'], ['016250', 'SGC이테크건설'], ['036620', '감성코퍼레이션'], ['382480', '지아이텍'], ['085670', '뉴프렉스'], ['293490', '카카오게임즈'], ['079970', '투비소프트'], ['365270', '큐라클'], ['174880', '장원테크'], ['159580', '제로투세븐'], ['053950', '경남제약'], ['053060', '세동'], ['290740', '액트로'], ['217190', '제너셈'], ['042520', '한스바이오메드'], ['074600', '원익QnC'], ['006620', '동구바이오제약'], ['214260', '라파스'], ['111710', '남화산업'], ['299030', '하나기술'], ['298380', '에이비엘바이오'], ['038110', '에코플라스틱'], ['053580', '웹케시'], ['083650', '비에이치아이'], ['033560', '블루콤'], ['290380', '대유'], ['069080', '웹젠'], ['021320', 'KCC건설'], ['089970', '에이피티씨'], ['054040', '한국컴퓨터'], ['109740', '디에스케이'], ['347770', '핌스'], ['294090', '이오플로우'], ['109080', '옵티시스'], ['134060', '이퓨쳐'], ['198940', '한주라이트메탈'], ['025900', '동화기업'], ['099750', '이지케어텍'], ['072020', '중앙백신'], ['317830', '에스피시스템스'], ['023790', '동일철강'], ['052300', '초록뱀컴퍼니'], ['066980', '이엔코퍼레이션'], ['368770', '파이버프로'], ['399720', '가온칩스'], ['217820', '원익피앤이'], ['073110', '엘엠에스'], ['220260', '켐트로스'], ['079940', '가비아'], ['058530', '파나케이아'], ['169330', '엠브레인'], ['097780', '에스맥'], ['065680', '우주일렉트로'], ['038010', '제일테크노스'], ['179290', '엠아이텍'], ['298870', '우리벤처파트너스'], ['121800', '비덴트'], ['305090', '마이크로디지탈'], ['356890', '싸이버원'], ['950220', '네오이뮨텍'], ['319400', '현대무벡스'], ['162300', '신스틸'], ['419540', '비스토스'], ['037030', '파워넷'], ['335870', '윙스풋'], ['441270', '파인엠텍'], ['014970', '삼륭물산'], ['090470', '제이스텍'], ['053030', '바이넥스'], ['079000', '와토스코리아'], ['161580', '필옵틱스'], ['012860', '모베이스전자'], ['095700', '제넥신'], ['378800', '샤페론'], ['200350', '래몽래인'], ['101360', '에코앤드림'], ['376180', '피코그램'], ['033310', '엠투엔'], ['093380', '풍강'], ['243070', '휴온스'], ['073570', '리튬포어스'], ['277410', '인산가'], ['405000', '플라즈맵'], ['122640', '예스티'], ['028300', 'HLB'], ['010240', '흥국'], ['007820', '에스엠코어'], ['057680', '티사이언티픽'], ['043650', '국순당'], ['039020', '이건홀딩스'], ['032580', '피델릭스'], ['053980', '오상자이엘'], ['054670', '대한뉴팜'], ['215000', '골프존'], ['060590', '씨티씨바이오'], ['012790', '신일제약'], ['038460', '바이오스마트'], ['075970', '동국알앤에스'], ['224110', '에이텍모빌리티'], ['064550', '바이오니아'], ['189980', '흥국에프엔비'], ['226950', '올릭스'], ['312610', '에이에프더블류'], ['058470', '리노공업'], ['187660', '에이디엠코리아'], ['163730', '핑거'], ['243840', '신흥에스이씨'], ['035200', '프럼파스트'], ['054300', '팬스타엔터프라이즈'], ['066130', '하츠'], ['244460', '올리패스'], ['037440', '희림'], ['151910', 'SBW생명과학'], ['023770', '플레이위드'], ['027580', '상보'], ['090410', '덕신하우징'], ['079810', '디이엔티'], ['950190', '미투젠'], ['270870', '뉴트리'], ['408900', '스튜디오미르'], ['045510', '정원엔시스'], ['060900', 'DGP'], ['230360', '에코마케팅'], ['047770', '코데즈컴바인'], ['124500', '아이티센'], ['073540', '에프알텍'], ['100030', '인지소프트'], ['088910', '동우팜투테이블'], ['211050', '인카금융서비스'], ['125210', '아모그린텍'], ['024950', '삼천리자전거'], ['067770', '세진티에스'], ['357230', '에이치피오'], ['024910', '경창산업'], ['227610', '아우딘퓨쳐스'], ['043100', '솔고바이오'], ['306040', '에스제이그룹'], ['393890', '더블유씨피'], ['038340', 'MIT'], ['019210', '와이지 ...

# %%
train_result = []
stock_codes += stock_codes2[:90]
print(len)
for i, ticker in enumerate(stock_codes):
    code, name = ticker[0], ticker[1]
    print(f"{i+1}번째 종목 {name} 추출중...   ")

    try:
        cnt = 0
        data = preprocess_data(fdr.DataReader(code, '2013-09-01', '2020-02-15'))  # 각 종목의 데이터 가져오기
        images = convert_image(data, 3000, day_num, 0.07)
        train_result += images
        cnt += len(images)
        data = preprocess_data(fdr.DataReader(code, '2020-03-01', '2022-12-31'))  # 각 종목의 데이터 가져오기
        images = convert_image(data, 1000, day_num, 0.07)
        train_result += images
        cnt += len(images)
        print(f"{cnt}개 추출완료. 누적{len(train_result)}개")
    except IndexError:
        print(f"{name}에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.")
        continue
# Out:
# <built-in function len>
# 1번째 종목 셀트리온제약 추출중...
# 셀트리온제약에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 2번째 종목 엔바이오니아 추출중...
# 17개 추출완료. 누적56개
# 3번째 종목 엘컴텍 추출중...
# 43개 추출완료. 누적99개
# 4번째 종목 다우데이타 추출중...
# 다우데이타에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 5번째 종목 비씨월드제약 추출중...
# 49개 추출완료. 누적184개
# 6번째 종목 CNH 추출중...
# 32개 추출완료. 누적216개
# 7번째 종목 지란지교시큐리티 추출중...
# 32개 추출완료. 누적248개
# 8번째 종목 서남 추출중...
# 11개 추출완료. 누적259개
# 9번째 종목 하나머티리얼즈 추출중...
# 하나머티리얼즈에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 10번째 종목 저스템 추출중...
# 0개 추출완료. 누적304개
# 11번째 종목 카나리아바이오 추출중...
# 24개 추출완료. 누적328개
# 12번째 종목 큐로컴 추출중...
# 큐로컴에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 13번째 종목 애니플러스 추출중...
# 15개 추출완료. 누적433개
# 14번째 종목 이상네트웍스 추출중...
# 42개 추출완료. 누적475개
# 15번째 종목 손오공 추출중...
# 60개 추출완료. 누적535개
# 16번째 종목 TS트릴리온 추출중...
# 9개 추출완료. 누적544개
# 17번째 종목 지노믹트리 추출중...
# 46개 추출완료. 누적590개
# 18번째 종목 에이팩트 추출중...
# 76개 추출완료. 누적666개
# 19번째 종목 마이크로투나노 추출중...
# 0개 추출완료. 누적666개
# 20번째 종목 셀바이오휴먼텍 추출중...
# 0개 추출완료. 누적666개
# 21번째 종목 피제이전자 추출중...
# 32개 추출완료. 누적698개
# 22번째 종목 그리티 추출중...
# 22개 추출완료. 누적720개
# 23번째 종목 세화피앤씨 추출중...
# 세화피앤씨에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 24번째 종목 애니젠 추출중...
# 61개 추출완료. 누적804개
# 25번째 종목 에이치엘사이언스 추출중...
# 39개 추출완료. 누적843개
# 26번째 종목 연우 추출중...
# 55개 추출완료. 누적898개
# 27번째 종목 아이오케이 추출중...
# 65개 추출완료. 누적963개
# 28번째 종목 네오셈 추출중...
# 14개 추출완료. 누적977개
# 29번째 종목 나노 추출중...
# 66개 추출완료. 누적1043개
# 30번째 종목 비엘 추출중...
# 98개 추출완료. 누적1141개
# 31번째 종목 티에프이 추출중...
# 0개 추출완료. 누적1141개
# 32번째 종목 우리기술 추출중...
# 73개 추출완료. 누적1214개
# 33번째 종목 슈피겐코리아 추출중...
# 슈피겐코리아에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 34번째 종목 인텍플러스 추출중...
# 인텍플러스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 35번째 종목 농우바이오 추출중...
# 24개 추출완료. 누적1277개
# 36번째 종목 루멘스 추출중...
# 72개 추출완료. 누적1349개
# 37번째 종목 NHN벅스 추출중...
# 68개 추출완료. 누적1417개
# 38번째 종목 골든센츄리 추출중...
# 42개 추출완료. 누적1459개
# 39번째 종목 아프리카TV 추출중...
# 113개 추출완료. 누적1572개
# 40번째 종목 모니터랩 추출중...
# 0개 추출완료. 누적1572개
# 41번째 종목 일신바이오 추출중...
# 58개 추출완료. 누적1630개
# 42번째 종목 LB인베스트먼트 추출중...
# 0개 추출완료. 누적1630개
# 43번째 종목 바디텍메드 추출중...
# 바디텍메드에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 44번째 종목 코리아에셋투자증권 추출중...
# 13개 추출완료. 누적1677개
# 45번째 종목 어보브반도체 추출중...
# 91개 추출완료. 누적1768개
# 46번째 종목 AP위성 추출중...
# 25개 추출완료. 누적1793개
# 47번째 종목 대한과학 추출중...
# 43개 추출완료. 누적1836개
# 48번째 종목 앱클론 추출중...
# 앱클론에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 49번째 종목 좋은사람들 추출중...
# 76개 추출완료. 누적1912개
# 50번째 종목 블레이드 Ent 추출중...
# 92개 추출완료. 누적2004개
# 51번째 종목 샘씨엔에스 추출중...
# 8개 추출완료. 누적2012개
# 52번째 종목 SCI평가정보 추출중...
# 43개 추출완료. 누적2055개
# 53번째 종목 하림 추출중...
# 32개 추출완료. 누적2087개
# 54번째 종목 한국정보인증 추출중...
# 한국정보인증에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 55번째 종목 매커스 추출중...
# 52개 추출완료. 누적2139개
# 56번째 종목 SGC이테크건설 추출중...
# 71개 추출완료. 누적2210개
# 57번째 종목 감성코퍼레이션 추출중...
# 69개 추출완료. 누적2279개
# 58번째 종목 지아이텍 추출중...
# 9개 추출완료. 누적2288개
# 59번째 종목 뉴프렉스 추출중...
# 107개 추출완료. 누적2395개
# 60번째 종목 카카오게임즈 추출중...
# 29개 추출완료. 누적2424개
# 61번째 종목 투비소프트 추출중...
# 투비소프트에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 62번째 종목 큐라클 추출중...
# 큐라클에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 63번째 종목 장원테크 추출중...
# 장원테크에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 64번째 종목 제로투세븐 추출중...
# 69개 추출완료. 누적2596개
# 65번째 종목 경남제약 추출중...
# 경남제약에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 66번째 종목 세동 추출중...
# 45개 추출완료. 누적2641개
# 67번째 종목 액트로 추출중...
# 액트로에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 68번째 종목 제너셈 추출중...
# 제너셈에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 69번째 종목 한스바이오메드 추출중...
# 한스바이오메드에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 70번째 종목 원익QnC 추출중...
# 90개 추출완료. 누적2731개
# 71번째 종목 동구바이오제약 추출중...
# 27개 추출완료. 누적2758개
# 72번째 종목 라파스 추출중...
# 42개 추출완료. 누적2800개
# 73번째 종목 남화산업 추출중...
# 15개 추출완료. 누적2815개
# 74번째 종목 하나기술 추출중...
# 하나기술에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 75번째 종목 에이비엘바이오 추출중...
# 63개 추출완료. 누적2878개
# 76번째 종목 에코플라스틱 추출중...
# 52개 추출완료. 누적2930개
# 77번째 종목 웹케시 추출중...
# 웹케시에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 78번째 종목 비에이치아이 추출중...
# 95개 추출완료. 누적3039개
# 79번째 종목 블루콤 추출중...
# 70개 추출완료. 누적3109개
# 80번째 종목 대유 추출중...
# 대유에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 81번째 종목 웹젠 추출중...
# 100개 추출완료. 누적3222개
# 82번째 종목 KCC건설 추출중...
# 53개 추출완료. 누적3275개
# 83번째 종목 에이피티씨 추출중...
# 42개 추출완료. 누적3317개
# 84번째 종목 한국컴퓨터 추출중...
# 34개 추출완료. 누적3351개
# 85번째 종목 디에스케이 추출중...
# 88개 추출완료. 누적3439개
# 86번째 종목 핌스 추출중...
# 29개 추출완료. 누적3468개
# 87번째 종목 이오플로우 추출중...
# 이오플로우에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 88번째 종목 옵티시스 추출중...
# 56개 추출완료. 누적3524개
# 89번째 종목 이퓨쳐 추출중...
# 56개 추출완료. 누적3580개
# 90번째 종목 한주라이트메탈 추출중...
# 0개 추출완료. 누적3580개
# 91번째 종목 동화기업 추출중...
# 94개 추출완료. 누적3674개
# 92번째 종목 이지케어텍 추출중...
# 35개 추출완료. 누적3709개
# 93번째 종목 중앙백신 추출중...
# 65개 추출완료. 누적3774개
# 94번째 종목 에스피시스템스 추출중...
# 25개 추출완료. 누적3799개
# 95번째 종목 동일철강 추출중...
# 38개 추출완료. 누적3837개
# 96번째 종목 초록뱀컴퍼니 추출중...
# 61개 추출완료. 누적3898개
# 97번째 종목 이엔코퍼레이션 추출중...
# 86개 추출완료. 누적3984개
# 98번째 종목 파이버프로 추출중...
# 13개 추출완료. 누적3997개
# 99번째 종목 가온칩스 추출중...
# 4개 추출완료. 누적4001개
# 100번째 종목 원익피앤이 추출중...
# 원익피앤이에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 101번째 종목 엘엠에스 추출중...
# 69개 추출완료. 누적4070개
# 102번째 종목 켐트로스 추출중...
# 켐트로스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 103번째 종목 가비아 추출중...
# 가비아에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 104번째 종목 파나케이아 추출중...
# 98개 추출완료. 누적4195개
# 105번째 종목 엠브레인 추출중...
# 3개 추출완료. 누적4198개
# 106번째 종목 에스맥 추출중...
# 109개 추출완료. 누적4307개
# 107번째 종목 우주일렉트로 추출중...
# 우주일렉트로에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 108번째 종목 제일테크노스 추출중...
# 53개 추출완료. 누적4360개
# 109번째 종목 엠아이텍 추출중...
# 24개 추출완료. 누적4384개
# 110번째 종목 우리벤처파트너스 추출중...
# 4개 추출완료. 누적4388개
# 111번째 종목 비덴트 추출중...
# 136개 추출완료. 누적4524개
# 112번째 종목 마이크로디지탈 추출중...
# 37개 추출완료. 누적4561개
# 113번째 종목 싸이버원 추출중...
# 9개 추출완료. 누적4570개
# 114번째 종목 네오이뮨텍 추출중...
# 25개 추출완료. 누적4595개
# 115번째 종목 현대무벡스 추출중...
# 5개 추출완료. 누적4600개
# 116번째 종목 신스틸 추출중...
# 0개 추출완료. 누적4600개
# 117번째 종목 비스토스 추출중...
# 0개 추출완료. 누적4600개
# 118번째 종목 파워넷 추출중...
# 19개 추출완료. 누적4619개
# 119번째 종목 윙스풋 추출중...
# 5개 추출완료. 누적4624개
# 120번째 종목 파인엠텍 추출중...
# 0개 추출완료. 누적4624개
# 121번째 종목 삼륭물산 추출중...
# 48개 추출완료. 누적4672개
# 122번째 종목 제이스텍 추출중...
# 88개 추출완료. 누적4760개
# 123번째 종목 바이넥스 추출중...
# 바이넥스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 124번째 종목 와토스코리아 추출중...
# 20개 추출완료. 누적4882개
# 125번째 종목 필옵틱스 추출중...
# 필옵틱스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 126번째 종목 모베이스전자 추출중...
# 35개 추출완료. 누적4917개
# 127번째 종목 제넥신 추출중...
# 122개 추출완료. 누적5039개
# 128번째 종목 샤페론 추출중...
# 0개 추출완료. 누적5039개
# 129번째 종목 래몽래인 추출중...
# 20개 추출완료. 누적5059개
# 130번째 종목 에코앤드림 추출중...
# 49개 추출완료. 누적5108개
# 131번째 종목 피코그램 추출중...
# 13개 추출완료. 누적5121개
# 132번째 종목 엠투엔 추출중...
# 103개 추출완료. 누적5224개
# 133번째 종목 풍강 추출중...
# 30개 추출완료. 누적5254개
# 134번째 종목 휴온스 추출중...
# 47개 추출완료. 누적5301개
# 135번째 종목 리튬포어스 추출중...
# 95개 추출완료. 누적5396개
# 136번째 종목 인산가 추출중...
# 17개 추출완료. 누적5413개
# 137번째 종목 플라즈맵 추출중...
# 0개 추출완료. 누적5413개
# 138번째 종목 예스티 추출중...
# 예스티에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 139번째 종목 HLB 추출중...
# HLB에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 140번째 종목 흥국 추출중...
# 38개 추출완료. 누적5533개
# 141번째 종목 에스엠코어 추출중...
# 73개 추출완료. 누적5606개
# 142번째 종목 티사이언티픽 추출중...
# 티사이언티픽에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 143번째 종목 국순당 추출중...
# 40개 추출완료. 누적5712개
# 144번째 종목 이건홀딩스 추출중...
# 이건홀딩스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 145번째 종목 피델릭스 추출중...
# 피델릭스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 146번째 종목 오상자이엘 추출중...
# 72개 추출완료. 누적5805개
# 147번째 종목 대한뉴팜 추출중...
# 대한뉴팜에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 148번째 종목 골프존 추출중...
# 골프존에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 149번째 종목 씨티씨바이오 추출중...
# 101개 추출완료. 누적5906개
# 150번째 종목 신일제약 추출중...
# 74개 추출완료. 누적5980개
# 151번째 종목 바이오스마트 추출중...
# 76개 추출완료. 누적6056개
# 152번째 종목 동국알앤에스 추출중...
# 동국알앤에스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 153번째 종목 에이텍모빌리티 추출중...
# 에이텍모빌리티에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 154번째 종목 바이오니아 추출중...
# 바이오니아에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 155번째 종목 흥국에프엔비 추출중...
# 흥국에프엔비에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 156번째 종목 올릭스 추출중...
# 올릭스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 157번째 종목 에이에프더블류 추출중...
# 23개 추출완료. 누적6102개
# 158번째 종목 리노공업 추출중...
# 39개 추출완료. 누적6141개
# 159번째 종목 에이디엠코리아 추출중...
# 에이디엠코리아에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 160번째 종목 핑거 추출중...
# 18개 추출완료. 누적6159개
# 161번째 종목 신흥에스이씨 추출중...
# 신흥에스이씨에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 162번째 종목 프럼파스트 추출중...
# 73개 추출완료. 누적6260개
# 163번째 종목 팬스타엔터프라이즈 추출중...
# 80개 추출완료. 누적6340개
# 164번째 종목 하츠 추출중...
# 93개 추출완료. 누적6433개
# 165번째 종목 올리패스 추출중...
# 27개 추출완료. 누적6460개
# 166번째 종목 희림 추출중...
# 29개 추출완료. 누적6489개
# 167번째 종목 SBW생명과학 추출중...
# 98개 추출완료. 누적6587개
# 168번째 종목 플레이위드 추출중...
# 81개 추출완료. 누적6668개
# 169번째 종목 상보 추출중...
# 60개 추출완료. 누적6728개
# 170번째 종목 덕신하우징 추출중...
# 54개 추출완료. 누적6782개
# 171번째 종목 디이엔티 추출중...
# 디이엔티에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 172번째 종목 미투젠 추출중...
# 6개 추출완료. 누적6842개
# 173번째 종목 뉴트리 추출중...
# 뉴트리에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 174번째 종목 스튜디오미르 추출중...
# 0개 추출완료. 누적6842개
# 175번째 종목 정원엔시스 추출중...
# 24개 추출완료. 누적6866개
# 176번째 종목 DGP 추출중...
# DGP에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 177번째 종목 에코마케팅 추출중...
# 64개 추출완료. 누적6978개
# 178번째 종목 코데즈컴바인 추출중...
# 51개 추출완료. 누적7029개
# 179번째 종목 아이티센 추출중...
# 67개 추출완료. 누적7096개
# 180번째 종목 에프알텍 추출중...
# 62개 추출완료. 누적7158개
# 181번째 종목 인지소프트 추출중...
# 56개 추출완료. 누적7214개
# 182번째 종목 동우팜투테이블 추출중...
# 25개 추출완료. 누적7239개
# 183번째 종목 인카금융서비스 추출중...
# 5개 추출완료. 누적7244개
# 184번째 종목 아모그린텍 추출중...
# 아모그린텍에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 185번째 종목 삼천리자전거 추출중...
# 삼천리자전거에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 186번째 종목 세진티에스 추출중...
# 38개 추출완료. 누적7305개
# 187번째 종목 에이치피오 추출중...
# 7개 추출완료. 누적7312개
# 188번째 종목 경창산업 추출중...
# 40개 추출완료. 누적7352개
# 189번째 종목 아우딘퓨쳐스 추출중...
# 아우딘퓨쳐스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 190번째 종목 솔고바이오 추출중...
# 56개 추출완료. 누적7408개
# 191번째 종목 에스제이그룹 추출중...
# 22개 추출완료. 누적7430개
# 192번째 종목 더블유씨피 추출중...
# 0개 추출완료. 누적7430개
# 193번째 종목 MIT 추출중...
# 77개 추출완료. 누적7507개
# 194번째 종목 와이지-원 추출중...
# 65개 추출완료. 누적7572개
# 195번째 종목 창해에탄올 추출중...
# 창해에탄올에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 196번째 종목 엔텔스 추출중...
# 엔텔스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 197번째 종목 코아시아씨엠 추출중...
# 113개 추출완료. 누적7685개
# 198번째 종목 와이아이케이 추출중...
# 57개 추출완료. 누적7742개
# 199번째 종목 시큐센 추출중...
# 4개 추출완료. 누적7746개
# 200번째 종목 아스트 추출중...
# 아스트에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 201번째 종목 EDGC 추출중...
# EDGC에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 202번째 종목 브이티 추출중...
# 브이티에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 203번째 종목 드래곤플라이 추출중...
# 94개 추출완료. 누적7849개
# 204번째 종목 KH바텍 추출중...
# 127개 추출완료. 누적7976개
# 205번째 종목 우진비앤지 추출중...
# 60개 추출완료. 누적8036개
# 206번째 종목 윌링스 추출중...
# 28개 추출완료. 누적8064개
# 207번째 종목 육일씨엔에쓰 추출중...
# 육일씨엔에쓰에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 208번째 종목 클리오 추출중...
# 66개 추출완료. 누적8130개
# 209번째 종목 메가엠디 추출중...
# 31개 추출완료. 누적8161개
# 210번째 종목 ISC 추출중...
# 114개 추출완료. 누적8275개
# 211번째 종목 한국파마 추출중...
# 22개 추출완료. 누적8297개
# 212번째 종목 모비릭스 추출중...
# 14개 추출완료. 누적8311개
# 213번째 종목 아이윈 추출중...
# 37개 추출완료. 누적8348개
# 214번째 종목 성광벤드 추출중...
# 58개 추출완료. 누적8406개
# 215번째 종목 아시아종묘 추출중...
# 34개 추출완료. 누적8440개
# 216번째 종목 알티캐스트 추출중...
# 34개 추출완료. 누적8474개
# 217번째 종목 팅크웨어 추출중...
# 61개 추출완료. 누적8535개
# 218번째 종목 큐로홀딩스 추출중...
# 47개 추출완료. 누적8582개
# 219번째 종목 인성정보 추출중...
# 78개 추출완료. 누적8660개
# 220번째 종목 중앙에너비스 추출중...
# 20개 추출완료. 누적8680개
# 221번째 종목 본느 추출중...
# 27개 추출완료. 누적8707개
# 222번째 종목 케이프 추출중...
# 55개 추출완료. 누적8762개
# 223번째 종목 이노와이어리스 추출중...
# 77개 추출완료. 누적8839개
# 224번째 종목 케이엠제약 추출중...
# 20개 추출완료. 누적8859개
# 225번째 종목 제이엔케이히터 추출중...
# 61개 추출완료. 누적8920개
# 226번째 종목 플레이디 추출중...
# 17개 추출완료. 누적8937개
# 227번째 종목 엔젯 추출중...
# 0개 추출완료. 누적8937개
# 228번째 종목 오에스피 추출중...
# 0개 추출완료. 누적8937개
# 229번째 종목 삼천당제약 추출중...
# 116개 추출완료. 누적9053개
# 230번째 종목 크루셜텍 추출중...
# 88개 추출완료. 누적9141개
# 231번째 종목 SG&G 추출중...
# 44개 추출완료. 누적9185개
# 232번째 종목 레몬 추출중...
# 21개 추출완료. 누적9206개
# 233번째 종목 꿈비 추출중...
# 0개 추출완료. 누적9206개
# 234번째 종목 오이솔루션 추출중...
# 오이솔루션에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 235번째 종목 아이톡시 추출중...
# 83개 추출완료. 누적9289개
# 236번째 종목 지에스이 추출중...
# 32개 추출완료. 누적9321개
# 237번째 종목 서울바이오시스 추출중...
# 18개 추출완료. 누적9339개
# 238번째 종목 포바이포 추출중...
# 포바이포에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 239번째 종목 우리산업홀딩스 추출중...
# 우리산업홀딩스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 240번째 종목 유바이오로직스 추출중...
# 유바이오로직스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 241번째 종목 쎄노텍 추출중...
# 32개 추출완료. 누적9371개
# 242번째 종목 메쎄이상 추출중...
# 0개 추출완료. 누적9371개
# 243번째 종목 베스파 추출중...
# 37개 추출완료. 누적9408개
# 244번째 종목 피에이치씨 추출중...
# 피에이치씨에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 245번째 종목 이글루 추출중...
# 19개 추출완료. 누적9493개
# 246번째 종목 비케이홀딩스 추출중...
# 57개 추출완료. 누적9550개
# 247번째 종목 케어젠 추출중...
# 42개 추출완료. 누적9592개
# 248번째 종목 시너지이노베이션 추출중...
# 72개 추출완료. 누적9664개
# 249번째 종목 밸로프 추출중...
# 3개 추출완료. 누적9667개
# 250번째 종목 코렌텍 추출중...
# 코렌텍에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 251번째 종목 제주맥주 추출중...
# 제주맥주에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 252번째 종목 파인테크닉스 추출중...
# 파인테크닉스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 253번째 종목 한국큐빅 추출중...
# 45개 추출완료. 누적9800개
# 254번째 종목 바이옵트로 추출중...
# 19개 추출완료. 누적9819개
# 255번째 종목 미디어젠 추출중...
# 21개 추출완료. 누적9840개
# 256번째 종목 휴맥스홀딩스 추출중...
# 14개 추출완료. 누적9854개
# 257번째 종목 신도기연 추출중...
# 14개 추출완료. 누적9868개
# 258번째 종목 와이엠씨 추출중...
# 와이엠씨에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 259번째 종목 텔레필드 추출중...
# 71개 추출완료. 누적10024개
# 260번째 종목 고영 추출중...
# 51개 추출완료. 누적10075개
# 261번째 종목 티피씨글로벌 추출중...
# 32개 추출완료. 누적10107개
# 262번째 종목 아진엑스텍 추출중...
# 85개 추출완료. 누적10192개
# 263번째 종목 이엠앤아이 추출중...
# 65개 추출완료. 누적10257개
# 264번째 종목 윙입푸드 추출중...
# 18개 추출완료. 누적10275개
# 265번째 종목 아이윈플러스 추출중...
# 아이윈플러스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 266번째 종목 유성티엔에스 추출중...
# 64개 추출완료. 누적10339개
# 267번째 종목 GRT 추출중...
# 16개 추출완료. 누적10355개
# 268번째 종목 아이진 추출중...
# 155개 추출완료. 누적10510개
# 269번째 종목 오션브릿지 추출중...
# 오션브릿지에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 270번째 종목 듀오백 추출중...
# 42개 추출완료. 누적10552개
# 271번째 종목 핸디소프트 추출중...
# 30개 추출완료. 누적10582개
# 272번째 종목 수성샐바시온 추출중...
# 61개 추출완료. 누적10643개
# 273번째 종목 DSEN 추출중...
# 48개 추출완료. 누적10691개
# 274번째 종목 케이엔솔 추출중...
# 12개 추출완료. 누적10703개
# 275번째 종목 코아시아 추출중...
# 29개 추출완료. 누적10732개
# 276번째 종목 HB테크놀러지 추출중...
# 112개 추출완료. 누적10844개
# 277번째 종목 오비고 추출중...
# 8개 추출완료. 누적10852개
# 278번째 종목 디딤이앤에프 추출중...
# 26개 추출완료. 누적10878개
# 279번째 종목 캠시스 추출중...
# 63개 추출완료. 누적10941개
# 280번째 종목 나인테크 추출중...
# 나인테크에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 281번째 종목 코디 추출중...
# 58개 추출완료. 누적10999개
# 282번째 종목 에이디테크놀로지 추출중...
# 에이디테크놀로지에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 283번째 종목 피에이치에이 추출중...
# 52개 추출완료. 누적11051개
# 284번째 종목 오로스테크놀로지 추출중...
# 15개 추출완료. 누적11066개
# 285번째 종목 메타바이오메드 추출중...
# 55개 추출완료. 누적11121개
# 286번째 종목 제이아이테크 추출중...
# 0개 추출완료. 누적11121개
# 287번째 종목 딜리 추출중...
# 딜리에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 288번째 종목 이씨에스 추출중...
# 17개 추출완료. 누적11138개
# 289번째 종목 유니테스트 추출중...
# 유니테스트에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 290번째 종목 베뉴지 추출중...
# 25개 추출완료. 누적11259개
# 291번째 종목 큐에스아이 추출중...
# 53개 추출완료. 누적11312개
# 292번째 종목 코리아에프티 추출중...
# 51개 추출완료. 누적11363개
# 293번째 종목 와이솔 추출중...
# 와이솔에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 294번째 종목 심텍 추출중...
# 심텍에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 295번째 종목 엔에프씨 추출중...
# 11개 추출완료. 누적11422개
# 296번째 종목 이큐셀 추출중...
# 43개 추출완료. 누적11465개
# 297번째 종목 신테카바이오 추출중...
# 40개 추출완료. 누적11505개
# 298번째 종목 CMG제약 추출중...
# 89개 추출완료. 누적11594개
# 299번째 종목 셀트리온헬스케어 추출중...
# 셀트리온헬스케어에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 300번째 종목 조광ILI 추출중...
# 70개 추출완료. 누적11664개
# 301번째 종목 에스유홀딩스 추출중...
# 에스유홀딩스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 302번째 종목 에이텍 추출중...
# 에이텍에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 303번째 종목 디와이씨 추출중...
# 18개 추출완료. 누적11830개
# 304번째 종목 잉크테크 추출중...
# 58개 추출완료. 누적11888개
# 305번째 종목 태양 추출중...
# 14개 추출완료. 누적11902개
# 306번째 종목 테스 추출중...
# 111개 추출완료. 누적12013개
# 307번째 종목 보광산업 추출중...
# 50개 추출완료. 누적12063개
# 308번째 종목 세명전기 추출중...
# 62개 추출완료. 누적12125개
# 309번째 종목 엑셈 추출중...
# 엑셈에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 310번째 종목 진로발효 추출중...
# 7개 추출완료. 누적12132개
# 311번째 종목 압타바이오 추출중...
# 59개 추출완료. 누적12191개
# 312번째 종목 세경하이테크 추출중...
# 27개 추출완료. 누적12218개
# 313번째 종목 스카이문스테크놀로지 추출중...
# 34개 추출완료. 누적12252개
# 314번째 종목 테고사이언스 추출중...
# 94개 추출완료. 누적12346개
# 315번째 종목 한국비엔씨 추출중...
# 57개 추출완료. 누적12403개
# 316번째 종목 이스트아시아홀딩스 추출중...
# 46개 추출완료. 누적12449개
# 317번째 종목 로보로보 추출중...
# 36개 추출완료. 누적12485개
# 318번째 종목 케이엠 추출중...
# 42개 추출완료. 누적12527개
# 319번째 종목 세림B&G 추출중...
# 8개 추출완료. 누적12535개
# 320번째 종목 엔터파트너즈 추출중...
# 73개 추출완료. 누적12608개
# 321번째 종목 정상제이엘에스 추출중...
# 5개 추출완료. 누적12613개
# 322번째 종목 디지틀조선 추출중...
# 61개 추출완료. 누적12674개
# 323번째 종목 코스텍시스 추출중...
# 0개 추출완료. 누적12674개
# 324번째 종목 오텍 추출중...
# 59개 추출완료. 누적12733개
# 325번째 종목 KCI 추출중...
# 74개 추출완료. 누적12807개
# 326번째 종목 대림제지 추출중...
# 54개 추출완료. 누적12861개
# 327번째 종목 씨아이에스 추출중...
# 52개 추출완료. 누적12913개
# 328번째 종목 제넨바이오 추출중...
# 134개 추출완료. 누적13047개
# 329번째 종목 알체라 추출중...
# 24개 추출완료. 누적13071개
# 330번째 종목 디지털대성 추출중...
# 29개 추출완료. 누적13100개
# 331번째 종목 대동기어 추출중...
# 14개 추출완료. 누적13114개
# 332번째 종목 세종메디칼 추출중...
# 세종메디칼에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 333번째 종목 티쓰리 추출중...
# 0개 추출완료. 누적13114개
# 334번째 종목 티에스이 추출중...
# 티에스이에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 335번째 종목 인트론바이오 추출중...
# 157개 추출완료. 누적13311개
# 336번째 종목 브이원텍 추출중...
# 52개 추출완료. 누적13363개
# 337번째 종목 케이아이엔엑스 추출중...
# 케이아이엔엑스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 338번째 종목 주성엔지니어링 추출중...
# 85개 추출완료. 누적13448개
# 339번째 종목 제이에스티나 추출중...
# 104개 추출완료. 누적13552개
# 340번째 종목 삼목에스폼 추출중...
# 90개 추출완료. 누적13642개
# 341번째 종목 잉글우드랩 추출중...
# 49개 추출완료. 누적13691개
# 342번째 종목 아이크래프트 추출중...
# 72개 추출완료. 누적13763개
# 343번째 종목 웨이버스 추출중...
# 10개 추출완료. 누적13773개
# 344번째 종목 유니테크노 추출중...
# 유니테크노에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 345번째 종목 KT서브마린 추출중...
# 33개 추출완료. 누적13806개
# 346번째 종목 아이엠 추출중...
# 85개 추출완료. 누적13891개
# 347번째 종목 와이지엔터테인먼트 추출중...
# 와이지엔터테인먼트에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 348번째 종목 씨엔알리서치 추출중...
# 6개 추출완료. 누적13897개
# 349번째 종목 남화토건 추출중...
# 64개 추출완료. 누적13961개
# 350번째 종목 레인보우로보틱스 추출중...
# 15개 추출완료. 누적13976개
# 351번째 종목 파워로직스 추출중...
# 76개 추출완료. 누적14052개
# 352번째 종목 크린앤사이언스 추출중...
# 크린앤사이언스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 353번째 종목 대성하이텍 추출중...
# 0개 추출완료. 누적14098개
# 354번째 종목 한일단조 추출중...
# 36개 추출완료. 누적14134개
# 355번째 종목 피에스케이홀딩스 추출중...
# 73개 추출완료. 누적14207개
# 356번째 종목 중앙디앤엠 추출중...
# 117개 추출완료. 누적14324개
# 357번째 종목 스톤브릿지벤처스 추출중...
# 4개 추출완료. 누적14328개
# 358번째 종목 상상인 추출중...
# 93개 추출완료. 누적14421개
# 359번째 종목 예스24 추출중...
# 49개 추출완료. 누적14470개
# 360번째 종목 엔피케이 추출중...
# 26개 추출완료. 누적14496개
# 361번째 종목 대원 추출중...
# 27개 추출완료. 누적14523개
# 362번째 종목 위닉스 추출중...
# 83개 추출완료. 누적14606개
# 363번째 종목 미코 추출중...
# 미코에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 364번째 종목 인트로메딕 추출중...
# 인트로메딕에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 365번째 종목 팜스빌 추출중...
# 23개 추출완료. 누적14688개
# 366번째 종목 파라다이스 추출중...
# 78개 추출완료. 누적14766개
# 367번째 종목 시공테크 추출중...
# 60개 추출완료. 누적14826개
# 368번째 종목 휴먼엔 추출중...
# 65개 추출완료. 누적14891개
# 369번째 종목 아스타 추출중...
# 29개 추출완료. 누적14920개
# 370번째 종목 이오테크닉스 추출중...
# 이오테크닉스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 371번째 종목 셀리버리 추출중...
# 셀리버리에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 372번째 종목 디아이티 추출중...
# 24개 추출완료. 누적15027개
# 373번째 종목 대주산업 추출중...
# 74개 추출완료. 누적15101개
# 374번째 종목 iMBC 추출중...
# 34개 추출완료. 누적15135개
# 375번째 종목 데이타솔루션 추출중...
# 19개 추출완료. 누적15154개
# 376번째 종목 더블유에스아이 추출중...
# 14개 추출완료. 누적15168개
# 377번째 종목 케이피에프 추출중...
# 케이피에프에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 378번째 종목 한탑 추출중...
# 58개 추출완료. 누적15245개
# 379번째 종목 헬릭스미스 추출중...
# 헬릭스미스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 380번째 종목 테크윙 추출중...
# 테크윙에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 381번째 종목 세토피아 추출중...
# 세토피아에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 382번째 종목 프로텍 추출중...
# 53개 추출완료. 누적15398개
# 383번째 종목 SGA 추출중...
# 46개 추출완료. 누적15444개
# 384번째 종목 화신정공 추출중...
# 19개 추출완료. 누적15463개
# 385번째 종목 코윈테크 추출중...
# 20개 추출완료. 누적15483개
# 386번째 종목 제놀루션 추출중...
# 24개 추출완료. 누적15507개
# 387번째 종목 솔트웨어 추출중...
# 2개 추출완료. 누적15509개
# 388번째 종목 초록뱀미디어 추출중...
# 89개 추출완료. 누적15598개
# 389번째 종목 이즈미디어 추출중...
# 55개 추출완료. 누적15653개
# 390번째 종목 파인텍 추출중...
# 65개 추출완료. 누적15718개
# 391번째 종목 NE능률 추출중...
# 39개 추출완료. 누적15757개
# 392번째 종목 엔투텍 추출중...
# 47개 추출완료. 누적15804개
# 393번째 종목 케이피에스 추출중...
# 47개 추출완료. 누적15851개
# 394번째 종목 효성오앤비 추출중...
# 효성오앤비에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 395번째 종목 강스템바이오텍 추출중...
# 77개 추출완료. 누적15928개
# 396번째 종목 홈센타홀딩스 추출중...
# 50개 추출완료. 누적15978개
# 397번째 종목 에이프릴바이오 추출중...
# 1개 추출완료. 누적15979개
# 398번째 종목 라이트론 추출중...
# 41개 추출완료. 누적16020개
# 399번째 종목 성우하이텍 추출중...
# 48개 추출완료. 누적16068개
# 400번째 종목 아이엘사이언스 추출중...
# 22개 추출완료. 누적16090개
# 401번째 종목 에스씨엠생명과학 추출중...
# 27개 추출완료. 누적16117개
# 402번째 종목 제이엘케이 추출중...
# 17개 추출완료. 누적16134개
# 403번째 종목 삼일기업공사 추출중...
# 40개 추출완료. 누적16174개
# 404번째 종목 천보 추출중...
# 33개 추출완료. 누적16207개
# 405번째 종목 이랜시스 추출중...
# 5개 추출완료. 누적16212개
# 406번째 종목 큐렉소 추출중...
# 82개 추출완료. 누적16294개
# 407번째 종목 진매트릭스 추출중...
# 진매트릭스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 408번째 종목 SM C&C 추출중...
# 74개 추출완료. 누적16433개
# 409번째 종목 한솔인티큐브 추출중...
# 57개 추출완료. 누적16490개
# 410번째 종목 유비쿼스홀딩스 추출중...
# 61개 추출완료. 누적16551개
# 411번째 종목 티앤엘 추출중...
# 16개 추출완료. 누적16567개
# 412번째 종목 퓨런티어 추출중...
# 8개 추출완료. 누적16575개
# 413번째 종목 씨유메디칼 추출중...
# 60개 추출완료. 누적16635개
# 414번째 종목 다원시스 추출중...
# 86개 추출완료. 누적16721개
# 415번째 종목 씨앤씨인터내셔널 추출중...
# 씨앤씨인터내셔널에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 416번째 종목 삼양옵틱스 추출중...
# 5개 추출완료. 누적16726개
# 417번째 종목 코스맥스엔비티 추출중...
# 코스맥스엔비티에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 418번째 종목 JTC 추출중...
# 45개 추출완료. 누적16820개
# 419번째 종목 CNT85 추출중...
# 84개 추출완료. 누적16904개
# 420번째 종목 마녀공장 추출중...
# 0개 추출완료. 누적16904개
# 421번째 종목 덕산하이메탈 추출중...
# 덕산하이메탈에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 422번째 종목 원텍 추출중...
# 6개 추출완료. 누적16910개
# 423번째 종목 에스티아이 추출중...
# 에스티아이에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 424번째 종목 에스트래픽 추출중...
# 49개 추출완료. 누적16959개
# 425번째 종목 유진로봇 추출중...
# 63개 추출완료. 누적17022개
# 426번째 종목 지아이이노베이션 추출중...
# 0개 추출완료. 누적17022개
# 427번째 종목 지니뮤직 추출중...
# 76개 추출완료. 누적17098개
# 428번째 종목 에프앤가이드 추출중...
# 15개 추출완료. 누적17113개
# 429번째 종목 멕아이씨에스 추출중...
# 멕아이씨에스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 430번째 종목 퀀타매트릭스 추출중...
# 11개 추출완료. 누적17153개
# 431번째 종목 휴림네트웍스 추출중...
# 59개 추출완료. 누적17212개
# 432번째 종목 SDN 추출중...
# 60개 추출완료. 누적17272개
# 433번째 종목 포스코DX 추출중...
# 32개 추출완료. 누적17304개
# 434번째 종목 그린플러스 추출중...
# 27개 추출완료. 누적17331개
# 435번째 종목 탑코미디어 추출중...
# 57개 추출완료. 누적17388개
# 436번째 종목 씨큐브 추출중...
# 30개 추출완료. 누적17418개
# 437번째 종목 뷰노 추출중...
# 14개 추출완료. 누적17432개
# 438번째 종목 쇼박스 추출중...
# 81개 추출완료. 누적17513개
# 439번째 종목 엠에프엠코리아 추출중...
# 10개 추출완료. 누적17523개
# 440번째 종목 동운아나텍 추출중...
# 동운아나텍에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 441번째 종목 에스앤디 추출중...
# 4개 추출완료. 누적17527개
# 442번째 종목 아모텍 추출중...
# 아모텍에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 443번째 종목 성창오토텍 추출중...
# 49개 추출완료. 누적17694개
# 444번째 종목 새빗켐 추출중...
# 0개 추출완료. 누적17694개
# 445번째 종목 윈팩 추출중...
# 103개 추출완료. 누적17797개
# 446번째 종목 티이엠씨 추출중...
# 0개 추출완료. 누적17797개
# 447번째 종목 오리엔트정공 추출중...
# 46개 추출완료. 누적17843개
# 448번째 종목 딥노이드 추출중...
# 9개 추출완료. 누적17852개
# 449번째 종목 디앤씨미디어 추출중...
# 42개 추출완료. 누적17894개
# 450번째 종목 알에프텍 추출중...
# 91개 추출완료. 누적17985개
# 451번째 종목 모트렉스 추출중...
# 42개 추출완료. 누적18027개
# 452번째 종목 테라젠이텍스 추출중...
# 96개 추출완료. 누적18123개
# 453번째 종목 이엔에프테크놀로지 추출중...
# 104개 추출완료. 누적18227개
# 454번째 종목 한네트 추출중...
# 41개 추출완료. 누적18268개
# 455번째 종목 경동제약 추출중...
# 25개 추출완료. 누적18293개
# 456번째 종목 슈프리마 추출중...
# 46개 추출완료. 누적18339개
# 457번째 종목 엔시스 추출중...
# 11개 추출완료. 누적18350개
# 458번째 종목 서울반도체 추출중...
# 서울반도체에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 459번째 종목 에이디칩스 추출중...
# 86개 추출완료. 누적18436개
# 460번째 종목 코메론 추출중...
# 30개 추출완료. 누적18466개
# 461번째 종목 AP시스템 추출중...
# 53개 추출완료. 누적18519개
# 462번째 종목 자연과환경 추출중...
# 자연과환경에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 463번째 종목 티씨케이 추출중...
# 98개 추출완료. 누적18617개
# 464번째 종목 유틸렉스 추출중...
# 51개 추출완료. 누적18668개
# 465번째 종목 하이로닉 추출중...
# 76개 추출완료. 누적18744개
# 466번째 종목 카이노스메드 추출중...
# 23개 추출완료. 누적18767개
# 467번째 종목 금강철강 추출중...
# 25개 추출완료. 누적18792개
# 468번째 종목 삼보모터스 추출중...
# 60개 추출완료. 누적18852개
# 469번째 종목 프로이천 추출중...
# 1개 추출완료. 누적18853개
# 470번째 종목 카스 추출중...
# 45개 추출완료. 누적18898개
# 471번째 종목 제이씨케미칼 추출중...
# 59개 추출완료. 누적18957개
# 472번째 종목 아가방컴퍼니 추출중...
# 61개 추출완료. 누적19018개
# 473번째 종목 형지I&C 추출중...
# 55개 추출완료. 누적19073개
# 474번째 종목 디오 추출중...
# 74개 추출완료. 누적19147개
# 475번째 종목 대주전자재료 추출중...
# 122개 추출완료. 누적19269개
# 476번째 종목 펩트론 추출중...
# 펩트론에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 477번째 종목 현대공업 추출중...
# 35개 추출완료. 누적19304개
# 478번째 종목 셀레믹스 추출중...
# 셀레믹스에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 479번째 종목 신원종합개발 추출중...
# 76개 추출완료. 누적19380개
# 480번째 종목 HLB생명과학 추출중...
# 127개 추출완료. 누적19507개
# 481번째 종목 알테오젠 추출중...
# 141개 추출완료. 누적19648개
# 482번째 종목 삼진엘앤디 추출중...
# 45개 추출완료. 누적19693개
# 483번째 종목 광진실업 추출중...
# 32개 추출완료. 누적19725개
# 484번째 종목 YBM넷 추출중...
# 35개 추출완료. 누적19760개
# 485번째 종목 린드먼아시아 추출중...
# 21개 추출완료. 누적19781개
# 486번째 종목 인터엠 추출중...
# 45개 추출완료. 누적19826개
# 487번째 종목 원익머트리얼즈 추출중...
# 54개 추출완료. 누적19880개
# 488번째 종목 케이엔제이 추출중...
# 32개 추출완료. 누적19912개
# 489번째 종목 동양이엔피 추출중...
# 37개 추출완료. 누적19949개
# 490번째 종목 제노레이 추출중...
# 제노레이에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 491번째 종목 상신이디피 추출중...
# 89개 추출완료. 누적20038개
# 492번째 종목 네온테크 추출중...
# 16개 추출완료. 누적20054개
# 493번째 종목 아이큐어 추출중...
# 43개 추출완료. 누적20097개
# 494번째 종목 국전약품 추출중...
# 22개 추출완료. 누적20119개
# 495번째 종목 펨트론 추출중...
# 0개 추출완료. 누적20119개
# 496번째 종목 다날 추출중...
# 62개 추출완료. 누적20181개
# 497번째 종목 토비스 추출중...
# 58개 추출완료. 누적20239개
# 498번째 종목 캐스텍코리아 추출중...
# 41개 추출완료. 누적20280개
# 499번째 종목 아톤 추출중...
# 30개 추출완료. 누적20310개
# 500번째 종목 대동스틸 추출중...
# 69개 추출완료. 누적20379개
# 501번째 종목 삼성전자 추출중...
# 13개 추출완료. 누적20392개
# 502번째 종목 LG화학 추출중...
# 63개 추출완료. 누적20455개
# 503번째 종목 SK하이닉스 추출중...
# 38개 추출완료. 누적20493개
# 504번째 종목 삼성바이오로직스 추출중...
# 40개 추출완료. 누적20533개
# 505번째 종목 삼성전자우 추출중...
# 19개 추출완료. 누적20552개
# 506번째 종목 LG화학우 추출중...
# 51개 추출완료. 누적20603개
# 507번째 종목 삼성SDI 추출중...
# 53개 추출완료. 누적20656개
# 508번째 종목 현대차 추출중...
# 22개 추출완료. 누적20678개
# 509번째 종목 효성화학 추출중...
# 효성화학에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 510번째 종목 에코프로비엠 추출중...
# 에코프로비엠에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 511번째 종목 기아 추출중...
# 23개 추출완료. 누적20701개
# 512번째 종목 에코프로 추출중...
# 141개 추출완료. 누적20842개
# 513번째 종목 카카오 추출중...
# 카카오에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 514번째 종목 셀트리온 추출중...
# 42개 추출완료. 누적20922개
# 515번째 종목 현대모비스 추출중...
# 32개 추출완료. 누적20954개
# 516번째 종목 KB금융 추출중...
# 13개 추출완료. 누적20967개
# 517번째 종목 삼성물산 추출중...
# 23개 추출완료. 누적20990개
# 518번째 종목 신한지주 추출중...
# 5개 추출완료. 누적20995개
# 519번째 종목 SK이노베이션 추출중...
# 49개 추출완료. 누적21044개
# 520번째 종목 LG전자 추출중...
# 46개 추출완료. 누적21090개
# 521번째 종목 대우조선해양 추출중...
# 60개 추출완료. 누적21150개
# 522번째 종목 삼성생명 추출중...
# 10개 추출완료. 누적21160개
# 523번째 종목 카카오뱅크 추출중...
# 18개 추출완료. 누적21178개
# 524번째 종목 LG 추출중...
# 15개 추출완료. 누적21193개
# 525번째 종목 한국전력 추출중...
# 17개 추출완료. 누적21210개
# 526번째 종목 삼성화재 추출중...
# 7개 추출완료. 누적21217개
# 527번째 종목 KT&G 추출중...
# 4개 추출완료. 누적21221개
# 528번째 종목 셀트리온헬스케어 추출중...
# 셀트리온헬스케어에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 529번째 종목 삼성전기 추출중...
# 53개 추출완료. 누적21274개
# 530번째 종목 하나금융지주 추출중...
# 29개 추출완료. 누적21303개
# 531번째 종목 SK 추출중...
# SK에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 532번째 종목 솔루스첨단소재 추출중...
# 38개 추출완료. 누적21359개
# 533번째 종목 하이브 추출중...
# 하이브에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 534번째 종목 삼성에스디에스 추출중...
# 26개 추출완료. 누적21385개
# 535번째 종목 KODEX 레버리지 추출중...
# 20개 추출완료. 누적21405개
# 536번째 종목 SK텔레콤 추출중...
# 10개 추출완료. 누적21415개
# 537번째 종목 고려아연 추출중...
# 21개 추출완료. 누적21436개
# 538번째 종목 케이씨케미칼 추출중...
# 케이씨케미칼에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 539번째 종목 대한항공 추출중...
# 47개 추출완료. 누적21502개
# 540번째 종목 S-Oil 추출중...
# 44개 추출완료. 누적21546개
# 541번째 종목 현대글로비스 추출중...
# 42개 추출완료. 누적21588개
# 542번째 종목 크래프톤 추출중...
# 20개 추출완료. 누적21608개
# 543번째 종목 기업은행 추출중...
# 9개 추출완료. 누적21617개
# 544번째 종목 케이티 추출중...
# 3개 추출완료. 누적21620개
# 545번째 종목 우리금융지주 추출중...
# 3개 추출완료. 누적21623개
# 546번째 종목 삼성중공업 추출중...
# 56개 추출완료. 누적21679개
# 547번째 종목 아모레퍼시픽 추출중...
# 78개 추출완료. 누적21757개
# 548번째 종목 LG생활건강 추출중...
# 53개 추출완료. 누적21810개
# 549번째 종목 삼성엔지니어링 추출중...
# 94개 추출완료. 누적21904개
# 550번째 종목 KODEX 코스닥 150 레버리지 추출중...
# 81개 추출완료. 누적21985개
# 551번째 종목 롯데케미칼 추출중...
# 56개 추출완료. 누적22041개
# 552번째 종목 유한양행 추출중...
# 27개 추출완료. 누적22068개
# 553번째 종목 한화에어로스페이스 추출중...
# 74개 추출완료. 누적22142개
# 554번째 종목 엔씨소프트 추출중...
# 54개 추출완료. 누적22196개
# 555번째 종목 두산밥캣 추출중...
# 25개 추출완료. 누적22221개
# 556번째 종목 DB손해보험 추출중...
# 21개 추출완료. 누적22242개
# 557번째 종목 한온시스템 추출중...
# 51개 추출완료. 누적22293개
# 558번째 종목 LG디스플레이 추출중...
# 44개 추출완료. 누적22337개
# 559번째 종목 HD현대 추출중...
# 36개 추출완료. 누적22373개
# 560번째 종목 맥쿼리인프라 추출중...
# 1개 추출완료. 누적22374개
# 561번째 종목 코스모신소재 추출중...
# 135개 추출완료. 누적22509개
# 562번째 종목 오리온 추출중...
# 22개 추출완료. 누적22531개
# 563번째 종목 현대제철 추출중...
# 41개 추출완료. 누적22572개
# 564번째 종목 CJ제일제당 추출중...
# CJ제일제당에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 565번째 종목 한국항공우주 추출중...
# 53개 추출완료. 누적22637개
# 566번째 종목 한미반도체 추출중...
# 한미반도체에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 567번째 종목 LG유플러스 추출중...
# 17개 추출완료. 누적22698개
# 568번째 종목 현대오토에버 추출중...
# 현대오토에버에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 569번째 종목 미래에셋증권 추출중...
# 35개 추출완료. 누적22733개
# 570번째 종목 F&F홀딩스 추출중...
# 113개 추출완료. 누적22846개
# 571번째 종목 넷마블 추출중...
# 넷마블에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 572번째 종목 한미약품 추출중...
# 80개 추출완료. 누적22950개
# 573번째 종목 현대건설 추출중...
# 53개 추출완료. 누적23003개
# 574번째 종목 현대미포조선 추출중...
# 97개 추출완료. 누적23100개
# 575번째 종목 LS 추출중...
# 52개 추출완료. 누적23152개
# 576번째 종목 GS 추출중...
# 9개 추출완료. 누적23161개
# 577번째 종목 금호석유 추출중...
# 72개 추출완료. 누적23233개
# 578번째 종목 강원랜드 추출중...
# 11개 추출완료. 누적23244개
# 579번째 종목 호텔신라 추출중...
# 66개 추출완료. 누적23310개
# 580번째 종목 NH투자증권 추출중...
# 25개 추출완료. 누적23335개
# 581번째 종목 한진칼 추출중...
# 84개 추출완료. 누적23419개
# 582번째 종목 삼성증권 추출중...
# 23개 추출완료. 누적23442개
# 583번째 종목 현대로템 추출중...
# 63개 추출완료. 누적23505개
# 584번째 종목 코웨이 추출중...
# 26개 추출완료. 누적23531개
# 585번째 종목 BGF리테일 추출중...
# 24개 추출완료. 누적23555개
# 586번째 종목 씨에스윈드 추출중...
# 씨에스윈드에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.
# 587번째 종목 한국금융지주 추출중...
# 38개 추출완료. 누적23647개
# 588번째 종목 아모레G 추출중...
# 60개 추출완료. 누적23707개
# 589번째 종목 한미사이언스 추출중...
# 97개 추출완료. 누적23804개
# 590번째 종목 롯데지주 추출중...
# 28개 추출완료. 누적23832개

# %%
print(len(train_result))
print(sum([low[1] for low in train_result]))
# Out:
# 23832
# 13942

# %%
def get_same_labelnum(result, num):

    # 라벨별로 이미지 데이터 분리
    label0_images = [image_data for image_data, label in result if label == 0]
    label1_images = [image_data for image_data, label in result if label == 1]

    # 각 라벨에서 랜덤하게 5,000개씩 뽑기
    random_label0_images = random.sample(label0_images, num)
    random_label1_images = random.sample(label1_images, num)

    # 뽑은 이미지 데이터와 라벨을 다시 묶기
    new_label0_result = [(image_data, 0) for image_data in random_label0_images]
    new_label1_result = [(image_data, 1) for image_data in random_label1_images]

    # 두 결과를 번갈아가면서 합치기
    result = [t for pair in zip(new_label0_result, new_label1_result) for t in pair]
    return result

# %%
train_result = get_same_labelnum(train_result, 5000)
train_images, train_labels = zip(*train_result)
print(sum(train_labels))
np.save('train_images.npy', train_images)
np.save('train_labels.npy', train_labels)
# Out:
# 5000

# %%
test_result = get_same_labelnum(test_result, 1250)
test_images, test_labels = zip(*test_result)
print(sum(test_labels))
np.save('test_images.npy', test_images)
np.save('test_labels.npy', test_labels)
# Out:
# 1250

# %%
train_images = np.load('train_images.npy')
train_labels = np.load('train_labels.npy')
# test_images = np.load('test_images.npy')
# test_labels = np.load('test_labels.npy')

train_images = train_images[:, :, :, :3]
# test_images = test_images[:, :, :, :3]

np.save('train_images.npy', train_images)
np.save('train_labels.npy', train_labels)
# np.save('test_images.npy', test_images)
# np.save('test_labels.npy', test_labels)

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# 이미지 개수와 그리드 크기 설정
num_images = len(train_images)
num_to_display = 100
grid_size = int(np.sqrt(num_to_display))

# 랜덤으로 이미지 인덱스 선택
random_indices = np.random.choice(num_images, num_to_display, replace=False)

fig, axes = plt.subplots(grid_size, grid_size, figsize=(16, 16))
for i in range(grid_size):
    for j in range(grid_size):
        img_idx = random_indices[i * grid_size + j]
        img = Image.fromarray(train_images[img_idx])
        axes[i, j].imshow(img)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        axes[i, j].set_xlabel(f'Img {img_idx + 1}', fontsize=9)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10, 10, figsize=(16, 16))
for i in range(10):
    for j in range(10):
        img_idx = i * 10 + j
        img = Image.fromarray(train_images[img_idx])
        axes[i, j].imshow(img)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        axes[i, j].set_xlabel(f'Img {img_idx + 1}', fontsize=9)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.show()
