# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.50 requests-file-1.5.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
a = fdr.DataReader('005930', '1999-03-01')
a
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1999-05-21   1673   1697   1578   1698   1180860       NaN
# 1999-05-24   1620   1668   1620   1626    826890 -0.042403
# 1999-05-25   1606   1670   1602   1640    548914  0.008610
# 1999-05-26   1638   1672   1614   1658    748059  0.010976
# 1999-05-27   1660   1724   1658   1660    803200  0.001206
# ...           ...    ...    ...    ...       ...       ...
# 2023-08-25  67100  67400  66900  67100   7032462 -0.016129
# 2023-08-28  66800  67000  66500  66800   5824628 -0.004471
# 2023-08-29  66900  67200  66600  66800   9114352  0.000000
# 2023-08-30  67300  67700  67100  67100   9181223  0.004491
# 2023-08-31  67100  67200  66400  66900  15415806 -0.002981
#
# [6000 rows x 6 columns]

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from datetime import datetime, timedelta
import random

day_num = 32

# %%
from keras.models import load_model

model6 = load_model('drive/MyDrive/Colab Notebooks/change4.h5')
model7 = load_model('drive/MyDrive/Colab Notebooks/change5.h5')
model8 = load_model('drive/MyDrive/Colab Notebooks/change6.h5')
model9 = load_model('drive/MyDrive/Colab Notebooks/pi90_daq500_label10_epoch40.h5')
model10 = load_model('drive/MyDrive/Colab Notebooks/pi90_daq500_label10_epoch50.h5')

# %%
def convert_image(data, num_images, day_num, name, code, save = False, test = False):

    def alpha_blend(color1, color2, alpha):
        return [
            int((color1[0] * alpha + color2[0] * (1 - alpha))),
            int((color1[1] * alpha + color2[1] * (1 - alpha))),
            int((color1[2] * alpha + color2[2] * (1 - alpha))),
            255,
        ]


    # 해당 종목의 주가 데이터 - 100이 요구되는 이미지 수보다 적으면(상장직후는 변동이 심할 수있으니 제외)
    if num_images > len(data) - 60 - day_num:
        num_images = len(data) - 60 - day_num

    #return_datas는 이미지, 라벨링(상승이면1 하락이면0), 변동률, 날짜를 담고있음
    return_datas = []

    image_idx = 1
    while(image_idx <= num_images):

        if image_idx != 1:
            stock_data = data[-image_idx - day_num + 1 : -image_idx + 1]
        else:
            stock_data = data[-day_num:]
        # 이미지 크기 설정
        width, height = day_num * 3, 96

        # High, Low, Close, Volume 데이터 정규화
        high_prices = stock_data['High'].values
        low_prices = stock_data['Low'].values
        close_prices = stock_data['Close'].values
        volume_data = stock_data['Volume'].values

        high_prices_norm = (high_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        low_prices_norm = (low_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        close_prices_norm = (close_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        volume_data_norm = height * (volume_data) / (2 * (np.max(volume_data)))

        if len(data) <= abs(-image_idx - day_num - 19):
            break

        # 이동평균선 추가를 위한 stock_data 생성
        if image_idx != 1:
            stock_data_ma20 = data[-image_idx - day_num - 19: -image_idx + 1]
        else:
            stock_data_ma20 = data[-image_idx - day_num - 19: ]

        stock_data_ma20 = stock_data_ma20.copy()
        stock_data_ma20['MA20'] = stock_data_ma20['Close'].rolling(window=20).mean()
        stock_data_ma20.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma20['MA20_norm'] = (
                (stock_data_ma20['MA20'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        if len(data) <= abs(-image_idx - day_num - 39):
            break

        if image_idx != 1:
            stock_data_ma40 = data[-image_idx - day_num - 39: -image_idx + 1]
        else:
            stock_data_ma40 = data[-image_idx - day_num - 39: ]

        stock_data_ma40 = stock_data_ma40.copy()
        stock_data_ma40['MA40'] = stock_data_ma40['Close'].rolling(window=40).mean()
        stock_data_ma40.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma40['MA40_norm'] = (
                (stock_data_ma40['MA40'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        if len(data) <= abs(-image_idx - day_num - 59):
            break

        if image_idx != 1:
            stock_data_ma60 = data[-image_idx - day_num - 59: -image_idx + 1]
        else:
            stock_data_ma60 = data[-image_idx - day_num - 59: ]

        stock_data_ma60 = stock_data_ma60.copy()
        stock_data_ma60['MA60'] = stock_data_ma60['Close'].rolling(window=60).mean()
        stock_data_ma60.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma60['MA60_norm'] = (
                (stock_data_ma60['MA60'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        # 96x96 이미지 생성
        img = np.zeros((height, width, 4), dtype=np.uint8)  # 4 channels for RGBA

        fail_generate = False
        for day in range(day_num):
            high_price = int(high_prices_norm[day] * (height - 1))
            low_price = int(low_prices_norm[day] * (height - 1))
            close_price = int(close_prices_norm[day] * (height - 1))
            open_price = int(
                (
                    (stock_data['Open'].values[day] - np.min(low_prices))
                    / (np.max(high_prices) - np.min(low_prices))
                )
                * (height - 1)
            )
            volume = int(volume_data_norm[day])

            x_start = day * 3

            # 시가, 종가, 고가, 저가 막대그래프
            # 막대 왼쪽, 오른쪽 그리기 (시가, 종가 범위)
            for x in range(x_start, x_start + 3):
                if close_prices[day] > stock_data['Open'].values[day]:
                    color = [255, 0, 0, 255]  # 상승: 빨강
                    tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                elif close_prices[day] < stock_data['Open'].values[day]:
                    color = [0, 0, 255, 255]  # 하락: 파랑
                    tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑
                else: # 시가와 종가가 같을경우 어제보다 같거나 올랐으면 빨강, 아니면 파랑
                    if 0 <= stock_data['Change'].values[day]:
                        color = [255, 0, 0, 255]  # 상승: 빨강
                        tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                    else:
                        color = [0, 0, 255, 255]  # 하락: 파랑
                        tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑

                for y in range(min(open_price, close_price), max(open_price, close_price) + 1):
                    img[height - 1 - y, x] = color

            # 꼬리 그리기 (High, Low 범위)
            for x in range(x_start + 1, x_start + 2):
                for y in range(low_price, high_price + 1):
                    if img[height - 1 - y, x][0] != 255 and img[height - 1 - y, x][2] != 255:
                        img[height - 1 - y, x] = tail_color

            # 거래량 그리기
            for x in range(x_start, x_start + 3):
                overlapped = height - volume
                if overlapped >= 0 and overlapped < height:
                    img[overlapped:, x] = [
                        alpha_blend(img[y, x], [128, 128, 128, 255], 0.45)
                        for y in range(overlapped, height)
                    ]

            # 20일 이동평균선 그리기
            ma20_norm = stock_data_ma20.iloc[day]['MA20_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma20_norm):
                    ma20_y = int(ma20_norm * (height - 1))
                    if 0 <= ma20_y < height:
                        for y in range(ma20_y - 1, ma20_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([255, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 노란색으로 변경
                                img[height - 1 - y, x] = new_color

            # 40일 이동평균선 그리기
            ma40_norm = stock_data_ma40.iloc[day]['MA40_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma40_norm):
                    ma40_y = int(ma40_norm * (height - 1))
                    if 0 <= ma40_y < height:
                        for y in range(ma40_y - 1, ma40_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([128, 0, 128, 255], img[height - 1 - y, x], 0.6)  # 보라색으로 변경
                                img[height - 1 - y, x] = new_color


            # 60일 이동평균선 그리기
            ma60_norm = stock_data_ma60.iloc[day]['MA60_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma60_norm):
                    ma60_y = int(ma60_norm * (height - 1))
                    if 0 <= ma60_y < height:
                        for y in range(ma60_y - 1, ma60_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([0, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 초록색으로 변경
                                img[height - 1 - y, x] = new_color

        #이미지가 day_num(그려지기 원하는 거래일 수)미만으로 그려졌으면
        if fail_generate:
            image_idx += 1
            continue

        if save :
            # 이미지 저장
            img = Image.fromarray(img, 'RGBA')
            img.save(f'stock_data_image_{image_idx}.png')


        return_datas.append((img, name, code, stock_data.index[-1]))

        image_idx += 1


    return return_datas

# %%
def preprocess_data(data):
    # 0이나 NaN을 포함하는 행 제거
    data = data[data['Volume'] != 0]
    data = data.dropna(how='any')

    return data

# %%
df = pd.read_excel('drive/MyDrive/Colab Notebooks/kospi.xlsx', usecols=[0, 1], dtype={1: str})
# df = df.sample(n=400, random_state=42)
# 첫 번째 열과 두 번째 열을 Nx2 리스트로 변환
stock_codes = df.values.tolist()

# 결과 출력
print(stock_codes)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# [['095570', 'AJ네트웍스'], ['006840', 'AK홀딩스'], ['027410', 'BGF'], ['282330', 'BGF리테일'], ['138930', 'BNK금융지주'], ['001460', 'BYC'], ['001465', 'BYC우'], ['001040', 'CJ'], ['079160', 'CJ CGV'], ['00104K', 'CJ4우(전환)'], ['000120', 'CJ대한통운'], ['011150', 'CJ씨푸드'], ['011155', 'CJ씨푸드1우'], ['001045', 'CJ우'], ['097950', 'CJ제일제당'], ['097955', 'CJ제일제당 우'], ['000480', 'CR홀딩스'], ['000590', 'CS홀딩스'], ['012030', 'DB'], ['016610', 'DB금융투자'], ['005830', 'DB손해보험'], ['000990', 'DB하이텍'], ['139130', 'DGB금융지주'], ['001530', 'DI동일'], ['000210', 'DL'], ['001880', 'DL건설'], ['000215', 'DL우'], ['375500', 'DL이앤씨'], ['37550L', 'DL이앤씨2우(전환)'], ['37550K', 'DL이앤씨우'], ['007340', 'DN오토모티브'], ['004840', 'DRB동일'], ['155660', 'DSR'], ['069730', 'DSR제강'], ['017940', 'E1'], ['365550', 'ESR켄달스퀘어리츠'], ['383220', 'F&F'], ['007700', 'F&F홀딩스'], ['114090', 'GKL'], ['078930', 'GS'], ['006360', 'GS건설'], ['001250', 'GS글로벌'], ['007070', 'GS리테일'], ['078935', 'GS우'], ['012630', 'HDC'], ['039570', 'HDC랩스'], ['089470', 'HDC현대EP'], ['294870', 'HDC현대산업개발'], ['009540', 'HD한국조선해양'], ['267250', 'HD현대'], ['267270', 'HD현대건설기계'], ['322000', 'HD현대에너지솔루션'], ['042670', 'HD현대인프라코어'], ['267260', 'HD현대일렉트릭'], ['329180', 'HD현대중공업'], ['097230', 'HJ중공업'], ['014790', 'HL D&I'], ['003580', 'HLB글로벌'], ['204320', 'HL만도'], ['060980', 'HL홀딩스'], ['011200', 'HMM'], ['082740', 'HSD엔진'], ['035000', 'HS애드'], ['003560', 'IHQ'], ['175330', 'JB금융지주'], ['234080', 'JW생명과학'], ['001060', 'JW중외제약'], ['001067', 'JW중외제약2우B'], ['001065', 'JW중외제약우'], ['096760', 'JW홀딩스'], ['105560', 'KB금융'], ['432320', 'KB스타리츠'], ['002380', 'KCC'], ['344820', 'KCC글라스'], ['009070', 'KCTC'], ['009440', 'KC그린홀딩스'], ['119650', 'KC코트렐'], ['092220', 'KEC'], ['003620', 'KG모빌리티'], ['016380', 'KG스틸'], ['001390', 'KG케미칼'], ['033180', 'KH 필룩스'], ['015590', 'KIB플러그에너지'], ['001940', 'KISCO홀딩스'], ['025000', 'KPX케미칼'], ['092230', 'KPX홀딩스'], ['000040', 'KR모터스'], ['044450', 'KSS해운'], ['030200', 'KT'], ['033780', 'KT&G'], ['058850', 'KTcs'], ['058860', 'KTis'], ['093050', 'LF'], ['003550', 'LG'], ['034220', 'LG디스플레이'], ['051900', 'LG생활건강'], ['051905', 'LG생활건강우'], ['373220', 'LG에너지솔루션'], ['003555', 'LG우'], ['032640', 'LG유플러스'], ['011070', 'LG이노텍'], ['066570', 'LG전자'], ['066575', 'LG전자우'], ['037560', 'LG헬로비전'], ['051910', 'LG화학'], ['051915', 'LG화학우'], ['079550', 'LIG넥스원'], ['006260', 'LS'], ['010120', 'LS ELECTRIC'], ['000680', 'LS네트웍스'], ['229640', 'LS전선아시아'], ['108320', 'LX세미콘'], ['001120', 'LX인터내셔널'], ['108670', 'LX하우시스'], ['108675', 'LX하우시스우'], ['383800', 'LX홀딩스'], ['38380K', 'LX홀딩스1우'], ['023150', 'MH에탄올'], ['035420', 'NAVER'], ['181710', 'NHN'], ['400760', 'NH올원리츠'], ['005940', 'NH투자증권'], ['005945', 'NH투자증권우'], ['338100', 'NH프라임리츠'], ['034310', 'NICE'], ['030190', 'NICE평가정보'], ['008260', 'NI스틸'], ['004250', 'NPC'], ['004255', 'NPC우'], ['456040', 'OCI'], ['010060', 'OCI홀딩스'], ['178920', 'PI첨단소재'], ['005490', 'POSCO홀딩스'], ['010950', 'S-Oil'], ['010955', 'S-Oil우'], ['034120', 'SBS'], ['005090', 'SGC에너지'], ['001380', 'SG글로벌'], ['004060', 'SG세계물산'], ['001770', 'SHD'], ['002360', 'SH에너지화학'], ['009160', 'SIMPAC'], ['123700', 'SJM'], ['025530', 'SJM홀딩스'], ['034730', 'SK'], ['011790', 'SKC'], ['018670', 'SK가스'], ['001740', 'SK네트웍스'], ['006120', 'SK디스커버리'], ['006125', 'SK디스커버리우'], ['210980', 'SK디앤디'], ['068400', 'SK렌터카'], ['395400', 'SK리츠'], ['302440', 'SK바이오사이언스'], ['326030', 'SK바이오팜'], ['402340', 'SK스퀘어'], ['361610', 'SK아이이테크놀로지'], ['100090', 'SK오션플랜트'], ['03473K', 'SK우'], ['096770', 'SK이노베이션'], ['096775', 'SK이노베이션우'], ['001510', 'SK증권'], ['001515', 'SK증권우'], ['285130', 'SK케미칼'], ['28513K', 'SK케미칼우'], ['017670', 'SK텔레콤'], ['000660', 'SK하이닉스'], ['003570', 'SNT다이내믹스'], ['064960', 'SNT모티브'], ['100840', 'SNT에너지'], ['036530', 'SNT홀딩스'], ['005610', 'SPC삼립'], ['011810', 'STX'], ['077970', 'STX엔진'], ['071970', 'STX중공업'], ['002820', 'SUN&L'], ['084870', 'TBH글로벌'], ['002710', 'TCC스틸'], ['069260', 'TKG휴켐스'], ['002900', 'TYM'], ['024070', 'WISCOM'], ['037270', 'YG PLUS'], ['000500', '가온전선'], ['000860', '강남제비스코'], ['035250', '강원랜드'], ['011420', '갤럭시아에스엠'], ['002100', '경농'], [' ...

# %%
up_images = []
up_images_info = []

def process():
    global up_images, up_images_info

    for n in range(0, len(stock_codes), 50):
        result_images = []
        for i, ticker in enumerate(stock_codes[n:min(n+50, len(stock_codes))]):
            code, name = ticker[0], ticker[1]
            print(f"{n+i+1}번째 종목 {name} 추출중...   ")

            try:
                data = preprocess_data(fdr.DataReader(code, '2023-03-01'))  # 각 종목의 데이터 가져오기
                images = convert_image(data, 1, day_num, name, code)
                result_images += images
                print(f"{len(images)}개 추출완료. 누적{len(result_images)}개")
            except IndexError:
                print(f"{name}에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.")
                continue

        if len(result_images) == 0:
            continue
        test_images = [image[0][:, :, :3] for image in result_images]
        test_images = np.array(test_images).reshape(-1, 96, 96, 3) / 255.0

        pred_probs6 = model6.predict(test_images)
        pred_probs7 = model7.predict(test_images)
        pred_probs8 = model8.predict(test_images)
        pred_probs9 = model9.predict(test_images)
        pred_probs10 = model10.predict(test_images)

        # 두 모델 같은 라벨이 하락으로 정답이라고 했을때

        selected_images = []
        selected_images_info = []

        for i in range(len(test_images)):
            pred_probs6_max_idx = np.argmax(pred_probs6[i])
            pred_probs7_max_idx = np.argmax(pred_probs7[i])
            pred_probs8_max_idx = np.argmax(pred_probs8[i])
            pred_probs9_max_idx = np.argmax(pred_probs9[i])
            pred_probs10_max_idx = np.argmax(pred_probs10[i])

            if pred_probs6_max_idx == pred_probs7_max_idx == pred_probs8_max_idx == pred_probs9_max_idx == pred_probs10_max_idx and 0.5 < pred_probs6[i][1] and 0.5 <= pred_probs6[i][pred_probs6_max_idx] <= 0.98 and 0.5 <= pred_probs7[i][pred_probs7_max_idx] <= 0.98 and 0.75 <= pred_probs8[i][pred_probs8_max_idx] <= 1 and 0.54 <= pred_probs9[i][pred_probs9_max_idx] <= 0.97 and 0.75 <= pred_probs10[i][pred_probs10_max_idx] <= 1:
                selected_images.append(test_images[i])
                selected_images_info.append(result_images[i][1:])

        selected_images = np.array(selected_images)

        print(len(selected_images))
        for i in selected_images_info:
            print(i[0], str(i[-1])[:10])

        up_images.append(selected_images)
        up_images_info.append(selected_images_info)

# %%
process()
# Out:
# 1번째 종목 AJ네트웍스 추출중...
# 1개 추출완료. 누적1개
# 2번째 종목 AK홀딩스 추출중...
# 1개 추출완료. 누적2개
# 3번째 종목 BGF 추출중...
# 1개 추출완료. 누적3개
# 4번째 종목 BGF리테일 추출중...
# 1개 추출완료. 누적4개
# 5번째 종목 BNK금융지주 추출중...
# 1개 추출완료. 누적5개
# 6번째 종목 BYC 추출중...
# 1개 추출완료. 누적6개
# 7번째 종목 BYC우 추출중...
# 1개 추출완료. 누적7개
# 8번째 종목 CJ 추출중...
# 1개 추출완료. 누적8개
# 9번째 종목 CJ CGV 추출중...
# 1개 추출완료. 누적9개
# 10번째 종목 CJ4우(전환) 추출중...
# 1개 추출완료. 누적10개
# 11번째 종목 CJ대한통운 추출중...
# 1개 추출완료. 누적11개
# 12번째 종목 CJ씨푸드 추출중...
# 1개 추출완료. 누적12개
# 13번째 종목 CJ씨푸드1우 추출중...
# 1개 추출완료. 누적13개
# 14번째 종목 CJ우 추출중...
# 1개 추출완료. 누적14개
# 15번째 종목 CJ제일제당 추출중...
# 1개 추출완료. 누적15개
# 16번째 종목 CJ제일제당 우 추출중...
# 1개 추출완료. 누적16개
# 17번째 종목 CR홀딩스 추출중...
# 1개 추출완료. 누적17개
# 18번째 종목 CS홀딩스 추출중...
# 1개 추출완료. 누적18개
# 19번째 종목 DB 추출중...
# 1개 추출완료. 누적19개
# 20번째 종목 DB금융투자 추출중...
# 1개 추출완료. 누적20개
# 21번째 종목 DB손해보험 추출중...
# 1개 추출완료. 누적21개
# 22번째 종목 DB하이텍 추출중...
# 1개 추출완료. 누적22개
# 23번째 종목 DGB금융지주 추출중...
# 1개 추출완료. 누적23개
# 24번째 종목 DI동일 추출중...
# 1개 추출완료. 누적24개
# 25번째 종목 DL 추출중...
# 1개 추출완료. 누적25개
# 26번째 종목 DL건설 추출중...
# 1개 추출완료. 누적26개
# 27번째 종목 DL우 추출중...
# 1개 추출완료. 누적27개
# 28번째 종목 DL이앤씨 추출중...
# 1개 추출완료. 누적28개
# 29번째 종목 DL이앤씨2우(전환) 추출중...
# 1개 추출완료. 누적29개
# 30번째 종목 DL이앤씨우 추출중...
# 1개 추출완료. 누적30개
# 31번째 종목 DN오토모티브 추출중...
# 1개 추출완료. 누적31개
# 32번째 종목 DRB동일 추출중...
# 1개 추출완료. 누적32개
# 33번째 종목 DSR 추출중...
# 1개 추출완료. 누적33개
# 34번째 종목 DSR제강 추출중...
# 1개 추출완료. 누적34개
# 35번째 종목 E1 추출중...
# 1개 추출완료. 누적35개
# 36번째 종목 ESR켄달스퀘어리츠 추출중...
# 1개 추출완료. 누적36개
# 37번째 종목 F&F 추출중...
# 1개 추출완료. 누적37개
# 38번째 종목 F&F홀딩스 추출중...
# 1개 추출완료. 누적38개
# 39번째 종목 GKL 추출중...
# 1개 추출완료. 누적39개
# 40번째 종목 GS 추출중...
# 1개 추출완료. 누적40개
# 41번째 종목 GS건설 추출중...
# 1개 추출완료. 누적41개
# 42번째 종목 GS글로벌 추출중...
# 1개 추출완료. 누적42개
# 43번째 종목 GS리테일 추출중...
# 1개 추출완료. 누적43개
# 44번째 종목 GS우 추출중...
# 1개 추출완료. 누적44개
# 45번째 종목 HDC 추출중...
# 1개 추출완료. 누적45개
# 46번째 종목 HDC랩스 추출중...
# 1개 추출완료. 누적46개
# 47번째 종목 HDC현대EP 추출중...
# 1개 추출완료. 누적47개
# 48번째 종목 HDC현대산업개발 추출중...
# 1개 추출완료. 누적48개
# 49번째 종목 HD한국조선해양 추출중...
# 1개 추출완료. 누적49개
# 50번째 종목 HD현대 추출중...
# 1개 추출완료. 누적50개
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 955ms/step
# 2/2 [==============================] - 3s 2s/step
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7866551969e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 4s 949ms/step
# 0
# 51번째 종목 HD현대건설기계 추출중...
# 1개 추출완료. 누적1개
# 52번째 종목 HD현대에너지솔루션 추출중...
# 1개 추출완료. 누적2개
# 53번째 종목 HD현대인프라코어 추출중...
# 1개 추출완료. 누적3개
# 54번째 종목 HD현대일렉트릭 추출중...
# 1개 추출완료. 누적4개
# 55번째 종목 HD현대중공업 추출중...
# 1개 추출완료. 누적5개
# 56번째 종목 HJ중공업 추출중...
# 1개 추출완료. 누적6개
# 57번째 종목 HL D&I 추출중...
# 1개 추출완료. 누적7개
# 58번째 종목 HLB글로벌 추출중...
# 1개 추출완료. 누적8개
# 59번째 종목 HL만도 추출중...
# 1개 추출완료. 누적9개
# 60번째 종목 HL홀딩스 추출중...
# 1개 추출완료. 누적10개
# 61번째 종목 HMM 추출중...
# 1개 추출완료. 누적11개
# 62번째 종목 HSD엔진 추출중...
# 1개 추출완료. 누적12개
# 63번째 종목 HS애드 추출중...
# 1개 추출완료. 누적13개
# 64번째 종목 IHQ 추출중...
# 0개 추출완료. 누적13개
# 65번째 종목 JB금융지주 추출중...
# 1개 추출완료. 누적14개
# 66번째 종목 JW생명과학 추출중...
# 1개 추출완료. 누적15개
# 67번째 종목 JW중외제약 추출중...
# 1개 추출완료. 누적16개
# 68번째 종목 JW중외제약2우B 추출중...
# 1개 추출완료. 누적17개
# 69번째 종목 JW중외제약우 추출중...
# 1개 추출완료. 누적18개
# 70번째 종목 JW홀딩스 추출중...
# 1개 추출완료. 누적19개
# 71번째 종목 KB금융 추출중...
# 1개 추출완료. 누적20개
# 72번째 종목 KB스타리츠 추출중...
# 1개 추출완료. 누적21개
# 73번째 종목 KCC 추출중...
# 1개 추출완료. 누적22개
# 74번째 종목 KCC글라스 추출중...
# 1개 추출완료. 누적23개
# 75번째 종목 KCTC 추출중...
# 1개 추출완료. 누적24개
# 76번째 종목 KC그린홀딩스 추출중...
# 1개 추출완료. 누적25개
# 77번째 종목 KC코트렐 추출중...
# 1개 추출완료. 누적26개
# 78번째 종목 KEC 추출중...
# 1개 추출완료. 누적27개
# 79번째 종목 KG모빌리티 추출중...
# 0개 추출완료. 누적27개
# 80번째 종목 KG스틸 추출중...
# 1개 추출완료. 누적28개
# 81번째 종목 KG케미칼 추출중...
# 1개 추출완료. 누적29개
# 82번째 종목 KH 필룩스 추출중...
# 0개 추출완료. 누적29개
# 83번째 종목 KIB플러그에너지 추출중...
# 1개 추출완료. 누적30개
# 84번째 종목 KISCO홀딩스 추출중...
# 1개 추출완료. 누적31개
# 85번째 종목 KPX케미칼 추출중...
# 1개 추출완료. 누적32개
# 86번째 종목 KPX홀딩스 추출중...
# 1개 추출완료. 누적33개
# 87번째 종목 KR모터스 추출중...
# 1개 추출완료. 누적34개
# 88번째 종목 KSS해운 추출중...
# 1개 추출완료. 누적35개
# 89번째 종목 KT 추출중...
# 1개 추출완료. 누적36개
# 90번째 종목 KT&G 추출중...
# 1개 추출완료. 누적37개
# 91번째 종목 KTcs 추출중...
# 1개 추출완료. 누적38개
# 92번째 종목 KTis 추출중...
# 1개 추출완료. 누적39개
# 93번째 종목 LF 추출중...
# 1개 추출완료. 누적40개
# 94번째 종목 LG 추출중...
# 1개 추출완료. 누적41개
# 95번째 종목 LG디스플레이 추출중...
# 1개 추출완료. 누적42개
# 96번째 종목 LG생활건강 추출중...
# 1개 추출완료. 누적43개
# 97번째 종목 LG생활건강우 추출중...
# 1개 추출완료. 누적44개
# 98번째 종목 LG에너지솔루션 추출중...
# 1개 추출완료. 누적45개
# 99번째 종목 LG우 추출중...
# 1개 추출완료. 누적46개
# 100번째 종목 LG유플러스 추출중...
# 1개 추출완료. 누적47개
# 2/2 [==============================] - 3s 783ms/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 788ms/step
# 2/2 [==============================] - 3s 789ms/step
# 2/2 [==============================] - 5s 1s/step
# 0
# 101번째 종목 LG이노텍 추출중...
# 1개 추출완료. 누적1개
# 102번째 종목 LG전자 추출중...
# 1개 추출완료. 누적2개
# 103번째 종목 LG전자우 추출중...
# 1개 추출완료. 누적3개
# 104번째 종목 LG헬로비전 추출중...
# 1개 추출완료. 누적4개
# 105번째 종목 LG화학 추출중...
# 1개 추출완료. 누적5개
# 106번째 종목 LG화학우 추출중...
# 1개 추출완료. 누적6개
# 107번째 종목 LIG넥스원 추출중...
# 1개 추출완료. 누적7개
# 108번째 종목 LS 추출중...
# 1개 추출완료. 누적8개
# 109번째 종목 LS ELECTRIC 추출중...
# 1개 추출완료. 누적9개
# 110번째 종목 LS네트웍스 추출중...
# 1개 추출완료. 누적10개
# 111번째 종목 LS전선아시아 추출중...
# 1개 추출완료. 누적11개
# 112번째 종목 LX세미콘 추출중...
# 1개 추출완료. 누적12개
# 113번째 종목 LX인터내셔널 추출중...
# 1개 추출완료. 누적13개
# 114번째 종목 LX하우시스 추출중...
# 1개 추출완료. 누적14개
# 115번째 종목 LX하우시스우 추출중...
# 1개 추출완료. 누적15개
# 116번째 종목 LX홀딩스 추출중...
# 1개 추출완료. 누적16개
# 117번째 종목 LX홀딩스1우 추출중...
# 1개 추출완료. 누적17개
# 118번째 종목 MH에탄올 추출중...
# 1개 추출완료. 누적18개
# 119번째 종목 NAVER 추출중...
# 1개 추출완료. 누적19개
# 120번째 종목 NHN 추출중...
# 1개 추출완료. 누적20개
# 121번째 종목 NH올원리츠 추출중...
# 1개 추출완료. 누적21개
# 122번째 종목 NH투자증권 추출중...
# 1개 추출완료. 누적22개
# 123번째 종목 NH투자증권우 추출중...
# 1개 추출완료. 누적23개
# 124번째 종목 NH프라임리츠 추출중...
# 1개 추출완료. 누적24개
# 125번째 종목 NICE 추출중...
# 1개 추출완료. 누적25개
# 126번째 종목 NICE평가정보 추출중...
# 1개 추출완료. 누적26개
# 127번째 종목 NI스틸 추출중...
# 1개 추출완료. 누적27개
# 128번째 종목 NPC 추출중...
# 1개 추출완료. 누적28개
# 129번째 종목 NPC우 추출중...
# 1개 추출완료. 누적29개
# 130번째 종목 OCI 추출중...
# 0개 추출완료. 누적29개
# 131번째 종목 OCI홀딩스 추출중...
# 1개 추출완료. 누적30개
# 132번째 종목 PI첨단소재 추출중...
# 1개 추출완료. 누적31개
# 133번째 종목 POSCO홀딩스 추출중...
# 1개 추출완료. 누적32개
# 134번째 종목 S-Oil 추출중...
# 1개 추출완료. 누적33개
# 135번째 종목 S-Oil우 추출중...
# 1개 추출완료. 누적34개
# 136번째 종목 SBS 추출중...
# 1개 추출완료. 누적35개
# 137번째 종목 SGC에너지 추출중...
# 1개 추출완료. 누적36개
# 138번째 종목 SG글로벌 추출중...
# 1개 추출완료. 누적37개
# 139번째 종목 SG세계물산 추출중...
# 1개 추출완료. 누적38개
# 140번째 종목 SHD 추출중...
# 1개 추출완료. 누적39개
# 141번째 종목 SH에너지화학 추출중...
# 1개 추출완료. 누적40개
# 142번째 종목 SIMPAC 추출중...
# 1개 추출완료. 누적41개
# 143번째 종목 SJM 추출중...
# 1개 추출완료. 누적42개
# 144번째 종목 SJM홀딩스 추출중...
# 1개 추출완료. 누적43개
# 145번째 종목 SK 추출중...
# 1개 추출완료. 누적44개
# 146번째 종목 SKC 추출중...
# 1개 추출완료. 누적45개
# 147번째 종목 SK가스 추출중...
# 1개 추출완료. 누적46개
# 148번째 종목 SK네트웍스 추출중...
# 1개 추출완료. 누적47개
# 149번째 종목 SK디스커버리 추출중...
# 1개 추출완료. 누적48개
# 150번째 종목 SK디스커버리우 추출중...
# 1개 추출완료. 누적49개
# 2/2 [==============================] - 3s 952ms/step
# 2/2 [==============================] - 4s 917ms/step
# 2/2 [==============================] - 3s 906ms/step
# 2/2 [==============================] - 3s 929ms/step
# 2/2 [==============================] - 3s 923ms/step
# 0
# 151번째 종목 SK디앤디 추출중...
# 1개 추출완료. 누적1개
# 152번째 종목 SK렌터카 추출중...
# 1개 추출완료. 누적2개
# 153번째 종목 SK리츠 추출중...
# 1개 추출완료. 누적3개
# 154번째 종목 SK바이오사이언스 추출중...
# 1개 추출완료. 누적4개
# 155번째 종목 SK바이오팜 추출중...
# 1개 추출완료. 누적5개
# 156번째 종목 SK스퀘어 추출중...
# 1개 추출완료. 누적6개
# 157번째 종목 SK아이이테크놀로지 추출중...
# 1개 추출완료. 누적7개
# 158번째 종목 SK오션플랜트 추출중...
# 1개 추출완료. 누적8개
# 159번째 종목 SK우 추출중...
# 1개 추출완료. 누적9개
# 160번째 종목 SK이노베이션 추출중...
# 1개 추출완료. 누적10개
# 161번째 종목 SK이노베이션우 추출중...
# 1개 추출완료. 누적11개
# 162번째 종목 SK증권 추출중...
# 1개 추출완료. 누적12개
# 163번째 종목 SK증권우 추출중...
# 1개 추출완료. 누적13개
# 164번째 종목 SK케미칼 추출중...
# 1개 추출완료. 누적14개
# 165번째 종목 SK케미칼우 추출중...
# 1개 추출완료. 누적15개
# 166번째 종목 SK텔레콤 추출중...
# 1개 추출완료. 누적16개
# 167번째 종목 SK하이닉스 추출중...
# 1개 추출완료. 누적17개
# 168번째 종목 SNT다이내믹스 추출중...
# 1개 추출완료. 누적18개
# 169번째 종목 SNT모티브 추출중...
# 1개 추출완료. 누적19개
# 170번째 종목 SNT에너지 추출중...
# 1개 추출완료. 누적20개
# 171번째 종목 SNT홀딩스 추출중...
# 1개 추출완료. 누적21개
# 172번째 종목 SPC삼립 추출중...
# 1개 추출완료. 누적22개
# 173번째 종목 STX 추출중...
# 1개 추출완료. 누적23개
# 174번째 종목 STX엔진 추출중...
# 1개 추출완료. 누적24개
# 175번째 종목 STX중공업 추출중...
# 1개 추출완료. 누적25개
# 176번째 종목 SUN&L 추출중...
# 1개 추출완료. 누적26개
# 177번째 종목 TBH글로벌 추출중...
# 1개 추출완료. 누적27개
# 178번째 종목 TCC스틸 추출중...
# 1개 추출완료. 누적28개
# 179번째 종목 TKG휴켐스 추출중...
# 1개 추출완료. 누적29개
# 180번째 종목 TYM 추출중...
# 1개 추출완료. 누적30개
# 181번째 종목 WISCOM 추출중...
# 1개 추출완료. 누적31개
# 182번째 종목 YG PLUS 추출중...
# 1개 추출완료. 누적32개
# 183번째 종목 가온전선 추출중...
# 1개 추출완료. 누적33개
# 184번째 종목 강남제비스코 추출중...
# 1개 추출완료. 누적34개
# 185번째 종목 강원랜드 추출중...
# 1개 추출완료. 누적35개
# 186번째 종목 갤럭시아에스엠 추출중...
# 1개 추출완료. 누적36개
# 187번째 종목 경농 추출중...
# 1개 추출완료. 누적37개
# 188번째 종목 경동나비엔 추출중...
# 1개 추출완료. 누적38개
# 189번째 종목 경동도시가스 추출중...
# 1개 추출완료. 누적39개
# 190번째 종목 경동인베스트 추출중...
# 1개 추출완료. 누적40개
# 191번째 종목 경방 추출중...
# 1개 추출완료. 누적41개
# 192번째 종목 경보제약 추출중...
# 1개 추출완료. 누적42개
# 193번째 종목 경인양행 추출중...
# 1개 추출완료. 누적43개
# 194번째 종목 경인전자 추출중...
# 1개 추출완료. 누적44개
# 195번째 종목 계룡건설 추출중...
# 1개 추출완료. 누적45개
# 196번째 종목 계양전기 추출중...
# 1개 추출완료. 누적46개
# 197번째 종목 계양전기우 추출중...
# 1개 추출완료. 누적47개
# 198번째 종목 고려산업 추출중...
# 1개 추출완료. 누적48개
# 199번째 종목 고려아연 추출중...
# 1개 추출완료. 누적49개
# 200번째 종목 고려제강 추출중...
# 1개 추출완료. 누적50개
# 2/2 [==============================] - 3s 985ms/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 948ms/step
# 2/2 [==============================] - 3s 949ms/step
# 2/2 [==============================] - 5s 2s/step
# 0
# 201번째 종목 광동제약 추출중...
# 1개 추출완료. 누적1개
# 202번째 종목 광명전기 추출중...
# 1개 추출완료. 누적2개
# 203번째 종목 광전자 추출중...
# 1개 추출완료. 누적3개
# 204번째 종목 광주신세계 추출중...
# 1개 추출완료. 누적4개
# 205번째 종목 교보증권 추출중...
# 1개 추출완료. 누적5개
# 206번째 종목 교촌에프앤비 추출중...
# 1개 추출완료. 누적6개
# 207번째 종목 국도화학 추출중...
# 1개 추출완료. 누적7개
# 208번째 종목 국동 추출중...
# 1개 추출완료. 누적8개
# 209번째 종목 국보 추출중...
# 1개 추출완료. 누적9개
# 210번째 종목 국제약품 추출중...
# 1개 추출완료. 누적10개
# 211번째 종목 그린케미칼 추출중...
# 1개 추출완료. 누적11개
# 212번째 종목 극동유화 추출중...
# 1개 추출완료. 누적12개
# 213번째 종목 금강공업 추출중...
# 1개 추출완료. 누적13개
# 214번째 종목 금강공업우 추출중...
# 1개 추출완료. 누적14개
# 215번째 종목 금비 추출중...
# 1개 추출완료. 누적15개
# 216번째 종목 금양 추출중...
# 1개 추출완료. 누적16개
# 217번째 종목 금호건설 추출중...
# 1개 추출완료. 누적17개
# 218번째 종목 금호건설우 추출중...
# 1개 추출완료. 누적18개
# 219번째 종목 금호석유 추출중...
# 1개 추출완료. 누적19개
# 220번째 종목 금호석유우 추출중...
# 1개 추출완료. 누적20개
# 221번째 종목 금호에이치티 추출중...
# 1개 추출완료. 누적21개
# 222번째 종목 금호전기 추출중...
# 1개 추출완료. 누적22개
# 223번째 종목 금호타이어 추출중...
# 1개 추출완료. 누적23개
# 224번째 종목 기신정기 추출중...
# 1개 추출완료. 누적24개
# 225번째 종목 기아 추출중...
# 1개 추출완료. 누적25개
# 226번째 종목 기업은행 추출중...
# 1개 추출완료. 누적26개
# 227번째 종목 까뮤이앤씨 추출중...
# 1개 추출완료. 누적27개
# 228번째 종목 깨끗한나라 추출중...
# 1개 추출완료. 누적28개
# 229번째 종목 깨끗한나라우 추출중...
# 1개 추출완료. 누적29개
# 230번째 종목 남광토건 추출중...
# 1개 추출완료. 누적30개
# 231번째 종목 남선알미늄 추출중...
# 1개 추출완료. 누적31개
# 232번째 종목 남선알미우 추출중...
# 1개 추출완료. 누적32개
# 233번째 종목 남성 추출중...
# 1개 추출완료. 누적33개
# 234번째 종목 남양유업 추출중...
# 1개 추출완료. 누적34개
# 235번째 종목 남양유업우 추출중...
# 1개 추출완료. 누적35개
# 236번째 종목 남해화학 추출중...
# 1개 추출완료. 누적36개
# 237번째 종목 넥센 추출중...
# 1개 추출완료. 누적37개
# 238번째 종목 넥센우 추출중...
# 1개 추출완료. 누적38개
# 239번째 종목 넥센타이어 추출중...
# 1개 추출완료. 누적39개
# 240번째 종목 넥센타이어1우B 추출중...
# 1개 추출완료. 누적40개
# 241번째 종목 넷마블 추출중...
# 1개 추출완료. 누적41개
# 242번째 종목 노루페인트 추출중...
# 1개 추출완료. 누적42개
# 243번째 종목 노루페인트우 추출중...
# 1개 추출완료. 누적43개
# 244번째 종목 노루홀딩스 추출중...
# 1개 추출완료. 누적44개
# 245번째 종목 노루홀딩스우 추출중...
# 1개 추출완료. 누적45개
# 246번째 종목 녹십자 추출중...
# 1개 추출완료. 누적46개
# 247번째 종목 녹십자홀딩스 추출중...
# 1개 추출완료. 누적47개
# 248번째 종목 녹십자홀딩스2우 추출중...
# 1개 추출완료. 누적48개
# 249번째 종목 농심 추출중...
# 1개 추출완료. 누적49개
# 250번째 종목 농심홀딩스 추출중...
# 1개 추출완료. 누적50개
# 2/2 [==============================] - 5s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 955ms/step
# 2/2 [==============================] - 3s 993ms/step
# 2/2 [==============================] - 5s 1s/step
# 0
# 251번째 종목 다스코 추출중...
# 1개 추출완료. 누적1개
# 252번째 종목 다올투자증권 추출중...
# 1개 추출완료. 누적2개
# 253번째 종목 다우기술 추출중...
# 1개 추출완료. 누적3개
# 254번째 종목 다이나믹디자인 추출중...
# 1개 추출완료. 누적4개
# 255번째 종목 대교 추출중...
# 1개 추출완료. 누적5개
# 256번째 종목 대교우B 추출중...
# 1개 추출완료. 누적6개
# 257번째 종목 대구백화점 추출중...
# 1개 추출완료. 누적7개
# 258번째 종목 대덕 추출중...
# 1개 추출완료. 누적8개
# 259번째 종목 대덕1우 추출중...
# 1개 추출완료. 누적9개
# 260번째 종목 대덕전자 추출중...
# 1개 추출완료. 누적10개
# 261번째 종목 대덕전자1우 추출중...
# 1개 추출완료. 누적11개
# 262번째 종목 대동 추출중...
# 1개 추출완료. 누적12개
# 263번째 종목 대동전자 추출중...
# 1개 추출완료. 누적13개
# 264번째 종목 대림B&Co 추출중...
# 1개 추출완료. 누적14개
# 265번째 종목 대림통상 추출중...
# 1개 추출완료. 누적15개
# 266번째 종목 대상 추출중...
# 1개 추출완료. 누적16개
# 267번째 종목 대상우 추출중...
# 1개 추출완료. 누적17개
# 268번째 종목 대상홀딩스 추출중...
# 1개 추출완료. 누적18개
# 269번째 종목 대상홀딩스우 추출중...
# 1개 추출완료. 누적19개
# 270번째 종목 대성산업 추출중...
# 1개 추출완료. 누적20개
# 271번째 종목 대성에너지 추출중...
# 1개 추출완료. 누적21개
# 272번째 종목 대성홀딩스 추출중...
# 1개 추출완료. 누적22개
# 273번째 종목 대신증권 추출중...
# 1개 추출완료. 누적23개
# 274번째 종목 대신증권2우B 추출중...
# 1개 추출완료. 누적24개
# 275번째 종목 대신증권우 추출중...
# 1개 추출완료. 누적25개
# 276번째 종목 대양금속 추출중...
# 1개 추출완료. 누적26개
# 277번째 종목 대영포장 추출중...
# 1개 추출완료. 누적27개
# 278번째 종목 대우건설 추출중...
# 1개 추출완료. 누적28개
# 279번째 종목 대우부품 추출중...
# 1개 추출완료. 누적29개
# 280번째 종목 대웅 추출중...
# 1개 추출완료. 누적30개
# 281번째 종목 대웅제약 추출중...
# 1개 추출완료. 누적31개
# 282번째 종목 대원강업 추출중...
# 1개 추출완료. 누적32개
# 283번째 종목 대원전선 추출중...
# 1개 추출완료. 누적33개
# 284번째 종목 대원전선우 추출중...
# 1개 추출완료. 누적34개
# 285번째 종목 대원제약 추출중...
# 1개 추출완료. 누적35개
# 286번째 종목 대원화성 추출중...
# 1개 추출완료. 누적36개
# 287번째 종목 대유에이텍 추출중...
# 1개 추출완료. 누적37개
# 288번째 종목 대유플러스 추출중...
# 1개 추출완료. 누적38개
# 289번째 종목 대창 추출중...
# 1개 추출완료. 누적39개
# 290번째 종목 대창단조 추출중...
# 1개 추출완료. 누적40개
# 291번째 종목 대한방직 추출중...
# 1개 추출완료. 누적41개
# 292번째 종목 대한유화 추출중...
# 1개 추출완료. 누적42개
# 293번째 종목 대한전선 추출중...
# 1개 추출완료. 누적43개
# 294번째 종목 대한제강 추출중...
# 1개 추출완료. 누적44개
# 295번째 종목 대한제당 추출중...
# 1개 추출완료. 누적45개
# 296번째 종목 대한제당우 추출중...
# 1개 추출완료. 누적46개
# 297번째 종목 대한제분 추출중...
# 1개 추출완료. 누적47개
# 298번째 종목 대한항공 추출중...
# 1개 추출완료. 누적48개
# 299번째 종목 대한항공우 추출중...
# 1개 추출완료. 누적49개
# 300번째 종목 대한해운 추출중...
# 1개 추출완료. 누적50개
# 2/2 [==============================] - 3s 948ms/step
# 2/2 [==============================] - 3s 953ms/step
# 2/2 [==============================] - 5s 2s/step
# 2/2 [==============================] - 3s 946ms/step
# 2/2 [==============================] - 3s 941ms/step
# 0
# 301번째 종목 대한화섬 추출중...
# 1개 추출완료. 누적1개
# 302번째 종목 대현 추출중...
# 1개 추출완료. 누적2개
# 303번째 종목 대호에이엘 추출중...
# 1개 추출완료. 누적3개
# 304번째 종목 더메디팜 추출중...
# 1개 추출완료. 누적4개
# 305번째 종목 더블유게임즈 추출중...
# 1개 추출완료. 누적5개
# 306번째 종목 더존비즈온 추출중...
# 1개 추출완료. 누적6개
# 307번째 종목 덕성 추출중...
# 1개 추출완료. 누적7개
# 308번째 종목 덕성우 추출중...
# 1개 추출완료. 누적8개
# 309번째 종목 덕양산업 추출중...
# 1개 추출완료. 누적9개
# 310번째 종목 덴티움 추출중...
# 1개 추출완료. 누적10개
# 311번째 종목 도화엔지니어링 추출중...
# 1개 추출완료. 누적11개
# 312번째 종목 동국씨엠 추출중...
# 0개 추출완료. 누적11개
# 313번째 종목 동국제강 추출중...
# 0개 추출완료. 누적11개
# 314번째 종목 동국홀딩스 추출중...
# 1개 추출완료. 누적12개
# 315번째 종목 동남합성 추출중...
# 1개 추출완료. 누적13개
# 316번째 종목 동방 추출중...
# 1개 추출완료. 누적14개
# 317번째 종목 동방아그로 추출중...
# 1개 추출완료. 누적15개
# 318번째 종목 동부건설 추출중...
# 1개 추출완료. 누적16개
# 319번째 종목 동부건설우 추출중...
# 1개 추출완료. 누적17개
# 320번째 종목 동서 추출중...
# 1개 추출완료. 누적18개
# 321번째 종목 동성제약 추출중...
# 1개 추출완료. 누적19개
# 322번째 종목 동성케미컬 추출중...
# 1개 추출완료. 누적20개
# 323번째 종목 동아쏘시오홀딩스 추출중...
# 1개 추출완료. 누적21개
# 324번째 종목 동아에스티 추출중...
# 1개 추출완료. 누적22개
# 325번째 종목 동아지질 추출중...
# 1개 추출완료. 누적23개
# 326번째 종목 동아타이어 추출중...
# 1개 추출완료. 누적24개
# 327번째 종목 동양 추출중...
# 1개 추출완료. 누적25개
# 328번째 종목 동양2우B 추출중...
# 1개 추출완료. 누적26개
# 329번째 종목 동양고속 추출중...
# 1개 추출완료. 누적27개
# 330번째 종목 동양생명 추출중...
# 1개 추출완료. 누적28개
# 331번째 종목 동양우 추출중...
# 1개 추출완료. 누적29개
# 332번째 종목 동양철관 추출중...
# 1개 추출완료. 누적30개
# 333번째 종목 동양피스톤 추출중...
# 1개 추출완료. 누적31개
# 334번째 종목 동원F&B 추출중...
# 1개 추출완료. 누적32개
# 335번째 종목 동원금속 추출중...
# 1개 추출완료. 누적33개
# 336번째 종목 동원산업 추출중...
# 1개 추출완료. 누적34개
# 337번째 종목 동원수산 추출중...
# 1개 추출완료. 누적35개
# 338번째 종목 동원시스템즈 추출중...
# 1개 추출완료. 누적36개
# 339번째 종목 동원시스템즈우 추출중...
# 1개 추출완료. 누적37개
# 340번째 종목 동일고무벨트 추출중...
# 1개 추출완료. 누적38개
# 341번째 종목 동일산업 추출중...
# 1개 추출완료. 누적39개
# 342번째 종목 동일제강 추출중...
# 1개 추출완료. 누적40개
# 343번째 종목 동화약품 추출중...
# 1개 추출완료. 누적41개
# 344번째 종목 두산 추출중...
# 1개 추출완료. 누적42개
# 345번째 종목 두산2우B 추출중...
# 1개 추출완료. 누적43개
# 346번째 종목 두산밥캣 추출중...
# 1개 추출완료. 누적44개
# 347번째 종목 두산에너빌리티 추출중...
# 1개 추출완료. 누적45개
# 348번째 종목 두산우 추출중...
# 1개 추출완료. 누적46개
# 349번째 종목 두산퓨얼셀 추출중...
# 1개 추출완료. 누적47개
# 350번째 종목 두산퓨얼셀1우 추출중...
# 1개 추출완료. 누적48개
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 4s 897ms/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 851ms/step
# 2/2 [==============================] - 4s 2s/step
# 0
# 351번째 종목 두산퓨얼셀2우B 추출중...
# 1개 추출완료. 누적1개
# 352번째 종목 두올 추출중...
# 1개 추출완료. 누적2개
# 353번째 종목 드림텍 추출중...
# 1개 추출완료. 누적3개
# 354번째 종목 디씨엠 추출중...
# 1개 추출완료. 누적4개
# 355번째 종목 디아이 추출중...
# 1개 추출완료. 누적5개
# 356번째 종목 디아이씨 추출중...
# 1개 추출완료. 누적6개
# 357번째 종목 디앤디플랫폼리츠 추출중...
# 1개 추출완료. 누적7개
# 358번째 종목 디와이 추출중...
# 1개 추출완료. 누적8개
# 359번째 종목 디와이파워 추출중...
# 1개 추출완료. 누적9개
# 360번째 종목 락앤락 추출중...
# 1개 추출완료. 누적10개
# 361번째 종목 롯데관광개발 추출중...
# 1개 추출완료. 누적11개
# 362번째 종목 롯데렌탈 추출중...
# 1개 추출완료. 누적12개
# 363번째 종목 롯데리츠 추출중...
# 1개 추출완료. 누적13개
# 364번째 종목 롯데손해보험 추출중...
# 1개 추출완료. 누적14개
# 365번째 종목 롯데쇼핑 추출중...
# 1개 추출완료. 누적15개
# 366번째 종목 롯데에너지머티리얼즈 추출중...
# 1개 추출완료. 누적16개
# 367번째 종목 롯데웰푸드 추출중...
# 1개 추출완료. 누적17개
# 368번째 종목 롯데정밀화학 추출중...
# 1개 추출완료. 누적18개
# 369번째 종목 롯데정보통신 추출중...
# 1개 추출완료. 누적19개
# 370번째 종목 롯데지주 추출중...
# 1개 추출완료. 누적20개
# 371번째 종목 롯데지주우 추출중...
# 1개 추출완료. 누적21개
# 372번째 종목 롯데칠성 추출중...
# 1개 추출완료. 누적22개
# 373번째 종목 롯데칠성우 추출중...
# 1개 추출완료. 누적23개
# 374번째 종목 롯데케미칼 추출중...
# 1개 추출완료. 누적24개
# 375번째 종목 롯데하이마트 추출중...
# 1개 추출완료. 누적25개
# 376번째 종목 마니커 추출중...
# 1개 추출완료. 누적26개
# 377번째 종목 마스턴프리미어리츠 추출중...
# 1개 추출완료. 누적27개
# 378번째 종목 만호제강 추출중...
# 1개 추출완료. 누적28개
# 379번째 종목 맥쿼리인프라 추출중...
# 1개 추출완료. 누적29개
# 380번째 종목 맵스리얼티1 추출중...
# 1개 추출완료. 누적30개
# 381번째 종목 메리츠금융지주 추출중...
# 1개 추출완료. 누적31개
# 382번째 종목 메타랩스 추출중...
# 1개 추출완료. 누적32개
# 383번째 종목 명문제약 추출중...
# 1개 추출완료. 누적33개
# 384번째 종목 명신산업 추출중...
# 1개 추출완료. 누적34개
# 385번째 종목 모나리자 추출중...
# 1개 추출완료. 누적35개
# 386번째 종목 모나미 추출중...
# 1개 추출완료. 누적36개
# 387번째 종목 모두투어리츠 추출중...
# 1개 추출완료. 누적37개
# 388번째 종목 모토닉 추출중...
# 1개 추출완료. 누적38개
# 389번째 종목 무림P&P 추출중...
# 1개 추출완료. 누적39개
# 390번째 종목 무림페이퍼 추출중...
# 1개 추출완료. 누적40개
# 391번째 종목 무학 추출중...
# 1개 추출완료. 누적41개
# 392번째 종목 문배철강 추출중...
# 1개 추출완료. 누적42개
# 393번째 종목 미래산업 추출중...
# 1개 추출완료. 누적43개
# 394번째 종목 미래아이앤지 추출중...
# 1개 추출완료. 누적44개
# 395번째 종목 미래에셋글로벌리츠 추출중...
# 1개 추출완료. 누적45개
# 396번째 종목 미래에셋맵스리츠 추출중...
# 1개 추출완료. 누적46개
# 397번째 종목 미래에셋생명 추출중...
# 1개 추출완료. 누적47개
# 398번째 종목 미래에셋증권 추출중...
# 1개 추출완료. 누적48개
# 399번째 종목 미래에셋증권2우B 추출중...
# 1개 추출완료. 누적49개
# 400번째 종목 미래에셋증권우 추출중...
# 1개 추출완료. 누적50개
# 2/2 [==============================] - 5s 2s/step
# 2/2 [==============================] - 3s 984ms/step
# 2/2 [==============================] - 3s 991ms/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 989ms/step
# 0
# 401번째 종목 미원상사 추출중...
# 1개 추출완료. 누적1개
# 402번째 종목 미원에스씨 추출중...
# 1개 추출완료. 누적2개
# 403번째 종목 미원홀딩스 추출중...
# 1개 추출완료. 누적3개
# 404번째 종목 미원화학 추출중...
# 1개 추출완료. 누적4개
# 405번째 종목 미창석유 추출중...
# 1개 추출완료. 누적5개
# 406번째 종목 바다로19호 추출중...
# 1개 추출완료. 누적6개
# 407번째 종목 바이오노트 추출중...
# 1개 추출완료. 누적7개
# 408번째 종목 방림 추출중...
# 1개 추출완료. 누적8개
# 409번째 종목 백광산업 추출중...
# 1개 추출완료. 누적9개
# 410번째 종목 백산 추출중...
# 1개 추출완료. 누적10개
# 411번째 종목 범양건영 추출중...
# 1개 추출완료. 누적11개
# 412번째 종목 벽산 추출중...
# 1개 추출완료. 누적12개
# 413번째 종목 보락 추출중...
# 1개 추출완료. 누적13개
# 414번째 종목 보령 추출중...
# 1개 추출완료. 누적14개
# 415번째 종목 보해양조 추출중...
# 1개 추출완료. 누적15개
# 416번째 종목 부광약품 추출중...
# 1개 추출완료. 누적16개
# 417번째 종목 부국증권 추출중...
# 1개 추출완료. 누적17개
# 418번째 종목 부국증권우 추출중...
# 1개 추출완료. 누적18개
# 419번째 종목 부국철강 추출중...
# 1개 추출완료. 누적19개
# 420번째 종목 부산산업 추출중...
# 1개 추출완료. 누적20개
# 421번째 종목 부산주공 추출중...
# 0개 추출완료. 누적20개
# 422번째 종목 비비안 추출중...
# 1개 추출완료. 누적21개
# 423번째 종목 비상교육 추출중...
# 1개 추출완료. 누적22개
# 424번째 종목 비에이치 추출중...
# 1개 추출완료. 누적23개
# 425번째 종목 비케이탑스 추출중...
# 0개 추출완료. 누적23개
# 426번째 종목 빙그레 추출중...
# 1개 추출완료. 누적24개
# 427번째 종목 사조대림 추출중...
# 1개 추출완료. 누적25개
# 428번째 종목 사조동아원 추출중...
# 1개 추출완료. 누적26개
# 429번째 종목 사조산업 추출중...
# 1개 추출완료. 누적27개
# 430번째 종목 사조씨푸드 추출중...
# 1개 추출완료. 누적28개
# 431번째 종목 사조오양 추출중...
# 1개 추출완료. 누적29개
# 432번째 종목 삼부토건 추출중...
# 1개 추출완료. 누적30개
# 433번째 종목 삼성FN리츠 추출중...
# 1개 추출완료. 누적31개
# 434번째 종목 삼성SDI 추출중...
# 1개 추출완료. 누적32개
# 435번째 종목 삼성SDI우 추출중...
# 1개 추출완료. 누적33개
# 436번째 종목 삼성공조 추출중...
# 1개 추출완료. 누적34개
# 437번째 종목 삼성물산 추출중...
# 1개 추출완료. 누적35개
# 438번째 종목 삼성물산우B 추출중...
# 1개 추출완료. 누적36개
# 439번째 종목 삼성바이오로직스 추출중...
# 1개 추출완료. 누적37개
# 440번째 종목 삼성생명 추출중...
# 1개 추출완료. 누적38개
# 441번째 종목 삼성에스디에스 추출중...
# 1개 추출완료. 누적39개
# 442번째 종목 삼성엔지니어링 추출중...
# 1개 추출완료. 누적40개
# 443번째 종목 삼성전기 추출중...
# 1개 추출완료. 누적41개
# 444번째 종목 삼성전기우 추출중...
# 1개 추출완료. 누적42개
# 445번째 종목 삼성전자 추출중...
# 1개 추출완료. 누적43개
# 446번째 종목 삼성전자우 추출중...
# 1개 추출완료. 누적44개
# 447번째 종목 삼성제약 추출중...
# 1개 추출완료. 누적45개
# 448번째 종목 삼성중공업 추출중...
# 1개 추출완료. 누적46개
# 449번째 종목 삼성증권 추출중...
# 1개 추출완료. 누적47개
# 450번째 종목 삼성출판사 추출중...
# 1개 추출완료. 누적48개
# 2/2 [==============================] - 3s 856ms/step
# 2/2 [==============================] - 4s 857ms/step
# 2/2 [==============================] - 3s 854ms/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 925ms/step
# 0
# 451번째 종목 삼성카드 추출중...
# 1개 추출완료. 누적1개
# 452번째 종목 삼성화재 추출중...
# 1개 추출완료. 누적2개
# 453번째 종목 삼성화재우 추출중...
# 1개 추출완료. 누적3개
# 454번째 종목 삼아알미늄 추출중...
# 1개 추출완료. 누적4개
# 455번째 종목 삼양사 추출중...
# 1개 추출완료. 누적5개
# 456번째 종목 삼양사우 추출중...
# 1개 추출완료. 누적6개
# 457번째 종목 삼양식품 추출중...
# 1개 추출완료. 누적7개
# 458번째 종목 삼양통상 추출중...
# 1개 추출완료. 누적8개
# 459번째 종목 삼양패키징 추출중...
# 1개 추출완료. 누적9개
# 460번째 종목 삼양홀딩스 추출중...
# 1개 추출완료. 누적10개
# 461번째 종목 삼양홀딩스우 추출중...
# 1개 추출완료. 누적11개
# 462번째 종목 삼영 추출중...
# 1개 추출완료. 누적12개
# 463번째 종목 삼영무역 추출중...
# 1개 추출완료. 누적13개
# 464번째 종목 삼영전자 추출중...
# 1개 추출완료. 누적14개
# 465번째 종목 삼원강재 추출중...
# 1개 추출완료. 누적15개
# 466번째 종목 삼익THK 추출중...
# 1개 추출완료. 누적16개
# 467번째 종목 삼익악기 추출중...
# 1개 추출완료. 누적17개
# 468번째 종목 삼일씨엔에스 추출중...
# 1개 추출완료. 누적18개
# 469번째 종목 삼일제약 추출중...
# 1개 추출완료. 누적19개
# 470번째 종목 삼정펄프 추출중...
# 1개 추출완료. 누적20개
# 471번째 종목 삼진제약 추출중...
# 1개 추출완료. 누적21개
# 472번째 종목 삼천리 추출중...
# 1개 추출완료. 누적22개
# 473번째 종목 삼호개발 추출중...
# 1개 추출완료. 누적23개
# 474번째 종목 삼화왕관 추출중...
# 1개 추출완료. 누적24개
# 475번째 종목 삼화전기 추출중...
# 1개 추출완료. 누적25개
# 476번째 종목 삼화전자 추출중...
# 1개 추출완료. 누적26개
# 477번째 종목 삼화콘덴서 추출중...
# 1개 추출완료. 누적27개
# 478번째 종목 삼화페인트 추출중...
# 1개 추출완료. 누적28개
# 479번째 종목 상상인증권 추출중...
# 1개 추출완료. 누적29개
# 480번째 종목 상신브레이크 추출중...
# 1개 추출완료. 누적30개
# 481번째 종목 새론오토모티브 추출중...
# 1개 추출완료. 누적31개
# 482번째 종목 샘표 추출중...
# 1개 추출완료. 누적32개
# 483번째 종목 샘표식품 추출중...
# 1개 추출완료. 누적33개
# 484번째 종목 서연 추출중...
# 1개 추출완료. 누적34개
# 485번째 종목 서연이화 추출중...
# 1개 추출완료. 누적35개
# 486번째 종목 서울가스 추출중...
# 1개 추출완료. 누적36개
# 487번째 종목 서울식품 추출중...
# 1개 추출완료. 누적37개
# 488번째 종목 서울식품우 추출중...
# 1개 추출완료. 누적38개
# 489번째 종목 서원 추출중...
# 1개 추출완료. 누적39개
# 490번째 종목 서흥 추출중...
# 1개 추출완료. 누적40개
# 491번째 종목 선도전기 추출중...
# 0개 추출완료. 누적40개
# 492번째 종목 선진 추출중...
# 1개 추출완료. 누적41개
# 493번째 종목 성문전자 추출중...
# 1개 추출완료. 누적42개
# 494번째 종목 성문전자우 추출중...
# 1개 추출완료. 누적43개
# 495번째 종목 성보화학 추출중...
# 1개 추출완료. 누적44개
# 496번째 종목 성신양회 추출중...
# 1개 추출완료. 누적45개
# 497번째 종목 성신양회우 추출중...
# 1개 추출완료. 누적46개
# 498번째 종목 성안 추출중...
# 1개 추출완료. 누적47개
# 499번째 종목 성창기업지주 추출중...
# 1개 추출완료. 누적48개
# 500번째 종목 세기상사 추출중...
# 1개 추출완료. 누적49개
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 899ms/step
# 2/2 [==============================] - 3s 903ms/step
# 2/2 [==============================] - 5s 1s/step
# 2/2 [==============================] - 3s 950ms/step
# 0
# 501번째 종목 세방 추출중...
# 1개 추출완료. 누적1개
# 502번째 종목 세방우 추출중...
# 1개 추출완료. 누적2개
# 503번째 종목 세방전지 추출중...
# 1개 추출완료. 누적3개
# 504번째 종목 세아베스틸지주 추출중...
# 1개 추출완료. 누적4개
# 505번째 종목 세아제강 추출중...
# 1개 추출완료. 누적5개
# 506번째 종목 세아제강지주 추출중...
# 1개 추출완료. 누적6개
# 507번째 종목 세아특수강 추출중...
# 1개 추출완료. 누적7개
# 508번째 종목 세아홀딩스 추출중...
# 1개 추출완료. 누적8개
# 509번째 종목 세우글로벌 추출중...
# 1개 추출완료. 누적9개
# 510번째 종목 세원이앤씨 추출중...
# 0개 추출완료. 누적9개
# 511번째 종목 세원정공 추출중...
# 1개 추출완료. 누적10개
# 512번째 종목 세이브존I&C 추출중...
# 1개 추출완료. 누적11개
# 513번째 종목 세종공업 추출중...
# 1개 추출완료. 누적12개
# 514번째 종목 세진중공업 추출중...
# 1개 추출완료. 누적13개
# 515번째 종목 세하 추출중...
# 1개 추출완료. 누적14개
# 516번째 종목 셀트리온 추출중...
# 1개 추출완료. 누적15개
# 517번째 종목 솔루스첨단소재 추출중...
# 1개 추출완료. 누적16개
# 518번째 종목 솔루스첨단소재1우 추출중...
# 1개 추출완료. 누적17개
# 519번째 종목 솔루스첨단소재2우B 추출중...
# 1개 추출완료. 누적18개
# 520번째 종목 솔루엠 추출중...
# 1개 추출완료. 누적19개
# 521번째 종목 송원산업 추출중...
# 1개 추출완료. 누적20개
# 522번째 종목 수산인더스트리 추출중...
# 1개 추출완료. 누적21개
# 523번째 종목 수산중공업 추출중...
# 1개 추출완료. 누적22개
# 524번째 종목 스카이라이프 추출중...
# 1개 추출완료. 누적23개
# 525번째 종목 스틱인베스트먼트 추출중...
# 1개 추출완료. 누적24개
# 526번째 종목 시디즈 추출중...
# 1개 추출완료. 누적25개
# 527번째 종목 신대양제지 추출중...
# 1개 추출완료. 누적26개
# 528번째 종목 신도리코 추출중...
# 1개 추출완료. 누적27개
# 529번째 종목 신라교역 추출중...
# 1개 추출완료. 누적28개
# 530번째 종목 신성이엔지 추출중...
# 1개 추출완료. 누적29개
# 531번째 종목 신성통상 추출중...
# 1개 추출완료. 누적30개
# 532번째 종목 신세계 추출중...
# 1개 추출완료. 누적31개
# 533번째 종목 신세계 I&C 추출중...
# 1개 추출완료. 누적32개
# 534번째 종목 신세계건설 추출중...
# 1개 추출완료. 누적33개
# 535번째 종목 신세계인터내셔날 추출중...
# 1개 추출완료. 누적34개
# 536번째 종목 신세계푸드 추출중...
# 1개 추출완료. 누적35개
# 537번째 종목 신송홀딩스 추출중...
# 1개 추출완료. 누적36개
# 538번째 종목 신영와코루 추출중...
# 1개 추출완료. 누적37개
# 539번째 종목 신영증권 추출중...
# 1개 추출완료. 누적38개
# 540번째 종목 신영증권우 추출중...
# 1개 추출완료. 누적39개
# 541번째 종목 신원 추출중...
# 1개 추출완료. 누적40개
# 542번째 종목 신일전자 추출중...
# 1개 추출완료. 누적41개
# 543번째 종목 신풍 추출중...
# 1개 추출완료. 누적42개
# 544번째 종목 신풍제약 추출중...
# 1개 추출완료. 누적43개
# 545번째 종목 신풍제약우 추출중...
# 1개 추출완료. 누적44개
# 546번째 종목 신한서부티엔디리츠 추출중...
# 1개 추출완료. 누적45개
# 547번째 종목 신한알파리츠 추출중...
# 1개 추출완료. 누적46개
# 548번째 종목 신한지주 추출중...
# 1개 추출완료. 누적47개
# 549번째 종목 신흥 추출중...
# 1개 추출완료. 누적48개
# 550번째 종목 쌍방울 추출중...
# 0개 추출완료. 누적48개
# 2/2 [==============================] - 3s 856ms/step
# 2/2 [==============================] - 4s 850ms/step
# 2/2 [==============================] - 3s 881ms/step
# 2/2 [==============================] - 3s 853ms/step
# 2/2 [==============================] - 4s 888ms/step
# 0
# 551번째 종목 쌍용C&E 추출중...
# 1개 추출완료. 누적1개
# 552번째 종목 써니전자 추출중...
# 1개 추출완료. 누적2개
# 553번째 종목 쎌마테라퓨틱스 추출중...
# 0개 추출완료. 누적2개
# 554번째 종목 쏘카 추출중...
# 1개 추출완료. 누적3개
# 555번째 종목 씨아이테크 추출중...
# 1개 추출완료. 누적4개
# 556번째 종목 씨에스윈드 추출중...
# 1개 추출완료. 누적5개
# 557번째 종목 씨티알모빌리티 추출중...
# 1개 추출완료. 누적6개
# 558번째 종목 아남전자 추출중...
# 1개 추출완료. 누적7개
# 559번째 종목 아모레G 추출중...
# 1개 추출완료. 누적8개
# 560번째 종목 아모레G3우(전환) 추출중...
# 1개 추출완료. 누적9개
# 561번째 종목 아모레G우 추출중...
# 1개 추출완료. 누적10개
# 562번째 종목 아모레퍼시픽 추출중...
# 1개 추출완료. 누적11개
# 563번째 종목 아모레퍼시픽우 추출중...
# 1개 추출완료. 누적12개
# 564번째 종목 아세아 추출중...
# 1개 추출완료. 누적13개
# 565번째 종목 아세아시멘트 추출중...
# 1개 추출완료. 누적14개
# 566번째 종목 아세아제지 추출중...
# 1개 추출완료. 누적15개
# 567번째 종목 아센디오 추출중...
# 1개 추출완료. 누적16개
# 568번째 종목 아시아나IDT 추출중...
# 1개 추출완료. 누적17개
# 569번째 종목 아시아나항공 추출중...
# 1개 추출완료. 누적18개
# 570번째 종목 아이마켓코리아 추출중...
# 1개 추출완료. 누적19개
# 571번째 종목 아이에스동서 추출중...
# 1개 추출완료. 누적20개
# 572번째 종목 아주스틸 추출중...
# 1개 추출완료. 누적21개
# 573번째 종목 알루코 추출중...
# 1개 추출완료. 누적22개
# 574번째 종목 애경산업 추출중...
# 1개 추출완료. 누적23개
# 575번째 종목 애경케미칼 추출중...
# 1개 추출완료. 누적24개
# 576번째 종목 에넥스 추출중...
# 1개 추출완료. 누적25개
# 577번째 종목 에스디바이오센서 추출중...
# 1개 추출완료. 누적26개
# 578번째 종목 에스엘 추출중...
# 1개 추출완료. 누적27개
# 579번째 종목 에스엠벡셀 추출중...
# 1개 추출완료. 누적28개
# 580번째 종목 에스원 추출중...
# 1개 추출완료. 누적29개
# 581번째 종목 에쓰씨엔지니어링 추출중...
# 1개 추출완료. 누적30개
# 582번째 종목 에어부산 추출중...
# 1개 추출완료. 누적31개
# 583번째 종목 에이리츠 추출중...
# 1개 추출완료. 누적32개
# 584번째 종목 에이블씨엔씨 추출중...
# 1개 추출완료. 누적33개
# 585번째 종목 에이엔피 추출중...
# 1개 추출완료. 누적34개
# 586번째 종목 에이프로젠 추출중...
# 1개 추출완료. 누적35개
# 587번째 종목 에이프로젠바이오로직스 추출중...
# 1개 추출완료. 누적36개
# 588번째 종목 에이플러스에셋 추출중...
# 1개 추출완료. 누적37개
# 589번째 종목 엔씨소프트 추출중...
# 1개 추출완료. 누적38개
# 590번째 종목 엔에이치스팩19호 추출중...
# 1개 추출완료. 누적39개
# 591번째 종목 엔케이 추출중...
# 1개 추출완료. 누적40개
# 592번째 종목 엘브이엠씨홀딩스 추출중...
# 1개 추출완료. 누적41개
# 593번째 종목 엠씨넥스 추출중...
# 1개 추출완료. 누적42개
# 594번째 종목 영보화학 추출중...
# 1개 추출완료. 누적43개
# 595번째 종목 영원무역 추출중...
# 1개 추출완료. 누적44개
# 596번째 종목 영원무역홀딩스 추출중...
# 1개 추출완료. 누적45개
# 597번째 종목 영진약품 추출중...
# 1개 추출완료. 누적46개
# 598번째 종목 영풍 추출중...
# 1개 추출완료. 누적47개
# 599번째 종목 영풍제지 추출중...
# 1개 추출완료. 누적48개
# 600번째 종목 영화금속 추출중...
# 1개 추출완료. 누적49개
# 2/2 [==============================] - 3s 903ms/step
# 2/2 [==============================] - 3s 899ms/step
# 2/2 [==============================] - 5s 1s/step
# 2/2 [==============================] - 3s 907ms/step
# 2/2 [==============================] - 3s 926ms/step
# 0
# 601번째 종목 영흥 추출중...
# 1개 추출완료. 누적1개
# 602번째 종목 예스코홀딩스 추출중...
# 1개 추출완료. 누적2개
# 603번째 종목 오뚜기 추출중...
# 1개 추출완료. 누적3개
# 604번째 종목 오리엔트바이오 추출중...
# 1개 추출완료. 누적4개
# 605번째 종목 오리온 추출중...
# 1개 추출완료. 누적5개
# 606번째 종목 오리온홀딩스 추출중...
# 1개 추출완료. 누적6개
# 607번째 종목 와이투솔루션 추출중...
# 1개 추출완료. 누적7개
# 608번째 종목 용평리조트 추출중...
# 1개 추출완료. 누적8개
# 609번째 종목 우리금융지주 추출중...
# 1개 추출완료. 누적9개
# 610번째 종목 우리종금 추출중...
# 1개 추출완료. 누적10개
# 611번째 종목 우성 추출중...
# 1개 추출완료. 누적11개
# 612번째 종목 우신시스템 추출중...
# 1개 추출완료. 누적12개
# 613번째 종목 우진 추출중...
# 1개 추출완료. 누적13개
# 614번째 종목 우진아이엔에스 추출중...
# 1개 추출완료. 누적14개
# 615번째 종목 우진플라임 추출중...
# 1개 추출완료. 누적15개
# 616번째 종목 웅진 추출중...
# 1개 추출완료. 누적16개
# 617번째 종목 웅진씽크빅 추출중...
# 1개 추출완료. 누적17개
# 618번째 종목 원림 추출중...
# 1개 추출완료. 누적18개
# 619번째 종목 웰바이오텍 추출중...
# 1개 추출완료. 누적19개
# 620번째 종목 윌비스 추출중...
# 1개 추출완료. 누적20개
# 621번째 종목 유나이티드제약 추출중...
# 1개 추출완료. 누적21개
# 622번째 종목 유니드 추출중...
# 1개 추출완료. 누적22개
# 623번째 종목 유니드비티플러스 추출중...
# 1개 추출완료. 누적23개
# 624번째 종목 유니온 추출중...
# 1개 추출완료. 누적24개
# 625번째 종목 유니온머티리얼 추출중...
# 1개 추출완료. 누적25개
# 626번째 종목 유니켐 추출중...
# 1개 추출완료. 누적26개
# 627번째 종목 유니퀘스트 추출중...
# 1개 추출완료. 누적27개
# 628번째 종목 유성기업 추출중...
# 1개 추출완료. 누적28개
# 629번째 종목 유수홀딩스 추출중...
# 1개 추출완료. 누적29개
# 630번째 종목 유안타증권 추출중...
# 1개 추출완료. 누적30개
# 631번째 종목 유안타증권우 추출중...
# 1개 추출완료. 누적31개
# 632번째 종목 유엔젤 추출중...
# 1개 추출완료. 누적32개
# 633번째 종목 유유제약 추출중...
# 1개 추출완료. 누적33개
# 634번째 종목 유유제약1우 추출중...
# 1개 추출완료. 누적34개
# 635번째 종목 유유제약2우B 추출중...
# 1개 추출완료. 누적35개
# 636번째 종목 유진투자증권 추출중...
# 1개 추출완료. 누적36개
# 637번째 종목 유한양행 추출중...
# 1개 추출완료. 누적37개
# 638번째 종목 유한양행우 추출중...
# 1개 추출완료. 누적38개
# 639번째 종목 유화증권 추출중...
# 1개 추출완료. 누적39개
# 640번째 종목 유화증권우 추출중...
# 1개 추출완료. 누적40개
# 641번째 종목 율촌화학 추출중...
# 1개 추출완료. 누적41개
# 642번째 종목 이건산업 추출중...
# 1개 추출완료. 누적42개
# 643번째 종목 이구산업 추출중...
# 1개 추출완료. 누적43개
# 644번째 종목 이노션 추출중...
# 1개 추출완료. 누적44개
# 645번째 종목 이리츠코크렙 추출중...
# 1개 추출완료. 누적45개
# 646번째 종목 이마트 추출중...
# 1개 추출완료. 누적46개
# 647번째 종목 이수스페셜티케미컬 추출중...
# 0개 추출완료. 누적46개
# 648번째 종목 이수페타시스 추출중...
# 1개 추출완료. 누적47개
# 649번째 종목 이수화학 추출중...
# 1개 추출완료. 누적48개
# 650번째 종목 이스타코 추출중...
# 1개 추출완료. 누적49개
# 2/2 [==============================] - 5s 2s/step
# 2/2 [==============================] - 3s 905ms/step
# 2/2 [==============================] - 3s 896ms/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 904ms/step
# 0
# 651번째 종목 이아이디 추출중...
# 0개 추출완료. 누적0개
# 652번째 종목 이엔플러스 추출중...
# 1개 추출완료. 누적1개
# 653번째 종목 이연제약 추출중...
# 1개 추출완료. 누적2개
# 654번째 종목 이월드 추출중...
# 1개 추출완료. 누적3개
# 655번째 종목 이지스레지던스리츠 추출중...
# 1개 추출완료. 누적4개
# 656번째 종목 이지스밸류리츠 추출중...
# 1개 추출완료. 누적5개
# 657번째 종목 이화산업 추출중...
# 1개 추출완료. 누적6개
# 658번째 종목 인디에프 추출중...
# 1개 추출완료. 누적7개
# 659번째 종목 인바이오젠 추출중...
# 0개 추출완료. 누적7개
# 660번째 종목 인스코비 추출중...
# 1개 추출완료. 누적8개
# 661번째 종목 인지컨트롤스 추출중...
# 1개 추출완료. 누적9개
# 662번째 종목 인천도시가스 추출중...
# 1개 추출완료. 누적10개
# 663번째 종목 인터지스 추출중...
# 1개 추출완료. 누적11개
# 664번째 종목 인팩 추출중...
# 1개 추출완료. 누적12개
# 665번째 종목 일동제약 추출중...
# 1개 추출완료. 누적13개
# 666번째 종목 일동홀딩스 추출중...
# 1개 추출완료. 누적14개
# 667번째 종목 일성건설 추출중...
# 1개 추출완료. 누적15개
# 668번째 종목 일성신약 추출중...
# 1개 추출완료. 누적16개
# 669번째 종목 일신방직 추출중...
# 1개 추출완료. 누적17개
# 670번째 종목 일신석재 추출중...
# 1개 추출완료. 누적18개
# 671번째 종목 일양약품 추출중...
# 1개 추출완료. 누적19개
# 672번째 종목 일양약품우 추출중...
# 1개 추출완료. 누적20개
# 673번째 종목 일정실업 추출중...
# 0개 추출완료. 누적20개
# 674번째 종목 일진다이아 추출중...
# 1개 추출완료. 누적21개
# 675번째 종목 일진디스플 추출중...
# 1개 추출완료. 누적22개
# 676번째 종목 일진전기 추출중...
# 1개 추출완료. 누적23개
# 677번째 종목 일진하이솔루스 추출중...
# 1개 추출완료. 누적24개
# 678번째 종목 일진홀딩스 추출중...
# 1개 추출완료. 누적25개
# 679번째 종목 잇츠한불 추출중...
# 1개 추출완료. 누적26개
# 680번째 종목 자이에스앤디 추출중...
# 1개 추출완료. 누적27개
# 681번째 종목 자화전자 추출중...
# 1개 추출완료. 누적28개
# 682번째 종목 전방 추출중...
# 1개 추출완료. 누적29개
# 683번째 종목 제이알글로벌리츠 추출중...
# 1개 추출완료. 누적30개
# 684번째 종목 제이에스코퍼레이션 추출중...
# 1개 추출완료. 누적31개
# 685번째 종목 제이준코스메틱 추출중...
# 1개 추출완료. 누적32개
# 686번째 종목 제일기획 추출중...
# 1개 추출완료. 누적33개
# 687번째 종목 제일약품 추출중...
# 1개 추출완료. 누적34개
# 688번째 종목 제일연마 추출중...
# 1개 추출완료. 누적35개
# 689번째 종목 제일파마홀딩스 추출중...
# 1개 추출완료. 누적36개
# 690번째 종목 제주은행 추출중...
# 1개 추출완료. 누적37개
# 691번째 종목 제주항공 추출중...
# 1개 추출완료. 누적38개
# 692번째 종목 조광페인트 추출중...
# 1개 추출완료. 누적39개
# 693번째 종목 조광피혁 추출중...
# 1개 추출완료. 누적40개
# 694번째 종목 조비 추출중...
# 1개 추출완료. 누적41개
# 695번째 종목 조선내화 추출중...
# 0개 추출완료. 누적41개
# 696번째 종목 조선선재 추출중...
# 1개 추출완료. 누적42개
# 697번째 종목 조일알미늄 추출중...
# 1개 추출완료. 누적43개
# 698번째 종목 조흥 추출중...
# 1개 추출완료. 누적44개
# 699번째 종목 종근당 추출중...
# 1개 추출완료. 누적45개
# 700번째 종목 종근당바이오 추출중...
# 1개 추출완료. 누적46개
# 2/2 [==============================] - 3s 752ms/step
# 2/2 [==============================] - 3s 745ms/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 739ms/step
# 2/2 [==============================] - 3s 735ms/step
# 0
# 701번째 종목 종근당홀딩스 추출중...
# 1개 추출완료. 누적1개
# 702번째 종목 주연테크 추출중...
# 1개 추출완료. 누적2개
# 703번째 종목 지누스 추출중...
# 1개 추출완료. 누적3개
# 704번째 종목 지엠비코리아 추출중...
# 1개 추출완료. 누적4개
# 705번째 종목 지역난방공사 추출중...
# 1개 추출완료. 누적5개
# 706번째 종목 진도 추출중...
# 1개 추출완료. 누적6개
# 707번째 종목 진양산업 추출중...
# 1개 추출완료. 누적7개
# 708번째 종목 진양폴리 추출중...
# 1개 추출완료. 누적8개
# 709번째 종목 진양홀딩스 추출중...
# 1개 추출완료. 누적9개
# 710번째 종목 진양화학 추출중...
# 1개 추출완료. 누적10개
# 711번째 종목 진에어 추출중...
# 1개 추출완료. 누적11개
# 712번째 종목 진원생명과학 추출중...
# 1개 추출완료. 누적12개
# 713번째 종목 진흥기업 추출중...
# 1개 추출완료. 누적13개
# 714번째 종목 진흥기업2우B 추출중...
# 1개 추출완료. 누적14개
# 715번째 종목 진흥기업우B 추출중...
# 1개 추출완료. 누적15개
# 716번째 종목 참엔지니어링 추출중...
# 1개 추출완료. 누적16개
# 717번째 종목 천일고속 추출중...
# 1개 추출완료. 누적17개
# 718번째 종목 청호ICT 추출중...
# 0개 추출완료. 누적17개
# 719번째 종목 체시스 추출중...
# 1개 추출완료. 누적18개
# 720번째 종목 카카오 추출중...
# 1개 추출완료. 누적19개
# 721번째 종목 카카오뱅크 추출중...
# 1개 추출완료. 누적20개
# 722번째 종목 카카오페이 추출중...
# 1개 추출완료. 누적21개
# 723번째 종목 카프로 추출중...
# 1개 추출완료. 누적22개
# 724번째 종목 컨버즈 추출중...
# 0개 추출완료. 누적22개
# 725번째 종목 케이비아이동국실업 추출중...
# 1개 추출완료. 누적23개
# 726번째 종목 케이씨 추출중...
# 1개 추출완료. 누적24개
# 727번째 종목 케이씨텍 추출중...
# 1개 추출완료. 누적25개
# 728번째 종목 케이카 추출중...
# 1개 추출완료. 누적26개
# 729번째 종목 케이탑리츠 추출중...
# 1개 추출완료. 누적27개
# 730번째 종목 코람코더원리츠 추출중...
# 1개 추출완료. 누적28개
# 731번째 종목 코람코에너지리츠 추출중...
# 1개 추출완료. 누적29개
# 732번째 종목 코리아써우 추출중...
# 1개 추출완료. 누적30개
# 733번째 종목 코리아써키트 추출중...
# 1개 추출완료. 누적31개
# 734번째 종목 코리아써키트2우B 추출중...
# 1개 추출완료. 누적32개
# 735번째 종목 코리안리 추출중...
# 1개 추출완료. 누적33개
# 736번째 종목 코스맥스 추출중...
# 1개 추출완료. 누적34개
# 737번째 종목 코스맥스비티아이 추출중...
# 1개 추출완료. 누적35개
# 738번째 종목 코스모신소재 추출중...
# 1개 추출완료. 누적36개
# 739번째 종목 코스모화학 추출중...
# 1개 추출완료. 누적37개
# 740번째 종목 코아스 추출중...
# 1개 추출완료. 누적38개
# 741번째 종목 코오롱 추출중...
# 1개 추출완료. 누적39개
# 742번째 종목 코오롱글로벌 추출중...
# 1개 추출완료. 누적40개
# 743번째 종목 코오롱글로벌우 추출중...
# 1개 추출완료. 누적41개
# 744번째 종목 코오롱모빌리티그룹 추출중...
# 1개 추출완료. 누적42개
# 745번째 종목 코오롱모빌리티그룹우 추출중...
# 1개 추출완료. 누적43개
# 746번째 종목 코오롱우 추출중...
# 1개 추출완료. 누적44개
# 747번째 종목 코오롱인더 추출중...
# 1개 추출완료. 누적45개
# 748번째 종목 코오롱인더우 추출중...
# 1개 추출완료. 누적46개
# 749번째 종목 코오롱플라스틱 추출중...
# 1개 추출완료. 누적47개
# 750번째 종목 코웨이 추출중...
# 1개 추출완료. 누적48개
# 2/2 [==============================] - 3s 885ms/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 858ms/step
# 2/2 [==============================] - 3s 851ms/step
# 2/2 [==============================] - 5s 1s/step
# 0
# 751번째 종목 콘텐트리중앙 추출중...
# 1개 추출완료. 누적1개
# 752번째 종목 콤텍시스템 추출중...
# 1개 추출완료. 누적2개
# 753번째 종목 쿠쿠홀딩스 추출중...
# 1개 추출완료. 누적3개
# 754번째 종목 쿠쿠홈시스 추출중...
# 1개 추출완료. 누적4개
# 755번째 종목 크라운제과 추출중...
# 1개 추출완료. 누적5개
# 756번째 종목 크라운제과우 추출중...
# 1개 추출완료. 누적6개
# 757번째 종목 크라운해태홀딩스 추출중...
# 1개 추출완료. 누적7개
# 758번째 종목 크라운해태홀딩스우 추출중...
# 1개 추출완료. 누적8개
# 759번째 종목 크래프톤 추출중...
# 1개 추출완료. 누적9개
# 760번째 종목 키다리스튜디오 추출중...
# 1개 추출완료. 누적10개
# 761번째 종목 키움증권 추출중...
# 1개 추출완료. 누적11개
# 762번째 종목 태경비케이 추출중...
# 1개 추출완료. 누적12개
# 763번째 종목 태경산업 추출중...
# 1개 추출완료. 누적13개
# 764번째 종목 태경케미컬 추출중...
# 1개 추출완료. 누적14개
# 765번째 종목 태광산업 추출중...
# 1개 추출완료. 누적15개
# 766번째 종목 태림포장 추출중...
# 1개 추출완료. 누적16개
# 767번째 종목 태양금속 추출중...
# 1개 추출완료. 누적17개
# 768번째 종목 태양금속우 추출중...
# 1개 추출완료. 누적18개
# 769번째 종목 태영건설 추출중...
# 1개 추출완료. 누적19개
# 770번째 종목 태영건설우 추출중...
# 1개 추출완료. 누적20개
# 771번째 종목 태원물산 추출중...
# 1개 추출완료. 누적21개
# 772번째 종목 태평양물산 추출중...
# 1개 추출완료. 누적22개
# 773번째 종목 테이팩스 추출중...
# 1개 추출완료. 누적23개
# 774번째 종목 텔코웨어 추출중...
# 1개 추출완료. 누적24개
# 775번째 종목 토니모리 추출중...
# 1개 추출완료. 누적25개
# 776번째 종목 티에이치엔 추출중...
# 1개 추출완료. 누적26개
# 777번째 종목 티와이홀딩스 추출중...
# 1개 추출완료. 누적27개
# 778번째 종목 티와이홀딩스우 추출중...
# 1개 추출완료. 누적28개
# 779번째 종목 티웨이항공 추출중...
# 1개 추출완료. 누적29개
# 780번째 종목 티웨이홀딩스 추출중...
# 1개 추출완료. 누적30개
# 781번째 종목 파미셀 추출중...
# 1개 추출완료. 누적31개
# 782번째 종목 팜스코 추출중...
# 1개 추출완료. 누적32개
# 783번째 종목 팜젠사이언스 추출중...
# 1개 추출완료. 누적33개
# 784번째 종목 팬오션 추출중...
# 1개 추출완료. 누적34개
# 785번째 종목 퍼스텍 추출중...
# 1개 추출완료. 누적35개
# 786번째 종목 퍼시스 추출중...
# 1개 추출완료. 누적36개
# 787번째 종목 페이퍼코리아 추출중...
# 1개 추출완료. 누적37개
# 788번째 종목 평화산업 추출중...
# 1개 추출완료. 누적38개
# 789번째 종목 평화홀딩스 추출중...
# 1개 추출완료. 누적39개
# 790번째 종목 포스코스틸리온 추출중...
# 1개 추출완료. 누적40개
# 791번째 종목 포스코인터내셔널 추출중...
# 1개 추출완료. 누적41개
# 792번째 종목 포스코퓨처엠 추출중...
# 1개 추출완료. 누적42개
# 793번째 종목 풀무원 추출중...
# 1개 추출완료. 누적43개
# 794번째 종목 풍산 추출중...
# 1개 추출완료. 누적44개
# 795번째 종목 풍산홀딩스 추출중...
# 1개 추출완료. 누적45개
# 796번째 종목 프레스티지바이오파마 추출중...
# 1개 추출완료. 누적46개
# 797번째 종목 플레이그램 추출중...
# 1개 추출완료. 누적47개
# 798번째 종목 하나금융지주 추출중...
# 1개 추출완료. 누적48개
# 799번째 종목 하나제약 추출중...
# 1개 추출완료. 누적49개
# 800번째 종목 하나투어 추출중...
# 1개 추출완료. 누적50개
# 2/2 [==============================] - 3s 955ms/step
# 2/2 [==============================] - 3s 984ms/step
# 2/2 [==============================] - 4s 948ms/step
# 2/2 [==============================] - 3s 957ms/step
# 2/2 [==============================] - 3s 999ms/step
# 0
# 801번째 종목 하이브 추출중...
# 1개 추출완료. 누적1개
# 802번째 종목 하이스틸 추출중...
# 1개 추출완료. 누적2개
# 803번째 종목 하이트론 추출중...
# 0개 추출완료. 누적2개
# 804번째 종목 하이트진로 추출중...
# 1개 추출완료. 누적3개
# 805번째 종목 하이트진로2우B 추출중...
# 1개 추출완료. 누적4개
# 806번째 종목 하이트진로홀딩스 추출중...
# 1개 추출완료. 누적5개
# 807번째 종목 하이트진로홀딩스우 추출중...
# 1개 추출완료. 누적6개
# 808번째 종목 한국ANKOR유전 추출중...
# 1개 추출완료. 누적7개
# 809번째 종목 한국가스공사 추출중...
# 1개 추출완료. 누적8개
# 810번째 종목 한국공항 추출중...
# 1개 추출완료. 누적9개
# 811번째 종목 한국금융지주 추출중...
# 1개 추출완료. 누적10개
# 812번째 종목 한국금융지주우 추출중...
# 1개 추출완료. 누적11개
# 813번째 종목 한국내화 추출중...
# 1개 추출완료. 누적12개
# 814번째 종목 한국단자 추출중...
# 1개 추출완료. 누적13개
# 815번째 종목 한국무브넥스 추출중...
# 1개 추출완료. 누적14개
# 816번째 종목 한국석유 추출중...
# 1개 추출완료. 누적15개
# 817번째 종목 한국수출포장 추출중...
# 1개 추출완료. 누적16개
# 818번째 종목 한국쉘석유 추출중...
# 1개 추출완료. 누적17개
# 819번째 종목 한국앤컴퍼니 추출중...
# 1개 추출완료. 누적18개
# 820번째 종목 한국자산신탁 추출중...
# 1개 추출완료. 누적19개
# 821번째 종목 한국전력 추출중...
# 1개 추출완료. 누적20개
# 822번째 종목 한국전자홀딩스 추출중...
# 1개 추출완료. 누적21개
# 823번째 종목 한국종합기술 추출중...
# 1개 추출완료. 누적22개
# 824번째 종목 한국주강 추출중...
# 1개 추출완료. 누적23개
# 825번째 종목 한국주철관 추출중...
# 1개 추출완료. 누적24개
# 826번째 종목 한국철강 추출중...
# 1개 추출완료. 누적25개
# 827번째 종목 한국카본 추출중...
# 1개 추출완료. 누적26개
# 828번째 종목 한국콜마 추출중...
# 1개 추출완료. 누적27개
# 829번째 종목 한국콜마홀딩스 추출중...
# 1개 추출완료. 누적28개
# 830번째 종목 한국타이어앤테크놀로지 추출중...
# 1개 추출완료. 누적29개
# 831번째 종목 한국토지신탁 추출중...
# 1개 추출완료. 누적30개
# 832번째 종목 한국특강 추출중...
# 1개 추출완료. 누적31개
# 833번째 종목 한국패러랠 추출중...
# 1개 추출완료. 누적32개
# 834번째 종목 한국항공우주 추출중...
# 1개 추출완료. 누적33개
# 835번째 종목 한국화장품 추출중...
# 1개 추출완료. 누적34개
# 836번째 종목 한국화장품제조 추출중...
# 1개 추출완료. 누적35개
# 837번째 종목 한농화성 추출중...
# 1개 추출완료. 누적36개
# 838번째 종목 한독 추출중...
# 1개 추출완료. 누적37개
# 839번째 종목 한미글로벌 추출중...
# 1개 추출완료. 누적38개
# 840번째 종목 한미반도체 추출중...
# 1개 추출완료. 누적39개
# 841번째 종목 한미사이언스 추출중...
# 1개 추출완료. 누적40개
# 842번째 종목 한미약품 추출중...
# 1개 추출완료. 누적41개
# 843번째 종목 한샘 추출중...
# 1개 추출완료. 누적42개
# 844번째 종목 한섬 추출중...
# 1개 추출완료. 누적43개
# 845번째 종목 한성기업 추출중...
# 1개 추출완료. 누적44개
# 846번째 종목 한세실업 추출중...
# 1개 추출완료. 누적45개
# 847번째 종목 한세엠케이 추출중...
# 1개 추출완료. 누적46개
# 848번째 종목 한세예스24홀딩스 추출중...
# 1개 추출완료. 누적47개
# 849번째 종목 한솔PNS 추출중...
# 1개 추출완료. 누적48개
# 850번째 종목 한솔로지스틱스 추출중...
# 1개 추출완료. 누적49개
# 2/2 [==============================] - 3s 908ms/step
# 2/2 [==============================] - 3s 902ms/step
# 2/2 [==============================] - 3s 948ms/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 898ms/step
# 0
# 851번째 종목 한솔제지 추출중...
# 1개 추출완료. 누적1개
# 852번째 종목 한솔케미칼 추출중...
# 1개 추출완료. 누적2개
# 853번째 종목 한솔테크닉스 추출중...
# 1개 추출완료. 누적3개
# 854번째 종목 한솔홀딩스 추출중...
# 1개 추출완료. 누적4개
# 855번째 종목 한솔홈데코 추출중...
# 1개 추출완료. 누적5개
# 856번째 종목 한신공영 추출중...
# 1개 추출완료. 누적6개
# 857번째 종목 한신기계 추출중...
# 1개 추출완료. 누적7개
# 858번째 종목 한양증권 추출중...
# 1개 추출완료. 누적8개
# 859번째 종목 한양증권우 추출중...
# 1개 추출완료. 누적9개
# 860번째 종목 한온시스템 추출중...
# 1개 추출완료. 누적10개
# 861번째 종목 한올바이오파마 추출중...
# 1개 추출완료. 누적11개
# 862번째 종목 한익스프레스 추출중...
# 1개 추출완료. 누적12개
# 863번째 종목 한일시멘트 추출중...
# 1개 추출완료. 누적13개
# 864번째 종목 한일철강 추출중...
# 1개 추출완료. 누적14개
# 865번째 종목 한일현대시멘트 추출중...
# 1개 추출완료. 누적15개
# 866번째 종목 한일홀딩스 추출중...
# 1개 추출완료. 누적16개
# 867번째 종목 한전KPS 추출중...
# 1개 추출완료. 누적17개
# 868번째 종목 한전기술 추출중...
# 1개 추출완료. 누적18개
# 869번째 종목 한전산업 추출중...
# 1개 추출완료. 누적19개
# 870번째 종목 한진 추출중...
# 1개 추출완료. 누적20개
# 871번째 종목 한진중공업홀딩스 추출중...
# 1개 추출완료. 누적21개
# 872번째 종목 한진칼 추출중...
# 1개 추출완료. 누적22개
# 873번째 종목 한진칼우 추출중...
# 1개 추출완료. 누적23개
# 874번째 종목 한창 추출중...
# 1개 추출완료. 누적24개
# 875번째 종목 한창제지 추출중...
# 1개 추출완료. 누적25개
# 876번째 종목 한컴라이프케어 추출중...
# 1개 추출완료. 누적26개
# 877번째 종목 한화 추출중...
# 1개 추출완료. 누적27개
# 878번째 종목 한화3우B 추출중...
# 1개 추출완료. 누적28개
# 879번째 종목 한화갤러리아 추출중...
# 1개 추출완료. 누적29개
# 880번째 종목 한화갤러리아우 추출중...
# 1개 추출완료. 누적30개
# 881번째 종목 한화리츠 추출중...
# 1개 추출완료. 누적31개
# 882번째 종목 한화생명 추출중...
# 1개 추출완료. 누적32개
# 883번째 종목 한화손해보험 추출중...
# 1개 추출완료. 누적33개
# 884번째 종목 한화솔루션 추출중...
# 1개 추출완료. 누적34개
# 885번째 종목 한화솔루션우 추출중...
# 1개 추출완료. 누적35개
# 886번째 종목 한화시스템 추출중...
# 1개 추출완료. 누적36개
# 887번째 종목 한화에어로스페이스 추출중...
# 1개 추출완료. 누적37개
# 888번째 종목 한화오션 추출중...
# 1개 추출완료. 누적38개
# 889번째 종목 한화우 추출중...
# 1개 추출완료. 누적39개
# 890번째 종목 한화투자증권 추출중...
# 1개 추출완료. 누적40개
# 891번째 종목 한화투자증권우 추출중...
# 1개 추출완료. 누적41개
# 892번째 종목 해성디에스 추출중...
# 1개 추출완료. 누적42개
# 893번째 종목 해태제과식품 추출중...
# 1개 추출완료. 누적43개
# 894번째 종목 핸즈코퍼레이션 추출중...
# 1개 추출완료. 누적44개
# 895번째 종목 현대건설 추출중...
# 1개 추출완료. 누적45개
# 896번째 종목 현대건설우 추출중...
# 1개 추출완료. 누적46개
# 897번째 종목 현대그린푸드 추출중...
# 1개 추출완료. 누적47개
# 898번째 종목 현대글로비스 추출중...
# 1개 추출완료. 누적48개
# 899번째 종목 현대로템 추출중...
# 1개 추출완료. 누적49개
# 900번째 종목 현대리바트 추출중...
# 1개 추출완료. 누적50개
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 4s 983ms/step
# 2/2 [==============================] - 3s 950ms/step
# 2/2 [==============================] - 3s 954ms/step
# 0
# 901번째 종목 현대모비스 추출중...
# 1개 추출완료. 누적1개
# 902번째 종목 현대미포조선 추출중...
# 1개 추출완료. 누적2개
# 903번째 종목 현대백화점 추출중...
# 1개 추출완료. 누적3개
# 904번째 종목 현대비앤지스틸 추출중...
# 1개 추출완료. 누적4개
# 905번째 종목 현대약품 추출중...
# 1개 추출완료. 누적5개
# 906번째 종목 현대엘리베이 추출중...
# 1개 추출완료. 누적6개
# 907번째 종목 현대오토에버 추출중...
# 1개 추출완료. 누적7개
# 908번째 종목 현대위아 추출중...
# 1개 추출완료. 누적8개
# 909번째 종목 현대제철 추출중...
# 1개 추출완료. 누적9개
# 910번째 종목 현대지에프홀딩스 추출중...
# 1개 추출완료. 누적10개
# 911번째 종목 현대차 추출중...
# 1개 추출완료. 누적11개
# 912번째 종목 현대차2우B 추출중...
# 1개 추출완료. 누적12개
# 913번째 종목 현대차3우B 추출중...
# 1개 추출완료. 누적13개
# 914번째 종목 현대차우 추출중...
# 1개 추출완료. 누적14개
# 915번째 종목 현대차증권 추출중...
# 1개 추출완료. 누적15개
# 916번째 종목 현대코퍼레이션 추출중...
# 1개 추출완료. 누적16개
# 917번째 종목 현대코퍼레이션홀딩스 추출중...
# 1개 추출완료. 누적17개
# 918번째 종목 현대퓨처넷 추출중...
# 1개 추출완료. 누적18개
# 919번째 종목 현대해상 추출중...
# 1개 추출완료. 누적19개
# 920번째 종목 현대홈쇼핑 추출중...
# 1개 추출완료. 누적20개
# 921번째 종목 형지엘리트 추출중...
# 1개 추출완료. 누적21개
# 922번째 종목 혜인 추출중...
# 1개 추출완료. 누적22개
# 923번째 종목 호전실업 추출중...
# 1개 추출완료. 누적23개
# 924번째 종목 호텔신라 추출중...
# 1개 추출완료. 누적24개
# 925번째 종목 호텔신라우 추출중...
# 1개 추출완료. 누적25개
# 926번째 종목 화성산업 추출중...
# 1개 추출완료. 누적26개
# 927번째 종목 화승알앤에이 추출중...
# 1개 추출완료. 누적27개
# 928번째 종목 화승엔터프라이즈 추출중...
# 1개 추출완료. 누적28개
# 929번째 종목 화승인더 추출중...
# 1개 추출완료. 누적29개
# 930번째 종목 화승코퍼레이션 추출중...
# 1개 추출완료. 누적30개
# 931번째 종목 화신 추출중...
# 1개 추출완료. 누적31개
# 932번째 종목 화인베스틸 추출중...
# 1개 추출완료. 누적32개
# 933번째 종목 화천기계 추출중...
# 1개 추출완료. 누적33개
# 934번째 종목 화천기공 추출중...
# 1개 추출완료. 누적34개
# 935번째 종목 환인제약 추출중...
# 1개 추출완료. 누적35개
# 936번째 종목 황금에스티 추출중...
# 1개 추출완료. 누적36개
# 937번째 종목 효성 추출중...
# 1개 추출완료. 누적37개
# 938번째 종목 효성ITX 추출중...
# 1개 추출완료. 누적38개
# 939번째 종목 효성중공업 추출중...
# 1개 추출완료. 누적39개
# 940번째 종목 효성첨단소재 추출중...
# 1개 추출완료. 누적40개
# 941번째 종목 효성티앤씨 추출중...
# 1개 추출완료. 누적41개
# 942번째 종목 효성화학 추출중...
# 1개 추출완료. 누적42개
# 943번째 종목 후성 추출중...
# 1개 추출완료. 누적43개
# 944번째 종목 휠라홀딩스 추출중...
# 1개 추출완료. 누적44개
# 945번째 종목 휴니드 추출중...
# 1개 추출완료. 누적45개
# 946번째 종목 휴비스 추출중...
# 1개 추출완료. 누적46개
# 947번째 종목 휴스틸 추출중...
# 1개 추출완료. 누적47개
# 948번째 종목 흥국화재 추출중...
# 1개 추출완료. 누적48개
# 949번째 종목 흥국화재우 추출중...
# 1개 추출완료. 누적49개
# 950번째 종목 흥아해운 추출중...
# 1개 추출완료. 누적50개
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 948ms/step
# 2/2 [==============================] - 3s 951ms/step
# 2/2 [==============================] - 5s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 0

# %%
for up in up_images_info:
    for i in up:
        print(i[0], str(i[2])[:10])

# %%
import matplotlib.pyplot as plt

# 레이블이 0인 이미지 선택

# 이미지 출력 함수
def display_images(images, rows, cols):
    fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
    axes = axes.ravel()

    for i in range(rows * cols):
        axes[i].imshow(images[i], cmap='gray')
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# 이미지 출력
num_examples = len(up_images)
rows = cols = int(np.sqrt(num_examples))
display_images(up_images[:num_examples], rows, cols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-6648e9467ee3> in <cell line: 20>()
#      18 num_examples = len(up_images)
#      19 rows = cols = int(np.sqrt(num_examples))
# ---> 20 display_images(up_images[:num_examples], rows, cols)
#
# <ipython-input-13-6648e9467ee3> in display_images(images, rows, cols)
#       9
#      10     for i in range(rows * cols):
# ---> 11         axes[i].imshow(images[i], cmap='gray')
#      12         axes[i].axis('off')
#      13
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5663                               **kwargs)
#    5664
# -> 5665         im.set_data(X)
#    5666         im.set_alpha(alpha)
#    5667         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in set_data(self, A)
#     708         if not (self._A.ndim == 2
#     709                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 710             raise TypeError("Invalid shape {} for image data"
#     711                             .format(self._A.shape))
#     712
#
# TypeError: Invalid shape (1, 96, 96, 3) for image data

# %%
import matplotlib.pyplot as plt
from datetime import datetime
plt.rc('font', family='NanumBarunGothic')

# 현재 날짜를 'x월 x일' 형식으로 변환합니다.
today = datetime.now().strftime("%m월 %d일")

fig, axes = plt.subplots(10, 10, figsize=(16, 16))
for i in range(10):
    for j in range(10):
        img_idx = i * 10 + j
        img = Image.fromarray(test_images[img_idx])
        axes[i, j].imshow(img)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        # 색상 변경을 위해 text 함수를 사용합니다.
        color = 'red' if predicted_labels[i*10 + j] else 'blue'
        text = f'{stock_codes[i*10 + j][1]} : {"상승" if predicted_labels[i*10 + j] else "하락"}'
        axes[i, j].text(0.5, -0.15, text, fontsize=9, color=color, ha='center', va='center', transform=axes[i, j].transAxes)

# 제목 추가 (날짜 포함)
plt.suptitle(f'{today} 종가대비 향후 5거래일 평균 가격 예상', fontsize=20, y=0.95)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-482bfd5f50b1> in <cell line: 9>()
#      10     for j in range(10):
#      11         img_idx = i * 10 + j
# ---> 12         img = Image.fromarray(test_images[img_idx])
#      13         axes[i, j].imshow(img)
#      14         axes[i, j].set_xticks([])
#
# IndexError: list index out of range
