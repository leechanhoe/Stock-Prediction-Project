# %%
import pandas as pd

with open('앙상블2023하락검증_코스피.txt', 'r') as f:
    data = f.read()

# 문자열을 줄 단위로 나누고, 각 줄을 종목명과 날짜로 분리합니다.
rows = [(line[:-10].strip(), line[-10:]) for line in data.split('\n')]

# 데이터 프레임을 생성합니다.
df = pd.DataFrame(rows, columns=['종목명', '기준일자'])

duplicated_rows = df[df.duplicated()]

if not duplicated_rows.empty:
    print("중복된 행:")
    print(duplicated_rows)

# 중복된 행 제거
df = df.drop_duplicates()

# 데이터 프레임을 엑셀 파일로 저장합니다.
df.to_excel('stock_data.xlsx', index=False)
df
# Out:
#          종목명        기준일자
# 0        BGF  2023-03-30
# 1        BYC  2022-12-29
# 2      CJ씨푸드  2023-03-21
# 3    CJ씨푸드1우  2023-07-03
# 4     CJ제일제당  2022-12-15
# ..       ...         ...
# 567      휴스틸  2023-08-24
# 568      휴스틸  2023-06-29
# 569     흥국화재  2023-03-30
# 570     흥국화재  2023-03-29
# 571    흥국화재우  2023-07-25
#
# [572 rows x 2 columns]
