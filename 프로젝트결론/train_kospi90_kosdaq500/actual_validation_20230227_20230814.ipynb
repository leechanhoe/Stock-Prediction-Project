# %%
# !pip install finance-datareader
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.50 requests-file-1.5.1
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (8,713 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120828 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from datetime import datetime, timedelta
import random

num_images = 5000
day_num = 32

# %%
from keras.models import load_model

model1 = load_model('drive/MyDrive/Colab Notebooks/kosdaq500_kospi90_epoch50_1.h5')
model2 = load_model('drive/MyDrive/Colab Notebooks/kosdaq500_kospi90_epoch50_2.h5')

# %%
def convert_image(data, num_images, day_num, name, code, save = False, test = False):

    def alpha_blend(color1, color2, alpha):
        return [
            int((color1[0] * alpha + color2[0] * (1 - alpha))),
            int((color1[1] * alpha + color2[1] * (1 - alpha))),
            int((color1[2] * alpha + color2[2] * (1 - alpha))),
            255,
        ]


    # 해당 종목의 주가 데이터 - 100이 요구되는 이미지 수보다 적으면(상장직후는 변동이 심할 수있으니 제외)
    if num_images > len(data) - 60 - day_num:
        num_images = len(data) - 60 - day_num

    #return_datas는 이미지, 라벨링(상승이면1 하락이면0), 변동률, 날짜를 담고있음
    return_datas = []

    image_idx = 1
    while(image_idx <= num_images):

        if image_idx != 1:
            stock_data = data[-image_idx - day_num + 1 : -image_idx + 1]
        else:
            stock_data = data[-day_num:]
        # 이미지 크기 설정
        width, height = 96, 96

        # High, Low, Close, Volume 데이터 정규화
        high_prices = stock_data['High'].values
        low_prices = stock_data['Low'].values
        close_prices = stock_data['Close'].values
        volume_data = stock_data['Volume'].values

        high_prices_norm = (high_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        low_prices_norm = (low_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        close_prices_norm = (close_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        volume_data_norm = height * (volume_data) / (2 * (np.max(volume_data)))

        if len(data) <= abs(-image_idx - day_num - 19):
            break

        # 이동평균선 추가를 위한 stock_data 생성
        if image_idx != 1:
            stock_data_ma20 = data[-image_idx - day_num - 19: -image_idx + 1]
        else:
            stock_data_ma20 = data[-image_idx - day_num - 19: ]

        stock_data_ma20 = stock_data_ma20.copy()
        stock_data_ma20['MA20'] = stock_data_ma20['Close'].rolling(window=20).mean()
        stock_data_ma20.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma20['MA20_norm'] = (
                (stock_data_ma20['MA20'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        if len(data) <= abs(-image_idx - day_num - 39):
            break

        if image_idx != 1:
            stock_data_ma40 = data[-image_idx - day_num - 39: -image_idx + 1]
        else:
            stock_data_ma40 = data[-image_idx - day_num - 39: ]

        stock_data_ma40 = stock_data_ma40.copy()
        stock_data_ma40['MA40'] = stock_data_ma40['Close'].rolling(window=40).mean()
        stock_data_ma40.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma40['MA40_norm'] = (
                (stock_data_ma40['MA40'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        if len(data) <= abs(-image_idx - day_num - 59):
            break

        if image_idx != 1:
            stock_data_ma60 = data[-image_idx - day_num - 59: -image_idx + 1]
        else:
            stock_data_ma60 = data[-image_idx - day_num - 59: ]

        stock_data_ma60 = stock_data_ma60.copy()
        stock_data_ma60['MA60'] = stock_data_ma60['Close'].rolling(window=60).mean()
        stock_data_ma60.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma60['MA60_norm'] = (
                (stock_data_ma60['MA60'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        # 96x96 이미지 생성
        img = np.zeros((height, width, 4), dtype=np.uint8)  # 4 channels for RGBA

        fail_generate = False
        for day in range(32):
            high_price = int(high_prices_norm[day] * (height - 1))
            low_price = int(low_prices_norm[day] * (height - 1))
            close_price = int(close_prices_norm[day] * (height - 1))
            open_price = int(
                (
                    (stock_data['Open'].values[day] - np.min(low_prices))
                    / (np.max(high_prices) - np.min(low_prices))
                )
                * (height - 1)
            )
            volume = int(volume_data_norm[day])

            x_start = day * 3

            # 시가, 종가, 고가, 저가 막대그래프
            # 막대 왼쪽, 오른쪽 그리기 (시가, 종가 범위)
            for x in range(x_start, x_start + 3):
                if close_prices[day] > stock_data['Open'].values[day]:
                    color = [255, 0, 0, 255]  # 상승: 빨강
                    tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                elif close_prices[day] < stock_data['Open'].values[day]:
                    color = [0, 0, 255, 255]  # 하락: 파랑
                    tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑
                else: # 시가와 종가가 같을경우 어제보다 같거나 올랐으면 빨강, 아니면 파랑
                    if 0 <= stock_data['Change'].values[day]:
                        color = [255, 0, 0, 255]  # 상승: 빨강
                        tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                    else:
                        color = [0, 0, 255, 255]  # 하락: 파랑
                        tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑

                for y in range(min(open_price, close_price), max(open_price, close_price) + 1):
                    img[height - 1 - y, x] = color

            # 꼬리 그리기 (High, Low 범위)
            for x in range(x_start + 1, x_start + 2):
                for y in range(low_price, high_price + 1):
                    if img[height - 1 - y, x][0] != 255 and img[height - 1 - y, x][2] != 255:
                        img[height - 1 - y, x] = tail_color

            # 거래량 그리기
            for x in range(x_start, x_start + 3):
                overlapped = height - volume
                if overlapped >= 0 and overlapped < height:
                    img[overlapped:, x] = [
                        alpha_blend(img[y, x], [128, 128, 128, 255], 0.45)
                        for y in range(overlapped, height)
                    ]

            # 20일 이동평균선 그리기
            ma20_norm = stock_data_ma20.iloc[day]['MA20_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma20_norm):
                    ma20_y = int(ma20_norm * (height - 1))
                    if 0 <= ma20_y < height:
                        for y in range(ma20_y - 1, ma20_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([255, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 노란색으로 변경
                                img[height - 1 - y, x] = new_color

            # 40일 이동평균선 그리기
            ma40_norm = stock_data_ma40.iloc[day]['MA40_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma40_norm):
                    ma40_y = int(ma40_norm * (height - 1))
                    if 0 <= ma40_y < height:
                        for y in range(ma40_y - 1, ma40_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([128, 0, 128, 255], img[height - 1 - y, x], 0.6)  # 보라색으로 변경
                                img[height - 1 - y, x] = new_color


            # 60일 이동평균선 그리기
            ma60_norm = stock_data_ma60.iloc[day]['MA60_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma60_norm):
                    ma60_y = int(ma60_norm * (height - 1))
                    if 0 <= ma60_y < height:
                        for y in range(ma60_y - 1, ma60_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([0, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 초록색으로 변경
                                img[height - 1 - y, x] = new_color

        #이미지가 day_num(그려지기 원하는 거래일 수)미만으로 그려졌으면
        if fail_generate:
            image_idx += 1
            continue

        if save :
            # 이미지 저장
            img = Image.fromarray(img, 'RGBA')
            img.save(f'stock_data_image_{image_idx}.png')


        return_datas.append((img, name, code, stock_data.index[-1]))

        image_idx += 1


    return return_datas

# %%
def preprocess_data(data):
    # 0이나 NaN을 포함하는 행 제거
    data = data[data['Volume'] != 0]
    data = data.dropna(how='any')

    return data

# %%
df = pd.read_excel('drive/MyDrive/Colab Notebooks/kospi.xlsx', usecols=[0, 1], dtype={1: str})
df = df[~df.iloc[:, 1].str.contains("스팩")]
# df = df.sample(n=400, random_state=42)

# 첫 번째 열과 두 번째 열을 Nx2 리스트로 변환
stock_codes = df.values.tolist()

# 결과 출력
print(stock_codes)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# [['095570', 'AJ네트웍스'], ['006840', 'AK홀딩스'], ['027410', 'BGF'], ['282330', 'BGF리테일'], ['138930', 'BNK금융지주'], ['001460', 'BYC'], ['001465', 'BYC우'], ['001040', 'CJ'], ['079160', 'CJ CGV'], ['00104K', 'CJ4우(전환)'], ['000120', 'CJ대한통운'], ['011150', 'CJ씨푸드'], ['011155', 'CJ씨푸드1우'], ['001045', 'CJ우'], ['097950', 'CJ제일제당'], ['097955', 'CJ제일제당 우'], ['000480', 'CR홀딩스'], ['000590', 'CS홀딩스'], ['012030', 'DB'], ['016610', 'DB금융투자'], ['005830', 'DB손해보험'], ['000990', 'DB하이텍'], ['139130', 'DGB금융지주'], ['001530', 'DI동일'], ['000210', 'DL'], ['001880', 'DL건설'], ['000215', 'DL우'], ['375500', 'DL이앤씨'], ['37550L', 'DL이앤씨2우(전환)'], ['37550K', 'DL이앤씨우'], ['007340', 'DN오토모티브'], ['004840', 'DRB동일'], ['155660', 'DSR'], ['069730', 'DSR제강'], ['017940', 'E1'], ['365550', 'ESR켄달스퀘어리츠'], ['383220', 'F&F'], ['007700', 'F&F홀딩스'], ['114090', 'GKL'], ['078930', 'GS'], ['006360', 'GS건설'], ['001250', 'GS글로벌'], ['007070', 'GS리테일'], ['078935', 'GS우'], ['012630', 'HDC'], ['039570', 'HDC랩스'], ['089470', 'HDC현대EP'], ['294870', 'HDC현대산업개발'], ['009540', 'HD한국조선해양'], ['267250', 'HD현대'], ['267270', 'HD현대건설기계'], ['322000', 'HD현대에너지솔루션'], ['042670', 'HD현대인프라코어'], ['267260', 'HD현대일렉트릭'], ['329180', 'HD현대중공업'], ['097230', 'HJ중공업'], ['014790', 'HL D&I'], ['003580', 'HLB글로벌'], ['204320', 'HL만도'], ['060980', 'HL홀딩스'], ['011200', 'HMM'], ['082740', 'HSD엔진'], ['035000', 'HS애드'], ['003560', 'IHQ'], ['175330', 'JB금융지주'], ['234080', 'JW생명과학'], ['001060', 'JW중외제약'], ['001067', 'JW중외제약2우B'], ['001065', 'JW중외제약우'], ['096760', 'JW홀딩스'], ['105560', 'KB금융'], ['432320', 'KB스타리츠'], ['002380', 'KCC'], ['344820', 'KCC글라스'], ['009070', 'KCTC'], ['009440', 'KC그린홀딩스'], ['119650', 'KC코트렐'], ['092220', 'KEC'], ['003620', 'KG모빌리티'], ['016380', 'KG스틸'], ['001390', 'KG케미칼'], ['033180', 'KH 필룩스'], ['015590', 'KIB플러그에너지'], ['001940', 'KISCO홀딩스'], ['025000', 'KPX케미칼'], ['092230', 'KPX홀딩스'], ['000040', 'KR모터스'], ['044450', 'KSS해운'], ['030200', 'KT'], ['033780', 'KT&G'], ['058850', 'KTcs'], ['058860', 'KTis'], ['093050', 'LF'], ['003550', 'LG'], ['034220', 'LG디스플레이'], ['051900', 'LG생활건강'], ['051905', 'LG생활건강우'], ['373220', 'LG에너지솔루션'], ['003555', 'LG우'], ['032640', 'LG유플러스'], ['011070', 'LG이노텍'], ['066570', 'LG전자'], ['066575', 'LG전자우'], ['037560', 'LG헬로비전'], ['051910', 'LG화학'], ['051915', 'LG화학우'], ['079550', 'LIG넥스원'], ['006260', 'LS'], ['010120', 'LS ELECTRIC'], ['000680', 'LS네트웍스'], ['229640', 'LS전선아시아'], ['108320', 'LX세미콘'], ['001120', 'LX인터내셔널'], ['108670', 'LX하우시스'], ['108675', 'LX하우시스우'], ['383800', 'LX홀딩스'], ['38380K', 'LX홀딩스1우'], ['023150', 'MH에탄올'], ['035420', 'NAVER'], ['181710', 'NHN'], ['400760', 'NH올원리츠'], ['005940', 'NH투자증권'], ['005945', 'NH투자증권우'], ['338100', 'NH프라임리츠'], ['034310', 'NICE'], ['030190', 'NICE평가정보'], ['008260', 'NI스틸'], ['004250', 'NPC'], ['004255', 'NPC우'], ['456040', 'OCI'], ['010060', 'OCI홀딩스'], ['178920', 'PI첨단소재'], ['005490', 'POSCO홀딩스'], ['010950', 'S-Oil'], ['010955', 'S-Oil우'], ['034120', 'SBS'], ['005090', 'SGC에너지'], ['001380', 'SG글로벌'], ['004060', 'SG세계물산'], ['001770', 'SHD'], ['002360', 'SH에너지화학'], ['009160', 'SIMPAC'], ['123700', 'SJM'], ['025530', 'SJM홀딩스'], ['034730', 'SK'], ['011790', 'SKC'], ['018670', 'SK가스'], ['001740', 'SK네트웍스'], ['006120', 'SK디스커버리'], ['006125', 'SK디스커버리우'], ['210980', 'SK디앤디'], ['068400', 'SK렌터카'], ['395400', 'SK리츠'], ['302440', 'SK바이오사이언스'], ['326030', 'SK바이오팜'], ['402340', 'SK스퀘어'], ['361610', 'SK아이이테크놀로지'], ['100090', 'SK오션플랜트'], ['03473K', 'SK우'], ['096770', 'SK이노베이션'], ['096775', 'SK이노베이션우'], ['001510', 'SK증권'], ['001515', 'SK증권우'], ['285130', 'SK케미칼'], ['28513K', 'SK케미칼우'], ['017670', 'SK텔레콤'], ['000660', 'SK하이닉스'], ['003570', 'SNT다이내믹스'], ['064960', 'SNT모티브'], ['100840', 'SNT에너지'], ['036530', 'SNT홀딩스'], ['005610', 'SPC삼립'], ['011810', 'STX'], ['077970', 'STX엔진'], ['071970', 'STX중공업'], ['002820', 'SUN&L'], ['084870', 'TBH글로벌'], ['002710', 'TCC스틸'], ['069260', 'TKG휴켐스'], ['002900', 'TYM'], ['024070', 'WISCOM'], ['037270', 'YG PLUS'], ['000500', '가온전선'], ['000860', '강남제비스코'], ['035250', '강원랜드'], ['011420', '갤럭시아에스엠'], ['002100', '경농'], [' ...

# %%
# 엑셀 파일 읽기
df = pd.read_csv('drive/MyDrive/Colab Notebooks/kosdaq.csv', usecols=[0, 1], dtype={1: str})
# df = df[~df.iloc[:, 0].str.contains("스팩")]
df = df.iloc[:, [1, 0]]
# df = df.sample(n=400, random_state=42)

#첫 번째 열과 두 번째 열을 Nx2 리스트로 변환
stock_codes = df.values.tolist()

# 결과 출력
print(stock_codes)
# Out:
# [['457940', 'SK증권제10호스팩'], ['458320', 'KB제26호스팩'], ['448710', '코츠테크놀로지'], ['445680', '큐리옥스바이오시스템즈'], ['454750', '하나28호스팩'], ['440110', '파두'], ['373170', '엠아이큐브솔루션'], ['429270', '시지트로닉스'], ['172670', '에이엘티'], ['450940', '유안타제14호스팩'], ['388870', '파로스아이바이오'], ['438700', '버넥트'], ['406820', '뷰티스킨'], ['455910', 'SK증권제9호스팩'], ['432430', '와이랩'], ['321370', '센서뷰'], ['378340', '필에너지'], ['456440', 'DB금융스팩11호'], ['456490', '교보14호스팩'], ['274400', '이노시뮬레이션'], ['354320', '알멕'], ['440320', '오픈놀'], ['232830', '시큐센'], ['454640', '하나29호스팩'], ['455250', 'KB제25호스팩'], ['451700', '엔에이치스팩29호'], ['450050', '하이제8호스팩'], ['303360', '프로테옴텍'], ['348080', '큐라티스'], ['439090', '마녀공장'], ['405920', '나라셀라'], ['285800', '진영'], ['420770', '기가비스'], ['271830', '팸텍'], ['434480', '모니터랩'], ['340810', '씨유박스'], ['446840', '키움제8호스팩'], ['417790', '트루엔'], ['304360', '에스바이오메딕스'], ['298830', '슈어소프트테크'], ['393210', '토마토시스템'], ['424980', '마이크로투나노'], ['318160', '셀바이오휴먼텍'], ['448830', '미래에셋비전스팩3호'], ['448760', 'IBKS제22호스팩'], ['448370', '하나27호스팩'], ['358570', '지아이이노베이션'], ['309960', 'LB인베스트먼트'], ['446150', '유안타제12호스팩'], ['356680', '엑스게이트'], ['442900', '미래에셋드림스팩1호'], ['282720', '금양그린파워'], ['418420', '라온텍'], ['450410', '엔에이치스팩28호'], ['389020', '자람테크놀로지'], ['446750', '하나26호스팩'], ['417010', '나노팀'], ['199730', '바이오인프라'], ['448740', '삼성스팩8호'], ['449020', '유안타제13호스팩'], ['446190', '미래에셋비전스팩2호'], ['344860', '이노진'], ['127980', '화인써키트'], ['418550', '제이오'], ['411080', '샌즈랩'], ['407400', '꿈비'], ['408900', '스튜디오미르'], ['419050', '삼기이브이'], ['417860', '오브젠'], ['254490', '미래반도체'], ['425040', '티이엠씨'], ['198940', '한주라이트메탈'], ['380540', '옵티코어'], ['445970', '신영스팩9호'], ['162300', '신스틸'], ['445360', '비엔케이제1호스팩'], ['442770', 'IBKS제21호스팩'], ['440820', '엔에이치스팩27호'], ['417180', '핑거스토리'], ['419530', 'SAMG엔터'], ['442310', '대신밸런스제14호스팩'], ['439410', '엔에이치스팩26호'], ['442130', '유진스팩9호'], ['438220', '대신밸런스제13호스팩'], ['168360', '펨트론'], ['389470', '인벤티지랩'], ['419080', '엔젯'], ['084440', '유비온'], ['204610', '티쓰리'], ['425420', '티에프이'], ['372170', '윤성에프앤씨'], ['383930', '디티앤씨알오'], ['348340', '뉴로메카'], ['417500', '제이아이테크'], ['438580', '엔에이치스팩25호'], ['440200', '케이비제23호스팩'], ['440790', '교보13호스팩'], ['405100', '큐알티'], ['439730', 'IBKS제20호스팩'], ['417840', '저스템'], ['419120', '산돌'], ['439250', '삼성스팩7호'], ['405000', '플라즈맵'], ['437780', '엔에이치스팩24호'], ['291810', '핀텔'], ['435620', '하나금융25호스팩'], ['436610', '한국제11호스팩'], ['378800', '샤페론'], ['419540', '비스토스'], ['360070', '탑머티리얼'], ['389500', '에스비비테크'], ['368970', '오에스피'], ['417970', '모델솔루션'], ['296640', '이노룰스'], ['441270', '파인엠텍'], ['435870', 'SK증권제8호스팩'], ['435380', '유안타제10호스팩'], ['067370', '선바이오'], ['393890', '더블유씨피'], ['314140', '알피바이오'], ['430230', '하나금융24호스팩'], ['430460', '한화플러스제3호스팩'], ['394280', '오픈엣지테크놀로지'], ['436530', '케이비제22호스팩'], ['427950', '하나금융23호스팩'], ['433530', '키움제7호스팩'], ['426550', 'IBKS제19호스팩'], ['430220', '신영스팩8호'], ['129920', '대성하이텍'], ['148930', '에이치와이티씨'], ['107600', '새빗켐'], ['430700', '유안타제9호스팩'], ['418210', '신한제10호스팩'], ['368600', '아이씨에이치'], ['365340', '성일하이텍'], ['397030', '에이프릴바이오'], ['424760', '벨로크'], ['328130', '루닛'], ['403870', 'HPSP'], ['112290', '와이씨켐'], ['402030', '코난테크놀로지'], ['396270', '넥스트칩'], ['425290', '삼성스팩6호'], ['422040', '엔에이치스팩23호'], ['421800', '교보12호스팩'], ['412350', '레이저쎌'], ['310210', '보로노이'], ['377460', '위니아에이드'], ['424140', '케이비제21호스팩'], ['148780', '비플라이소프트'], ['382900', '범한퓨얼셀'], ['362320', '청담글로벌'], ['418170', '하나금융22호스팩'], ['399720', '가온칩스'], ['389260', '대명에너지'], ['415580', '상상인제3호스팩'], ['419270', '신영스팩7호'], ['389140', '포바이포'], ['405640', '신한제9호스팩'], ['412930', '미래에셋비전스팩1호'], ['413600', '키움제6호스팩'], ['388050', '지투파워'], ['413630', '유진스팩8호'], ['396300', '세아메카닉스'], ['366030', '공구우먼'], ['388720', '유일로보틱스'], ['288980', '모아데이타'], ['408920', '메쎄이상'], ['376930', '노을'], ['146320', '비씨엔씨'], ['371950', '풍원정밀'], ['330730', '스톤브릿지벤처스'], ['406760', '하나금융21호스팩'], ['365900', '브이씨'], ['370090', '퓨런티어'], ['251120', '바이오에프디엔씨'], ['409570', '한국제10호스팩'], ['405350', 'IBKS제17호스팩'], ['211050', '인카금융서비스'], ['137080', '나래나노텍'], ['136410', '아셈스'], ['276040', '스코넥'], ['3773 ...

# %%
down_images = []
down_images_info = []

def process():
    global down_images, down_images_info

    for n in range(0, len(stock_codes), 50):
        result_images = []
        for i, ticker in enumerate(stock_codes[n:min(n+50, len(stock_codes))]):
            code, name = ticker[0], ticker[1]
            print(f"{n+i+1}번째 종목 {name} 추출중...   ")

            try:
                data = preprocess_data(fdr.DataReader(code, '2022-10-15'))  # 각 종목의 데이터 가져오기
                images = convert_image(data, 300, day_num, name, code)
                result_images += images
                print(f"{len(images)}개 추출완료. 누적{len(result_images)}개")
            except IndexError:
                print(f"{name}에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.")
                continue
        test_images = [image[0][:, :, :3] for image in result_images]
        test_images = np.array(test_images).reshape(-1, 96, 96, 3) / 255.0

        pred_probs1 = model1.predict(test_images)
        pred_probs2 = model2.predict(test_images)

        # 두 모델 같은 라벨이 하락으로 정답이라고 했을때

        selected_images = []
        selected_images_info = []

        for i in range(len(test_images)):
            pred_probs1_max_idx = np.argmax(pred_probs1[i])
            pred_probs2_max_idx = np.argmax(pred_probs2[i])

            if pred_probs1_max_idx == pred_probs2_max_idx and 0.5 < pred_probs1[i][0] and 0.81 <= pred_probs1[i][pred_probs1_max_idx] <= 0.91 and 0.87 <= pred_probs2[i][pred_probs2_max_idx] <= 0.88:
                selected_images.append(test_images[i])
                selected_images_info.append(result_images[i][1:])

        selected_images = np.array(selected_images)

        print(len(selected_images))
        for i in selected_images_info:
            print(i[0], str(i[-1])[:10])

        down_images.append(selected_images)
        down_images_info.append(selected_images_info)

# %%
process()
# Out:
# 1번째 종목 SK증권제10호스팩 추출중...
# 0개 추출완료. 누적0개
# 2번째 종목 KB제26호스팩 추출중...
# 0개 추출완료. 누적0개
# 3번째 종목 코츠테크놀로지 추출중...
# 0개 추출완료. 누적0개
# 4번째 종목 큐리옥스바이오시스템즈 추출중...
# 0개 추출완료. 누적0개
# 5번째 종목 하나28호스팩 추출중...
# 0개 추출완료. 누적0개
# 6번째 종목 파두 추출중...
# 0개 추출완료. 누적0개
# 7번째 종목 엠아이큐브솔루션 추출중...
# 0개 추출완료. 누적0개
# 8번째 종목 시지트로닉스 추출중...
# 0개 추출완료. 누적0개
# 9번째 종목 에이엘티 추출중...
# 0개 추출완료. 누적0개
# 10번째 종목 유안타제14호스팩 추출중...
# 0개 추출완료. 누적0개
# 11번째 종목 파로스아이바이오 추출중...
# 0개 추출완료. 누적0개
# 12번째 종목 버넥트 추출중...
# 0개 추출완료. 누적0개
# 13번째 종목 뷰티스킨 추출중...
# 0개 추출완료. 누적0개
# 14번째 종목 SK증권제9호스팩 추출중...
# 0개 추출완료. 누적0개
# 15번째 종목 와이랩 추출중...
# 0개 추출완료. 누적0개
# 16번째 종목 센서뷰 추출중...
# 0개 추출완료. 누적0개
# 17번째 종목 필에너지 추출중...
# 0개 추출완료. 누적0개
# 18번째 종목 DB금융스팩11호 추출중...
# 0개 추출완료. 누적0개
# 19번째 종목 교보14호스팩 추출중...
# 0개 추출완료. 누적0개
# 20번째 종목 이노시뮬레이션 추출중...
# 0개 추출완료. 누적0개
# 21번째 종목 알멕 추출중...
# 0개 추출완료. 누적0개
# 22번째 종목 오픈놀 추출중...
# 0개 추출완료. 누적0개
# 23번째 종목 시큐센 추출중...
# 116개 추출완료. 누적116개
# 24번째 종목 하나29호스팩 추출중...
# 0개 추출완료. 누적116개
# 25번째 종목 KB제25호스팩 추출중...
# 0개 추출완료. 누적116개
# 26번째 종목 엔에이치스팩29호 추출중...
# 0개 추출완료. 누적116개
# 27번째 종목 하이제8호스팩 추출중...
# 0개 추출완료. 누적116개
# 28번째 종목 프로테옴텍 추출중...
# 116개 추출완료. 누적232개
# 29번째 종목 큐라티스 추출중...
# 0개 추출완료. 누적232개
# 30번째 종목 마녀공장 추출중...
# 0개 추출완료. 누적232개
# 31번째 종목 나라셀라 추출중...
# 0개 추출완료. 누적232개
# 32번째 종목 진영 추출중...
# 0개 추출완료. 누적232개
# 33번째 종목 기가비스 추출중...
# 0개 추출완료. 누적232개
# 34번째 종목 팸텍 추출중...
# 0개 추출완료. 누적232개
# 35번째 종목 모니터랩 추출중...
# 0개 추출완료. 누적232개
# 36번째 종목 씨유박스 추출중...
# 0개 추출완료. 누적232개
# 37번째 종목 키움제8호스팩 추출중...
# 0개 추출완료. 누적232개
# 38번째 종목 트루엔 추출중...
# 0개 추출완료. 누적232개
# 39번째 종목 에스바이오메딕스 추출중...
# 0개 추출완료. 누적232개
# 40번째 종목 슈어소프트테크 추출중...
# 0개 추출완료. 누적232개
# 41번째 종목 토마토시스템 추출중...
# 101개 추출완료. 누적333개
# 42번째 종목 마이크로투나노 추출중...
# 0개 추출완료. 누적333개
# 43번째 종목 셀바이오휴먼텍 추출중...
# 0개 추출완료. 누적333개
# 44번째 종목 미래에셋비전스팩3호 추출중...
# 0개 추출완료. 누적333개
# 45번째 종목 IBKS제22호스팩 추출중...
# 0개 추출완료. 누적333개
# 46번째 종목 하나27호스팩 추출중...
# 0개 추출완료. 누적333개
# 47번째 종목 지아이이노베이션 추출중...
# 1개 추출완료. 누적334개
# 48번째 종목 LB인베스트먼트 추출중...
# 2개 추출완료. 누적336개
# 49번째 종목 유안타제12호스팩 추출중...
# 10개 추출완료. 누적346개
# 50번째 종목 엑스게이트 추출중...
# 11개 추출완료. 누적357개
# 12/12 [==============================] - 0s 42ms/step
# 12/12 [==============================] - 0s 15ms/step
# 1
# 시큐센 2023-07-24
# 51번째 종목 미래에셋드림스팩1호 추출중...
# 12개 추출완료. 누적12개
# 52번째 종목 금양그린파워 추출중...
# 14개 추출완료. 누적26개
# 53번째 종목 라온텍 추출중...
# 16개 추출완료. 누적42개
# 54번째 종목 엔에이치스팩28호 추출중...
# 0개 추출완료. 누적42개
# 55번째 종목 자람테크놀로지 추출중...
# 18개 추출완료. 누적60개
# 56번째 종목 하나26호스팩 추출중...
# 18개 추출완료. 누적78개
# 57번째 종목 나노팀 추출중...
# 20개 추출완료. 누적98개
# 58번째 종목 바이오인프라 추출중...
# 21개 추출완료. 누적119개
# 59번째 종목 삼성스팩8호 추출중...
# 21개 추출완료. 누적140개
# 60번째 종목 유안타제13호스팩 추출중...
# 22개 추출완료. 누적162개
# 61번째 종목 미래에셋비전스팩2호 추출중...
# 24개 추출완료. 누적186개
# 62번째 종목 이노진 추출중...
# 116개 추출완료. 누적302개
# 63번째 종목 화인써키트 추출중...
# 29개 추출완료. 누적331개
# 64번째 종목 제이오 추출중...
# 30개 추출완료. 누적361개
# 65번째 종목 샌즈랩 추출중...
# 31개 추출완료. 누적392개
# 66번째 종목 꿈비 추출중...
# 35개 추출완료. 누적427개
# 67번째 종목 스튜디오미르 추출중...
# 37개 추출완료. 누적464개
# 68번째 종목 삼기이브이 추출중...
# 39개 추출완료. 누적503개
# 69번째 종목 오브젠 추출중...
# 43개 추출완료. 누적546개
# 70번째 종목 미래반도체 추출중...
# 44개 추출완료. 누적590개
# 71번째 종목 티이엠씨 추출중...
# 48개 추출완료. 누적638개
# 72번째 종목 한주라이트메탈 추출중...
# 49개 추출완료. 누적687개
# 73번째 종목 옵티코어 추출중...
# 62개 추출완료. 누적749개
# 74번째 종목 신영스팩9호 추출중...
# 64개 추출완료. 누적813개
# 75번째 종목 신스틸 추출중...
# 66개 추출완료. 누적879개
# 76번째 종목 비엔케이제1호스팩 추출중...
# 66개 추출완료. 누적945개
# 77번째 종목 IBKS제21호스팩 추출중...
# 71개 추출완료. 누적1016개
# 78번째 종목 엔에이치스팩27호 추출중...
# 71개 추출완료. 누적1087개
# 79번째 종목 핑거스토리 추출중...
# 77개 추출완료. 누적1164개
# 80번째 종목 SAMG엔터 추출중...
# 79개 추출완료. 누적1243개
# 81번째 종목 대신밸런스제14호스팩 추출중...
# 29개 추출완료. 누적1272개
# 82번째 종목 엔에이치스팩26호 추출중...
# 82개 추출완료. 누적1354개
# 83번째 종목 유진스팩9호 추출중...
# 82개 추출완료. 누적1436개
# 84번째 종목 대신밸런스제13호스팩 추출중...
# 19개 추출완료. 누적1455개
# 85번째 종목 펨트론 추출중...
# 87개 추출완료. 누적1542개
# 86번째 종목 인벤티지랩 추출중...
# 89개 추출완료. 누적1631개
# 87번째 종목 엔젯 추출중...
# 91개 추출완료. 누적1722개
# 88번째 종목 유비온 추출중...
# 116개 추출완료. 누적1838개
# 89번째 종목 티쓰리 추출중...
# 92개 추출완료. 누적1930개
# 90번째 종목 티에프이 추출중...
# 92개 추출완료. 누적2022개
# 91번째 종목 윤성에프앤씨 추출중...
# 95개 추출완료. 누적2117개
# 92번째 종목 디티앤씨알오 추출중...
# 96개 추출완료. 누적2213개
# 93번째 종목 뉴로메카 추출중...
# 101개 추출완료. 누적2314개
# 94번째 종목 제이아이테크 추출중...
# 101개 추출완료. 누적2415개
# 95번째 종목 엔에이치스팩25호 추출중...
# 74개 추출완료. 누적2489개
# 96번째 종목 케이비제23호스팩 추출중...
# 41개 추출완료. 누적2530개
# 97번째 종목 교보13호스팩 추출중...
# 103개 추출완료. 누적2633개
# 98번째 종목 큐알티 추출중...
# 103개 추출완료. 누적2736개
# 99번째 종목 IBKS제20호스팩 추출중...
# 106개 추출완료. 누적2842개
# 100번째 종목 저스템 추출중...
# 106개 추출완료. 누적2948개
# 93/93 [==============================] - 2s 18ms/step
# 93/93 [==============================] - 1s 15ms/step
# 1
# 뉴로메카 2023-06-20
# 101번째 종목 산돌 추출중...
# 107개 추출완료. 누적107개
# 102번째 종목 삼성스팩7호 추출중...
# 108개 추출완료. 누적215개
# 103번째 종목 플라즈맵 추출중...
# 111개 추출완료. 누적326개
# 104번째 종목 엔에이치스팩24호 추출중...
# 32개 추출완료. 누적358개
# 105번째 종목 핀텔 추출중...
# 112개 추출완료. 누적470개
# 106번째 종목 하나금융25호스팩 추출중...
# 55개 추출완료. 누적525개
# 107번째 종목 한국제11호스팩 추출중...
# 19개 추출완료. 누적544개
# 108번째 종목 샤페론 추출중...
# 113개 추출완료. 누적657개
# 109번째 종목 비스토스 추출중...
# 114개 추출완료. 누적771개
# 110번째 종목 탑머티리얼 추출중...
# 114개 추출완료. 누적885개
# 111번째 종목 에스비비테크 추출중...
# 115개 추출완료. 누적1000개
# 112번째 종목 오에스피 추출중...
# 116개 추출완료. 누적1116개
# 113번째 종목 모델솔루션 추출중...
# 116개 추출완료. 누적1232개
# 114번째 종목 이노룰스 추출중...
# 116개 추출완료. 누적1348개
# 115번째 종목 파인엠텍 추출중...
# 116개 추출완료. 누적1464개
# 116번째 종목 SK증권제8호스팩 추출중...
# 104개 추출완료. 누적1568개
# 117번째 종목 유안타제10호스팩 추출중...
# 116개 추출완료. 누적1684개
# 118번째 종목 선바이오 추출중...
# 116개 추출완료. 누적1800개
# 119번째 종목 더블유씨피 추출중...
# 116개 추출완료. 누적1916개
# 120번째 종목 알피바이오 추출중...
# 116개 추출완료. 누적2032개
# 121번째 종목 하나금융24호스팩 추출중...
# 116개 추출완료. 누적2148개
# 122번째 종목 한화플러스제3호스팩 추출중...
# 116개 추출완료. 누적2264개
# 123번째 종목 오픈엣지테크놀로지 추출중...
# 116개 추출완료. 누적2380개
# 124번째 종목 케이비제22호스팩 추출중...
# 65개 추출완료. 누적2445개
# 125번째 종목 하나금융23호스팩 추출중...
# 57개 추출완료. 누적2502개
# 126번째 종목 키움제7호스팩 추출중...
# 116개 추출완료. 누적2618개
# 127번째 종목 IBKS제19호스팩 추출중...
# 52개 추출완료. 누적2670개
# 128번째 종목 신영스팩8호 추출중...
# 116개 추출완료. 누적2786개
# 129번째 종목 대성하이텍 추출중...
# 116개 추출완료. 누적2902개
# 130번째 종목 에이치와이티씨 추출중...
# 116개 추출완료. 누적3018개
# 131번째 종목 새빗켐 추출중...
# 116개 추출완료. 누적3134개
# 132번째 종목 유안타제9호스팩 추출중...
# 116개 추출완료. 누적3250개
# 133번째 종목 신한제10호스팩 추출중...
# 116개 추출완료. 누적3366개
# 134번째 종목 아이씨에이치 추출중...
# 116개 추출완료. 누적3482개
# 135번째 종목 성일하이텍 추출중...
# 116개 추출완료. 누적3598개
# 136번째 종목 에이프릴바이오 추출중...
# 116개 추출완료. 누적3714개
# 137번째 종목 벨로크 추출중...
# 78개 추출완료. 누적3792개
# 138번째 종목 루닛 추출중...
# 116개 추출완료. 누적3908개
# 139번째 종목 HPSP 추출중...
# 116개 추출완료. 누적4024개
# 140번째 종목 와이씨켐 추출중...
# 116개 추출완료. 누적4140개
# 141번째 종목 코난테크놀로지 추출중...
# 115개 추출완료. 누적4255개
# 142번째 종목 넥스트칩 추출중...
# 116개 추출완료. 누적4371개
# 143번째 종목 삼성스팩6호 추출중...
# 116개 추출완료. 누적4487개
# 144번째 종목 엔에이치스팩23호 추출중...
# 0개 추출완료. 누적4487개
# 145번째 종목 교보12호스팩 추출중...
# 116개 추출완료. 누적4603개
# 146번째 종목 레이저쎌 추출중...
# 116개 추출완료. 누적4719개
# 147번째 종목 보로노이 추출중...
# 116개 추출완료. 누적4835개
# 148번째 종목 위니아에이드 추출중...
# 116개 추출완료. 누적4951개
# 149번째 종목 케이비제21호스팩 추출중...
# 116개 추출완료. 누적5067개
# 150번째 종목 비플라이소프트 추출중...
# 116개 추출완료. 누적5183개
# 162/162 [==============================] - 3s 20ms/step
# 162/162 [==============================] - 3s 16ms/step
# 3
# 산돌 2023-07-13
# 모델솔루션 2023-07-05
# SK증권제8호스팩 2023-03-20
# 151번째 종목 범한퓨얼셀 추출중...
# 116개 추출완료. 누적116개
# 152번째 종목 청담글로벌 추출중...
# 116개 추출완료. 누적232개
# 153번째 종목 하나금융22호스팩 추출중...
# 56개 추출완료. 누적288개
# 154번째 종목 가온칩스 추출중...
# 116개 추출완료. 누적404개
# 155번째 종목 대명에너지 추출중...
# 116개 추출완료. 누적520개
# 156번째 종목 상상인제3호스팩 추출중...
# 116개 추출완료. 누적636개
# 157번째 종목 신영스팩7호 추출중...
# 116개 추출완료. 누적752개
# 158번째 종목 포바이포 추출중...
# 116개 추출완료. 누적868개
# 159번째 종목 신한제9호스팩 추출중...
# 116개 추출완료. 누적984개
# 160번째 종목 미래에셋비전스팩1호 추출중...
# 116개 추출완료. 누적1100개
# 161번째 종목 키움제6호스팩 추출중...
# 116개 추출완료. 누적1216개
# 162번째 종목 지투파워 추출중...
# 116개 추출완료. 누적1332개
# 163번째 종목 유진스팩8호 추출중...
# 116개 추출완료. 누적1448개
# 164번째 종목 세아메카닉스 추출중...
# 116개 추출완료. 누적1564개
# 165번째 종목 공구우먼 추출중...
# 116개 추출완료. 누적1680개
# 166번째 종목 유일로보틱스 추출중...
# 116개 추출완료. 누적1796개
# 167번째 종목 모아데이타 추출중...
# 116개 추출완료. 누적1912개
# 168번째 종목 메쎄이상 추출중...
# 102개 추출완료. 누적2014개
# 169번째 종목 노을 추출중...
# 116개 추출완료. 누적2130개
# 170번째 종목 비씨엔씨 추출중...
# 116개 추출완료. 누적2246개
# 171번째 종목 풍원정밀 추출중...
# 116개 추출완료. 누적2362개
# 172번째 종목 스톤브릿지벤처스 추출중...
# 116개 추출완료. 누적2478개
# 173번째 종목 하나금융21호스팩 추출중...
# 116개 추출완료. 누적2594개
# 174번째 종목 브이씨 추출중...
# 116개 추출완료. 누적2710개
# 175번째 종목 퓨런티어 추출중...
# 116개 추출완료. 누적2826개
# 176번째 종목 바이오에프디엔씨 추출중...
# 116개 추출완료. 누적2942개
# 177번째 종목 한국제10호스팩 추출중...
# 19개 추출완료. 누적2961개
# 178번째 종목 IBKS제17호스팩 추출중...
# 0개 추출완료. 누적2961개
# 179번째 종목 인카금융서비스 추출중...
# 116개 추출완료. 누적3077개
# 180번째 종목 나래나노텍 추출중...
# 116개 추출완료. 누적3193개
# 181번째 종목 아셈스 추출중...
# 116개 추출완료. 누적3309개
# 182번째 종목 스코넥 추출중...
# 116개 추출완료. 누적3425개
# 183번째 종목 이지트로닉스 추출중...
# 116개 추출완료. 누적3541개
# 184번째 종목 애드바이오텍 추출중...
# 116개 추출완료. 누적3657개
# 185번째 종목 케이옥션 추출중...
# 116개 추출완료. 누적3773개
# 186번째 종목 디비금융스팩10호 추출중...
# 24개 추출완료. 누적3797개
# 187번째 종목 오토앤 추출중...
# 116개 추출완료. 누적3913개
# 188번째 종목 래몽래인 추출중...
# 116개 추출완료. 누적4029개
# 189번째 종목 하나금융20호스팩 추출중...
# 58개 추출완료. 누적4087개
# 190번째 종목 교보11호스팩 추출중...
# 116개 추출완료. 누적4203개
# 191번째 종목 하이제7호스팩 추출중...
# 116개 추출완료. 누적4319개
# 192번째 종목 우리벤처파트너스 추출중...
# 109개 추출완료. 누적4428개
# 193번째 종목 툴젠 추출중...
# 116개 추출완료. 누적4544개
# 194번째 종목 마음AI 추출중...
# 116개 추출완료. 누적4660개
# 195번째 종목 알비더블유 추출중...
# 116개 추출완료. 누적4776개
# 196번째 종목 바이옵트로 추출중...
# 116개 추출완료. 누적4892개
# 197번째 종목 트윔 추출중...
# 116개 추출완료. 누적5008개
# 198번째 종목 아이티아이즈 추출중...
# 116개 추출완료. 누적5124개
# 199번째 종목 지오엘리먼트 추출중...
# 116개 추출완료. 누적5240개
# 200번째 종목 디어유 추출중...
# 116개 추출완료. 누적5356개
# 168/168 [==============================] - 3s 16ms/step
# 168/168 [==============================] - 3s 15ms/step
# 5
# 세아메카닉스 2023-03-17
# 모아데이타 2023-04-14
# 바이오에프디엔씨 2023-07-21
# 스코넥 2023-07-18
# 디어유 2023-08-08
# 201번째 종목 비트나인 추출중...
# 116개 추출완료. 누적116개
# 202번째 종목 지니너스 추출중...
# 116개 추출완료. 누적232개
# 203번째 종목 피코그램 추출중...
# 116개 추출완료. 누적348개
# 204번째 종목 엔켐 추출중...
# 116개 추출완료. 누적464개
# 205번째 종목 리파인 추출중...
# 116개 추출완료. 누적580개
# 206번째 종목 지앤비에스 에코 추출중...
# 116개 추출완료. 누적696개
# 207번째 종목 아이패밀리에스씨 추출중...
# 116개 추출완료. 누적812개
# 208번째 종목 차백신연구소 추출중...
# 116개 추출완료. 누적928개
# 209번째 종목 지아이텍 추출중...
# 116개 추출완료. 누적1044개
# 210번째 종목 코닉오토메이션 추출중...
# 116개 추출완료. 누적1160개
# 211번째 종목 씨유테크 추출중...
# 116개 추출완료. 누적1276개
# 212번째 종목 아스플로 추출중...
# 116개 추출완료. 누적1392개
# 213번째 종목 원준 추출중...
# 116개 추출완료. 누적1508개
# 214번째 종목 엔에이치스팩20호 추출중...
# 100개 추출완료. 누적1608개
# 215번째 종목 실리콘투 추출중...
# 116개 추출완료. 누적1724개
# 216번째 종목 에스앤디 추출중...
# 116개 추출완료. 누적1840개
# 217번째 종목 프롬바이오 추출중...
# 116개 추출완료. 누적1956개
# 218번째 종목 바이오플러스 추출중...
# 116개 추출완료. 누적2072개
# 219번째 종목 신한제8호스팩 추출중...
# 66개 추출완료. 누적2138개
# 220번째 종목 유진스팩7호 추출중...
# 116개 추출완료. 누적2254개
# 221번째 종목 와이엠텍 추출중...
# 116개 추출완료. 누적2370개
# 222번째 종목 에이비온 추출중...
# 116개 추출완료. 누적2486개
# 223번째 종목 라이콤 추출중...
# 107개 추출완료. 누적2593개
# 224번째 종목 바이젠셀 추출중...
# 116개 추출완료. 누적2709개
# 225번째 종목 브레인즈컴퍼니 추출중...
# 116개 추출완료. 누적2825개
# 226번째 종목 딥노이드 추출중...
# 116개 추출완료. 누적2941개
# 227번째 종목 엠로 추출중...
# 116개 추출완료. 누적3057개
# 228번째 종목 플래티어 추출중...
# 116개 추출완료. 누적3173개
# 229번째 종목 원티드랩 추출중...
# 116개 추출완료. 누적3289개
# 230번째 종목 HK이노엔 추출중...
# 116개 추출완료. 누적3405개
# 231번째 종목 한화플러스제2호스팩 추출중...
# 116개 추출완료. 누적3521개
# 232번째 종목 에브리봇 추출중...
# 116개 추출완료. 누적3637개
# 233번째 종목 맥스트 추출중...
# 116개 추출완료. 누적3753개
# 234번째 종목 큐라클 추출중...
# 116개 추출완료. 누적3869개
# 235번째 종목 오비고 추출중...
# 116개 추출완료. 누적3985개
# 236번째 종목 아모센스 추출중...
# 116개 추출완료. 누적4101개
# 237번째 종목 이노뎁 추출중...
# 116개 추출완료. 누적4217개
# 238번째 종목 라온테크 추출중...
# 116개 추출완료. 누적4333개
# 239번째 종목 삼성머스트스팩5호 추출중...
# 116개 추출완료. 누적4449개
# 240번째 종목 LB루셈 추출중...
# 116개 추출완료. 누적4565개
# 241번째 종목 에이디엠코리아 추출중...
# 116개 추출완료. 누적4681개
# 242번째 종목 에코프로에이치엔 추출중...
# 116개 추출완료. 누적4797개
# 243번째 종목 제주맥주 추출중...
# 116개 추출완료. 누적4913개
# 244번째 종목 진시스템 추출중...
# 116개 추출완료. 누적5029개
# 245번째 종목 삼성스팩4호 추출중...
# 116개 추출완료. 누적5145개
# 246번째 종목 삼영에스앤씨 추출중...
# 116개 추출완료. 누적5261개
# 247번째 종목 샘씨엔에스 추출중...
# 116개 추출완료. 누적5377개
# 248번째 종목 씨앤씨인터내셔널 추출중...
# 116개 추출완료. 누적5493개
# 249번째 종목 에이치피오 추출중...
# 116개 추출완료. 누적5609개
# 250번째 종목 하이제6호스팩 추출중...
# 50개 추출완료. 누적5659개
# 177/177 [==============================] - 4s 20ms/step
# 177/177 [==============================] - 3s 15ms/step
# 3
# 큐라클 2023-04-06
# 이노뎁 2023-02-28
# LB루셈 2023-08-07
# 251번째 종목 쿠콘 추출중...
# 116개 추출완료. 누적116개
# 252번째 종목 이삭엔지니어링 추출중...
# 116개 추출완료. 누적232개
# 253번째 종목 해성티피씨 추출중...
# 116개 추출완료. 누적348개
# 254번째 종목 유진스팩6호 추출중...
# 48개 추출완료. 누적396개
# 255번째 종목 유안타제8호스팩 추출중...
# 7개 추출완료. 누적403개
# 256번째 종목 엔시스 추출중...
# 116개 추출완료. 누적519개
# 257번째 종목 자이언트스텝 추출중...
# 116개 추출완료. 누적635개
# 258번째 종목 제노코 추출중...
# 116개 추출완료. 누적751개
# 259번째 종목 라이프시맨틱스 추출중...
# 116개 추출완료. 누적867개
# 260번째 종목 바이오다인 추출중...
# 116개 추출완료. 누적983개
# 261번째 종목 DB금융스팩9호 추출중...
# 22개 추출완료. 누적1005개
# 262번째 종목 네오이뮨텍 추출중...
# 116개 추출완료. 누적1121개
# 263번째 종목 싸이버원 추출중...
# 116개 추출완료. 누적1237개
# 264번째 종목 프레스티지바이오로직스 추출중...
# 116개 추출완료. 누적1353개
# 265번째 종목 나노씨엠에스 추출중...
# 116개 추출완료. 누적1469개
# 266번째 종목 하나머스트7호스팩 추출중...
# 85개 추출완료. 누적1554개
# 267번째 종목 뷰노 추출중...
# 116개 추출완료. 누적1670개
# 268번째 종목 하인크코리아 추출중...
# 116개 추출완료. 누적1786개
# 269번째 종목 유일에너테크 추출중...
# 116개 추출완료. 누적1902개
# 270번째 종목 씨이랩 추출중...
# 116개 추출완료. 누적2018개
# 271번째 종목 오로스테크놀로지 추출중...
# 116개 추출완료. 누적2134개
# 272번째 종목 피엔에이치테크 추출중...
# 116개 추출완료. 누적2250개
# 273번째 종목 모비데이즈 추출중...
# 116개 추출완료. 누적2366개
# 274번째 종목 아이퀘스트 추출중...
# 116개 추출완료. 누적2482개
# 275번째 종목 신한제7호스팩 추출중...
# 65개 추출완료. 누적2547개
# 276번째 종목 레인보우로보틱스 추출중...
# 116개 추출완료. 누적2663개
# 277번째 종목 와이더플래닛 추출중...
# 116개 추출완료. 누적2779개
# 278번째 종목 핑거 추출중...
# 116개 추출완료. 누적2895개
# 279번째 종목 모비릭스 추출중...
# 116개 추출완료. 누적3011개
# 280번째 종목 씨앤투스 추출중...
# 116개 추출완료. 누적3127개
# 281번째 종목 선진뷰티사이언스 추출중...
# 116개 추출완료. 누적3243개
# 282번째 종목 엔비티 추출중...
# 116개 추출완료. 누적3359개
# 283번째 종목 파이버프로 추출중...
# 116개 추출완료. 누적3475개
# 284번째 종목 블리츠웨이 추출중...
# 116개 추출완료. 누적3591개
# 285번째 종목 석경에이티 추출중...
# 116개 추출완료. 누적3707개
# 286번째 종목 지놈앤컴퍼니 추출중...
# 116개 추출완료. 누적3823개
# 287번째 종목 프리시젼바이오 추출중...
# 116개 추출완료. 누적3939개
# 288번째 종목 알체라 추출중...
# 116개 추출완료. 누적4055개
# 289번째 종목 하이딥 추출중...
# 116개 추출완료. 누적4171개
# 290번째 종목 에프앤가이드 추출중...
# 116개 추출완료. 누적4287개
# 291번째 종목 에이치엠씨제5호스팩 추출중...
# 50개 추출완료. 누적4337개
# 292번째 종목 티엘비 추출중...
# 116개 추출완료. 누적4453개
# 293번째 종목 인바이오 추출중...
# 116개 추출완료. 누적4569개
# 294번째 종목 엔젠바이오 추출중...
# 116개 추출완료. 누적4685개
# 295번째 종목 퀀타매트릭스 추출중...
# 116개 추출완료. 누적4801개
# 296번째 종목 클리노믹스 추출중...
# 116개 추출완료. 누적4917개
# 297번째 종목 포인트모바일 추출중...
# 0개 추출완료. 누적4917개
# 298번째 종목 앱코 추출중...
# 116개 추출완료. 누적5033개
# 299번째 종목 엔에프씨 추출중...
# 116개 추출완료. 누적5149개
# 300번째 종목 제일전기공업 추출중...
# 116개 추출완료. 누적5265개
# 165/165 [==============================] - 3s 19ms/step
# 165/165 [==============================] - 3s 16ms/step
# 4
# 라이프시맨틱스 2023-08-10
# 싸이버원 2023-05-12
# 아이퀘스트 2023-03-29
# 제일전기공업 2023-03-29
# 301번째 종목 하나기술 추출중...
# 116개 추출완료. 누적116개
# 302번째 종목 티앤엘 추출중...
# 116개 추출완료. 누적232개
# 303번째 종목 고바이오랩 추출중...
# 116개 추출완료. 누적348개
# 304번째 종목 네패스아크 추출중...
# 116개 추출완료. 누적464개
# 305번째 종목 소룩스 추출중...
# 114개 추출완료. 누적578개
# 306번째 종목 위드텍 추출중...
# 116개 추출완료. 누적694개
# 307번째 종목 센코 추출중...
# 116개 추출완료. 누적810개
# 308번째 종목 바이브컴퍼니 추출중...
# 116개 추출완료. 누적926개
# 309번째 종목 미코바이오메드 추출중...
# 116개 추출완료. 누적1042개
# 310번째 종목 피플바이오 추출중...
# 116개 추출완료. 누적1158개
# 311번째 종목 넥스틴 추출중...
# 116개 추출완료. 누적1274개
# 312번째 종목 케이엔솔 추출중...
# 116개 추출완료. 누적1390개
# 313번째 종목 비나텍 추출중...
# 116개 추출완료. 누적1506개
# 314번째 종목 씨엔알리서치 추출중...
# 116개 추출완료. 누적1622개
# 315번째 종목 박셀바이오 추출중...
# 116개 추출완료. 누적1738개
# 316번째 종목 비비씨 추출중...
# 116개 추출완료. 누적1854개
# 317번째 종목 코스텍시스 추출중...
# 67개 추출완료. 누적1921개
# 318번째 종목 핌스 추출중...
# 116개 추출완료. 누적2037개
# 319번째 종목 압타머사이언스 추출중...
# 116개 추출완료. 누적2153개
# 320번째 종목 이오플로우 추출중...
# 116개 추출완료. 누적2269개
# 321번째 종목 카카오게임즈 추출중...
# 116개 추출완료. 누적2385개
# 322번째 종목 피엔케이피부임상연구센타 추출중...
# 116개 추출완료. 누적2501개
# 323번째 종목 아이디피 추출중...
# 116개 추출완료. 누적2617개
# 324번째 종목 셀레믹스 추출중...
# 116개 추출완료. 누적2733개
# 325번째 종목 미투젠 추출중...
# 116개 추출완료. 누적2849개
# 326번째 종목 브랜드엑스코퍼레이션 추출중...
# 116개 추출완료. 누적2965개
# 327번째 종목 영림원소프트랩 추출중...
# 116개 추출완료. 누적3081개
# 328번째 종목 한국파마 추출중...
# 116개 추출완료. 누적3197개
# 329번째 종목 솔브레인 추출중...
# 116개 추출완료. 누적3313개
# 330번째 종목 이루다 추출중...
# 116개 추출완료. 누적3429개
# 331번째 종목 와이팜 추출중...
# 116개 추출완료. 누적3545개
# 332번째 종목 에코앤드림 추출중...
# 116개 추출완료. 누적3661개
# 333번째 종목 엠투아이 추출중...
# 116개 추출완료. 누적3777개
# 334번째 종목 더네이쳐홀딩스 추출중...
# 116개 추출완료. 누적3893개
# 335번째 종목 제놀루션 추출중...
# 116개 추출완료. 누적4009개
# 336번째 종목 솔트룩스 추출중...
# 116개 추출완료. 누적4125개
# 337번째 종목 티에스아이 추출중...
# 116개 추출완료. 누적4241개
# 338번째 종목 에이프로 추출중...
# 116개 추출완료. 누적4357개
# 339번째 종목 소마젠 추출중...
# 116개 추출완료. 누적4473개
# 340번째 종목 신도기연 추출중...
# 116개 추출완료. 누적4589개
# 341번째 종목 위더스제약 추출중...
# 116개 추출완료. 누적4705개
# 342번째 종목 엠브레인 추출중...
# 116개 추출완료. 누적4821개
# 343번째 종목 젠큐릭스 추출중...
# 116개 추출완료. 누적4937개
# 344번째 종목 HB솔루션 추출중...
# 116개 추출완료. 누적5053개
# 345번째 종목 에스에이티이엔지 추출중...
# 116개 추출완료. 누적5169개
# 346번째 종목 에스씨엠생명과학 추출중...
# 115개 추출완료. 누적5284개
# 347번째 종목 휴럼 추출중...
# 116개 추출완료. 누적5400개
# 348번째 종목 이지바이오 추출중...
# 116개 추출완료. 누적5516개
# 349번째 종목 드림씨아이에스 추출중...
# 116개 추출완료. 누적5632개
# 350번째 종목 엔피디 추출중...
# 116개 추출완료. 누적5748개
# 180/180 [==============================] - 3s 18ms/step
# 180/180 [==============================] - 3s 16ms/step
# 2
# 네패스아크 2023-03-09
# HB솔루션 2023-04-19
# 351번째 종목 플레이디 추출중...
# 116개 추출완료. 누적116개
# 352번째 종목 서울바이오시스 추출중...
# 116개 추출완료. 누적232개
# 353번째 종목 제이앤티씨 추출중...
# 116개 추출완료. 누적348개
# 354번째 종목 켄코아에어로스페이스 추출중...
# 116개 추출완료. 누적464개
# 355번째 종목 레몬 추출중...
# 116개 추출완료. 누적580개
# 356번째 종목 서남 추출중...
# 115개 추출완료. 누적695개
# 357번째 종목 위세아이텍 추출중...
# 116개 추출완료. 누적811개
# 358번째 종목 세림B&G 추출중...
# 116개 추출완료. 누적927개
# 359번째 종목 CJ 바이오사이언스 추출중...
# 116개 추출완료. 누적1043개
# 360번째 종목 피피아이 추출중...
# 116개 추출완료. 누적1159개
# 361번째 종목 RF머트리얼즈 추출중...
# 116개 추출완료. 누적1275개
# 362번째 종목 아이비김영 추출중...
# 116개 추출완료. 누적1391개
# 363번째 종목 브릿지바이오 추출중...
# 116개 추출완료. 누적1507개
# 364번째 종목 다보링크 추출중...
# 116개 추출완료. 누적1623개
# 365번째 종목 메드팩토 추출중...
# 116개 추출완료. 누적1739개
# 366번째 종목 원텍 추출중...
# 116개 추출완료. 누적1855개
# 367번째 종목 신테카바이오 추출중...
# 116개 추출완료. 누적1971개
# 368번째 종목 제이엘케이 추출중...
# 116개 추출완료. 누적2087개
# 369번째 종목 태웅로직스 추출중...
# 116개 추출완료. 누적2203개
# 370번째 종목 윙스풋 추출중...
# 116개 추출완료. 누적2319개
# 371번째 종목 리메드 추출중...
# 116개 추출완료. 누적2435개
# 372번째 종목 비올 추출중...
# 116개 추출완료. 누적2551개
# 373번째 종목 웨이버스 추출중...
# 116개 추출완료. 누적2667개
# 374번째 종목 HLB바이오스텝 추출중...
# 116개 추출완료. 누적2783개
# 375번째 종목 티움바이오 추출중...
# 116개 추출완료. 누적2899개
# 376번째 종목 씨에스베어링 추출중...
# 116개 추출완료. 누적3015개
# 377번째 종목 우양 추출중...
# 116개 추출완료. 누적3131개
# 378번째 종목 코리아에셋투자증권 추출중...
# 116개 추출완료. 누적3247개
# 379번째 종목 에스제이그룹 추출중...
# 116개 추출완료. 누적3363개
# 380번째 종목 제테마 추출중...
# 116개 추출완료. 누적3479개
# 381번째 종목 라파스 추출중...
# 116개 추출완료. 누적3595개
# 382번째 종목 아이티엠반도체 추출중...
# 116개 추출완료. 누적3711개
# 383번째 종목 일승 추출중...
# 116개 추출완료. 누적3827개
# 384번째 종목 미디어젠 추출중...
# 116개 추출완료. 누적3943개
# 385번째 종목 모코엠시스 추출중...
# 116개 추출완료. 누적4059개
# 386번째 종목 티라유텍 추출중...
# 116개 추출완료. 누적4175개
# 387번째 종목 밸로프 추출중...
# 116개 추출완료. 누적4291개
# 388번째 종목 캐리소프트 추출중...
# 116개 추출완료. 누적4407개
# 389번째 종목 케이엔제이 추출중...
# 116개 추출완료. 누적4523개
# 390번째 종목 엔바이오니아 추출중...
# 116개 추출완료. 누적4639개
# 391번째 종목 팜스빌 추출중...
# 116개 추출완료. 누적4755개
# 392번째 종목 라온피플 추출중...
# 116개 추출완료. 누적4871개
# 393번째 종목 아톤 추출중...
# 116개 추출완료. 누적4987개
# 394번째 종목 녹십자웰빙 추출중...
# 116개 추출완료. 누적5103개
# 395번째 종목 누보 추출중...
# 116개 추출완료. 누적5219개
# 396번째 종목 포커스에이치엔에스 추출중...
# 116개 추출완료. 누적5335개
# 397번째 종목 올리패스 추출중...
# 116개 추출완료. 누적5451개
# 398번째 종목 라닉스 추출중...
# 116개 추출완료. 누적5567개
# 399번째 종목 윈텍 추출중...
# 116개 추출완료. 누적5683개
# 400번째 종목 한독크린텍 추출중...
# 116개 추출완료. 누적5799개
# 182/182 [==============================] - 3s 17ms/step
# 182/182 [==============================] - 3s 16ms/step
# 1
# HLB바이오스텝 2023-04-12
# 401번째 종목 네오크레마 추출중...
# 116개 추출완료. 누적116개
# 402번째 종목 마니커에프앤지 추출중...
# 116개 추출완료. 누적232개
# 403번째 종목 솔트웨어 추출중...
# 116개 추출완료. 누적348개
# 404번째 종목 나노브릭 추출중...
# 116개 추출완료. 누적464개
# 405번째 종목 에스피시스템스 추출중...
# 116개 추출완료. 누적580개
# 406번째 종목 레이 추출중...
# 116개 추출완료. 누적696개
# 407번째 종목 그린플러스 추출중...
# 116개 추출완료. 누적812개
# 408번째 종목 코윈테크 추출중...
# 116개 추출완료. 누적928개
# 409번째 종목 덕산테코피아 추출중...
# 116개 추출완료. 누적1044개
# 410번째 종목 KBG 추출중...
# 116개 추출완료. 누적1160개
# 411번째 종목 엑스페릭스 추출중...
# 116개 추출완료. 누적1276개
# 412번째 종목 세경하이테크 추출중...
# 116개 추출완료. 누적1392개
# 413번째 종목 윌링스 추출중...
# 116개 추출완료. 누적1508개
# 414번째 종목 대모 추출중...
# 116개 추출완료. 누적1624개
# 415번째 종목 에이스토리 추출중...
# 116개 추출완료. 누적1740개
# 416번째 종목 플리토 추출중...
# 116개 추출완료. 누적1856개
# 417번째 종목 헥토파이낸셜 추출중...
# 116개 추출완료. 누적1972개
# 418번째 종목 아이스크림에듀 추출중...
# 116개 추출완료. 누적2088개
# 419번째 종목 펌텍코리아 추출중...
# 116개 추출완료. 누적2204개
# 420번째 종목 에이에프더블류 추출중...
# 116개 추출완료. 누적2320개
# 421번째 종목 태성 추출중...
# 116개 추출완료. 누적2436개
# 422번째 종목 엠에프엠코리아 추출중...
# 116개 추출완료. 누적2552개
# 423번째 종목 압타바이오 추출중...
# 116개 추출완료. 누적2668개
# 424번째 종목 까스텔바작 추출중...
# 116개 추출완료. 누적2784개
# 425번째 종목 마이크로디지탈 추출중...
# 116개 추출완료. 누적2900개
# 426번째 종목 코퍼스코리아 추출중...
# 116개 추출완료. 누적3016개
# 427번째 종목 프로이천 추출중...
# 116개 추출완료. 누적3132개
# 428번째 종목 수젠텍 추출중...
# 116개 추출완료. 누적3248개
# 429번째 종목 컴퍼니케이 추출중...
# 116개 추출완료. 누적3364개
# 430번째 종목 피에스케이 추출중...
# 116개 추출완료. 누적3480개
# 431번째 종목 현대무벡스 추출중...
# 116개 추출완료. 누적3596개
# 432번째 종목 TS트릴리온 추출중...
# 116개 추출완료. 누적3712개
# 433번째 종목 아모그린텍 추출중...
# 116개 추출완료. 누적3828개
# 434번째 종목 지노믹트리 추출중...
# 116개 추출완료. 누적3944개
# 435번째 종목 이지케어텍 추출중...
# 116개 추출완료. 누적4060개
# 436번째 종목 미래에셋벤처투자 추출중...
# 116개 추출완료. 누적4176개
# 437번째 종목 에코프로비엠 추출중...
# 116개 추출완료. 누적4292개
# 438번째 종목 셀리드 추출중...
# 116개 추출완료. 누적4408개
# 439번째 종목 천보 추출중...
# 116개 추출완료. 누적4524개
# 440번째 종목 이노테라피 추출중...
# 116개 추출완료. 누적4640개
# 441번째 종목 노랑풍선 추출중...
# 116개 추출완료. 누적4756개
# 442번째 종목 웹케시 추출중...
# 116개 추출완료. 누적4872개
# 443번째 종목 비피도 추출중...
# 116개 추출완료. 누적4988개
# 444번째 종목 유틸렉스 추출중...
# 116개 추출완료. 누적5104개
# 445번째 종목 디케이티 추출중...
# 116개 추출완료. 누적5220개
# 446번째 종목 아이엘사이언스 추출중...
# 116개 추출완료. 누적5336개
# 447번째 종목 애니플러스 추출중...
# 116개 추출완료. 누적5452개
# 448번째 종목 디와이씨 추출중...
# 116개 추출완료. 누적5568개
# 449번째 종목 오하임아이엔티 추출중...
# 116개 추출완료. 누적5684개
# 450번째 종목 위지윅스튜디오 추출중...
# 116개 추출완료. 누적5800개
# 182/182 [==============================] - 3s 18ms/step
# 182/182 [==============================] - 3s 15ms/step
# 2
# 플리토 2023-03-29
# 에이에프더블류 2023-07-19
# 451번째 종목 국전약품 추출중...
# 116개 추출완료. 누적116개
# 452번째 종목 에이비엘바이오 추출중...
# 116개 추출완료. 누적232개
# 453번째 종목 머큐리 추출중...
# 116개 추출완료. 누적348개
# 454번째 종목 전진바이오팜 추출중...
# 116개 추출완료. 누적464개
# 455번째 종목 뉴트리 추출중...
# 116개 추출완료. 누적580개
# 456번째 종목 비투엔 추출중...
# 116개 추출완료. 누적696개
# 457번째 종목 이노메트리 추출중...
# 116개 추출완료. 누적812개
# 458번째 종목 대유에이피 추출중...
# 116개 추출완료. 누적928개
# 459번째 종목 에코캡 추출중...
# 116개 추출완료. 누적1044개
# 460번째 종목 원바이오젠 추출중...
# 116개 추출완료. 누적1160개
# 461번째 종목 베스파 추출중...
# 0개 추출완료. 누적1160개
# 462번째 종목 윙입푸드 추출중...
# 116개 추출완료. 누적1276개
# 463번째 종목 남화산업 추출중...
# 116개 추출완료. 누적1392개
# 464번째 종목 엠아이텍 추출중...
# 116개 추출완료. 누적1508개
# 465번째 종목 티로보틱스 추출중...
# 116개 추출완료. 누적1624개
# 466번째 종목 네오펙트 추출중...
# 116개 추출완료. 누적1740개
# 467번째 종목 티앤알바이오팹 추출중...
# 116개 추출완료. 누적1856개
# 468번째 종목 디알젬 추출중...
# 116개 추출완료. 누적1972개
# 469번째 종목 싸이토젠 추출중...
# 116개 추출완료. 누적2088개
# 470번째 종목 아주IB투자 추출중...
# 116개 추출완료. 누적2204개
# 471번째 종목 파멥신 추출중...
# 116개 추출완료. 누적2320개
# 472번째 종목 디케이앤디 추출중...
# 116개 추출완료. 누적2436개
# 473번째 종목 에이치앤비디자인 추출중...
# 116개 추출완료. 누적2552개
# 474번째 종목 노바렉스 추출중...
# 116개 추출완료. 누적2668개
# 475번째 종목 셀리버리 추출중...
# 18개 추출완료. 누적2686개
# 476번째 종목 대보마그네틱 추출중...
# 116개 추출완료. 누적2802개
# 477번째 종목 노바텍 추출중...
# 116개 추출완료. 누적2918개
# 478번째 종목 엘앤씨바이오 추출중...
# 116개 추출완료. 누적3034개
# 479번째 종목 네온테크 추출중...
# 116개 추출완료. 누적3150개
# 480번째 종목 로보티즈 추출중...
# 116개 추출완료. 누적3266개
# 481번째 종목 옵티팜 추출중...
# 116개 추출완료. 누적3382개
# 482번째 종목 에스퓨얼셀 추출중...
# 116개 추출완료. 누적3498개
# 483번째 종목 나우IB 추출중...
# 103개 추출완료. 누적3601개
# 484번째 종목 푸드나무 추출중...
# 116개 추출완료. 누적3717개
# 485번째 종목 크리스에프앤씨 추출중...
# 116개 추출완료. 누적3833개
# 486번째 종목 더블유에스아이 추출중...
# 116개 추출완료. 누적3949개
# 487번째 종목 지티지웰니스 추출중...
# 0개 추출완료. 누적3949개
# 488번째 종목 명성티엔에스 추출중...
# 0개 추출완료. 누적3949개
# 489번째 종목 엔피 추출중...
# 116개 추출완료. 누적4065개
# 490번째 종목 디지캡 추출중...
# 116개 추출완료. 누적4181개
# 491번째 종목 지니틱스 추출중...
# 116개 추출완료. 누적4297개
# 492번째 종목 액트로 추출중...
# 116개 추출완료. 누적4413개
# 493번째 종목 오파스넷 추출중...
# 116개 추출완료. 누적4529개
# 494번째 종목 에이피티씨 추출중...
# 116개 추출완료. 누적4645개
# 495번째 종목 바이오솔루션 추출중...
# 116개 추출완료. 누적4761개
# 496번째 종목 대유 추출중...
# 42개 추출완료. 누적4803개
# 497번째 종목 디아이티 추출중...
# 116개 추출완료. 누적4919개
# 498번째 종목 에스에스알 추출중...
# 102개 추출완료. 누적5021개
# 499번째 종목 휴네시온 추출중...
# 116개 추출완료. 누적5137개
# 500번째 종목 한국유니온제약 추출중...
# 116개 추출완료. 누적5253개
# 165/165 [==============================] - 3s 16ms/step
# 165/165 [==============================] - 3s 15ms/step
# 8
# 에이비엘바이오 2023-05-10
# 비투엔 2023-06-09
# 엠아이텍 2023-06-27
# 티앤알바이오팹 2023-03-28
# 디알젬 2023-07-19
# 에이치앤비디자인 2023-06-21
# 푸드나무 2023-08-01
# 휴네시온 2023-03-28
# 501번째 종목 그리티 추출중...
# 116개 추출완료. 누적116개
# 502번째 종목 알로이스 추출중...
# 116개 추출완료. 누적232개
# 503번째 종목 올릭스 추출중...
# 116개 추출완료. 누적348개
# 504번째 종목 아이큐어 추출중...
# 116개 추출완료. 누적464개
# 505번째 종목 SV인베스트먼트 추출중...
# 116개 추출완료. 누적580개
# 506번째 종목 EDGC 추출중...
# 116개 추출완료. 누적696개
# 507번째 종목 카이노스메드 추출중...
# 116개 추출완료. 누적812개
# 508번째 종목 파워넷 추출중...
# 116개 추출완료. 누적928개
# 509번째 종목 카나리아바이오 추출중...
# 116개 추출완료. 누적1044개
# 510번째 종목 세종메디칼 추출중...
# 116개 추출완료. 누적1160개
# 511번째 종목 제노레이 추출중...
# 116개 추출완료. 누적1276개
# 512번째 종목 제이시스메디칼 추출중...
# 116개 추출완료. 누적1392개
# 513번째 종목 JTC 추출중...
# 116개 추출완료. 누적1508개
# 514번째 종목 네오셈 추출중...
# 116개 추출완료. 누적1624개
# 515번째 종목 케어랩스 추출중...
# 116개 추출완료. 누적1740개
# 516번째 종목 린드먼아시아 추출중...
# 116개 추출완료. 누적1856개
# 517번째 종목 오스테오닉 추출중...
# 116개 추출완료. 누적1972개
# 518번째 종목 엔지켐생명과학 추출중...
# 116개 추출완료. 누적2088개
# 519번째 종목 동구바이오제약 추출중...
# 116개 추출완료. 누적2204개
# 520번째 종목 아시아종묘 추출중...
# 116개 추출완료. 누적2320개
# 521번째 종목 알리코제약 추출중...
# 116개 추출완료. 누적2436개
# 522번째 종목 카페24 추출중...
# 116개 추출완료. 누적2552개
# 523번째 종목 링크제니시스 추출중...
# 116개 추출완료. 누적2668개
# 524번째 종목 배럴 추출중...
# 116개 추출완료. 누적2784개
# 525번째 종목 SG 추출중...
# 116개 추출완료. 누적2900개
# 526번째 종목 씨앤지하이테크 추출중...
# 116개 추출완료. 누적3016개
# 527번째 종목 시스웍 추출중...
# 0개 추출완료. 누적3016개
# 528번째 종목 디바이스이엔지 추출중...
# 116개 추출완료. 누적3132개
# 529번째 종목 레이크머티리얼즈 추출중...
# 116개 추출완료. 누적3248개
# 530번째 종목 씨티케이 추출중...
# 116개 추출완료. 누적3364개
# 531번째 종목 메카로 추출중...
# 116개 추출완료. 누적3480개
# 532번째 종목 에스트래픽 추출중...
# 116개 추출완료. 누적3596개
# 533번째 종목 체리부로 추출중...
# 116개 추출완료. 누적3712개
# 534번째 종목 대원 추출중...
# 116개 추출완료. 누적3828개
# 535번째 종목 비즈니스온 추출중...
# 116개 추출완료. 누적3944개
# 536번째 종목 스튜디오드래곤 추출중...
# 116개 추출완료. 누적4060개
# 537번째 종목 비디아이 추출중...
# 0개 추출완료. 누적4060개
# 538번째 종목 코오롱티슈진 추출중...
# 110개 추출완료. 누적4170개
# 539번째 종목 영화테크 추출중...
# 116개 추출완료. 누적4286개
# 540번째 종목 폴라리스세원 추출중...
# 116개 추출완료. 누적4402개
# 541번째 종목 상신전자 추출중...
# 116개 추출완료. 누적4518개
# 542번째 종목 야스 추출중...
# 116개 추출완료. 누적4634개
# 543번째 종목 인산가 추출중...
# 116개 추출완료. 누적4750개
# 544번째 종목 휴엠앤씨 추출중...
# 116개 추출완료. 누적4866개
# 545번째 종목 신흥에스이씨 추출중...
# 116개 추출완료. 누적4982개
# 546번째 종목 유티아이 추출중...
# 116개 추출완료. 누적5098개
# 547번째 종목 선익시스템 추출중...
# 116개 추출완료. 누적5214개
# 548번째 종목 엠플러스 추출중...
# 116개 추출완료. 누적5330개
# 549번째 종목 앱클론 추출중...
# 116개 추출완료. 누적5446개
# 550번째 종목 어스앤에어로스페이스 추출중...
# 0개 추출완료. 누적5446개
# 171/171 [==============================] - 3s 17ms/step
# 171/171 [==============================] - 3s 16ms/step
# 3
# 아이큐어 2023-07-07
# 제노레이 2023-08-01
# 폴라리스세원 2023-06-14
# 551번째 종목 펄어비스 추출중...
# 116개 추출완료. 누적116개
# 552번째 종목 케이피에스 추출중...
# 116개 추출완료. 누적232개
# 553번째 종목 덕우전자 추출중...
# 116개 추출완료. 누적348개
# 554번째 종목 지오릿에너지 추출중...
# 116개 추출완료. 누적464개
# 555번째 종목 케일럼 추출중...
# 116개 추출완료. 누적580개
# 556번째 종목 알에스오토메이션 추출중...
# 116개 추출완료. 누적696개
# 557번째 종목 컬러레이 추출중...
# 116개 추출완료. 누적812개
# 558번째 종목 와이즈버즈 추출중...
# 116개 추출완료. 누적928개
# 559번째 종목 모트렉스 추출중...
# 116개 추출완료. 누적1044개
# 560번째 종목 데이타솔루션 추출중...
# 116개 추출완료. 누적1160개
# 561번째 종목 지니언스 추출중...
# 116개 추출완료. 누적1276개
# 562번째 종목 디앤씨미디어 추출중...
# 116개 추출완료. 누적1392개
# 563번째 종목 셀트리온헬스케어 추출중...
# 116개 추출완료. 누적1508개
# 564번째 종목 이즈미디어 추출중...
# 0개 추출완료. 누적1508개
# 565번째 종목 힘스 추출중...
# 116개 추출완료. 누적1624개
# 566번째 종목 브이원텍 추출중...
# 116개 추출완료. 누적1740개
# 567번째 종목 아우딘퓨쳐스 추출중...
# 116개 추출완료. 누적1856개
# 568번째 종목 이녹스첨단소재 추출중...
# 116개 추출완료. 누적1972개
# 569번째 종목 하림지주 추출중...
# 116개 추출완료. 누적2088개
# 570번째 종목 덴티스 추출중...
# 116개 추출완료. 누적2204개
# 571번째 종목 나인테크 추출중...
# 116개 추출완료. 누적2320개
# 572번째 종목 보라티알 추출중...
# 116개 추출완료. 누적2436개
# 573번째 종목 매일유업 추출중...
# 116개 추출완료. 누적2552개
# 574번째 종목 삼양옵틱스 추출중...
# 116개 추출완료. 누적2668개
# 575번째 종목 이랜시스 추출중...
# 116개 추출완료. 누적2784개
# 576번째 종목 필옵틱스 추출중...
# 116개 추출완료. 누적2900개
# 577번째 종목 포인트엔지니어링 추출중...
# 116개 추출완료. 누적3016개
# 578번째 종목 하나머티리얼즈 추출중...
# 116개 추출완료. 누적3132개
# 579번째 종목 소프트캠프 추출중...
# 116개 추출완료. 누적3248개
# 580번째 종목 와이엠티 추출중...
# 116개 추출완료. 누적3364개
# 581번째 종목 AP시스템 추출중...
# 116개 추출완료. 누적3480개
# 582번째 종목 유에스티 추출중...
# 116개 추출완료. 누적3596개
# 583번째 종목 이엘피 추출중...
# 116개 추출완료. 누적3712개
# 584번째 종목 유비쿼스 추출중...
# 116개 추출완료. 누적3828개
# 585번째 종목 서진시스템 추출중...
# 116개 추출완료. 누적3944개
# 586번째 종목 코미코 추출중...
# 116개 추출완료. 누적4060개
# 587번째 종목 아스타 추출중...
# 116개 추출완료. 누적4176개
# 588번째 종목 에스디생명공학 추출중...
# 17개 추출완료. 누적4193개
# 589번째 종목 신신제약 추출중...
# 116개 추출완료. 누적4309개
# 590번째 종목 에프엔에스테크 추출중...
# 116개 추출완료. 누적4425개
# 591번째 종목 모바일어플라이언스 추출중...
# 116개 추출완료. 누적4541개
# 592번째 종목 피씨엘 추출중...
# 116개 추출완료. 누적4657개
# 593번째 종목 서플러스글로벌 추출중...
# 116개 추출완료. 누적4773개
# 594번째 종목 유바이오로직스 추출중...
# 116개 추출완료. 누적4889개
# 595번째 종목 한국비엔씨 추출중...
# 116개 추출완료. 누적5005개
# 596번째 종목 DSC인베스트먼트 추출중...
# 116개 추출완료. 누적5121개
# 597번째 종목 TS인베스트먼트 추출중...
# 116개 추출완료. 누적5237개
# 598번째 종목 피엠티 추출중...
# 116개 추출완료. 누적5353개
# 599번째 종목 애니젠 추출중...
# 116개 추출완료. 누적5469개
# 600번째 종목 유니온커뮤니티 추출중...
# 116개 추출완료. 누적5585개
# 175/175 [==============================] - 3s 15ms/step
# 175/175 [==============================] - 3s 16ms/step
# 4
# 모트렉스 2023-05-30
# 삼양옵틱스 2023-05-25
# 에스디생명공학 2023-03-16
# DSC인베스트먼트 2023-07-12
# 601번째 종목 신라젠 추출중...
# 116개 추출완료. 누적116개
# 602번째 종목 자비스 추출중...
# 116개 추출완료. 누적232개
# 603번째 종목 오션브릿지 추출중...
# 116개 추출완료. 누적348개
# 604번째 종목 퓨쳐켐 추출중...
# 116개 추출완료. 누적464개
# 605번째 종목 뉴파워프라즈마 추출중...
# 116개 추출완료. 누적580개
# 606번째 종목 엘앤케이바이오 추출중...
# 116개 추출완료. 누적696개
# 607번째 종목 핸디소프트 추출중...
# 116개 추출완료. 누적812개
# 608번째 종목 클리오 추출중...
# 116개 추출완료. 누적928개
# 609번째 종목 오가닉티코스메틱 추출중...
# 116개 추출완료. 누적1044개
# 610번째 종목 얼라인드 추출중...
# 116개 추출완료. 누적1160개
# 611번째 종목 세화피앤씨 추출중...
# 116개 추출완료. 누적1276개
# 612번째 종목 인크로스 추출중...
# 116개 추출완료. 누적1392개
# 613번째 종목 에이치엘사이언스 추출중...
# 116개 추출완료. 누적1508개
# 614번째 종목 코스메카코리아 추출중...
# 116개 추출완료. 누적1624개
# 615번째 종목 GRT 추출중...
# 116개 추출완료. 누적1740개
# 616번째 종목 골든센츄리 추출중...
# 116개 추출완료. 누적1856개
# 617번째 종목 인텔리안테크 추출중...
# 116개 추출완료. 누적1972개
# 618번째 종목 에이치시티 추출중...
# 116개 추출완료. 누적2088개
# 619번째 종목 잉글우드랩 추출중...
# 116개 추출완료. 누적2204개
# 620번째 종목 앤디포스 추출중...
# 86개 추출완료. 누적2290개
# 621번째 종목 수산아이앤티 추출중...
# 116개 추출완료. 누적2406개
# 622번째 종목 미투온 추출중...
# 116개 추출완료. 누적2522개
# 623번째 종목 예선테크 추출중...
# 116개 추출완료. 누적2638개
# 624번째 종목 유니테크노 추출중...
# 116개 추출완료. 누적2754개
# 625번째 종목 모비스 추출중...
# 116개 추출완료. 누적2870개
# 626번째 종목 나무기술 추출중...
# 116개 추출완료. 누적2986개
# 627번째 종목 자이글 추출중...
# 114개 추출완료. 누적3100개
# 628번째 종목 헝셩그룹 추출중...
# 116개 추출완료. 누적3216개
# 629번째 종목 에코마케팅 추출중...
# 116개 추출완료. 누적3332개
# 630번째 종목 엔지스테크널러지 추출중...
# 0개 추출완료. 누적3332개
# 631번째 종목 우리손에프앤지 추출중...
# 116개 추출완료. 누적3448개
# 632번째 종목 아이윈플러스 추출중...
# 102개 추출완료. 누적3550개
# 633번째 종목 장원테크 추출중...
# 27개 추출완료. 누적3577개
# 634번째 종목 위니아 추출중...
# 116개 추출완료. 누적3693개
# 635번째 종목 비엘 추출중...
# 116개 추출완료. 누적3809개
# 636번째 종목 피앤씨테크 추출중...
# 116개 추출완료. 누적3925개
# 637번째 종목 로스웰 추출중...
# 102개 추출완료. 누적4027개
# 638번째 종목 에스티팜 추출중...
# 116개 추출완료. 누적4143개
# 639번째 종목 지씨셀 추출중...
# 116개 추출완료. 누적4259개
# 640번째 종목 알엔투테크놀로지 추출중...
# 115개 추출완료. 누적4374개
# 641번째 종목 줌인터넷 추출중...
# 116개 추출완료. 누적4490개
# 642번째 종목 휴온스 추출중...
# 116개 추출완료. 누적4606개
# 643번째 종목 원익IPS 추출중...
# 116개 추출완료. 누적4722개
# 644번째 종목 레이언스 추출중...
# 116개 추출완료. 누적4838개
# 645번째 종목 동양파일 추출중...
# 116개 추출완료. 누적4954개
# 646번째 종목 팬젠 추출중...
# 116개 추출완료. 누적5070개
# 647번째 종목 AP위성 추출중...
# 116개 추출완료. 누적5186개
# 648번째 종목 에이트원 추출중...
# 116개 추출완료. 누적5302개
# 649번째 종목 큐리언트 추출중...
# 116개 추출완료. 누적5418개
# 650번째 종목 안트로젠 추출중...
# 116개 추출완료. 누적5534개
# 173/173 [==============================] - 4s 20ms/step
# 173/173 [==============================] - 3s 15ms/step
# 3
# 엘앤케이바이오 2023-02-28
# 골든센츄리 2023-03-06
# 지씨셀 2023-06-19
# 651번째 종목 슈프리마 추출중...
# 116개 추출완료. 누적116개
# 652번째 종목 유니트론텍 추출중...
# 116개 추출완료. 누적232개
# 653번째 종목 크리스탈신소재 추출중...
# 116개 추출완료. 누적348개
# 654번째 종목 더코디 추출중...
# 96개 추출완료. 누적444개
# 655번째 종목 에스와이 추출중...
# 116개 추출완료. 누적560개
# 656번째 종목 와이아이케이 추출중...
# 116개 추출완료. 누적676개
# 657번째 종목 육일씨엔에쓰 추출중...
# 116개 추출완료. 누적792개
# 658번째 종목 커머스마이너 추출중...
# 0개 추출완료. 누적792개
# 659번째 종목 휴젤 추출중...
# 116개 추출완료. 누적908개
# 660번째 종목 한국맥널티 추출중...
# 116개 추출완료. 누적1024개
# 661번째 종목 덱스터 추출중...
# 116개 추출완료. 누적1140개
# 662번째 종목 아진산업 추출중...
# 116개 추출완료. 누적1256개
# 663번째 종목 HLB제약 추출중...
# 116개 추출완료. 누적1372개
# 664번째 종목 강스템바이오텍 추출중...
# 116개 추출완료. 누적1488개
# 665번째 종목 메가엠디 추출중...
# 116개 추출완료. 누적1604개
# 666번째 종목 보광산업 추출중...
# 116개 추출완료. 누적1720개
# 667번째 종목 파크시스템스 추출중...
# 116개 추출완료. 누적1836개
# 668번째 종목 에치에프알 추출중...
# 116개 추출완료. 누적1952개
# 669번째 종목 예스티 추출중...
# 116개 추출완료. 누적2068개
# 670번째 종목 코스맥스엔비티 추출중...
# 116개 추출완료. 누적2184개
# 671번째 종목 멕아이씨에스 추출중...
# 116개 추출완료. 누적2300개
# 672번째 종목 원익피앤이 추출중...
# 116개 추출완료. 누적2416개
# 673번째 종목 하이즈항공 추출중...
# 116개 추출완료. 누적2532개
# 674번째 종목 DXVX 추출중...
# 4개 추출완료. 누적2536개
# 675번째 종목 케이디켐 추출중...
# 116개 추출완료. 누적2652개
# 676번째 종목 네오오토 추출중...
# 116개 추출완료. 누적2768개
# 677번째 종목 엔투텍 추출중...
# 116개 추출완료. 누적2884개
# 678번째 종목 케어젠 추출중...
# 113개 추출완료. 누적2997개
# 679번째 종목 아이진 추출중...
# 116개 추출완료. 누적3113개
# 680번째 종목 나무가 추출중...
# 116개 추출완료. 누적3229개
# 681번째 종목 이노시스 추출중...
# 0개 추출완료. 누적3229개
# 682번째 종목 본느 추출중...
# 116개 추출완료. 누적3345개
# 683번째 종목 연우 추출중...
# 116개 추출완료. 누적3461개
# 684번째 종목 엔케이맥스 추출중...
# 116개 추출완료. 누적3577개
# 685번째 종목 KH 건설 추출중...
# 27개 추출완료. 누적3604개
# 686번째 종목 엑시콘 추출중...
# 116개 추출완료. 누적3720개
# 687번째 종목 뉴지랩파마 추출중...
# 0개 추출완료. 누적3720개
# 688번째 종목 케이엠제약 추출중...
# 116개 추출완료. 누적3836개
# 689번째 종목 한송네오텍 추출중...
# 0개 추출완료. 누적3836개
# 690번째 종목 패션플랫폼 추출중...
# 116개 추출완료. 누적3952개
# 691번째 종목 넥슨게임즈 추출중...
# 116개 추출완료. 누적4068개
# 692번째 종목 제너셈 추출중...
# 116개 추출완료. 누적4184개
# 693번째 종목 타이거일렉 추출중...
# 116개 추출완료. 누적4300개
# 694번째 종목 인포마크 추출중...
# 116개 추출완료. 누적4416개
# 695번째 종목 씨아이에스 추출중...
# 116개 추출완료. 누적4532개
# 696번째 종목 에이텍모빌리티 추출중...
# 116개 추출완료. 누적4648개
# 697번째 종목 웹스 추출중...
# 116개 추출완료. 누적4764개
# 698번째 종목 파인텍 추출중...
# 116개 추출완료. 누적4880개
# 699번째 종목 세토피아 추출중...
# 115개 추출완료. 누적4995개
# 700번째 종목 심텍 추출중...
# 116개 추출완료. 누적5111개
# 160/160 [==============================] - 3s 16ms/step
# 160/160 [==============================] - 3s 16ms/step
# 1
# 보광산업 2023-05-03
# 701번째 종목 흥국에프엔비 추출중...
# 116개 추출완료. 누적116개
# 702번째 종목 쎄노텍 추출중...
# 116개 추출완료. 누적232개
# 703번째 종목 칩스앤미디어 추출중...
# 116개 추출완료. 누적348개
# 704번째 종목 아시아경제 추출중...
# 116개 추출완료. 누적464개
# 705번째 종목 아이쓰리시스템 추출중...
# 116개 추출완료. 누적580개
# 706번째 종목 로지시스 추출중...
# 116개 추출완료. 누적696개
# 707번째 종목 켐트로스 추출중...
# 116개 추출완료. 누적812개
# 708번째 종목 파마리서치 추출중...
# 116개 추출완료. 누적928개
# 709번째 종목 디와이디 추출중...
# 116개 추출완료. 누적1044개
# 710번째 종목 펩트론 추출중...
# 116개 추출완료. 누적1160개
# 711번째 종목 RFHIC 추출중...
# 116개 추출완료. 누적1276개
# 712번째 종목 동운아나텍 추출중...
# 115개 추출완료. 누적1391개
# 713번째 종목 일월지엠엘 추출중...
# 0개 추출완료. 누적1391개
# 714번째 종목 헥토이노베이션 추출중...
# 116개 추출완료. 누적1507개
# 715번째 종목 이큐셀 추출중...
# 0개 추출완료. 누적1507개
# 716번째 종목 코아스템켐온 추출중...
# 116개 추출완료. 누적1623개
# 717번째 종목 에스엘에너지 추출중...
# 0개 추출완료. 누적1623개
# 718번째 종목 베셀 추출중...
# 116개 추출완료. 누적1739개
# 719번째 종목 넵튠 추출중...
# 116개 추출완료. 누적1855개
# 720번째 종목 미래생명자원 추출중...
# 116개 추출완료. 누적1971개
# 721번째 종목 싸이맥스 추출중...
# 116개 추출완료. 누적2087개
# 722번째 종목 러셀 추출중...
# 116개 추출완료. 누적2203개
# 723번째 종목 픽셀플러스 추출중...
# 116개 추출완료. 누적2319개
# 724번째 종목 디딤이앤에프 추출중...
# 116개 추출완료. 누적2435개
# 725번째 종목 제노포커스 추출중...
# 116개 추출완료. 누적2551개
# 726번째 종목 우정바이오 추출중...
# 116개 추출완료. 누적2667개
# 727번째 종목 토박스코리아 추출중...
# 116개 추출완료. 누적2783개
# 728번째 종목 이노인스트루먼트 추출중...
# 116개 추출완료. 누적2899개
# 729번째 종목 우리산업 추출중...
# 116개 추출완료. 누적3015개
# 730번째 종목 메가스터디교육 추출중...
# 116개 추출완료. 누적3131개
# 731번째 종목 휴센텍 추출중...
# 0개 추출완료. 누적3131개
# 732번째 종목 로보로보 추출중...
# 116개 추출완료. 누적3247개
# 733번째 종목 디알텍 추출중...
# 116개 추출완료. 누적3363개
# 734번째 종목 에이비프로바이오 추출중...
# 116개 추출완료. 누적3479개
# 735번째 종목 골프존 추출중...
# 116개 추출완료. 누적3595개
# 736번째 종목 클래시스 추출중...
# 116개 추출완료. 누적3711개
# 737번째 종목 FSN 추출중...
# 116개 추출완료. 누적3827개
# 738번째 종목 포시에스 추출중...
# 116개 추출완료. 누적3943개
# 739번째 종목 덕산네오룩스 추출중...
# 116개 추출완료. 누적4059개
# 740번째 종목 국일신동 추출중...
# 116개 추출완료. 누적4175개
# 741번째 종목 바디텍메드 추출중...
# 116개 추출완료. 누적4291개
# 742번째 종목 스튜디오산타클로스 추출중...
# 116개 추출완료. 누적4407개
# 743번째 종목 썸에이지 추출중...
# 116개 추출완료. 누적4523개
# 744번째 종목 와이제이엠게임즈 추출중...
# 116개 추출완료. 누적4639개
# 745번째 종목 에이팩트 추출중...
# 116개 추출완료. 누적4755개
# 746번째 종목 휴메딕스 추출중...
# 116개 추출완료. 누적4871개
# 747번째 종목 바이오로그디바이스 추출중...
# 116개 추출완료. 누적4987개
# 748번째 종목 서전기전 추출중...
# 116개 추출완료. 누적5103개
# 749번째 종목 아스트 추출중...
# 116개 추출완료. 누적5219개
# 750번째 종목 오킨스전자 추출중...
# 116개 추출완료. 누적5335개
# 167/167 [==============================] - 3s 16ms/step
# 167/167 [==============================] - 3s 16ms/step
# 1
# 제노포커스 2023-06-14
# 751번째 종목 지란지교시큐리티 추출중...
# 116개 추출완료. 누적116개
# 752번째 종목 NEW 추출중...
# 116개 추출완료. 누적232개
# 753번째 종목 아이티센 추출중...
# 116개 추출완료. 누적348개
# 754번째 종목 녹십자엠에스 추출중...
# 116개 추출완료. 누적464개
# 755번째 종목 디티앤씨 추출중...
# 116개 추출완료. 누적580개
# 756번째 종목 셀바스헬스케어 추출중...
# 115개 추출완료. 누적695개
# 757번째 종목 정다운 추출중...
# 116개 추출완료. 누적811개
# 758번째 종목 하이로닉 추출중...
# 116개 추출완료. 누적927개
# 759번째 종목 랩지노믹스 추출중...
# 116개 추출완료. 누적1043개
# 760번째 종목 에이디테크놀로지 추출중...
# 116개 추출완료. 누적1159개
# 761번째 종목 비씨월드제약 추출중...
# 116개 추출완료. 누적1275개
# 762번째 종목 미스터블루 추출중...
# 116개 추출완료. 누적1391개
# 763번째 종목 알테오젠 추출중...
# 116개 추출완료. 누적1507개
# 764번째 종목 베노티앤알 추출중...
# 116개 추출완료. 누적1623개
# 765번째 종목 대창스틸 추출중...
# 116개 추출완료. 누적1739개
# 766번째 종목 에프엔씨엔터 추출중...
# 116개 추출완료. 누적1855개
# 767번째 종목 휴마시스 추출중...
# 116개 추출완료. 누적1971개
# 768번째 종목 텔콘RF제약 추출중...
# 116개 추출완료. 누적2087개
# 769번째 종목 지엘팜텍 추출중...
# 116개 추출완료. 누적2203개
# 770번째 종목 글로벌텍스프리 추출중...
# 116개 추출완료. 누적2319개
# 771번째 종목 디에이테크놀로지 추출중...
# 116개 추출완료. 누적2435개
# 772번째 종목 액션스퀘어 추출중...
# 116개 추출완료. 누적2551개
# 773번째 종목 엑셈 추출중...
# 116개 추출완료. 누적2667개
# 774번째 종목 테고사이언스 추출중...
# 116개 추출완료. 누적2783개
# 775번째 종목 슈피겐코리아 추출중...
# 116개 추출완료. 누적2899개
# 776번째 종목 영우디에스피 추출중...
# 116개 추출완료. 누적3015개
# 777번째 종목 드림시큐리티 추출중...
# 116개 추출완료. 누적3131개
# 778번째 종목 메디아나 추출중...
# 116개 추출완료. 누적3247개
# 779번째 종목 데브시스터즈 추출중...
# 116개 추출완료. 누적3363개
# 780번째 종목 스피어파워 추출중...
# 98개 추출완료. 누적3461개
# 781번째 종목 휴림네트웍스 추출중...
# 116개 추출완료. 누적3577개
# 782번째 종목 고려시멘트 추출중...
# 116개 추출완료. 누적3693개
# 783번째 종목 신화콘텍 추출중...
# 116개 추출완료. 누적3809개
# 784번째 종목 파버나인 추출중...
# 116개 추출완료. 누적3925개
# 785번째 종목 덕신하우징 추출중...
# 116개 추출완료. 누적4041개
# 786번째 종목 창해에탄올 추출중...
# 116개 추출완료. 누적4157개
# 787번째 종목 윈하이텍 추출중...
# 116개 추출완료. 누적4273개
# 788번째 종목 아진엑스텍 추출중...
# 116개 추출완료. 누적4389개
# 789번째 종목 콜마비앤에이치 추출중...
# 116개 추출완료. 누적4505개
# 790번째 종목 트루윈 추출중...
# 116개 추출완료. 누적4621개
# 791번째 종목 코아시아씨엠 추출중...
# 116개 추출완료. 누적4737개
# 792번째 종목 캐스텍코리아 추출중...
# 116개 추출완료. 누적4853개
# 793번째 종목 나노 추출중...
# 116개 추출완료. 누적4969개
# 794번째 종목 케이사인 추출중...
# 116개 추출완료. 누적5085개
# 795번째 종목 오이솔루션 추출중...
# 116개 추출완료. 누적5201개
# 796번째 종목 한국정보인증 추출중...
# 116개 추출완료. 누적5317개
# 797번째 종목 다산솔루에타 추출중...
# 116개 추출완료. 누적5433개
# 798번째 종목 현대이지웰 추출중...
# 116개 추출완료. 누적5549개
# 799번째 종목 SGA솔루션즈 추출중...
# 116개 추출완료. 누적5665개
# 800번째 종목 기가레인 추출중...
# 116개 추출완료. 누적5781개
# 181/181 [==============================] - 3s 17ms/step
# 181/181 [==============================] - 4s 19ms/step
# 3
# 테고사이언스 2023-05-15
# 고려시멘트 2023-06-20
# 다산솔루에타 2023-07-24
# 801번째 종목 인트로메딕 추출중...
# 0개 추출완료. 누적0개
# 802번째 종목 알티캐스트 추출중...
# 116개 추출완료. 누적116개
# 803번째 종목 현대공업 추출중...
# 116개 추출완료. 누적232개
# 804번째 종목 엔브이에이치코리아 추출중...
# 116개 추출완료. 누적348개
# 805번째 종목 탑코미디어 추출중...
# 116개 추출완료. 누적464개
# 806번째 종목 큐브엔터 추출중...
# 116개 추출완료. 누적580개
# 807번째 종목 라이온켐텍 추출중...
# 116개 추출완료. 누적696개
# 808번째 종목 램테크놀러지 추출중...
# 116개 추출완료. 누적812개
# 809번째 종목 THE MIDONG 추출중...
# 116개 추출완료. 누적928개
# 810번째 종목 협진 추출중...
# 45개 추출완료. 누적973개
# 811번째 종목 해성옵틱스 추출중...
# 116개 추출완료. 누적1089개
# 812번째 종목 내츄럴엔도텍 추출중...
# 116개 추출완료. 누적1205개
# 813번째 종목 두산테스나 추출중...
# 116개 추출완료. 누적1321개
# 814번째 종목 파수 추출중...
# 116개 추출완료. 누적1437개
# 815번째 종목 엘티씨 추출중...
# 116개 추출완료. 누적1553개
# 816번째 종목 지엔씨에너지 추출중...
# 116개 추출완료. 누적1669개
# 817번째 종목 아미코젠 추출중...
# 116개 추출완료. 누적1785개
# 818번째 종목 GH신소재 추출중...
# 116개 추출완료. 누적1901개
# 819번째 종목 파이오링크 추출중...
# 116개 추출완료. 누적2017개
# 820번째 종목 KG ETS 추출중...
# 116개 추출완료. 누적2133개
# 821번째 종목 나스미디어 추출중...
# 116개 추출완료. 누적2249개
# 822번째 종목 엑세스바이오 추출중...
# 116개 추출완료. 누적2365개
# 823번째 종목 레고켐바이오 추출중...
# 116개 추출완료. 누적2481개
# 824번째 종목 윈팩 추출중...
# 116개 추출완료. 누적2597개
# 825번째 종목 코렌텍 추출중...
# 116개 추출완료. 누적2713개
# 826번째 종목 제로투세븐 추출중...
# 116개 추출완료. 누적2829개
# 827번째 종목 한솔아이원스 추출중...
# 116개 추출완료. 누적2945개
# 828번째 종목 우리이앤엘 추출중...
# 116개 추출완료. 누적3061개
# 829번째 종목 아이센스 추출중...
# 116개 추출완료. 누적3177개
# 830번째 종목 디에스앤엘 추출중...
# 0개 추출완료. 누적3177개
# 831번째 종목 스킨앤스킨 추출중...
# 116개 추출완료. 누적3293개
# 832번째 종목 SBI핀테크솔루션즈 추출중...
# 116개 추출완료. 누적3409개
# 833번째 종목 우리로 추출중...
# 116개 추출완료. 누적3525개
# 834번째 종목 디젠스 추출중...
# 116개 추출완료. 누적3641개
# 835번째 종목 와이엠씨 추출중...
# 116개 추출완료. 누적3757개
# 836번째 종목 아바텍 추출중...
# 116개 추출완료. 누적3873개
# 837번째 종목 코이즈 추출중...
# 116개 추출완료. 누적3989개
# 838번째 종목 SBW생명과학 추출중...
# 116개 추출완료. 누적4105개
# 839번째 종목 네이블커뮤니케이션즈 추출중...
# 116개 추출완료. 누적4221개
# 840번째 종목 노블엠앤비 추출중...
# 29개 추출완료. 누적4250개
# 841번째 종목 피엔티 추출중...
# 116개 추출완료. 누적4366개
# 842번째 종목 비아트론 추출중...
# 116개 추출완료. 누적4482개
# 843번째 종목 빛샘전자 추출중...
# 116개 추출완료. 누적4598개
# 844번째 종목 사람인 추출중...
# 116개 추출완료. 누적4714개
# 845번째 종목 제룡산업 추출중...
# 116개 추출완료. 누적4830개
# 846번째 종목 남화토건 추출중...
# 116개 추출완료. 누적4946개
# 847번째 종목 메지온 추출중...
# 116개 추출완료. 누적5062개
# 848번째 종목 원익머트리얼즈 추출중...
# 116개 추출완료. 누적5178개
# 849번째 종목 디엔에이링크 추출중...
# 116개 추출완료. 누적5294개
# 850번째 종목 나이스디앤비 추출중...
# 116개 추출완료. 누적5410개
# 170/170 [==============================] - 3s 17ms/step
# 170/170 [==============================] - 3s 17ms/step
# 4
# 엔브이에이치코리아 2023-06-26
# 내츄럴엔도텍 2023-06-28
# 우리이앤엘 2023-06-23
# SBW생명과학 2023-06-26
# 851번째 종목 시큐브 추출중...
# 116개 추출완료. 누적116개
# 852번째 종목 서암기계공업 추출중...
# 116개 추출완료. 누적232개
# 853번째 종목 씨유메디칼 추출중...
# 116개 추출완료. 누적348개
# 854번째 종목 키네마스터 추출중...
# 116개 추출완료. 누적464개
# 855번째 종목 비덴트 추출중...
# 24개 추출완료. 누적488개
# 856번째 종목 신진에스엠 추출중...
# 116개 추출완료. 누적604개
# 857번째 종목 이엠넷 추출중...
# 116개 추출완료. 누적720개
# 858번째 종목 와이지엔터테인먼트 추출중...
# 116개 추출완료. 누적836개
# 859번째 종목 스마트솔루션즈 추출중...
# 0개 추출완료. 누적836개
# 860번째 종목 에이티세미콘 추출중...
# 39개 추출완료. 누적875개
# 861번째 종목 테크윙 추출중...
# 116개 추출완료. 누적991개
# 862번째 종목 씨큐브 추출중...
# 116개 추출완료. 누적1107개
# 863번째 종목 에스엠코어 추출중...
# 116개 추출완료. 누적1223개
# 864번째 종목 씨엔플러스 추출중...
# 116개 추출완료. 누적1339개
# 865번째 종목 로보스타 추출중...
# 116개 추출완료. 누적1455개
# 866번째 종목 대한과학 추출중...
# 116개 추출완료. 누적1571개
# 867번째 종목 아이디스 추출중...
# 116개 추출완료. 누적1687개
# 868번째 종목 제이씨케미칼 추출중...
# 116개 추출완료. 누적1803개
# 869번째 종목 아이씨디 추출중...
# 116개 추출완료. 누적1919개
# 870번째 종목 제닉 추출중...
# 116개 추출완료. 누적2035개
# 871번째 종목 시티랩스 추출중...
# 101개 추출완료. 누적2136개
# 872번째 종목 상아프론테크 추출중...
# 116개 추출완료. 누적2252개
# 873번째 종목 나이벡 추출중...
# 116개 추출완료. 누적2368개
# 874번째 종목 옵티시스 추출중...
# 116개 추출완료. 누적2484개
# 875번째 종목 대양전기공업 추출중...
# 116개 추출완료. 누적2600개
# 876번째 종목 서연탑메탈 추출중...
# 116개 추출완료. 누적2716개
# 877번째 종목 넥스트아이 추출중...
# 116개 추출완료. 누적2832개
# 878번째 종목 초록뱀이앤엠 추출중...
# 116개 추출완료. 누적2948개
# 879번째 종목 엘아이에스 추출중...
# 0개 추출완료. 누적2948개
# 880번째 종목 KX 추출중...
# 116개 추출완료. 누적3064개
# 881번째 종목 골프존뉴딘홀딩스 추출중...
# 116개 추출완료. 누적3180개
# 882번째 종목 윈스 추출중...
# 116개 추출완료. 누적3296개
# 883번째 종목 하림 추출중...
# 116개 추출완료. 누적3412개
# 884번째 종목 이퓨쳐 추출중...
# 116개 추출완료. 누적3528개
# 885번째 종목 티케이케미칼 추출중...
# 116개 추출완료. 누적3644개
# 886번째 종목 부스타 추출중...
# 116개 추출완료. 누적3760개
# 887번째 종목 나노신소재 추출중...
# 116개 추출완료. 누적3876개
# 888번째 종목 케이아이엔엑스 추출중...
# 116개 추출완료. 누적3992개
# 889번째 종목 티피씨글로벌 추출중...
# 116개 추출완료. 누적4108개
# 890번째 종목 LB세미콘 추출중...
# 116개 추출완료. 누적4224개
# 891번째 종목 딜리 추출중...
# 116개 추출완료. 누적4340개
# 892번째 종목 제이엔케이히터 추출중...
# 116개 추출완료. 누적4456개
# 893번째 종목 블루콤 추출중...
# 116개 추출완료. 누적4572개
# 894번째 종목 인트론바이오 추출중...
# 116개 추출완료. 누적4688개
# 895번째 종목 커넥트웨이브 추출중...
# 116개 추출완료. 누적4804개
# 896번째 종목 알서포트 추출중...
# 116개 추출완료. 누적4920개
# 897번째 종목 인텍플러스 추출중...
# 116개 추출완료. 누적5036개
# 898번째 종목 티에스이 추출중...
# 116개 추출완료. 누적5152개
# 899번째 종목 이브이첨단소재 추출중...
# 98개 추출완료. 누적5250개
# 900번째 종목 대정화금 추출중...
# 116개 추출완료. 누적5366개
# 168/168 [==============================] - 3s 19ms/step
# 168/168 [==============================] - 3s 16ms/step
# 2
# 나노신소재 2023-07-03
# 딜리 2023-05-15
# 901번째 종목 피제이메탈 추출중...
# 116개 추출완료. 누적116개
# 902번째 종목 옵투스제약 추출중...
# 116개 추출완료. 누적232개
# 903번째 종목 에이루트 추출중...
# 116개 추출완료. 누적348개
# 904번째 종목 티비씨 추출중...
# 116개 추출완료. 누적464개
# 905번째 종목 시그네틱스 추출중...
# 116개 추출완료. 누적580개
# 906번째 종목 한국전자인증 추출중...
# 116개 추출완료. 누적696개
# 907번째 종목 BGF에코머티리얼즈 추출중...
# 116개 추출완료. 누적812개
# 908번째 종목 디케이락 추출중...
# 116개 추출완료. 누적928개
# 909번째 종목 위메이드플레이 추출중...
# 116개 추출완료. 누적1044개
# 910번째 종목 KH 전자 추출중...
# 27개 추출완료. 누적1071개
# 911번째 종목 아나패스 추출중...
# 116개 추출완료. 누적1187개
# 912번째 종목 KNN 추출중...
# 116개 추출완료. 누적1303개
# 913번째 종목 누리플랜 추출중...
# 116개 추출완료. 누적1419개
# 914번째 종목 아이텍 추출중...
# 116개 추출완료. 누적1535개
# 915번째 종목 인화정공 추출중...
# 116개 추출완료. 누적1651개
# 916번째 종목 셀피글로벌 추출중...
# 16개 추출완료. 누적1667개
# 917번째 종목 한일진공 추출중...
# 116개 추출완료. 누적1783개
# 918번째 종목 알파홀딩스 추출중...
# 29개 추출완료. 누적1812개
# 919번째 종목 포메탈 추출중...
# 116개 추출완료. 누적1928개
# 920번째 종목 다원시스 추출중...
# 116개 추출완료. 누적2044개
# 921번째 종목 씨젠 추출중...
# 116개 추출완료. 누적2160개
# 922번째 종목 와이솔 추출중...
# 116개 추출완료. 누적2276개
# 923번째 종목 하이비젼시스템 추출중...
# 116개 추출완료. 누적2392개
# 924번째 종목 화신정공 추출중...
# 116개 추출완료. 누적2508개
# 925번째 종목 코리아에프티 추출중...
# 116개 추출완료. 누적2624개
# 926번째 종목 엠에스오토텍 추출중...
# 116개 추출완료. 누적2740개
# 927번째 종목 이글루 추출중...
# 116개 추출완료. 누적2856개
# 928번째 종목 인터로조 추출중...
# 116개 추출완료. 누적2972개
# 929번째 종목 하이텍팜 추출중...
# 116개 추출완료. 누적3088개
# 930번째 종목 크루셜텍 추출중...
# 0개 추출완료. 누적3088개
# 931번째 종목 에스디시스템 추출중...
# 0개 추출완료. 누적3088개
# 932번째 종목 알톤스포츠 추출중...
# 116개 추출완료. 누적3204개
# 933번째 종목 유비벨록스 추출중...
# 116개 추출완료. 누적3320개
# 934번째 종목 오르비텍 추출중...
# 116개 추출완료. 누적3436개
# 935번째 종목 엑스큐어 추출중...
# 116개 추출완료. 누적3552개
# 936번째 종목 투비소프트 추출중...
# 116개 추출완료. 누적3668개
# 937번째 종목 인피니트헬스케어 추출중...
# 116개 추출완료. 누적3784개
# 938번째 종목 서진오토모티브 추출중...
# 116개 추출완료. 누적3900개
# 939번째 종목 인지소프트 추출중...
# 116개 추출완료. 누적4016개
# 940번째 종목 이스트아시아홀딩스 추출중...
# 116개 추출완료. 누적4132개
# 941번째 종목 애머릿지 추출중...
# 116개 추출완료. 누적4248개
# 942번째 종목 케이씨에스 추출중...
# 116개 추출완료. 누적4364개
# 943번째 종목 씨케이에이치 추출중...
# 116개 추출완료. 누적4480개
# 944번째 종목 HLB테라퓨틱스 추출중...
# 116개 추출완료. 누적4596개
# 945번째 종목 삼기 추출중...
# 116개 추출완료. 누적4712개
# 946번째 종목 이미지스 추출중...
# 116개 추출완료. 누적4828개
# 947번째 종목 인포바인 추출중...
# 116개 추출완료. 누적4944개
# 948번째 종목 하이소닉 추출중...
# 4개 추출완료. 누적4948개
# 949번째 종목 모베이스 추출중...
# 116개 추출완료. 누적5064개
# 950번째 종목 스타플렉스 추출중...
# 116개 추출완료. 누적5180개
# 162/162 [==============================] - 3s 15ms/step
# 162/162 [==============================] - 3s 17ms/step
# 7
# 피제이메탈 2023-03-20
# 시그네틱스 2023-06-26
# 디케이락 2023-03-22
# 인화정공 2023-08-03
# 오르비텍 2023-05-10
# 서진오토모티브 2023-06-14
# 삼기 2023-04-27
# 951번째 종목 우리넷 추출중...
# 116개 추출완료. 누적116개
# 952번째 종목 아세아텍 추출중...
# 116개 추출완료. 누적232개
# 953번째 종목 폴라리스우노 추출중...
# 116개 추출완료. 누적348개
# 954번째 종목 코디 추출중...
# 116개 추출완료. 누적464개
# 955번째 종목 글로벌에스엠 추출중...
# 116개 추출완료. 누적580개
# 956번째 종목 ITX-AI 추출중...
# 0개 추출완료. 누적580개
# 957번째 종목 그린생명과학 추출중...
# 116개 추출완료. 누적696개
# 958번째 종목 디와이피엔에프 추출중...
# 116개 추출완료. 누적812개
# 959번째 종목 위메이드 추출중...
# 116개 추출완료. 누적928개
# 960번째 종목 셀바스AI 추출중...
# 116개 추출완료. 누적1044개
# 961번째 종목 이원컴포텍 추출중...
# 116개 추출완료. 누적1160개
# 962번째 종목 강원에너지 추출중...
# 116개 추출완료. 누적1276개
# 963번째 종목 휴맥스 추출중...
# 116개 추출완료. 누적1392개
# 964번째 종목 에이프로젠 H&G 추출중...
# 102개 추출완료. 누적1494개
# 965번째 종목 동방선기 추출중...
# 116개 추출완료. 누적1610개
# 966번째 종목 상상인인더스트리 추출중...
# 98개 추출완료. 누적1708개
# 967번째 종목 진매트릭스 추출중...
# 116개 추출완료. 누적1824개
# 968번째 종목 비츠로셀 추출중...
# 116개 추출완료. 누적1940개
# 969번째 종목 한스바이오메드 추출중...
# 116개 추출완료. 누적2056개
# 970번째 종목 NHN벅스 추출중...
# 116개 추출완료. 누적2172개
# 971번째 종목 아이앤씨 추출중...
# 116개 추출완료. 누적2288개
# 972번째 종목 케이엔더블유 추출중...
# 116개 추출완료. 누적2404개
# 973번째 종목 디에스케이 추출중...
# 116개 추출완료. 누적2520개
# 974번째 종목 제넥신 추출중...
# 116개 추출완료. 누적2636개
# 975번째 종목 톱텍 추출중...
# 116개 추출완료. 누적2752개
# 976번째 종목 동국S&C 추출중...
# 116개 추출완료. 누적2868개
# 977번째 종목 에스앤더블류 추출중...
# 4개 추출완료. 누적2872개
# 978번째 종목 컴투스홀딩스 추출중...
# 116개 추출완료. 누적2988개
# 979번째 종목 동일금속 추출중...
# 104개 추출완료. 누적3092개
# 980번째 종목 어보브반도체 추출중...
# 116개 추출완료. 누적3208개
# 981번째 종목 위메이드맥스 추출중...
# 116개 추출완료. 누적3324개
# 982번째 종목 이엔에프테크놀로지 추출중...
# 116개 추출완료. 누적3440개
# 983번째 종목 스맥 추출중...
# 116개 추출완료. 누적3556개
# 984번째 종목 SDN 추출중...
# 116개 추출완료. 누적3672개
# 985번째 종목 한국정밀기계 추출중...
# 4개 추출완료. 누적3676개
# 986번째 종목 흥국 추출중...
# 116개 추출완료. 누적3792개
# 987번째 종목 우림피티에스 추출중...
# 116개 추출완료. 누적3908개
# 988번째 종목 티플랙스 추출중...
# 116개 추출완료. 누적4024개
# 989번째 종목 에스티오 추출중...
# 116개 추출완료. 누적4140개
# 990번째 종목 에이테크솔루션 추출중...
# 116개 추출완료. 누적4256개
# 991번째 종목 에스앤에스텍 추출중...
# 116개 추출완료. 누적4372개
# 992번째 종목 뷰웍스 추출중...
# 116개 추출완료. 누적4488개
# 993번째 종목 코오롱생명과학 추출중...
# 116개 추출완료. 누적4604개
# 994번째 종목 엔시트론 추출중...
# 116개 추출완료. 누적4720개
# 995번째 종목 파인테크닉스 추출중...
# 116개 추출완료. 누적4836개
# 996번째 종목 이수앱지스 추출중...
# 116개 추출완료. 누적4952개
# 997번째 종목 대성파인텍 추출중...
# 116개 추출완료. 누적5068개
# 998번째 종목 유비쿼스홀딩스 추출중...
# 116개 추출완료. 누적5184개
# 999번째 종목 메디톡스 추출중...
# 116개 추출완료. 누적5300개
# 1000번째 종목 엠게임 추출중...
# 116개 추출완료. 누적5416개
# 170/170 [==============================] - 3s 16ms/step
# 170/170 [==============================] - 3s 15ms/step
# 1
# 동방선기 2023-07-12
# 1001번째 종목 아이컴포넌트 추출중...
# 116개 추출완료. 누적116개
# 1002번째 종목 HLB생명과학 추출중...
# 116개 추출완료. 누적232개
# 1003번째 종목 이크레더블 추출중...
# 116개 추출완료. 누적348개
# 1004번째 종목 세운메디칼 추출중...
# 116개 추출완료. 누적464개
# 1005번째 종목 마이크로컨텍솔 추출중...
# 116개 추출완료. 누적580개
# 1006번째 종목 이엠앤아이 추출중...
# 99개 추출완료. 누적679개
# 1007번째 종목 아이엠 추출중...
# 116개 추출완료. 누적795개
# 1008번째 종목 웰크론한텍 추출중...
# 116개 추출완료. 누적911개
# 1009번째 종목 하이드로리튬 추출중...
# 116개 추출완료. 누적1027개
# 1010번째 종목 슈프리마에이치큐 추출중...
# 116개 추출완료. 누적1143개
# 1011번째 종목 서울옥션 추출중...
# 116개 추출완료. 누적1259개
# 1012번째 종목 이스트소프트 추출중...
# 116개 추출완료. 누적1375개
# 1013번째 종목 크레버스 추출중...
# 116개 추출완료. 누적1491개
# 1014번째 종목 월덱스 추출중...
# 116개 추출완료. 누적1607개
# 1015번째 종목 쎄트렉아이 추출중...
# 116개 추출완료. 누적1723개
# 1016번째 종목 브리지텍 추출중...
# 116개 추출완료. 누적1839개
# 1017번째 종목 고영 추출중...
# 116개 추출완료. 누적1955개
# 1018번째 종목 조이시티 추출중...
# 116개 추출완료. 누적2071개
# 1019번째 종목 우진비앤지 추출중...
# 116개 추출완료. 누적2187개
# 1020번째 종목 테스 추출중...
# 116개 추출완료. 누적2303개
# 1021번째 종목 예스24 추출중...
# 116개 추출완료. 누적2419개
# 1022번째 종목 엘디티 추출중...
# 116개 추출완료. 누적2535개
# 1023번째 종목 메타바이오메드 추출중...
# 116개 추출완료. 누적2651개
# 1024번째 종목 효성오앤비 추출중...
# 116개 추출완료. 누적2767개
# 1025번째 종목 텔레필드 추출중...
# 116개 추출완료. 누적2883개
# 1026번째 종목 이트론 추출중...
# 52개 추출완료. 누적2935개
# 1027번째 종목 에스맥 추출중...
# 116개 추출완료. 누적3051개
# 1028번째 종목 에스코넥 추출중...
# 116개 추출완료. 누적3167개
# 1029번째 종목 일신바이오 추출중...
# 116개 추출완료. 누적3283개
# 1030번째 종목 서원인텍 추출중...
# ...
# 1251번째 종목 KG이니시스 추출중...
# 116개 추출완료. 누적116개
# 1252번째 종목 비엘팜텍 추출중...
# 116개 추출완료. 누적232개
# 1253번째 종목 파라다이스 추출중...
# 116개 추출완료. 누적348개
# 1254번째 종목 플래스크 추출중...
# 116개 추출완료. 누적464개
# 1255번째 종목 새로닉스 추출중...
# 116개 추출완료. 누적580개
# 1256번째 종목 오리엔트정공 추출중...
# 116개 추출완료. 누적696개
# 1257번째 종목 DGP 추출중...
# 103개 추출완료. 누적799개
# 1258번째 종목 국보디자인 추출중...
# 116개 추출완료. 누적915개
# 1259번째 종목 아이톡시 추출중...
# 0개 추출완료. 누적915개
# 1260번째 종목 에스아이리소스 추출중...
# 116개 추출완료. 누적1031개
# 1261번째 종목 젬백스링크 추출중...
# 116개 추출완료. 누적1147개
# 1262번째 종목 리노스 추출중...
# 116개 추출완료. 누적1263개
# 1263번째 종목 현대바이오 추출중...
# 116개 추출완료. 누적1379개
# 1264번째 종목 에스피지 추출중...
# 116개 추출완료. 누적1495개
# 1265번째 종목 토탈소프트 추출중...
# 116개 추출완료. 누적1611개
# 1266번째 종목 서호전기 추출중...
# 116개 추출완료. 누적1727개
# 1267번째 종목 파커스 추출중...
# 116개 추출완료. 누적1843개
# 1268번째 종목 서울리거 추출중...
# 116개 추출완료. 누적1959개
# 1269번째 종목 홈센타홀딩스 추출중...
# 116개 추출완료. 누적2075개
# 1270번째 종목 아비코전자 추출중...
# 116개 추출완료. 누적2191개
# 1271번째 종목 큐렉소 추출중...
# 116개 추출완료. 누적2307개
# 1272번째 종목 소니드 추출중...
# 116개 추출완료. 누적2423개
# 1273번째 종목 우원개발 추출중...
# 116개 추출완료. 누적2539개
# 1274번째 종목 티사이언티픽 추출중...
# 116개 추출완료. 누적2655개
# 1275번째 종목 인선이엔티 추출중...
# 116개 추출완료. 누적2771개
# 1276번째 종목 와이어블 추출중...
# 116개 추출완료. 누적2887개
# 1277번째 종목 SM Life Design 추출중...
# 116개 추출완료. 누적3003개
# 1278번째 종목 지어소프트 추출중...
# 116개 추출완료. 누적3119개
# 1279번째 종목 지엔코 추출중...
# 116개 추출완료. 누적3235개
# 1280번째 종목 셀루메드 추출중...
# 116개 추출완료. 누적3351개
# 1281번째 종목 KH바텍 추출중...
# 116개 추출완료. 누적3467개
# 1282번째 종목 알에프텍 추출중...
# 116개 추출완료. 누적3583개
# 1283번째 종목 에스폴리텍 추출중...
# 116개 추출완료. 누적3699개
# 1284번째 종목 이랜텍 추출중...
# 116개 추출완료. 누적3815개
# 1285번째 종목 ES큐브 추출중...
# 116개 추출완료. 누적3931개
# 1286번째 종목 케이피티유 추출중...
# 116개 추출완료. 누적4047개
# 1287번째 종목 3S 추출중...
# 116개 추출완료. 누적4163개
# 1288번째 종목 화일약품 추출중...
# 116개 추출완료. 누적4279개
# 1289번째 종목 오상자이엘 추출중...
# 116개 추출완료. 누적4395개
# 1290번째 종목 농우바이오 추출중...
# 116개 추출완료. 누적4511개
# 1291번째 종목 케이엘넷 추출중...
# 116개 추출완료. 누적4627개
# 1292번째 종목 에스티아이 추출중...
# 116개 추출완료. 누적4743개
# 1293번째 종목 잉크테크 추출중...
# 116개 추출완료. 누적4859개
# 1294번째 종목 대한뉴팜 추출중...
# 116개 추출완료. 누적4975개
# 1295번째 종목 씨티씨바이오 추출중...
# 116개 추출완료. 누적5091개
# 1296번째 종목 인탑스 추출중...
# 116개 추출완료. 누적5207개
# 1297번째 종목 KT서브마린 추출중...
# 116개 추출완료. 누적5323개
# 1298번째 종목 피씨디렉트 추출중...
# 116개 추출완료. 누적5439개
# 1299번째 종목 구영테크 추출중...
# 116개 추출완료. 누적5555개
# 1300번째 종목 한국기업평가 추출중...
# 116개 추출완료. 누적5671개
# 178/178 [==============================] - 3s 16ms/step
# 178/178 [==============================] - 3s 16ms/step
# 4
# 에스아이리소스 2023-07-20
# 셀루메드 2023-06-13
# ES큐브 2023-07-18
# 농우바이오 2023-02-28
# 1301번째 종목 뉴보텍 추출중...
# 116개 추출완료. 누적116개
# 1302번째 종목 동양에스텍 추출중...
# 116개 추출완료. 누적232개
# 1303번째 종목 백금T&A 추출중...
# 116개 추출완료. 누적348개
# 1304번째 종목 파나케이아 추출중...
# 0개 추출완료. 누적348개
# 1305번째 종목 고려신용정보 추출중...
# 116개 추출완료. 누적464개
# 1306번째 종목 제일바이오 추출중...
# 99개 추출완료. 누적563개
# 1307번째 종목 서울반도체 추출중...
# 116개 추출완료. 누적679개
# 1308번째 종목 아가방컴퍼니 추출중...
# 116개 추출완료. 누적795개
# 1309번째 종목 엔터파트너즈 추출중...
# 116개 추출완료. 누적911개
# 1310번째 종목 미코 추출중...
# 116개 추출완료. 누적1027개
# 1311번째 종목 유신 추출중...
# 116개 추출완료. 누적1143개
# 1312번째 종목 프럼파스트 추출중...
# 116개 추출완료. 누적1259개
# 1313번째 종목 한국컴퓨터 추출중...
# 116개 추출완료. 누적1375개
# 1314번째 종목 대동스틸 추출중...
# 116개 추출완료. 누적1491개
# 1315번째 종목 링네트 추출중...
# 116개 추출완료. 누적1607개
# 1316번째 종목 큐로컴 추출중...
# 116개 추출완료. 누적1723개
# 1317번째 종목 팬스타엔터프라이즈 추출중...
# 116개 추출완료. 누적1839개
# 1318번째 종목 한빛소프트 추출중...
# 116개 추출완료. 누적1955개
# 1319번째 종목 NHN KCP 추출중...
# 116개 추출완료. 누적2071개
# 1320번째 종목 CNT85 추출중...
# 2개 추출완료. 누적2073개
# 1321번째 종목 금강철강 추출중...
# 116개 추출완료. 누적2189개
# 1322번째 종목 룽투코리아 추출중...
# 116개 추출완료. 누적2305개
# 1323번째 종목 동아화성 추출중...
# 116개 추출완료. 누적2421개
# 1324번째 종목 비츠로시스 추출중...
# 116개 추출완료. 누적2537개
# 1325번째 종목 오리엔탈정공 추출중...
# 116개 추출완료. 누적2653개
# 1326번째 종목 웰킵스하이텍 추출중...
# 116개 추출완료. 누적2769개
# 1327번째 종목 리노공업 추출중...
# 116개 추출완료. 누적2885개
# 1328번째 종목 성우테크론 추출중...
# 116개 추출완료. 누적3001개
# 1329번째 종목 에스에프에이 추출중...
# 116개 추출완료. 누적3117개
# 1330번째 종목 신화인터텍 추출중...
# 116개 추출완료. 누적3233개
# 1331번째 종목 엑사이엔씨 추출중...
# 116개 추출완료. 누적3349개
# 1332번째 종목 피에이치에이 추출중...
# 116개 추출완료. 누적3465개
# 1333번째 종목 APS 추출중...
# 116개 추출완료. 누적3581개
# 1334번째 종목 코위버 추출중...
# 116개 추출완료. 누적3697개
# 1335번째 종목 성호전자 추출중...
# 116개 추출완료. 누적3813개
# 1336번째 종목 MIT 추출중...
# 0개 추출완료. 누적3813개
# 1337번째 종목 YW 추출중...
# 116개 추출완료. 누적3929개
# 1338번째 종목 삼영엠텍 추출중...
# 116개 추출완료. 누적4045개
# 1339번째 종목 이니텍 추출중...
# 116개 추출완료. 누적4161개
# 1340번째 종목 에이디칩스 추출중...
# 116개 추출완료. 누적4277개
# 1341번째 종목 유진로봇 추출중...
# 116개 추출완료. 누적4393개
# 1342번째 종목 태웅 추출중...
# 116개 추출완료. 누적4509개
# 1343번째 종목 경남제약 추출중...
# 116개 추출완료. 누적4625개
# 1344번째 종목 삼보모터스 추출중...
# 116개 추출완료. 누적4741개
# 1345번째 종목 한컴위드 추출중...
# 116개 추출완료. 누적4857개
# 1346번째 종목 코미팜 추출중...
# 116개 추출완료. 누적4973개
# 1347번째 종목 프리엠스 추출중...
# 116개 추출완료. 누적5089개
# 1348번째 종목 코나아이 추출중...
# 116개 추출완료. 누적5205개
# 1349번째 종목 메디콕스 추출중...
# 116개 추출완료. 누적5321개
# 1350번째 종목 SGA 추출중...
# 116개 추출완료. 누적5437개
# 170/170 [==============================] - 3s 16ms/step
# 170/170 [==============================] - 3s 16ms/step
# 4
# 동양에스텍 2023-04-21
# 오리엔탈정공 2023-03-09
# 성우테크론 2023-06-22
# APS 2023-05-03
# 1351번째 종목 엑서지21 추출중...
# 116개 추출완료. 누적116개
# 1352번째 종목 지에스이 추출중...
# 116개 추출완료. 누적232개
# 1353번째 종목 아이디스홀딩스 추출중...
# 116개 추출완료. 누적348개
# 1354번째 종목 코데즈컴바인 추출중...
# 116개 추출완료. 누적464개
# 1355번째 종목 안랩 추출중...
# 116개 추출완료. 누적580개
# 1356번째 종목 YTN 추출중...
# 116개 추출완료. 누적696개
# 1357번째 종목 CMG제약 추출중...
# 116개 추출완료. 누적812개
# 1358번째 종목 JYP Ent. 추출중...
# 116개 추출완료. 누적928개
# 1359번째 종목 한국테크놀로지 추출중...
# 0개 추출완료. 누적928개
# 1360번째 종목 KCC건설 추출중...
# 116개 추출완료. 누적1044개
# 1361번째 종목 세동 추출중...
# 116개 추출완료. 누적1160개
# 1362번째 종목 프로텍 추출중...
# 116개 추출완료. 누적1276개
# 1363번째 종목 액토즈소프트 추출중...
# 116개 추출완료. 누적1392개
# 1364번째 종목 세코닉스 추출중...
# 116개 추출완료. 누적1508개
# 1365번째 종목 바이넥스 추출중...
# 116개 추출완료. 누적1624개
# 1366번째 종목 오성첨단소재 추출중...
# 116개 추출완료. 누적1740개
# 1367번째 종목 태양 추출중...
# 116개 추출완료. 누적1856개
# 1368번째 종목 유아이엘 추출중...
# 116개 추출완료. 누적1972개
# 1369번째 종목 초록뱀컴퍼니 추출중...
# 116개 추출완료. 누적2088개
# 1370번째 종목 대원미디어 추출중...
# 116개 추출완료. 누적2204개
# 1371번째 종목 중앙디앤엠 추출중...
# 116개 추출완료. 누적2320개
# 1372번째 종목 CJ프레시웨이 추출중...
# 116개 추출완료. 누적2436개
# 1373번째 종목 파인디앤씨 추출중...
# 116개 추출완료. 누적2552개
# 1374번째 종목 디지아이 추출중...
# 116개 추출완료. 누적2668개
# 1375번째 종목 코텍 추출중...
# 116개 추출완료. 누적2784개
# 1376번째 종목 한네트 추출중...
# 116개 추출완료. 누적2900개
# 1377번째 종목 에스티큐브 추출중...
# 116개 추출완료. 누적3016개
# 1378번째 종목 티에스넥스젠 추출중...
# 116개 추출완료. 누적3132개
# 1379번째 종목 스카이문스테크놀로지 추출중...
# 2개 추출완료. 누적3134개
# 1380번째 종목 큐로홀딩스 추출중...
# 116개 추출완료. 누적3250개
# 1381번째 종목 나라엠앤디 추출중...
# 116개 추출완료. 누적3366개
# 1382번째 종목 에코바이오 추출중...
# 116개 추출완료. 누적3482개
# 1383번째 종목 에이텍 추출중...
# 116개 추출완료. 누적3598개
# 1384번째 종목 대아티아이 추출중...
# 116개 추출완료. 누적3714개
# 1385번째 종목 캠시스 추출중...
# 116개 추출완료. 누적3830개
# 1386번째 종목 현대바이오랜드 추출중...
# 116개 추출완료. 누적3946개
# 1387번째 종목 SFA반도체 추출중...
# 116개 추출완료. 누적4062개
# 1388번째 종목 삼표시멘트 추출중...
# 116개 추출완료. 누적4178개
# 1389번째 종목 HLB이노베이션 추출중...
# 116개 추출완료. 누적4294개
# 1390번째 종목 SM C&C 추출중...
# 116개 추출완료. 누적4410개
# 1391번째 종목 승일 추출중...
# 116개 추출완료. 누적4526개
# 1392번째 종목 조광ILI 추출중...
# 42개 추출완료. 누적4568개
# 1393번째 종목 TPC 추출중...
# 116개 추출완료. 누적4684개
# 1394번째 종목 코메론 추출중...
# 116개 추출완료. 누적4800개
# 1395번째 종목 블레이드 Ent 추출중...
# 116개 추출완료. 누적4916개
# 1396번째 종목 삼화네트웍스 추출중...
# 116개 추출완료. 누적5032개
# 1397번째 종목 성광벤드 추출중...
# 116개 추출완료. 누적5148개
# 1398번째 종목 유라테크 추출중...
# 116개 추출완료. 누적5264개
# 1399번째 종목 삼현철강 추출중...
# 116개 추출완료. 누적5380개
# 1400번째 종목 오픈베이스 추출중...
# 116개 추출완료. 누적5496개
# 172/172 [==============================] - 3s 16ms/step
# 172/172 [==============================] - 3s 15ms/step
# 0
# 1401번째 종목 KCI 추출중...
# 116개 추출완료. 누적116개
# 1402번째 종목 라온시큐어 추출중...
# 116개 추출완료. 누적232개
# 1403번째 종목 오로라 추출중...
# 116개 추출완료. 누적348개
# 1404번째 종목 금화피에스시 추출중...
# 116개 추출완료. 누적464개
# 1405번째 종목 코다코 추출중...
# 116개 추출완료. 누적580개
# 1406번째 종목 인바디 추출중...
# 116개 추출완료. 누적696개
# 1407번째 종목 고려제약 추출중...
# 116개 추출완료. 누적812개
# 1408번째 종목 크린앤사이언스 추출중...
# 116개 추출완료. 누적928개
# 1409번째 종목 포스코DX 추출중...
# 116개 추출완료. 누적1044개
# 1410번째 종목 KD 추출중...
# 116개 추출완료. 누적1160개
# 1411번째 종목 이글벳 추출중...
# 116개 추출완료. 누적1276개
# 1412번째 종목 아즈텍WB 추출중...
# 116개 추출완료. 누적1392개
# 1413번째 종목 오리콤 추출중...
# 116개 추출완료. 누적1508개
# 1414번째 종목 위닉스 추출중...
# 116개 추출완료. 누적1624개
# 1415번째 종목 상지카일룸 추출중...
# 116개 추출완료. 누적1740개
# 1416번째 종목 엔피케이 추출중...
# 116개 추출완료. 누적1856개
# 1417번째 종목 삼천당제약 추출중...
# 116개 추출완료. 누적1972개
# 1418번째 종목 에이치케이 추출중...
# 116개 추출완료. 누적2088개
# 1419번째 종목 정원엔시스 추출중...
# 116개 추출완료. 누적2204개
# 1420번째 종목 한양이엔지 추출중...
# 116개 추출완료. 누적2320개
# 1421번째 종목 누리플렉스 추출중...
# 116개 추출완료. 누적2436개
# 1422번째 종목 에쎈테크 추출중...
# 116개 추출완료. 누적2552개
# 1423번째 종목 국순당 추출중...
# 116개 추출완료. 누적2668개
# 1424번째 종목 엘컴텍 추출중...
# 116개 추출완료. 누적2784개
# 1425번째 종목 이오테크닉스 추출중...
# 116개 추출완료. 누적2900개
# 1426번째 종목 상상인 추출중...
# 116개 추출완료. 누적3016개
# 1427번째 종목 서울제약 추출중...
# 93개 추출완료. 누적3109개
# 1428번째 종목 나노엔텍 추출중...
# 116개 추출완료. 누적3225개
# 1429번째 종목 파나진 추출중...
# 116개 추출완료. 누적3341개
# 1430번째 종목 오공 추출중...
# 116개 추출완료. 누적3457개
# 1431번째 종목 솔고바이오 추출중...
# 116개 추출완료. 누적3573개
# 1432번째 종목 비츠로테크 추출중...
# 116개 추출완료. 누적3689개
# 1433번째 종목 코아시아 추출중...
# 116개 추출완료. 누적3805개
# 1434번째 종목 정상제이엘에스 추출중...
# 116개 추출완료. 누적3921개
# 1435번째 종목 진양제약 추출중...
# 116개 추출완료. 누적4037개
# 1436번째 종목 지니뮤직 추출중...
# 116개 추출완료. 누적4153개
# 1437번째 종목 진성티이씨 추출중...
# 116개 추출완료. 누적4269개
# 1438번째 종목 현대에이치티 추출중...
# 116개 추출완료. 누적4385개
# 1439번째 종목 삼아제약 추출중...
# 116개 추출완료. 누적4501개
# 1440번째 종목 파루 추출중...
# 116개 추출완료. 누적4617개
# 1441번째 종목 에스씨디 추출중...
# 116개 추출완료. 누적4733개
# 1442번째 종목 한국정보공학 추출중...
# 116개 추출완료. 누적4849개
# 1443번째 종목 디오 추출중...
# 116개 추출완료. 누적4965개
# 1444번째 종목 네오위즈홀딩스 추출중...
# 116개 추출완료. 누적5081개
# 1445번째 종목 다산네트웍스 추출중...
# 116개 추출완료. 누적5197개
# 1446번째 종목 바이오스마트 추출중...
# 116개 추출완료. 누적5313개
# 1447번째 종목 우리기술 추출중...
# 116개 추출완료. 누적5429개
# 1448번째 종목 안국약품 추출중...
# 116개 추출완료. 누적5545개
# 1449번째 종목 세중 추출중...
# 116개 추출완료. 누적5661개
# 1450번째 종목 우리기술투자 추출중...
# 116개 추출완료. 누적5777개
# 181/181 [==============================] - 3s 16ms/step
# 181/181 [==============================] - 3s 16ms/step
# 3
# 정원엔시스 2023-04-21
# 나노엔텍 2023-02-27
# 다산네트웍스 2023-03-16
# 1451번째 종목 케이바이오 추출중...
# 41개 추출완료. 누적41개
# 1452번째 종목 HRS 추출중...
# 116개 추출완료. 누적157개
# 1453번째 종목 에스에이엠티 추출중...
# 116개 추출완료. 누적273개
# 1454번째 종목 위즈코프 추출중...
# 116개 추출완료. 누적389개
# 1455번째 종목 이건홀딩스 추출중...
# 116개 추출완료. 누적505개
# 1456번째 종목 파인디지털 추출중...
# 116개 추출완료. 누적621개
# 1457번째 종목 나이스정보통신 추출중...
# 116개 추출완료. 누적737개
# 1458번째 종목 SG&G 추출중...
# 116개 추출완료. 누적853개
# 1459번째 종목 아이에이 추출중...
# 116개 추출완료. 누적969개
# 1460번째 종목 에스넷 추출중...
# 116개 추출완료. 누적1085개
# 1461번째 종목 에스엠 추출중...
# 116개 추출완료. 누적1201개
# 1462번째 종목 쌍용정보통신 추출중...
# 116개 추출완료. 누적1317개
# 1463번째 종목 쎄니트 추출중...
# 116개 추출완료. 누적1433개
# 1464번째 종목 대성미생물 추출중...
# 116개 추출완료. 누적1549개
# 1465번째 종목 에코플라스틱 추출중...
# 116개 추출완료. 누적1665개
# 1466번째 종목 케이엠더블유 추출중...
# 116개 추출완료. 누적1781개
# 1467번째 종목 화성밸브 추출중...
# 116개 추출완료. 누적1897개
# 1468번째 종목 경남스틸 추출중...
# 116개 추출완료. 누적2013개
# 1469번째 종목 마크로젠 추출중...
# 116개 추출완료. 누적2129개
# 1470번째 종목 희림 추출중...
# 116개 추출완료. 누적2245개
# 1471번째 종목 레드캡투어 추출중...
# 116개 추출완료. 누적2361개
# 1472번째 종목 솔브레인홀딩스 추출중...
# 116개 추출완료. 누적2477개
# 1473번째 종목 에프에스티 추출중...
# 116개 추출완료. 누적2593개
# 1474번째 종목 코맥스 추출중...
# 116개 추출완료. 누적2709개
# 1475번째 종목 EG 추출중...
# 116개 추출완료. 누적2825개
# 1476번째 종목 감성코퍼레이션 추출중...
# 116개 추출완료. 누적2941개
# 1477번째 종목 성도이엔지 추출중...
# 116개 추출완료. 누적3057개
# 1478번째 종목 제일테크노스 추출중...
# 116개 추출완료. 누적3173개
# 1479번째 종목 무림SP 추출중...
# 116개 추출완료. 누적3289개
# 1480번째 종목 세종텔레콤 추출중...
# 116개 추출완료. 누적3405개
# 1481번째 종목 심텍홀딩스 추출중...
# 116개 추출완료. 누적3521개
# 1482번째 종목 파세코 추출중...
# 116개 추출완료. 누적3637개
# 1483번째 종목 SGC이테크건설 추출중...
# 116개 추출완료. 누적3753개
# 1484번째 종목 영풍정밀 추출중...
# 116개 추출완료. 누적3869개
# 1485번째 종목 서희건설 추출중...
# 116개 추출완료. 누적3985개
# 1486번째 종목 주성엔지니어링 추출중...
# 116개 추출완료. 누적4101개
# 1487번째 종목 케이티알파 추출중...
# 116개 추출완료. 누적4217개
# 1488번째 종목 다우데이타 추출중...
# 116개 추출완료. 누적4333개
# 1489번째 종목 동진쎄미켐 추출중...
# 116개 추출완료. 누적4449개
# 1490번째 종목 선광 추출중...
# 116개 추출완료. 누적4565개
# 1491번째 종목 제이에스티나 추출중...
# 116개 추출완료. 누적4681개
# 1492번째 종목 지더블유바이텍 추출중...
# 115개 추출완료. 누적4796개
# 1493번째 종목 클라우드에어 추출중...
# 116개 추출완료. 누적4912개
# 1494번째 종목 한국팩키지 추출중...
# 116개 추출완료. 누적5028개
# 1495번째 종목 삼지전자 추출중...
# 116개 추출완료. 누적5144개
# 1496번째 종목 우리엔터프라이즈 추출중...
# 116개 추출완료. 누적5260개
# 1497번째 종목 네패스 추출중...
# 116개 추출완료. 누적5376개
# 1498번째 종목 인지디스플레 추출중...
# 116개 추출완료. 누적5492개
# 1499번째 종목 위지트 추출중...
# 116개 추출완료. 누적5608개
# 1500번째 종목 유니셈 추출중...
# 116개 추출완료. 누적5724개
# 179/179 [==============================] - 3s 16ms/step
# 179/179 [==============================] - 3s 16ms/step
# 3
# 레드캡투어 2023-03-27
# 제일테크노스 2023-07-05
# 심텍홀딩스 2023-07-10
# 1501번째 종목 유성티엔에스 추출중...
# 116개 추출완료. 누적116개
# 1502번째 종목 코리아나 추출중...
# 116개 추출완료. 누적232개
# 1503번째 종목 SCI평가정보 추출중...
# 116개 추출완료. 누적348개
# 1504번째 종목 골드앤에스 추출중...
# 116개 추출완료. 누적464개
# 1505번째 종목 서울전자통신 추출중...
# 116개 추출완료. 누적580개
# 1506번째 종목 대성창투 추출중...
# 116개 추출완료. 누적696개
# 1507번째 종목 예림당 추출중...
# 116개 추출완료. 누적812개
# 1508번째 종목 CJ ENM 추출중...
# 116개 추출완료. 누적928개
# 1509번째 종목 이지홀딩스 추출중...
# 116개 추출완료. 누적1044개
# 1510번째 종목 기산텔레콤 추출중...
# 116개 추출완료. 누적1160개
# 1511번째 종목 바른손이앤에이 추출중...
# 116개 추출완료. 누적1276개
# 1512번째 종목 솔본 추출중...
# 116개 추출완료. 누적1392개
# 1513번째 종목 시공테크 추출중...
# 116개 추출완료. 누적1508개
# 1514번째 종목 신일제약 추출중...
# 116개 추출완료. 누적1624개
# 1515번째 종목 조아제약 추출중...
# 116개 추출완료. 누적1740개
# 1516번째 종목 인성정보 추출중...
# 116개 추출완료. 누적1856개
# 1517번째 종목 그래디언트 추출중...
# 116개 추출완료. 누적1972개
# 1518번째 종목 동국산업 추출중...
# 116개 추출완료. 누적2088개
# 1519번째 종목 매일홀딩스 추출중...
# 116개 추출완료. 누적2204개
# 1520번째 종목 해성산업 추출중...
# 116개 추출완료. 누적2320개
# 1521번째 종목 한국정보통신 추출중...
# 116개 추출완료. 누적2436개
# 1522번째 종목 파라텍 추출중...
# 116개 추출완료. 누적2552개
# 1523번째 종목 동성화인텍 추출중...
# 116개 추출완료. 누적2668개
# 1524번째 종목 드래곤플라이 추출중...
# 116개 추출완료. 누적2784개
# 1525번째 종목 엠케이전자 추출중...
# 116개 추출완료. 누적2900개
# 1526번째 종목 엠투엔 추출중...
# 116개 추출완료. 누적3016개
# 1527번째 종목 제이씨현시스템 추출중...
# 116개 추출완료. 누적3132개
# 1528번째 종목 포스코엠텍 추출중...
# 116개 추출완료. 누적3248개
# 1529번째 종목 스페코 추출중...
# 116개 추출완료. 누적3364개
# 1530번째 종목 좋은사람들 추출중...
# 0개 추출완료. 누적3364개
# 1531번째 종목 모아텍 추출중...
# 116개 추출완료. 누적3480개
# 1532번째 종목 코웰패션 추출중...
# 116개 추출완료. 누적3596개
# 1533번째 종목 코콤 추출중...
# 116개 추출완료. 누적3712개
# 1534번째 종목 제룡전기 추출중...
# 116개 추출완료. 누적3828개
# 1535번째 종목 제이엠아이 추출중...
# 116개 추출완료. 누적3944개
# 1536번째 종목 디지틀조선 추출중...
# 116개 추출완료. 누적4060개
# 1537번째 종목 바이온 추출중...
# 116개 추출완료. 누적4176개
# 1538번째 종목 와이지-원 추출중...
# 116개 추출완료. 누적4292개
# 1539번째 종목 특수건설 추출중...
# 116개 추출완료. 누적4408개
# 1540번째 종목 아이즈비전 추출중...
# 116개 추출완료. 누적4524개
# 1541번째 종목 동일기연 추출중...
# 116개 추출완료. 누적4640개
# 1542번째 종목 소프트센 추출중...
# 104개 추출완료. 누적4744개
# 1543번째 종목 원익 추출중...
# 116개 추출완료. 누적4860개
# 1544번째 종목 원풍물산 추출중...
# 116개 추출완료. 누적4976개
# 1545번째 종목 삼진 추출중...
# 116개 추출완료. 누적5092개
# 1546번째 종목 비트컴퓨터 추출중...
# 116개 추출완료. 누적5208개
# 1547번째 종목 휴먼엔 추출중...
# 0개 추출완료. 누적5208개
# 1548번째 종목 엠젠솔루션 추출중...
# 109개 추출완료. 누적5317개
# 1549번째 종목 판타지오 추출중...
# 116개 추출완료. 누적5433개
# 1550번째 종목 유비케어 추출중...
# 116개 추출완료. 누적5549개
# 174/174 [==============================] - 3s 18ms/step
# 174/174 [==============================] - 3s 16ms/step
# 2
# 대성창투 2023-06-09
# 조아제약 2023-03-09
# 1551번째 종목 피델릭스 추출중...
# 116개 추출완료. 누적116개
# 1552번째 종목 TJ미디어 추출중...
# 116개 추출완료. 누적232개
# 1553번째 종목 휴맥스홀딩스 추출중...
# 116개 추출완료. 누적348개
# 1554번째 종목 삼일 추출중...
# 116개 추출완료. 누적464개
# 1555번째 종목 뉴인텍 추출중...
# 116개 추출완료. 누적580개
# 1556번째 종목 오스템 추출중...
# 116개 추출완료. 누적696개
# 1557번째 종목 에스유홀딩스 추출중...
# 116개 추출완료. 누적812개
# 1558번째 종목 피에스케이홀딩스 추출중...
# 116개 추출완료. 누적928개
# 1559번째 종목 세보엠이씨 추출중...
# 116개 추출완료. 누적1044개
# 1560번째 종목 한일단조 추출중...
# 116개 추출완료. 누적1160개
# 1561번째 종목 양지사 추출중...
# 116개 추출완료. 누적1276개
# 1562번째 종목 원익홀딩스 추출중...
# 116개 추출완료. 누적1392개
# 1563번째 종목 한글과컴퓨터 추출중...
# 116개 추출완료. 누적1508개
# 1564번째 종목 메이슨캐피탈 추출중...
# 116개 추출완료. 누적1624개
# 1565번째 종목 광무 추출중...
# 86개 추출완료. 누적1710개
# 1566번째 종목 대호특수강 추출중...
# 91개 추출완료. 누적1801개
# 1567번째 종목 HLB 추출중...
# 116개 추출완료. 누적1917개
# 1568번째 종목 팜스토리 추출중...
# 116개 추출완료. 누적2033개
# 1569번째 종목 삼보판지 추출중...
# 116개 추출완료. 누적2149개
# 1570번째 종목 삼목에스폼 추출중...
# 116개 추출완료. 누적2265개
# 1571번째 종목 에이스침대 추출중...
# 116개 추출완료. 누적2381개
# 1572번째 종목 원익큐브 추출중...
# 116개 추출완료. 누적2497개
# 1573번째 종목 리드코프 추출중...
# 116개 추출완료. 누적2613개
# 1574번째 종목 유니슨 추출중...
# 116개 추출완료. 누적2729개
# 1575번째 종목 아난티 추출중...
# 116개 추출완료. 누적2845개
# 1576번째 종목 광진실업 추출중...
# 116개 추출완료. 누적2961개
# 1577번째 종목 인터엠 추출중...
# 116개 추출완료. 누적3077개
# 1578번째 종목 성우하이텍 추출중...
# 116개 추출완료. 누적3193개
# 1579번째 종목 대신정보통신 추출중...
# 116개 추출완료. 누적3309개
# 1580번째 종목 서부T&D 추출중...
# 116개 추출완료. 누적3425개
# 1581번째 종목 동신건설 추출중...
# 116개 추출완료. 누적3541개
# 1582번째 종목 동화기업 추출중...
# 116개 추출완료. 누적3657개
# 1583번째 종목 신라에스지 추출중...
# 116개 추출완료. 누적3773개
# 1584번째 종목 케이씨피드 추출중...
# 116개 추출완료. 누적3889개
# 1585번째 종목 한탑 추출중...
# 116개 추출완료. 누적4005개
# 1586번째 종목 한국선재 추출중...
# 116개 추출완료. 누적4121개
# 1587번째 종목 DH오토웨어 추출중...
# 97개 추출완료. 누적4218개
# 1588번째 종목 시노펙스 추출중...
# 116개 추출완료. 누적4334개
# 1589번째 종목 PN풍년 추출중...
# 116개 추출완료. 누적4450개
# 1590번째 종목 삼천리자전거 추출중...

# %%
for down in down_images_info:
    for i in down:
        print(i[0], str(i[2])[:10])
# Out:
# 케이비아이동국실업 2023-02-16
# 코오롱우 2023-03-08
# 쿠쿠홈시스 2023-02-16
# 크래프톤 2023-05-24
# 풀무원 2023-05-30
# 한국주철관 2023-05-24
# 한화오션 2023-03-08
# 현대코퍼레이션홀딩스 2023-05-08
#
# 수산인더스트리 2023-04-18
# 이수화학 2023-03-17
# 코오롱플라스틱 2023-03-03
# 하나제약 2023-02-20
# 한일철강 2023-04-04
# 한화투자증권 2023-05-10
# 현대리바트 2023-07-07

# %%
np.save('down_images_20230227-20230814.npy', down)

with open("down_images_info.txt", "w") as file:
    for info in down_images_info:
        # 튜플에 있는 문자열을 콤마로 구분 하나의 문자열로 합칩니다.
        line = ', '.join(info)
        file.write(f"{line}\n")

# %%
import matplotlib.pyplot as plt

# 레이블이 0인 이미지 선택

# 이미지 출력 함수
def display_images(images, rows, cols):
    fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
    axes = axes.ravel()

    for i in range(rows * cols):
        axes[i].imshow(images[i], cmap='gray')
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# 이미지 출력
num_examples = min(len(test_images), 7)
rows = cols = int(np.sqrt(num_examples))
display_images(test_images[:num_examples], rows, cols)

# %%
import matplotlib.pyplot as plt
from datetime import datetime
plt.rc('font', family='NanumBarunGothic')

# 현재 날짜를 'x월 x일' 형식으로 변환합니다.
today = datetime.now().strftime("%m월 %d일")

fig, axes = plt.subplots(10, 10, figsize=(16, 16))
for i in range(10):
    for j in range(10):
        img_idx = i * 10 + j
        img = Image.fromarray(test_images[img_idx])
        axes[i, j].imshow(img)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        # 색상 변경을 위해 text 함수를 사용합니다.
        color = 'red' if predicted_labels[i*10 + j] else 'blue'
        text = f'{stock_codes[i*10 + j][1]} : {"상승" if predicted_labels[i*10 + j] else "하락"}'
        axes[i, j].text(0.5, -0.15, text, fontsize=9, color=color, ha='center', va='center', transform=axes[i, j].transAxes)

# 제목 추가 (날짜 포함)
plt.suptitle(f'{today} 종가대비 향후 5거래일 평균 가격 예상', fontsize=20, y=0.95)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-482bfd5f50b1> in <cell line: 9>()
#      10     for j in range(10):
#      11         img_idx = i * 10 + j
# ---> 12         img = Image.fromarray(test_images[img_idx])
#      13         axes[i, j].imshow(img)
#      14         axes[i, j].set_xticks([])
#
# IndexError: list index out of range

# %%
a = fdr.DataReader('035250')
print(a.tail())
# Out:
#              Open   High    Low  Close   Volume    Change
# Date
# 2023-08-04  15640  15910  15520  15840   526457  0.022595
# 2023-08-07  15840  16300  15840  16160   818666  0.020202
# 2023-08-08  16390  16740  15990  16070  1248098 -0.005569
# 2023-08-09  16140  16140  15830  16070   410114  0.000000
# 2023-08-10  16680  17270  16450  16680  3594068  0.037959
