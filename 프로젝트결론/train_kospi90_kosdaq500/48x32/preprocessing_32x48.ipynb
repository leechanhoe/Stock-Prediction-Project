# %%
# !pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in /usr/local/lib/python3.10/dist-packages (0.9.50)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from datetime import datetime, timedelta
import random

day_num = 48

# %%
def convert_image(data, num_images, day_num, change_std, save = False, test = False):
    if test:
        change_std = 0

    def alpha_blend(color1, color2, alpha):
        return [
            int((color1[0] * alpha + color2[0] * (1 - alpha))),
            int((color1[1] * alpha + color2[1] * (1 - alpha))),
            int((color1[2] * alpha + color2[2] * (1 - alpha))),
            255,
        ]

    # 데이터수가 너무 적으면 패스
    if len(data) <= day_num + 60:
        return []


    # 해당 종목의 주가 데이터 - 100이 요구되는 이미지 수보다 적으면(상장직후는 변동이 심할 수있으니 제외)
    if num_images - day_num - 60 > len(data):
        num_images = len(data) - day_num - 60

    #return_datas는 이미지, 라벨링(상승이면1 하락이면0), 변동률, 날짜를 담고있음
    return_datas = []
    prediction_day_num = 5


    image_idx = 1
    while(image_idx <= num_images):
        prediction_day5 = data[-image_idx - (prediction_day_num * 2) : -image_idx - prediction_day_num]
        predict_mean5 = prediction_day5['Close'].mean()
        prediction_day5_10 = data[-image_idx - prediction_day_num : -image_idx]
        predict_mean5_10 = prediction_day5_10['Close'].mean()
        prediction_day10 = data[-image_idx - (prediction_day_num * 2) : -image_idx]
        predict_mean10 = prediction_day10['Close'].mean()

        now = data.iloc[-image_idx - (prediction_day_num * 2) - 1]
        change5 = (predict_mean5 - now['Close']) / now['Close']
        after5 = prediction_day5.iloc[-1]
        change5_10 = (predict_mean5_10 - after5['Close']) / after5['Close']
        change10 = (predict_mean10 - now['Close']) / now['Close']

        # change가 너무 높으면 이상치라고 판단하여 패스
        if not test and (abs(change5) < change_std or change_std * 3 < abs(change5)): # 향후 prediction_day_num일의 변동률이 기준 이하면
            image_idx += 1
            continue

        stock_data = data[-image_idx - day_num - (prediction_day_num * 2): -image_idx - (prediction_day_num * 2)]

        # 이미지 크기 설정
        width, height = day_num * 3, 96

        # High, Low, Close, Volume 데이터 정규화
        high_prices = stock_data['High'].values
        low_prices = stock_data['Low'].values
        close_prices = stock_data['Close'].values
        volume_data = stock_data['Volume'].values

        high_prices_norm = (high_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        low_prices_norm = (low_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        close_prices_norm = (close_prices - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
        volume_data_norm = height * (volume_data) / (2 * (np.max(volume_data)))

        if len(data) <= abs(-image_idx - day_num - 20 - (prediction_day_num * 2)):
            break
        # 이동평균선 추가를 위한 stock_data 생성
        stock_data_ma20 = data[-image_idx - day_num - 20 - (prediction_day_num * 2): -image_idx - (prediction_day_num * 2)]
        stock_data_ma20 = stock_data_ma20.copy()
        stock_data_ma20['MA20'] = stock_data_ma20['Close'].rolling(window=20).mean()
        stock_data_ma20.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma20['MA20_norm'] = (
                (stock_data_ma20['MA20'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        if len(data) <= abs(-image_idx - day_num - 40 - (prediction_day_num * 2)):
            break
        stock_data_ma40 = data[-image_idx - day_num - 40 - (prediction_day_num * 2): -image_idx - (prediction_day_num * 2)]
        stock_data_ma40 = stock_data_ma40.copy()
        stock_data_ma40['MA40'] = stock_data_ma40['Close'].rolling(window=40).mean()
        stock_data_ma40.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma40['MA40_norm'] = (
                (stock_data_ma40['MA40'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )


        if len(data) <= abs(-image_idx - day_num - 60 - (prediction_day_num * 2)):
            break
        stock_data_ma60 = data[-image_idx - day_num - 60 - (prediction_day_num * 2): -image_idx - (prediction_day_num * 2)]
        stock_data_ma60 = stock_data_ma60.copy()
        stock_data_ma60['MA60'] = stock_data_ma60['Close'].rolling(window=60).mean()
        stock_data_ma60.dropna(inplace=True)

        # 이동평균선 값을 정규화
        stock_data_ma60['MA60_norm'] = (
                (stock_data_ma60['MA60'] - np.min(low_prices)) / (np.max(high_prices) - np.min(low_prices))
            )

        # 96x96 이미지 생성
        img = np.zeros((height, width, 4), dtype=np.uint8)  # 4 channels for RGBA

        fail_generate = False
        for day in range(day_num):
            high_price = int(high_prices_norm[day] * (height - 1))
            low_price = int(low_prices_norm[day] * (height - 1))
            close_price = int(close_prices_norm[day] * (height - 1))
            open_price = int(
                (
                    (stock_data['Open'].values[day] - np.min(low_prices))
                    / (np.max(high_prices) - np.min(low_prices))
                )
                * (height - 1)
            )
            volume = int(volume_data_norm[day])
            if(volume == 0):
                fail_generate = True
                break

            x_start = day * 3

            # 시가, 종가, 고가, 저가 막대그래프
            # 막대 왼쪽, 오른쪽 그리기 (시가, 종가 범위)
            for x in range(x_start, x_start + 3):
                if close_prices[day] > stock_data['Open'].values[day]:
                    color = [255, 0, 0, 255]  # 상승: 빨강
                    tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                elif close_prices[day] < stock_data['Open'].values[day]:
                    color = [0, 0, 255, 255]  # 하락: 파랑
                    tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑
                else: # 시가와 종가가 같을경우 어제보다 같거나 올랐으면 빨강, 아니면 파랑
                    if 0 <= stock_data['Change'].values[day]:
                        color = [255, 0, 0, 255]  # 상승: 빨강
                        tail_color = [200, 0, 0, 255]  # 상승 시 꼬리: 어두운 빨강
                    else:
                        color = [0, 0, 255, 255]  # 하락: 파랑
                        tail_color = [0, 0, 200, 255]  # 하락 시 꼬리: 어두운 파랑

                for y in range(min(open_price, close_price), max(open_price, close_price) + 1):
                    img[height - 1 - y, x] = color

            # 꼬리 그리기 (High, Low 범위)
            for x in range(x_start + 1, x_start + 2):
                for y in range(low_price, high_price + 1):
                    if img[height - 1 - y, x][0] != 255 and img[height - 1 - y, x][2] != 255:
                        img[height - 1 - y, x] = tail_color

            # 거래량 그리기
            for x in range(x_start, x_start + 3):
                overlapped = height - volume
                if overlapped >= 0 and overlapped < height:
                    img[overlapped:, x] = [
                        alpha_blend(img[y, x], [128, 128, 128, 255], 0.45)
                        for y in range(overlapped, height)
                    ]

            # 20일 이동평균선 그리기
            ma20_norm = stock_data_ma20.iloc[day]['MA20_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma20_norm):
                    ma20_y = int(ma20_norm * (height - 1))
                    if 0 <= ma20_y < height:
                        for y in range(ma20_y - 1, ma20_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([255, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 노란색으로 변경
                                img[height - 1 - y, x] = new_color

            # 40일 이동평균선 그리기
            ma40_norm = stock_data_ma40.iloc[day]['MA40_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma40_norm):
                    ma40_y = int(ma40_norm * (height - 1))
                    if 0 <= ma40_y < height:
                        for y in range(ma40_y - 1, ma40_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([128, 0, 128, 255], img[height - 1 - y, x], 0.6)  # 보라색으로 변경
                                img[height - 1 - y, x] = new_color

            # 60일 이동평균선 그리기
            ma60_norm = stock_data_ma60.iloc[day]['MA60_norm']

            for x in range(x_start, x_start + 3):
                if not np.isnan(ma60_norm):
                    ma60_y = int(ma60_norm * (height - 1))
                    if 0 <= ma60_y < height:
                        for y in range(ma60_y - 1, ma60_y + 2):  # 이동평균선 주변에 블렌딩 처리
                            if 0 <= y < height:
                                new_color = alpha_blend([0, 255, 0, 255], img[height - 1 - y, x], 0.6)  # 초록색으로 변경
                                img[height - 1 - y, x] = new_color

        #이미지가 day_num(그려지기 원하는 거래일 수)미만으로 그려졌으면
        if fail_generate:
            image_idx += (prediction_day_num * 2)
            continue

        if save :
            # 이미지 저장
            img = Image.fromarray(img, 'RGBA')
            img.save(f'stock_data_image_{image_idx}.png')
        if not test:
            if change_std <= change5 and 0 < change5_10:
                return_datas.append((img, 1))
            elif change5 < -change_std and change5_10 < 0:
                return_datas.append((img, 0))
        else:
            if change_std <= change10:
                return_datas.append((img, 1))
            elif change10 < -change_std:
                return_datas.append((img, 0))

            # 테스트는 촘촘하게 모든 데이터로
        if test:
            image_idx += random.choice(range(1, 5))
        else:
            # 비슷한 이미지를 피하기 위해 기준 예측일만큼 건너뜀
            image_idx += random.choice(range(1, 5))


    return return_datas

# %%
def preprocess_data(data):
    # 0이나 NaN을 포함하는 행 제거
    data = data[data['Volume'] != 0]
    data = data.dropna(how='any')

    return data

# %%
stock_codes2 = [
    ["005930", "삼성전자"],
    ["051910", "LG화학"],
    ["000660", "SK하이닉스"],
    ["207940", "삼성바이오로직스"],
    ["005935", "삼성전자우"],
    ["051915", "LG화학우"],
    ["006400", "삼성SDI"],
    ["005380", "현대차"],
    ["363280", "효성화학"],
    ["247540", "에코프로비엠"],
    ["000270", "기아"],
    ["086520", "에코프로"],
    ["035720", "카카오"],
    ["068270", "셀트리온"],
    ["012330", "현대모비스"],
    ["105560", "KB금융"],
    ["028260", "삼성물산"],
    ["055550", "신한지주"],
    ["096770", "SK이노베이션"],
    ["066570", "LG전자"],
    ["047050", "대우조선해양"],
    ["032830", "삼성생명"],
    ["323410", "카카오뱅크"],
    ["003550", "LG"],
    ["015760", "한국전력"],
    ["000810", "삼성화재"],
    ["033780", "KT&G"],
    ["091990", "셀트리온헬스케어"],
    ["009150", "삼성전기"],
    ["086790", "하나금융지주"],
    ["034730", "SK"],
    ["336370", "솔루스첨단소재"],
    ["352820", "하이브"],
    ["018260", "삼성에스디에스"],
    ["122630", "KODEX 레버리지"],
    ["017670", "SK텔레콤"],
    ["010130", "고려아연"],
    ["024880", "케이씨케미칼"],
    ["003490", "대한항공"],
    ["010950", "S-Oil"],
    ["086280", "현대글로비스"],
    ["259960", "크래프톤"],
    ["024110", "기업은행"],
    ["030200", "케이티"],
    ["316140", "우리금융지주"],
    ["010140", "삼성중공업"],
    ["090430", "아모레퍼시픽"],
    ["051900", "LG생활건강"],
    ["028050", "삼성엔지니어링"],
    ["233740", "KODEX 코스닥 150 레버리지"],
    ["011170", "롯데케미칼"],
    ["000100", "유한양행"],
    ["012450", "한화에어로스페이스"],
    ["036570", "엔씨소프트"],
    ["241560", "두산밥캣"],
    ["005830", "DB손해보험"],
    ["018880", "한온시스템"],
    ["034220", "LG디스플레이"],
    ["170030", "HD현대"],
    ["088980", "맥쿼리인프라"],
    ["005070", "코스모신소재"],
    ["271560", "오리온"],
    ["004020", "현대제철"],
    ["097950", "CJ제일제당"],
    ["047810", "한국항공우주"],
    ["042700", "한미반도체"],
    ["032640", "LG유플러스"],
    ["307950", "현대오토에버"],
    ["006800", "미래에셋증권"],
    ["007700", "F&F홀딩스"],
    ["251270", "넷마블"],
    ["128940", "한미약품"],
    ["000720", "현대건설"],
    ["010620", "현대미포조선"],
    ["006260", "LS"],
    ["078930", "GS"],
    ["011780", "금호석유"],
    ["035250", "강원랜드"],
    ["008770", "호텔신라"],
    ["005940", "NH투자증권"],
    ["180640", "한진칼"],
    ["016360", "삼성증권"],
    ["064350", "현대로템"],
    ["021240", "코웨이"],
    ["282330", "BGF리테일"],
    ["112610", "씨에스윈드"],
    ["071050", "한국금융지주"],
    ["002790", "아모레G"],
    ["008930", "한미사이언스"],
    ["004990", "롯데지주"],
    ["010780", "쌍용C&E"],
    ["001450",  "현대해상"],
    ["111770",  "영원무역"],
    ["272210",  "한화시스템"],
    ["052690",  "한전기술"],
    ["267260",  "HD현대일렉트릭"],
    ["007070",  "GS리테일"],
    ["028670",  "팬오션"],
    ["139480",  "이마트"],
    ["035900", "JYP Ent."], # 여기서부터는 코스닥
    ["263750", "펄어비스"],
    ["293490", "카카오게임즈"],
    ["196170", "알테오젠"],
    ["058470", "리노공업"],
    ["214150", "클래시스"],
    ["039030", "이오테크닉스"],
    ["278280", "천보"],
    ["137400", "피엔티"],
    ["237690", "에스티팜"],
    ["214450", "파마리서치"],
    ["240810", "원익IPS"],
    ["145020", "휴젤"],
    ["035760", "CJ ENM"],
    ["056190", "에스에프에이"],
    ["036930", "주성엔지니어링"],
    ["064760", "티씨케이"],
    ["213420", "덕산네오룩스"],
    ["195940", "HK이노엔"],
    ["014130", "레고켐바이오"],
    ["098460", "고영"],
    ["067310", "하나마이크론"],
    ["166090", "하나머티리얼즈"],
    ["348210", "넥스틴"],
    ["003380", "하림지주"],
    ["272290", "이녹스첨단소재"],
    ["085660", "차바이오텍"],
    ["074610", "원익QnC"],
    ["083470", "유진테크"],
    ["046890", "서울반도체"],
    ["086450", "동국제약"],
    ["215000", "골프존"],
    ["215200", "메가스터디교육"],
    ["319660", "피에스케이"],
    ["183300", "코미코"],
    ["200130", "콜마비앤에이치"],
    ["069080", "웹젠"],
    ["036830", "솔브레인홀딩스"],
    ["084850", "아이티엠반도체"],
    ["243070", "휴온스"],
    ["049070", "인탑스"],
    ["131290", "티에스이"],
    ["091700", "파트론"],
    ["064550", "바이오니아"],
    ["019550", "SFA반도체"],
    ["095610", "테스"],
    ["230360", "에코마케팅"],
    ["267980", "매일유업"],
    ['205470', '휴마시스'],
    ['060150', '인선이엔티'],
    ['417010', '나노팀'],
    ['036620', '감성코퍼레이션'],
    ['047920', 'HLB제약'],
    ['243840', '신흥에스이씨'],
    ['217270', '넵튠'],
    ['056080', '유진로봇'],
    ['018290', '브이티'],
    ['108490', '로보티즈'],
    ['059090', '미코'],
    ['348340', '뉴로메카'],
    ['041830', '인바디'],
    ['101360', '에코앤드림'],
    ['013030', '하이록코리아'],
    ['038500', '삼표시멘트'],
    ['307750', '국전약품'],
    ['049950', '미래컴퍼니'],
    ['092040', '아미코젠'],
    ['382840', '원준'],
    ['094360', '칩스앤미디어'],
    ['290670', '대보마그네틱'],
    ['029960', '코엔텍'],
    ['058820', 'CMG제약'],
    ['314930', '바이오다인'],
    ['047310', '파워로직스'],
    ['297090', '씨에스베어링'],
    ['104830', '원익머트리얼즈'],
    ['282880', '코윈테크'],
    ['077360', '덕산하이메탈'],
    ['214610', '미코바이오메드'],
    ['297890', 'HB솔루션'],
    ['122640', '예스티'],
    ['054210', '이랜텍'],
    ['285490', '노바텍'],
    ['025770', '한국정보통신'],
    ['089010', '켐트로닉스'],
    ['053030', '바이넥스'],
    ['030520', '한글과컴퓨터'],
    ['060370', 'KT서브마린'],
    ['126340', '비나텍'],
    ['254490', '미래반도체'],
    ['235980', '메드팩토'],
    ['102940', '코오롱생명과학'],
    ['101730', '위메이드맥스'],
    ['093320', '케이아이엔엑스'],
    ['251970', '펌텍코리아'],
    ['005160', '동국산업'],
    ['051500', 'CJ프레시웨이'],
    ['005090', 'SGC에너지'],
    ['232140', '와이아이케이'],
    ['000210', 'DL'],
    ['053210', '스카이라이프'],
]
print(len(stock_codes2))

def check_duplicate_stock_codes(stock_codes2):
    stock_codes_set = set()

    for code, name in stock_codes2:
        if code in stock_codes_set:
            print(f"중복된 종목코드 발견: {code} ({name})")
        else:
            stock_codes_set.add(code)

    if len(stock_codes_set) == len(stock_codes2):
        print("중복된 종목코드가 없습니다.")

# 종목코드 중복 여부 확인
check_duplicate_stock_codes(stock_codes2)
# Out:
# 200
# 중복된 종목코드가 없습니다.

# %%
# 엑셀 파일 읽기
df = pd.read_csv('drive/MyDrive/Colab Notebooks/kosdaq.csv', usecols=[0, 1], dtype={1: str})
df = df[~df.iloc[:, 0].str.contains("스팩")]
df = df.iloc[:, [1, 0]]
df = df.sample(n=500, random_state=42)
# 첫 번째 열과 두 번째 열을 Nx2 리스트로 변환
stock_codes = df.values.tolist()

# 결과 출력
print(stock_codes)
# Out:
# [['068760', '셀트리온제약'], ['317870', '엔바이오니아'], ['037950', '엘컴텍'], ['032190', '다우데이타'], ['200780', '비씨월드제약'], ['023460', 'CNH'], ['208350', '지란지교시큐리티'], ['294630', '서남'], ['166090', '하나머티리얼즈'], ['417840', '저스템'], ['016790', '카나리아바이오'], ['040350', '큐로컴'], ['310200', '애니플러스'], ['080010', '이상네트웍스'], ['066910', '손오공'], ['317240', 'TS트릴리온'], ['228760', '지노믹트리'], ['200470', '에이팩트'], ['424980', '마이크로투나노'], ['318160', '셀바이오휴먼텍'], ['006140', '피제이전자'], ['204020', '그리티'], ['252500', '세화피앤씨'], ['196300', '애니젠'], ['239610', '에이치엘사이언스'], ['115960', '연우'], ['078860', '아이오케이'], ['253590', '네오셈'], ['187790', '나노'], ['142760', '비엘'], ['425420', '티에프이'], ['032820', '우리기술'], ['192440', '슈피겐코리아'], ['064290', '인텍플러스'], ['054050', '농우바이오'], ['038060', '루멘스'], ['104200', 'NHN벅스'], ['900280', '골든센츄리'], ['067160', '아프리카TV'], ['434480', '모니터랩'], ['068330', '일신바이오'], ['309960', 'LB인베스트먼트'], ['206640', '바디텍메드'], ['190650', '코리아에셋투자증권'], ['102120', '어보브반도체'], ['211270', 'AP위성'], ['131220', '대한과학'], ['174900', '앱클론'], ['033340', '좋은사람들'], ['044480', '블레이드 Ent'], ['252990', '샘씨엔에스'], ['036120', 'SCI평가정보'], ['136480', '하림'], ['053300', '한국정보인증'], ['093520', '매커스'], ['016250', 'SGC이테크건설'], ['036620', '감성코퍼레이션'], ['382480', '지아이텍'], ['085670', '뉴프렉스'], ['293490', '카카오게임즈'], ['079970', '투비소프트'], ['365270', '큐라클'], ['174880', '장원테크'], ['159580', '제로투세븐'], ['053950', '경남제약'], ['053060', '세동'], ['290740', '액트로'], ['217190', '제너셈'], ['042520', '한스바이오메드'], ['074600', '원익QnC'], ['006620', '동구바이오제약'], ['214260', '라파스'], ['111710', '남화산업'], ['299030', '하나기술'], ['298380', '에이비엘바이오'], ['038110', '에코플라스틱'], ['053580', '웹케시'], ['083650', '비에이치아이'], ['033560', '블루콤'], ['290380', '대유'], ['069080', '웹젠'], ['021320', 'KCC건설'], ['089970', '에이피티씨'], ['054040', '한국컴퓨터'], ['109740', '디에스케이'], ['347770', '핌스'], ['294090', '이오플로우'], ['109080', '옵티시스'], ['134060', '이퓨쳐'], ['198940', '한주라이트메탈'], ['025900', '동화기업'], ['099750', '이지케어텍'], ['072020', '중앙백신'], ['317830', '에스피시스템스'], ['023790', '동일철강'], ['052300', '초록뱀컴퍼니'], ['066980', '이엔코퍼레이션'], ['368770', '파이버프로'], ['399720', '가온칩스'], ['217820', '원익피앤이'], ['073110', '엘엠에스'], ['220260', '켐트로스'], ['079940', '가비아'], ['058530', '파나케이아'], ['169330', '엠브레인'], ['097780', '에스맥'], ['065680', '우주일렉트로'], ['038010', '제일테크노스'], ['179290', '엠아이텍'], ['298870', '우리벤처파트너스'], ['121800', '비덴트'], ['305090', '마이크로디지탈'], ['356890', '싸이버원'], ['950220', '네오이뮨텍'], ['319400', '현대무벡스'], ['162300', '신스틸'], ['419540', '비스토스'], ['037030', '파워넷'], ['335870', '윙스풋'], ['441270', '파인엠텍'], ['014970', '삼륭물산'], ['090470', '제이스텍'], ['053030', '바이넥스'], ['079000', '와토스코리아'], ['161580', '필옵틱스'], ['012860', '모베이스전자'], ['095700', '제넥신'], ['378800', '샤페론'], ['200350', '래몽래인'], ['101360', '에코앤드림'], ['376180', '피코그램'], ['033310', '엠투엔'], ['093380', '풍강'], ['243070', '휴온스'], ['073570', '리튬포어스'], ['277410', '인산가'], ['405000', '플라즈맵'], ['122640', '예스티'], ['028300', 'HLB'], ['010240', '흥국'], ['007820', '에스엠코어'], ['057680', '티사이언티픽'], ['043650', '국순당'], ['039020', '이건홀딩스'], ['032580', '피델릭스'], ['053980', '오상자이엘'], ['054670', '대한뉴팜'], ['215000', '골프존'], ['060590', '씨티씨바이오'], ['012790', '신일제약'], ['038460', '바이오스마트'], ['075970', '동국알앤에스'], ['224110', '에이텍모빌리티'], ['064550', '바이오니아'], ['189980', '흥국에프엔비'], ['226950', '올릭스'], ['312610', '에이에프더블류'], ['058470', '리노공업'], ['187660', '에이디엠코리아'], ['163730', '핑거'], ['243840', '신흥에스이씨'], ['035200', '프럼파스트'], ['054300', '팬스타엔터프라이즈'], ['066130', '하츠'], ['244460', '올리패스'], ['037440', '희림'], ['151910', 'SBW생명과학'], ['023770', '플레이위드'], ['027580', '상보'], ['090410', '덕신하우징'], ['079810', '디이엔티'], ['950190', '미투젠'], ['270870', '뉴트리'], ['408900', '스튜디오미르'], ['045510', '정원엔시스'], ['060900', 'DGP'], ['230360', '에코마케팅'], ['047770', '코데즈컴바인'], ['124500', '아이티센'], ['073540', '에프알텍'], ['100030', '인지소프트'], ['088910', '동우팜투테이블'], ['211050', '인카금융서비스'], ['125210', '아모그린텍'], ['024950', '삼천리자전거'], ['067770', '세진티에스'], ['357230', '에이치피오'], ['024910', '경창산업'], ['227610', '아우딘퓨쳐스'], ['043100', '솔고바이오'], ['306040', '에스제이그룹'], ['393890', '더블유씨피'], ['038340', 'MIT'], ['019210', '와이지 ...

# %%
train_result = []
stock_codes += stock_codes2[:90]
for i, ticker in enumerate(stock_codes):
    code, name = ticker[0], ticker[1]
    print(f"{i+1}번째 종목 {name} 추출중...   ")

    try:
        cnt = 0
        data = preprocess_data(fdr.DataReader(code, '2014-01-01', '2020-02-20'))  # 각 종목의 데이터 가져오기
        images = convert_image(data, 3000, day_num, 0.07)
        train_result += images
        cnt += len(images)
        data = preprocess_data(fdr.DataReader(code, '2020-02-01', '2022-12-31'))  # 각 종목의 데이터 가져오기
        images = convert_image(data, 1000, day_num, 0.07)
        train_result += images
        cnt += len(images)
        print(f"{cnt}개 추출완료. 누적{len(train_result)}개")
    except IndexError:
        print(f"{name}에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.")
        continue
# Out:
# 1번째 종목 셀트리온제약 추출중...
# 32개 추출완료. 누적32개
# 2번째 종목 엔바이오니아 추출중...
# 8개 추출완료. 누적40개
# 3번째 종목 엘컴텍 추출중...
# 14개 추출완료. 누적54개
# 4번째 종목 다우데이타 추출중...
# 31개 추출완료. 누적85개
# 5번째 종목 비씨월드제약 추출중...
# 20개 추출완료. 누적105개
# 6번째 종목 CNH 추출중...
# 13개 추출완료. 누적118개
# 7번째 종목 지란지교시큐리티 추출중...
# 8개 추출완료. 누적126개
# 8번째 종목 서남 추출중...
# 5개 추출완료. 누적131개
# 9번째 종목 하나머티리얼즈 추출중...
# 38개 추출완료. 누적169개
# 10번째 종목 저스템 추출중...
# 0개 추출완료. 누적169개
# 11번째 종목 카나리아바이오 추출중...
# 8개 추출완료. 누적177개
# 12번째 종목 큐로컴 추출중...
# 51개 추출완료. 누적228개
# 13번째 종목 애니플러스 추출중...
# 7개 추출완료. 누적235개
# 14번째 종목 이상네트웍스 추출중...
# 23개 추출완료. 누적258개
# 15번째 종목 손오공 추출중...
# 28개 추출완료. 누적286개
# 16번째 종목 TS트릴리온 추출중...
# 0개 추출완료. 누적286개
# 17번째 종목 지노믹트리 추출중...
# 19개 추출완료. 누적305개
# 18번째 종목 에이팩트 추출중...
# 40개 추출완료. 누적345개
# 19번째 종목 마이크로투나노 추출중...
# 0개 추출완료. 누적345개
# 20번째 종목 셀바이오휴먼텍 추출중...
# 0개 추출완료. 누적345개
# 21번째 종목 피제이전자 추출중...
# 11개 추출완료. 누적356개
# 22번째 종목 그리티 추출중...
# 3개 추출완료. 누적359개
# 23번째 종목 세화피앤씨 추출중...
# 18개 추출완료. 누적377개
# 24번째 종목 애니젠 추출중...
# 32개 추출완료. 누적409개
# 25번째 종목 에이치엘사이언스 추출중...
# 21개 추출완료. 누적430개
# 26번째 종목 연우 추출중...
# 23개 추출완료. 누적453개
# 27번째 종목 아이오케이 추출중...
# 27개 추출완료. 누적480개
# 28번째 종목 네오셈 추출중...
# 6개 추출완료. 누적486개
# 29번째 종목 나노 추출중...
# 23개 추출완료. 누적509개
# 30번째 종목 비엘 추출중...
# 35개 추출완료. 누적544개
# 31번째 종목 티에프이 추출중...
# 0개 추출완료. 누적544개
# 32번째 종목 우리기술 추출중...
# 36개 추출완료. 누적580개
# 33번째 종목 슈피겐코리아 추출중...
# 36개 추출완료. 누적616개
# 34번째 종목 인텍플러스 추출중...
# 34개 추출완료. 누적650개
# 35번째 종목 농우바이오 추출중...
# 13개 추출완료. 누적663개
# 36번째 종목 루멘스 추출중...
# 21개 추출완료. 누적684개
# 37번째 종목 NHN벅스 추출중...
# 26개 추출완료. 누적710개
# 38번째 종목 골든센츄리 추출중...
# 22개 추출완료. 누적732개
# 39번째 종목 아프리카TV 추출중...
# 65개 추출완료. 누적797개
# 40번째 종목 모니터랩 추출중...
# 0개 추출완료. 누적797개
# 41번째 종목 일신바이오 추출중...
# 19개 추출완료. 누적816개
# 42번째 종목 LB인베스트먼트 추출중...
# 0개 추출완료. 누적816개
# 43번째 종목 바디텍메드 추출중...
# 29개 추출완료. 누적845개
# 44번째 종목 코리아에셋투자증권 추출중...
# 6개 추출완료. 누적851개
# 45번째 종목 어보브반도체 추출중...
# 45개 추출완료. 누적896개
# 46번째 종목 AP위성 추출중...
# 5개 추출완료. 누적901개
# 47번째 종목 대한과학 추출중...
# 12개 추출완료. 누적913개
# 48번째 종목 앱클론 추출중...
# 37개 추출완료. 누적950개
# 49번째 종목 좋은사람들 추출중...
# 36개 추출완료. 누적986개
# 50번째 종목 블레이드 Ent 추출중...
# 36개 추출완료. 누적1022개
# 51번째 종목 샘씨엔에스 추출중...
# 4개 추출완료. 누적1026개
# 52번째 종목 SCI평가정보 추출중...
# 9개 추출완료. 누적1035개
# 53번째 종목 하림 추출중...
# 18개 추출완료. 누적1053개
# 54번째 종목 한국정보인증 추출중...
# 24개 추출완료. 누적1077개
# 55번째 종목 매커스 추출중...
# 21개 추출완료. 누적1098개
# 56번째 종목 SGC이테크건설 추출중...
# 33개 추출완료. 누적1131개
# 57번째 종목 감성코퍼레이션 추출중...
# 16개 추출완료. 누적1147개
# 58번째 종목 지아이텍 추출중...
# 5개 추출완료. 누적1152개
# 59번째 종목 뉴프렉스 추출중...
# 48개 추출완료. 누적1200개
# 60번째 종목 카카오게임즈 추출중...
# 21개 추출완료. 누적1221개
# 61번째 종목 투비소프트 추출중...
# 37개 추출완료. 누적1258개
# 62번째 종목 큐라클 추출중...
# 5개 추출완료. 누적1263개
# 63번째 종목 장원테크 추출중...
# 25개 추출완료. 누적1288개
# 64번째 종목 제로투세븐 추출중...
# 31개 추출완료. 누적1319개
# 65번째 종목 경남제약 추출중...
# 31개 추출완료. 누적1350개
# 66번째 종목 세동 추출중...
# 12개 추출완료. 누적1362개
# 67번째 종목 액트로 추출중...
# 16개 추출완료. 누적1378개
# 68번째 종목 제너셈 추출중...
# 19개 추출완료. 누적1397개
# 69번째 종목 한스바이오메드 추출중...
# 39개 추출완료. 누적1436개
# 70번째 종목 원익QnC 추출중...
# 41개 추출완료. 누적1477개
# 71번째 종목 동구바이오제약 추출중...
# 3개 추출완료. 누적1480개
# 72번째 종목 라파스 추출중...
# 20개 추출완료. 누적1500개
# 73번째 종목 남화산업 추출중...
# 2개 추출완료. 누적1502개
# 74번째 종목 하나기술 추출중...
# 5개 추출완료. 누적1507개
# 75번째 종목 에이비엘바이오 추출중...
# 31개 추출완료. 누적1538개
# 76번째 종목 에코플라스틱 추출중...
# 17개 추출완료. 누적1555개
# 77번째 종목 웹케시 추출중...
# 15개 추출완료. 누적1570개
# 78번째 종목 비에이치아이 추출중...
# 30개 추출완료. 누적1600개
# 79번째 종목 블루콤 추출중...
# 39개 추출완료. 누적1639개
# 80번째 종목 대유 추출중...
# 11개 추출완료. 누적1650개
# 81번째 종목 웹젠 추출중...
# 53개 추출완료. 누적1703개
# 82번째 종목 KCC건설 추출중...
# 24개 추출완료. 누적1727개
# 83번째 종목 에이피티씨 추출중...
# 25개 추출완료. 누적1752개
# 84번째 종목 한국컴퓨터 추출중...
# 7개 추출완료. 누적1759개
# 85번째 종목 디에스케이 추출중...
# 54개 추출완료. 누적1813개
# 86번째 종목 핌스 추출중...
# 12개 추출완료. 누적1825개
# 87번째 종목 이오플로우 추출중...
# 13개 추출완료. 누적1838개
# 88번째 종목 옵티시스 추출중...
# 22개 추출완료. 누적1860개
# 89번째 종목 이퓨쳐 추출중...
# 20개 추출완료. 누적1880개
# 90번째 종목 한주라이트메탈 추출중...
# 0개 추출완료. 누적1880개
# 91번째 종목 동화기업 추출중...
# 70개 추출완료. 누적1950개
# 92번째 종목 이지케어텍 추출중...
# 14개 추출완료. 누적1964개
# 93번째 종목 중앙백신 추출중...
# 40개 추출완료. 누적2004개
# 94번째 종목 에스피시스템스 추출중...
# 4개 추출완료. 누적2008개
# 95번째 종목 동일철강 추출중...
# 10개 추출완료. 누적2018개
# 96번째 종목 초록뱀컴퍼니 추출중...
# 20개 추출완료. 누적2038개
# 97번째 종목 이엔코퍼레이션 추출중...
# 31개 추출완료. 누적2069개
# 98번째 종목 파이버프로 추출중...
# 6개 추출완료. 누적2075개
# 99번째 종목 가온칩스 추출중...
# 0개 추출완료. 누적2075개
# 100번째 종목 원익피앤이 추출중...
# 14개 추출완료. 누적2089개
# 101번째 종목 엘엠에스 추출중...
# 29개 추출완료. 누적2118개
# 102번째 종목 켐트로스 추출중...
# 25개 추출완료. 누적2143개
# 103번째 종목 가비아 추출중...
# 11개 추출완료. 누적2154개
# 104번째 종목 파나케이아 추출중...
# 57개 추출완료. 누적2211개
# 105번째 종목 엠브레인 추출중...
# 3개 추출완료. 누적2214개
# 106번째 종목 에스맥 추출중...
# 58개 추출완료. 누적2272개
# 107번째 종목 우주일렉트로 추출중...
# 35개 추출완료. 누적2307개
# 108번째 종목 제일테크노스 추출중...
# 11개 추출완료. 누적2318개
# 109번째 종목 엠아이텍 추출중...
# 4개 추출완료. 누적2322개
# 110번째 종목 우리벤처파트너스 추출중...
# 2개 추출완료. 누적2324개
# 111번째 종목 비덴트 추출중...
# 73개 추출완료. 누적2397개
# 112번째 종목 마이크로디지탈 추출중...
# 21개 추출완료. 누적2418개
# 113번째 종목 싸이버원 추출중...
# 2개 추출완료. 누적2420개
# 114번째 종목 네오이뮨텍 추출중...
# 17개 추출완료. 누적2437개
# 115번째 종목 현대무벡스 추출중...
# 0개 추출완료. 누적2437개
# 116번째 종목 신스틸 추출중...
# 0개 추출완료. 누적2437개
# 117번째 종목 비스토스 추출중...
# 0개 추출완료. 누적2437개
# 118번째 종목 파워넷 추출중...
# 3개 추출완료. 누적2440개
# 119번째 종목 윙스풋 추출중...
# 0개 추출완료. 누적2440개
# 120번째 종목 파인엠텍 추출중...
# 0개 추출완료. 누적2440개
# 121번째 종목 삼륭물산 추출중...
# 12개 추출완료. 누적2452개
# 122번째 종목 제이스텍 추출중...
# 40개 추출완료. 누적2492개
# 123번째 종목 바이넥스 추출중...
# 69개 추출완료. 누적2561개
# 124번째 종목 와토스코리아 추출중...
# 4개 추출완료. 누적2565개
# 125번째 종목 필옵틱스 추출중...
# 25개 추출완료. 누적2590개
# 126번째 종목 모베이스전자 추출중...
# 9개 추출완료. 누적2599개
# 127번째 종목 제넥신 추출중...
# 66개 추출완료. 누적2665개
# 128번째 종목 샤페론 추출중...
# 0개 추출완료. 누적2665개
# 129번째 종목 래몽래인 추출중...
# 7개 추출완료. 누적2672개
# 130번째 종목 에코앤드림 추출중...
# 22개 추출완료. 누적2694개
# 131번째 종목 피코그램 추출중...
# 7개 추출완료. 누적2701개
# 132번째 종목 엠투엔 추출중...
# 37개 추출완료. 누적2738개
# 133번째 종목 풍강 추출중...
# 10개 추출완료. 누적2748개
# 134번째 종목 휴온스 추출중...
# 17개 추출완료. 누적2765개
# 135번째 종목 리튬포어스 추출중...
# 43개 추출완료. 누적2808개
# 136번째 종목 인산가 추출중...
# 2개 추출완료. 누적2810개
# 137번째 종목 플라즈맵 추출중...
# 0개 추출완료. 누적2810개
# 138번째 종목 예스티 추출중...
# 56개 추출완료. 누적2866개
# 139번째 종목 HLB 추출중...
# 106개 추출완료. 누적2972개
# 140번째 종목 흥국 추출중...
# 12개 추출완료. 누적2984개
# 141번째 종목 에스엠코어 추출중...
# 32개 추출완료. 누적3016개
# 142번째 종목 티사이언티픽 추출중...
# 35개 추출완료. 누적3051개
# 143번째 종목 국순당 추출중...
# 15개 추출완료. 누적3066개
# 144번째 종목 이건홀딩스 추출중...
# 13개 추출완료. 누적3079개
# 145번째 종목 피델릭스 추출중...
# 19개 추출완료. 누적3098개
# 146번째 종목 오상자이엘 추출중...
# 29개 추출완료. 누적3127개
# 147번째 종목 대한뉴팜 추출중...
# 46개 추출완료. 누적3173개
# 148번째 종목 골프존 추출중...
# 19개 추출완료. 누적3192개
# 149번째 종목 씨티씨바이오 추출중...
# 45개 추출완료. 누적3237개
# 150번째 종목 신일제약 추출중...
# 33개 추출완료. 누적3270개
# 151번째 종목 바이오스마트 추출중...
# 48개 추출완료. 누적3318개
# 152번째 종목 동국알앤에스 추출중...
# 8개 추출완료. 누적3326개
# 153번째 종목 에이텍모빌리티 추출중...
# 32개 추출완료. 누적3358개
# 154번째 종목 바이오니아 추출중...
# 75개 추출완료. 누적3433개
# 155번째 종목 흥국에프엔비 추출중...
# 9개 추출완료. 누적3442개
# 156번째 종목 올릭스 추출중...
# 38개 추출완료. 누적3480개
# 157번째 종목 에이에프더블류 추출중...
# 8개 추출완료. 누적3488개
# 158번째 종목 리노공업 추출중...
# 24개 추출완료. 누적3512개
# 159번째 종목 에이디엠코리아 추출중...
# 5개 추출완료. 누적3517개
# 160번째 종목 핑거 추출중...
# 5개 추출완료. 누적3522개
# 161번째 종목 신흥에스이씨 추출중...
# 28개 추출완료. 누적3550개
# 162번째 종목 프럼파스트 추출중...
# 28개 추출완료. 누적3578개
# 163번째 종목 팬스타엔터프라이즈 추출중...
# 22개 추출완료. 누적3600개
# 164번째 종목 하츠 추출중...
# 29개 추출완료. 누적3629개
# 165번째 종목 올리패스 추출중...
# 13개 추출완료. 누적3642개
# 166번째 종목 희림 추출중...
# 8개 추출완료. 누적3650개
# 167번째 종목 SBW생명과학 추출중...
# 43개 추출완료. 누적3693개
# 168번째 종목 플레이위드 추출중...
# 32개 추출완료. 누적3725개
# 169번째 종목 상보 추출중...
# 26개 추출완료. 누적3751개
# 170번째 종목 덕신하우징 추출중...
# 24개 추출완료. 누적3775개
# 171번째 종목 디이엔티 추출중...
# 31개 추출완료. 누적3806개
# 172번째 종목 미투젠 추출중...
# 5개 추출완료. 누적3811개
# 173번째 종목 뉴트리 추출중...
# 10개 추출완료. 누적3821개
# 174번째 종목 스튜디오미르 추출중...
# 0개 추출완료. 누적3821개
# 175번째 종목 정원엔시스 추출중...
# 5개 추출완료. 누적3826개
# 176번째 종목 DGP 추출중...
# 42개 추출완료. 누적3868개
# 177번째 종목 에코마케팅 추출중...
# 36개 추출완료. 누적3904개
# 178번째 종목 코데즈컴바인 추출중...
# 12개 추출완료. 누적3916개
# 179번째 종목 아이티센 추출중...
# 27개 추출완료. 누적3943개
# 180번째 종목 에프알텍 추출중...
# 13개 추출완료. 누적3956개
# 181번째 종목 인지소프트 추출중...
# 24개 추출완료. 누적3980개
# 182번째 종목 동우팜투테이블 추출중...
# 8개 추출완료. 누적3988개
# 183번째 종목 인카금융서비스 추출중...
# 0개 추출완료. 누적3988개
# 184번째 종목 아모그린텍 추출중...
# 17개 추출완료. 누적4005개
# 185번째 종목 삼천리자전거 추출중...
# 18개 추출완료. 누적4023개
# 186번째 종목 세진티에스 추출중...
# 15개 추출완료. 누적4038개
# 187번째 종목 에이치피오 추출중...
# 2개 추출완료. 누적4040개
# 188번째 종목 경창산업 추출중...
# 14개 추출완료. 누적4054개
# 189번째 종목 아우딘퓨쳐스 추출중...
# 28개 추출완료. 누적4082개
# 190번째 종목 솔고바이오 추출중...
# 21개 추출완료. 누적4103개
# 191번째 종목 에스제이그룹 추출중...
# 12개 추출완료. 누적4115개
# 192번째 종목 더블유씨피 추출중...
# 0개 추출완료. 누적4115개
# 193번째 종목 MIT 추출중...
# 47개 추출완료. 누적4162개
# 194번째 종목 와이지-원 추출중...
# 25개 추출완료. 누적4187개
# 195번째 종목 창해에탄올 추출중...
# 17개 추출완료. 누적4204개
# 196번째 종목 엔텔스 추출중...
# 35개 추출완료. 누적4239개
# 197번째 종목 코아시아씨엠 추출중...
# 40개 추출완료. 누적4279개
# 198번째 종목 와이아이케이 추출중...
# 28개 추출완료. 누적4307개
# 199번째 종목 시큐센 추출중...
# 0개 추출완료. 누적4307개
# 200번째 종목 아스트 추출중...
# 30개 추출완료. 누적4337개
# 201번째 종목 EDGC 추출중...
# 12개 추출완료. 누적4349개
# 202번째 종목 브이티 추출중...
# 36개 추출완료. 누적4385개
# 203번째 종목 드래곤플라이 추출중...
# 36개 추출완료. 누적4421개
# 204번째 종목 KH바텍 추출중...
# 62개 추출완료. 누적4483개
# 205번째 종목 우진비앤지 추출중...
# 16개 추출완료. 누적4499개
# 206번째 종목 윌링스 추출중...
# 10개 추출완료. 누적4509개
# 207번째 종목 육일씨엔에쓰 추출중...
# 7개 추출완료. 누적4516개
# 208번째 종목 클리오 추출중...
# 28개 추출완료. 누적4544개
# 209번째 종목 메가엠디 추출중...
# 10개 추출완료. 누적4554개
# 210번째 종목 ISC 추출중...
# 54개 추출완료. 누적4608개
# 211번째 종목 한국파마 추출중...
# 5개 추출완료. 누적4613개
# 212번째 종목 모비릭스 추출중...
# 8개 추출완료. 누적4621개
# 213번째 종목 아이윈 추출중...
# 2개 추출완료. 누적4623개
# 214번째 종목 성광벤드 추출중...
# 37개 추출완료. 누적4660개
# 215번째 종목 아시아종묘 추출중...
# 12개 추출완료. 누적4672개
# 216번째 종목 알티캐스트 추출중...
# 15개 추출완료. 누적4687개
# 217번째 종목 팅크웨어 추출중...
# 20개 추출완료. 누적4707개
# 218번째 종목 큐로홀딩스 추출중...
# 10개 추출완료. 누적4717개
# 219번째 종목 인성정보 추출중...
# 29개 추출완료. 누적4746개
# 220번째 종목 중앙에너비스 추출중...
# 2개 추출완료. 누적4748개
# 221번째 종목 본느 추출중...
# 8개 추출완료. 누적4756개
# 222번째 종목 케이프 추출중...
# 16개 추출완료. 누적4772개
# 223번째 종목 이노와이어리스 추출중...
# 46개 추출완료. 누적4818개
# 224번째 종목 케이엠제약 추출중...
# 2개 추출완료. 누적4820개
# 225번째 종목 제이엔케이히터 추출중...
# 24개 추출완료. 누적4844개
# 226번째 종목 플레이디 추출중...
# 5개 추출완료. 누적4849개
# 227번째 종목 엔젯 추출중...
# 0개 추출완료. 누적4849개
# 228번째 종목 오에스피 추출중...
# 0개 추출완료. 누적4849개
# 229번째 종목 삼천당제약 추출중...
# 74개 추출완료. 누적4923개
# 230번째 종목 크루셜텍 추출중...
# 48개 추출완료. 누적4971개
# 231번째 종목 SG&G 추출중...
# 11개 추출완료. 누적4982개
# 232번째 종목 레몬 추출중...
# 6개 추출완료. 누적4988개
# 233번째 종목 꿈비 추출중...
# 0개 추출완료. 누적4988개
# 234번째 종목 오이솔루션 추출중...
# 50개 추출완료. 누적5038개
# 235번째 종목 아이톡시 추출중...
# 42개 추출완료. 누적5080개
# 236번째 종목 지에스이 추출중...
# 9개 추출완료. 누적5089개
# 237번째 종목 서울바이오시스 추출중...
# 4개 추출완료. 누적5093개
# 238번째 종목 포바이포 추출중...
# 5개 추출완료. 누적5098개
# 239번째 종목 우리산업홀딩스 추출중...
# 20개 추출완료. 누적5118개
# 240번째 종목 유바이오로직스 추출중...
# 39개 추출완료. 누적5157개
# 241번째 종목 쎄노텍 추출중...
# 5개 추출완료. 누적5162개
# 242번째 종목 메쎄이상 추출중...
# 0개 추출완료. 누적5162개
# 243번째 종목 베스파 추출중...
# 12개 추출완료. 누적5174개
# 244번째 종목 피에이치씨 추출중...
# 32개 추출완료. 누적5206개
# 245번째 종목 이글루 추출중...
# 4개 추출완료. 누적5210개
# 246번째 종목 비케이홀딩스 추출중...
# 21개 추출완료. 누적5231개
# 247번째 종목 케어젠 추출중...
# 21개 추출완료. 누적5252개
# 248번째 종목 시너지이노베이션 추출중...
# 24개 추출완료. 누적5276개
# 249번째 종목 밸로프 추출중...
# 0개 추출완료. 누적5276개
# 250번째 종목 코렌텍 추출중...
# 23개 추출완료. 누적5299개
# 251번째 종목 제주맥주 추출중...
# 2개 추출완료. 누적5301개
# 252번째 종목 파인테크닉스 추출중...
# 48개 추출완료. 누적5349개
# 253번째 종목 한국큐빅 추출중...
# 11개 추출완료. 누적5360개
# 254번째 종목 바이옵트로 추출중...
# 6개 추출완료. 누적5366개
# 255번째 종목 미디어젠 추출중...
# 2개 추출완료. 누적5368개
# 256번째 종목 휴맥스홀딩스 추출중...
# 1개 추출완료. 누적5369개
# 257번째 종목 신도기연 추출중...
# 4개 추출완료. 누적5373개
# 258번째 종목 와이엠씨 추출중...
# 63개 추출완료. 누적5436개
# 259번째 종목 텔레필드 추출중...
# 23개 추출완료. 누적5459개
# 260번째 종목 고영 추출중...
# 33개 추출완료. 누적5492개
# 261번째 종목 티피씨글로벌 추출중...
# 15개 추출완료. 누적5507개
# 262번째 종목 아진엑스텍 추출중...
# 44개 추출완료. 누적5551개
# 263번째 종목 이엠앤아이 추출중...
# 32개 추출완료. 누적5583개
# 264번째 종목 윙입푸드 추출중...
# 2개 추출완료. 누적5585개
# 265번째 종목 아이윈플러스 추출중...
# 28개 추출완료. 누적5613개
# 266번째 종목 유성티엔에스 추출중...
# 15개 추출완료. 누적5628개
# 267번째 종목 GRT 추출중...
# 6개 추출완료. 누적5634개
# 268번째 종목 아이진 추출중...
# 81개 추출완료. 누적5715개
# 269번째 종목 오션브릿지 추출중...
# 21개 추출완료. 누적5736개
# 270번째 종목 듀오백 추출중...
# 12개 추출완료. 누적5748개
# 271번째 종목 핸디소프트 추출중...
# 7개 추출완료. 누적5755개
# 272번째 종목 수성샐바시온 추출중...
# 26개 추출완료. 누적5781개
# 273번째 종목 DSEN 추출중...
# 23개 추출완료. 누적5804개
# 274번째 종목 케이엔솔 추출중...
# 4개 추출완료. 누적5808개
# 275번째 종목 코아시아 추출중...
# 11개 추출완료. 누적5819개
# 276번째 종목 HB테크놀러지 추출중...
# 68개 추출완료. 누적5887개
# 277번째 종목 오비고 추출중...
# 1개 추출완료. 누적5888개
# 278번째 종목 디딤이앤에프 추출중...
# 5개 추출완료. 누적5893개
# 279번째 종목 캠시스 추출중...
# 19개 추출완료. 누적5912개
# 280번째 종목 나인테크 추출중...
# 5개 추출완료. 누적5917개
# 281번째 종목 코디 추출중...
# 18개 추출완료. 누적5935개
# 282번째 종목 에이디테크놀로지 추출중...
# 42개 추출완료. 누적5977개
# 283번째 종목 피에이치에이 추출중...
# 24개 추출완료. 누적6001개
# 284번째 종목 오로스테크놀로지 추출중...
# 12개 추출완료. 누적6013개
# 285번째 종목 메타바이오메드 추출중...
# 19개 추출완료. 누적6032개
# 286번째 종목 제이아이테크 추출중...
# 0개 추출완료. 누적6032개
# 287번째 종목 딜리 추출중...
# 13개 추출완료. 누적6045개
# 288번째 종목 이씨에스 추출중...
# 6개 추출완료. 누적6051개
# 289번째 종목 유니테스트 추출중...
# 88개 추출완료. 누적6139개
# 290번째 종목 베뉴지 추출중...
# 8개 추출완료. 누적6147개
# 291번째 종목 큐에스아이 추출중...
# 16개 추출완료. 누적6163개
# 292번째 종목 코리아에프티 추출중...
# 19개 추출완료. 누적6182개
# 293번째 종목 와이솔 추출중...
# 28개 추출완료. 누적6210개
# 294번째 종목 심텍 추출중...
# 35개 추출완료. 누적6245개
# 295번째 종목 엔에프씨 추출중...
# 3개 추출완료. 누적6248개
# 296번째 종목 이큐셀 추출중...
# 10개 추출완료. 누적6258개
# 297번째 종목 신테카바이오 추출중...
# 20개 추출완료. 누적6278개
# 298번째 종목 CMG제약 추출중...
# 48개 추출완료. 누적6326개
# 299번째 종목 셀트리온헬스케어 추출중...
# 26개 추출완료. 누적6352개
# 300번째 종목 조광ILI 추출중...
# 14개 추출완료. 누적6366개
# 301번째 종목 에스유홀딩스 추출중...
# 72개 추출완료. 누적6438개
# 302번째 종목 에이텍 추출중...
# 34개 추출완료. 누적6472개
# 303번째 종목 디와이씨 추출중...
# 5개 추출완료. 누적6477개
# 304번째 종목 잉크테크 추출중...
# 17개 추출완료. 누적6494개
# 305번째 종목 태양 추출중...
# 5개 추출완료. 누적6499개
# 306번째 종목 테스 추출중...
# 59개 추출완료. 누적6558개
# 307번째 종목 보광산업 추출중...
# 15개 추출완료. 누적6573개
# 308번째 종목 세명전기 추출중...
# 37개 추출완료. 누적6610개
# 309번째 종목 엑셈 추출중...
# 24개 추출완료. 누적6634개
# 310번째 종목 진로발효 추출중...
# 3개 추출완료. 누적6637개
# 311번째 종목 압타바이오 추출중...
# 31개 추출완료. 누적6668개
# 312번째 종목 세경하이테크 추출중...
# 12개 추출완료. 누적6680개
# 313번째 종목 스카이문스테크놀로지 추출중...
# 15개 추출완료. 누적6695개
# 314번째 종목 테고사이언스 추출중...
# 40개 추출완료. 누적6735개
# 315번째 종목 한국비엔씨 추출중...
# 36개 추출완료. 누적6771개
# 316번째 종목 이스트아시아홀딩스 추출중...
# 17개 추출완료. 누적6788개
# 317번째 종목 로보로보 추출중...
# 7개 추출완료. 누적6795개
# 318번째 종목 케이엠 추출중...
# 10개 추출완료. 누적6805개
# 319번째 종목 세림B&G 추출중...
# 0개 추출완료. 누적6805개
# 320번째 종목 엔터파트너즈 추출중...
# 25개 추출완료. 누적6830개
# 321번째 종목 정상제이엘에스 추출중...
# 4개 추출완료. 누적6834개
# 322번째 종목 디지틀조선 추출중...
# 20개 추출완료. 누적6854개
# 323번째 종목 코스텍시스 추출중...
# 0개 추출완료. 누적6854개
# 324번째 종목 오텍 추출중...
# 28개 추출완료. 누적6882개
# 325번째 종목 KCI 추출중...
# 30개 추출완료. 누적6912개
# 326번째 종목 대림제지 추출중...
# 16개 추출완료. 누적6928개
# 327번째 종목 씨아이에스 추출중...
# 19개 추출완료. 누적6947개
# 328번째 종목 제넨바이오 추출중...
# 60개 추출완료. 누적7007개
# 329번째 종목 알체라 추출중...
# 12개 추출완료. 누적7019개
# 330번째 종목 디지털대성 추출중...
# 8개 추출완료. 누적7027개
# 331번째 종목 대동기어 추출중...
# 2개 추출완료. 누적7029개
# 332번째 종목 세종메디칼 추출중...
# 14개 추출완료. 누적7043개
# 333번째 종목 티쓰리 추출중...
# 0개 추출완료. 누적7043개
# 334번째 종목 티에스이 추출중...
# 40개 추출완료. 누적7083개
# 335번째 종목 인트론바이오 추출중...
# 101개 추출완료. 누적7184개
# 336번째 종목 브이원텍 추출중...
# 25개 추출완료. 누적7209개
# 337번째 종목 케이아이엔엑스 추출중...
# 35개 추출완료. 누적7244개
# 338번째 종목 주성엔지니어링 추출중...
# 40개 추출완료. 누적7284개
# 339번째 종목 제이에스티나 추출중...
# 46개 추출완료. 누적7330개
# 340번째 종목 삼목에스폼 추출중...
# 36개 추출완료. 누적7366개
# 341번째 종목 잉글우드랩 추출중...
# 24개 추출완료. 누적7390개
# 342번째 종목 아이크래프트 추출중...
# 35개 추출완료. 누적7425개
# 343번째 종목 웨이버스 추출중...
# 5개 추출완료. 누적7430개
# 344번째 종목 유니테크노 추출중...
# 15개 추출완료. 누적7445개
# 345번째 종목 KT서브마린 추출중...
# 12개 추출완료. 누적7457개
# 346번째 종목 아이엠 추출중...
# 43개 추출완료. 누적7500개
# 347번째 종목 와이지엔터테인먼트 추출중...
# 52개 추출완료. 누적7552개
# 348번째 종목 씨엔알리서치 추출중...
# 2개 추출완료. 누적7554개
# 349번째 종목 남화토건 추출중...
# 26개 추출완료. 누적7580개
# 350번째 종목 레인보우로보틱스 추출중...
# 4개 추출완료. 누적7584개
# 351번째 종목 파워로직스 추출중...
# 30개 추출완료. 누적7614개
# 352번째 종목 크린앤사이언스 추출중...
# 30개 추출완료. 누적7644개
# 353번째 종목 대성하이텍 추출중...
# 0개 추출완료. 누적7644개
# 354번째 종목 한일단조 추출중...
# 5개 추출완료. 누적7649개
# 355번째 종목 피에스케이홀딩스 추출중...
# 38개 추출완료. 누적7687개
# 356번째 종목 중앙디앤엠 추출중...
# 45개 추출완료. 누적7732개
# 357번째 종목 스톤브릿지벤처스 추출중...
# 1개 추출완료. 누적7733개
# 358번째 종목 상상인 추출중...
# 49개 추출완료. 누적7782개
# 359번째 종목 예스24 추출중...
# 22개 추출완료. 누적7804개
# 360번째 종목 엔피케이 추출중...
# 7개 추출완료. 누적7811개
# 361번째 종목 대원 추출중...
# 10개 추출완료. 누적7821개
# 362번째 종목 위닉스 추출중...
# 49개 추출완료. 누적7870개
# 363번째 종목 미코 추출중...
# 32개 추출완료. 누적7902개
# 364번째 종목 인트로메딕 추출중...
# 64개 추출완료. 누적7966개
# 365번째 종목 팜스빌 추출중...
# 14개 추출완료. 누적7980개
# 366번째 종목 파라다이스 추출중...
# 29개 추출완료. 누적8009개
# 367번째 종목 시공테크 추출중...
# 33개 추출완료. 누적8042개
# 368번째 종목 휴먼엔 추출중...
# 19개 추출완료. 누적8061개
# 369번째 종목 아스타 추출중...
# 15개 추출완료. 누적8076개
# 370번째 종목 이오테크닉스 추출중...
# 57개 추출완료. 누적8133개
# 371번째 종목 셀리버리 추출중...
# 47개 추출완료. 누적8180개
# 372번째 종목 디아이티 추출중...
# 11개 추출완료. 누적8191개
# 373번째 종목 대주산업 추출중...
# 21개 추출완료. 누적8212개
# 374번째 종목 iMBC 추출중...
# 10개 추출완료. 누적8222개
# 375번째 종목 데이타솔루션 추출중...
# 2개 추출완료. 누적8224개
# 376번째 종목 더블유에스아이 추출중...
# 2개 추출완료. 누적8226개
# 377번째 종목 케이피에프 추출중...
# 10개 추출완료. 누적8236개
# 378번째 종목 한탑 추출중...
# 15개 추출완료. 누적8251개
# 379번째 종목 헬릭스미스 추출중...
# 78개 추출완료. 누적8329개
# 380번째 종목 테크윙 추출중...
# 54개 추출완료. 누적8383개
# 381번째 종목 세토피아 추출중...
# 12개 추출완료. 누적8395개
# 382번째 종목 프로텍 추출중...
# 22개 추출완료. 누적8417개
# 383번째 종목 SGA 추출중...
# 13개 추출완료. 누적8430개
# 384번째 종목 화신정공 추출중...
# 6개 추출완료. 누적8436개
# 385번째 종목 코윈테크 추출중...
# 9개 추출완료. 누적8445개
# 386번째 종목 제놀루션 추출중...
# 8개 추출완료. 누적8453개
# 387번째 종목 솔트웨어 추출중...
# 0개 추출완료. 누적8453개
# 388번째 종목 초록뱀미디어 추출중...
# 33개 추출완료. 누적8486개
# 389번째 종목 이즈미디어 추출중...
# 32개 추출완료. 누적8518개
# 390번째 종목 파인텍 추출중...
# 28개 추출완료. 누적8546개
# 391번째 종목 NE능률 추출중...
# 9개 추출완료. 누적8555개
# 392번째 종목 엔투텍 추출중...
# 21개 추출완료. 누적8576개
# 393번째 종목 케이피에스 추출중...
# 23개 추출완료. 누적8599개
# 394번째 종목 효성오앤비 추출중...
# 25개 추출완료. 누적8624개
# 395번째 종목 강스템바이오텍 추출중...
# 50개 추출완료. 누적8674개
# 396번째 종목 홈센타홀딩스 추출중...
# 15개 추출완료. 누적8689개
# 397번째 종목 에이프릴바이오 추출중...
# 0개 추출완료. 누적8689개
# 398번째 종목 라이트론 추출중...
# 15개 추출완료. 누적8704개
# 399번째 종목 성우하이텍 추출중...
# 18개 추출완료. 누적8722개
# 400번째 종목 아이엘사이언스 추출중...
# 10개 추출완료. 누적8732개
# 401번째 종목 에스씨엠생명과학 추출중...
# 15개 추출완료. 누적8747개
# 402번째 종목 제이엘케이 추출중...
# 5개 추출완료. 누적8752개
# 403번째 종목 삼일기업공사 추출중...
# 9개 추출완료. 누적8761개
# 404번째 종목 천보 추출중...
# 23개 추출완료. 누적8784개
# 405번째 종목 이랜시스 추출중...
# 2개 추출완료. 누적8786개
# 406번째 종목 큐렉소 추출중...
# 43개 추출완료. 누적8829개
# 407번째 종목 진매트릭스 추출중...
# 30개 추출완료. 누적8859개
# 408번째 종목 SM C&C 추출중...
# 30개 추출완료. 누적8889개
# 409번째 종목 한솔인티큐브 추출중...
# 12개 추출완료. 누적8901개
# 410번째 종목 유비쿼스홀딩스 추출중...
# 37개 추출완료. 누적8938개
# 411번째 종목 티앤엘 추출중...
# 5개 추출완료. 누적8943개
# 412번째 종목 퓨런티어 추출중...
# 0개 추출완료. 누적8943개
# 413번째 종목 씨유메디칼 추출중...
# 26개 추출완료. 누적8969개
# 414번째 종목 다원시스 추출중...
# 47개 추출완료. 누적9016개
# 415번째 종목 씨앤씨인터내셔널 추출중...
# 6개 추출완료. 누적9022개
# 416번째 종목 삼양옵틱스 추출중...
# 4개 추출완료. 누적9026개
# 417번째 종목 코스맥스엔비티 추출중...
# 33개 추출완료. 누적9059개
# 418번째 종목 JTC 추출중...
# 15개 추출완료. 누적9074개
# 419번째 종목 CNT85 추출중...
# 40개 추출완료. 누적9114개
# 420번째 종목 마녀공장 추출중...
# 0개 추출완료. 누적9114개
# 421번째 종목 덕산하이메탈 추출중...
# 22개 추출완료. 누적9136개
# 422번째 종목 원텍 추출중...
# 2개 추출완료. 누적9138개
# 423번째 종목 에스티아이 추출중...
# 70개 추출완료. 누적9208개
# 424번째 종목 에스트래픽 추출중...
# 13개 추출완료. 누적9221개
# 425번째 종목 유진로봇 추출중...
# 21개 추출완료. 누적9242개
# 426번째 종목 지아이이노베이션 추출중...
# 0개 추출완료. 누적9242개
# 427번째 종목 지니뮤직 추출중...
# 39개 추출완료. 누적9281개
# 428번째 종목 에프앤가이드 추출중...
# 5개 추출완료. 누적9286개
# 429번째 종목 멕아이씨에스 추출중...
# 33개 추출완료. 누적9319개
# 430번째 종목 퀀타매트릭스 추출중...
# 6개 추출완료. 누적9325개
# 431번째 종목 휴림네트웍스 추출중...
# 12개 추출완료. 누적9337개
# 432번째 종목 SDN 추출중...
# 11개 추출완료. 누적9348개
# 433번째 종목 포스코DX 추출중...
# 16개 추출완료. 누적9364개
# 434번째 종목 그린플러스 추출중...
# 13개 추출완료. 누적9377개
# 435번째 종목 탑코미디어 추출중...
# 13개 추출완료. 누적9390개
# 436번째 종목 씨큐브 추출중...
# 11개 추출완료. 누적9401개
# 437번째 종목 뷰노 추출중...
# 3개 추출완료. 누적9404개
# 438번째 종목 쇼박스 추출중...
# 40개 추출완료. 누적9444개
# 439번째 종목 엠에프엠코리아 추출중...
# 2개 추출완료. 누적9446개
# 440번째 종목 동운아나텍 추출중...
# 52개 추출완료. 누적9498개
# 441번째 종목 에스앤디 추출중...
# 4개 추출완료. 누적9502개
# 442번째 종목 아모텍 추출중...
# 63개 추출완료. 누적9565개
# 443번째 종목 성창오토텍 추출중...
# 20개 추출완료. 누적9585개
# 444번째 종목 새빗켐 추출중...
# 0개 추출완료. 누적9585개
# 445번째 종목 윈팩 추출중...
# 34개 추출완료. 누적9619개
# 446번째 종목 티이엠씨 추출중...
# 0개 추출완료. 누적9619개
# 447번째 종목 오리엔트정공 추출중...
# 18개 추출완료. 누적9637개
# 448번째 종목 딥노이드 추출중...
# 7개 추출완료. 누적9644개
# 449번째 종목 디앤씨미디어 추출중...
# 18개 추출완료. 누적9662개
# 450번째 종목 알에프텍 추출중...
# 44개 추출완료. 누적9706개
# 451번째 종목 모트렉스 추출중...
# 15개 추출완료. 누적9721개
# 452번째 종목 테라젠이텍스 추출중...
# 49개 추출완료. 누적9770개
# 453번째 종목 이엔에프테크놀로지 추출중...
# 53개 추출완료. 누적9823개
# 454번째 종목 한네트 추출중...
# 14개 추출완료. 누적9837개
# 455번째 종목 경동제약 추출중...
# 8개 추출완료. 누적9845개
# 456번째 종목 슈프리마 추출중...
# 27개 추출완료. 누적9872개
# 457번째 종목 엔시스 추출중...
# 3개 추출완료. 누적9875개
# 458번째 종목 서울반도체 추출중...
# 36개 추출완료. 누적9911개
# 459번째 종목 에이디칩스 추출중...
# 34개 추출완료. 누적9945개
# 460번째 종목 코메론 추출중...
# 23개 추출완료. 누적9968개
# 461번째 종목 AP시스템 추출중...
# 29개 추출완료. 누적9997개
# 462번째 종목 자연과환경 추출중...
# 26개 추출완료. 누적10023개
# 463번째 종목 티씨케이 추출중...
# 65개 추출완료. 누적10088개
# 464번째 종목 유틸렉스 추출중...
# 26개 추출완료. 누적10114개
# 465번째 종목 하이로닉 추출중...
# 29개 추출완료. 누적10143개
# 466번째 종목 카이노스메드 추출중...
# 14개 추출완료. 누적10157개
# 467번째 종목 금강철강 추출중...
# 5개 추출완료. 누적10162개
# 468번째 종목 삼보모터스 추출중...
# 20개 추출완료. 누적10182개
# 469번째 종목 프로이천 추출중...
# 0개 추출완료. 누적10182개
# 470번째 종목 카스 추출중...
# 3개 추출완료. 누적10185개
# 471번째 종목 제이씨케미칼 추출중...
# 15개 추출완료. 누적10200개
# 472번째 종목 아가방컴퍼니 추출중...
# 28개 추출완료. 누적10228개
# 473번째 종목 형지I&C 추출중...
# 22개 추출완료. 누적10250개
# 474번째 종목 디오 추출중...
# 39개 추출완료. 누적10289개
# 475번째 종목 대주전자재료 추출중...
# 70개 추출완료. 누적10359개
# 476번째 종목 펩트론 추출중...
# 49개 추출완료. 누적10408개
# 477번째 종목 현대공업 추출중...
# 15개 추출완료. 누적10423개
# 478번째 종목 셀레믹스 추출중...
# 5개 추출완료. 누적10428개
# 479번째 종목 신원종합개발 추출중...
# 32개 추출완료. 누적10460개
# 480번째 종목 HLB생명과학 추출중...
# 75개 추출완료. 누적10535개
# 481번째 종목 알테오젠 추출중...
# 82개 추출완료. 누적10617개
# 482번째 종목 삼진엘앤디 추출중...
# 13개 추출완료. 누적10630개
# 483번째 종목 광진실업 추출중...
# 8개 추출완료. 누적10638개
# 484번째 종목 YBM넷 추출중...
# 10개 추출완료. 누적10648개
# 485번째 종목 린드먼아시아 추출중...
# 4개 추출완료. 누적10652개
# 486번째 종목 인터엠 추출중...
# 11개 추출완료. 누적10663개
# 487번째 종목 원익머트리얼즈 추출중...
# 29개 추출완료. 누적10692개
# 488번째 종목 케이엔제이 추출중...
# 12개 추출완료. 누적10704개
# 489번째 종목 동양이엔피 추출중...
# 18개 추출완료. 누적10722개
# 490번째 종목 제노레이 추출중...
# 6개 추출완료. 누적10728개
# 491번째 종목 상신이디피 추출중...
# 37개 추출완료. 누적10765개
# 492번째 종목 네온테크 추출중...
# 5개 추출완료. 누적10770개
# 493번째 종목 아이큐어 추출중...
# 16개 추출완료. 누적10786개
# 494번째 종목 국전약품 추출중...
# 9개 추출완료. 누적10795개
# 495번째 종목 펨트론 추출중...
# 0개 추출완료. 누적10795개
# 496번째 종목 다날 추출중...
# 23개 추출완료. 누적10818개
# 497번째 종목 토비스 추출중...
# 24개 추출완료. 누적10842개
# 498번째 종목 캐스텍코리아 추출중...
# 18개 추출완료. 누적10860개
# 499번째 종목 아톤 추출중...
# 13개 추출완료. 누적10873개
# 500번째 종목 대동스틸 추출중...
# 31개 추출완료. 누적10904개
# 501번째 종목 삼성전자 추출중...
# 6개 추출완료. 누적10910개
# 502번째 종목 LG화학 추출중...
# 38개 추출완료. 누적10948개
# 503번째 종목 SK하이닉스 추출중...
# 17개 추출완료. 누적10965개
# 504번째 종목 삼성바이오로직스 추출중...
# 18개 추출완료. 누적10983개
# 505번째 종목 삼성전자우 추출중...
# 4개 추출완료. 누적10987개
# 506번째 종목 LG화학우 추출중...
# 22개 추출완료. 누적11009개
# 507번째 종목 삼성SDI 추출중...
# 34개 추출완료. 누적11043개
# 508번째 종목 현대차 추출중...
# 12개 추출완료. 누적11055개
# 509번째 종목 효성화학 추출중...
# 8개 추출완료. 누적11063개
# 510번째 종목 에코프로비엠 추출중...
# 25개 추출완료. 누적11088개
# 511번째 종목 기아 추출중...
# 12개 추출완료. 누적11100개
# 512번째 종목 에코프로 추출중...
# 80개 추출완료. 누적11180개
# 513번째 종목 카카오 추출중...
# 29개 추출완료. 누적11209개
# 514번째 종목 셀트리온 추출중...
# 21개 추출완료. 누적11230개
# 515번째 종목 현대모비스 추출중...
# 13개 추출완료. 누적11243개
# 516번째 종목 KB금융 추출중...
# 4개 추출완료. 누적11247개
# 517번째 종목 삼성물산 추출중...
# 11개 추출완료. 누적11258개
# 518번째 종목 신한지주 추출중...
# 3개 추출완료. 누적11261개
# 519번째 종목 SK이노베이션 추출중...
# 33개 추출완료. 누적11294개
# 520번째 종목 LG전자 추출중...
# 20개 추출완료. 누적11314개
# 521번째 종목 대우조선해양 추출중...
# 26개 추출완료. 누적11340개
# 522번째 종목 삼성생명 추출중...
# 6개 추출완료. 누적11346개
# 523번째 종목 카카오뱅크 추출중...
# 13개 추출완료. 누적11359개
# 524번째 종목 LG 추출중...
# 9개 추출완료. 누적11368개
# 525번째 종목 한국전력 추출중...
# 15개 추출완료. 누적11383개
# 526번째 종목 삼성화재 추출중...
# 5개 추출완료. 누적11388개
# 527번째 종목 KT&G 추출중...
# 2개 추출완료. 누적11390개
# 528번째 종목 셀트리온헬스케어 추출중...
# 29개 추출완료. 누적11419개
# 529번째 종목 삼성전기 추출중...
# 30개 추출완료. 누적11449개
# 530번째 종목 하나금융지주 추출중...
# 14개 추출완료. 누적11463개
# 531번째 종목 SK 추출중...
# 13개 추출완료. 누적11476개
# 532번째 종목 솔루스첨단소재 추출중...
# 24개 추출완료. 누적11500개
# 533번째 종목 하이브 추출중...
# 16개 추출완료. 누적11516개
# 534번째 종목 삼성에스디에스 추출중...
# 10개 추출완료. 누적11526개
# 535번째 종목 KODEX 레버리지 추출중...
# 13개 추출완료. 누적11539개
# 536번째 종목 SK텔레콤 추출중...
# 3개 추출완료. 누적11542개
# 537번째 종목 고려아연 추출중...
# 10개 추출완료. 누적11552개
# 538번째 종목 케이씨케미칼 추출중...
# 11개 추출완료. 누적11563개
# 539번째 종목 대한항공 추출중...
# 17개 추출완료. 누적11580개
# 540번째 종목 S-Oil 추출중...
# 19개 추출완료. 누적11599개
# 541번째 종목 현대글로비스 추출중...
# 20개 추출완료. 누적11619개
# 542번째 종목 크래프톤 추출중...
# 5개 추출완료. 누적11624개
# 543번째 종목 기업은행 추출중...
# 4개 추출완료. 누적11628개
# 544번째 종목 케이티 추출중...
# 2개 추출완료. 누적11630개
# 545번째 종목 우리금융지주 추출중...
# 0개 추출완료. 누적11630개
# 546번째 종목 삼성중공업 추출중...
# 29개 추출완료. 누적11659개
# 547번째 종목 아모레퍼시픽 추출중...
# 44개 추출완료. 누적11703개
# 548번째 종목 LG생활건강 추출중...
# 32개 추출완료. 누적11735개
# 549번째 종목 삼성엔지니어링 추출중...
# 43개 추출완료. 누적11778개
# 550번째 종목 KODEX 코스닥 150 레버리지 추출중...
# 53개 추출완료. 누적11831개
# 551번째 종목 롯데케미칼 추출중...
# 28개 추출완료. 누적11859개
# 552번째 종목 유한양행 추출중...
# 16개 추출완료. 누적11875개
# 553번째 종목 한화에어로스페이스 추출중...
# 47개 추출완료. 누적11922개
# 554번째 종목 엔씨소프트 추출중...
# 28개 추출완료. 누적11950개
# 555번째 종목 두산밥캣 추출중...
# 10개 추출완료. 누적11960개
# 556번째 종목 DB손해보험 추출중...
# 8개 추출완료. 누적11968개
# 557번째 종목 한온시스템 추출중...
# 27개 추출완료. 누적11995개
# 558번째 종목 LG디스플레이 추출중...
# 23개 추출완료. 누적12018개
# 559번째 종목 HD현대 추출중...
# 14개 추출완료. 누적12032개
# 560번째 종목 맥쿼리인프라 추출중...
# 1개 추출완료. 누적12033개
# 561번째 종목 코스모신소재 추출중...
# 68개 추출완료. 누적12101개
# 562번째 종목 오리온 추출중...
# 9개 추출완료. 누적12110개
# 563번째 종목 현대제철 추출중...
# 24개 추출완료. 누적12134개
# 564번째 종목 CJ제일제당 추출중...
# 13개 추출완료. 누적12147개
# 565번째 종목 한국항공우주 추출중...
# 29개 추출완료. 누적12176개
# 566번째 종목 한미반도체 추출중...
# 35개 추출완료. 누적12211개
# 567번째 종목 LG유플러스 추출중...
# 7개 추출완료. 누적12218개
# 568번째 종목 현대오토에버 추출중...
# 14개 추출완료. 누적12232개
# 569번째 종목 미래에셋증권 추출중...
# 20개 추출완료. 누적12252개
# 570번째 종목 F&F홀딩스 추출중...
# 80개 추출완료. 누적12332개
# 571번째 종목 넷마블 추출중...
# 26개 추출완료. 누적12358개
# 572번째 종목 한미약품 추출중...
# 38개 추출완료. 누적12396개
# 573번째 종목 현대건설 추출중...
# 29개 추출완료. 누적12425개
# 574번째 종목 현대미포조선 추출중...
# 52개 추출완료. 누적12477개
# 575번째 종목 LS 추출중...
# 23개 추출완료. 누적12500개
# 576번째 종목 GS 추출중...
# 2개 추출완료. 누적12502개
# 577번째 종목 금호석유 추출중...
# 28개 추출완료. 누적12530개
# 578번째 종목 강원랜드 추출중...
# 9개 추출완료. 누적12539개
# 579번째 종목 호텔신라 추출중...
# 44개 추출완료. 누적12583개
# 580번째 종목 NH투자증권 추출중...
# 14개 추출완료. 누적12597개
# 581번째 종목 한진칼 추출중...
# 48개 추출완료. 누적12645개
# 582번째 종목 삼성증권 추출중...
# 9개 추출완료. 누적12654개
# 583번째 종목 현대로템 추출중...
# 35개 추출완료. 누적12689개
# 584번째 종목 코웨이 추출중...
# 14개 추출완료. 누적12703개
# 585번째 종목 BGF리테일 추출중...
# 12개 추출완료. 누적12715개
# 586번째 종목 씨에스윈드 추출중...
# 55개 추출완료. 누적12770개
# 587번째 종목 한국금융지주 추출중...
# 22개 추출완료. 누적12792개
# 588번째 종목 아모레G 추출중...
# 37개 추출완료. 누적12829개
# 589번째 종목 한미사이언스 추출중...
# 57개 추출완료. 누적12886개
# 590번째 종목 롯데지주 추출중...
# 13개 추출완료. 누적12899개

# %%
print(len(train_result))
print(sum([low[1] for low in train_result]))
# Out:
# 12899
# 7364

# %%
def get_same_labelnum(result, num):

    # 라벨별로 이미지 데이터 분리
    label0_images = [image_data for image_data, label in result if label == 0]
    label1_images = [image_data for image_data, label in result if label == 1]

    # 각 라벨에서 랜덤하게 5,000개씩 뽑기
    random_label0_images = random.sample(label0_images, num)
    random_label1_images = random.sample(label1_images, num)

    # 뽑은 이미지 데이터와 라벨을 다시 묶기
    new_label0_result = [(image_data, 0) for image_data in random_label0_images]
    new_label1_result = [(image_data, 1) for image_data in random_label1_images]

    # 두 결과를 번갈아가면서 합치기
    result = [t for pair in zip(new_label0_result, new_label1_result) for t in pair]
    return result

# %%
train_result = get_same_labelnum(train_result, 5000)
train_images, train_labels = zip(*train_result)
print(sum(train_labels))
np.save('train_images.npy', train_images)
np.save('train_labels.npy', train_labels)
# Out:
# 5000

# %%
test_result = []
for i, ticker in enumerate(stock_codes):
    code, name = ticker[0], ticker[1]
    print(f"{i+1}번째 종목 {name} 추출중...   ")
    try:
        data = preprocess_data(fdr.DataReader(code, "2022-10-15"))  # 각 종목의 데이터 가져오기
        images = convert_image(data, 300, day_num, 0.1, test=True)
        test_result += images
        print(f"{len(images)}개 추출완료. 누적{len(test_result)}개")
    except IndexError:
        print(f"{name}에서 IndexError가 발생했습니다. 다음 종목으로 이동합니다.")
        continue
# Out:
# 1번째 종목 셀트리온제약 추출중...
# 29개 추출완료. 누적29개
# 2번째 종목 엔바이오니아 추출중...
# 34개 추출완료. 누적63개
# 3번째 종목 엘컴텍 추출중...
# 14개 추출완료. 누적77개
# 4번째 종목 다우데이타 추출중...
# 29개 추출완료. 누적106개
# 5번째 종목 비씨월드제약 추출중...
# 44개 추출완료. 누적150개
# 6번째 종목 CNH 추출중...
# 19개 추출완료. 누적169개
# 7번째 종목 지란지교시큐리티 추출중...
# 39개 추출완료. 누적208개
# 8번째 종목 서남 추출중...
# 18개 추출완료. 누적226개
# 9번째 종목 하나머티리얼즈 추출중...
# 39개 추출완료. 누적265개
# 10번째 종목 저스템 추출중...
# 41개 추출완료. 누적306개
# 11번째 종목 카나리아바이오 추출중...
# 35개 추출완료. 누적341개
# 12번째 종목 큐로컴 추출중...
# 18개 추출완료. 누적359개
# 13번째 종목 애니플러스 추출중...
# 44개 추출완료. 누적403개
# 14번째 종목 이상네트웍스 추출중...
# 37개 추출완료. 누적440개
# 15번째 종목 손오공 추출중...
# 37개 추출완료. 누적477개
# 16번째 종목 TS트릴리온 추출중...
# 28개 추출완료. 누적505개
# 17번째 종목 지노믹트리 추출중...
# 32개 추출완료. 누적537개
# 18번째 종목 에이팩트 추출중...
# 21개 추출완료. 누적558개
# 19번째 종목 마이크로투나노 추출중...
# 0개 추출완료. 누적558개
# 20번째 종목 셀바이오휴먼텍 추출중...
# 0개 추출완료. 누적558개
# 21번째 종목 피제이전자 추출중...
# 29개 추출완료. 누적587개
# 22번째 종목 그리티 추출중...
# 43개 추출완료. 누적630개
# 23번째 종목 세화피앤씨 추출중...
# 40개 추출완료. 누적670개
# 24번째 종목 애니젠 추출중...
# 30개 추출완료. 누적700개
# 25번째 종목 에이치엘사이언스 추출중...
# 25개 추출완료. 누적725개
# 26번째 종목 연우 추출중...
# 22개 추출완료. 누적747개
# 27번째 종목 아이오케이 추출중...
# 16개 추출완료. 누적763개
# 28번째 종목 네오셈 추출중...
# 29개 추출완료. 누적792개
# 29번째 종목 나노 추출중...
# 15개 추출완료. 누적807개
# 30번째 종목 비엘 추출중...
# 30개 추출완료. 누적837개
# 31번째 종목 티에프이 추출중...
# 0개 추출완료. 누적837개
# 32번째 종목 우리기술 추출중...
# 16개 추출완료. 누적853개
# 33번째 종목 슈피겐코리아 추출중...
# 45개 추출완료. 누적898개
# 34번째 종목 인텍플러스 추출중...
# 33개 추출완료. 누적931개
# 35번째 종목 농우바이오 추출중...
# 37개 추출완료. 누적968개
# 36번째 종목 루멘스 추출중...
# 18개 추출완료. 누적986개
# 37번째 종목 NHN벅스 추출중...
# 10개 추출완료. 누적996개
# 38번째 종목 골든센츄리 추출중...
# 32개 추출완료. 누적1028개
# 39번째 종목 아프리카TV 추출중...
# 39개 추출완료. 누적1067개
# 40번째 종목 모니터랩 추출중...
# 0개 추출완료. 누적1067개
# 41번째 종목 일신바이오 추출중...
# 14개 추출완료. 누적1081개
# 42번째 종목 LB인베스트먼트 추출중...
# 0개 추출완료. 누적1081개
# 43번째 종목 바디텍메드 추출중...
# 19개 추출완료. 누적1100개
# 44번째 종목 코리아에셋투자증권 추출중...
# 18개 추출완료. 누적1118개
# 45번째 종목 어보브반도체 추출중...
# 28개 추출완료. 누적1146개
# 46번째 종목 AP위성 추출중...
# 35개 추출완료. 누적1181개
# 47번째 종목 대한과학 추출중...
# 32개 추출완료. 누적1213개
# 48번째 종목 앱클론 추출중...
# 22개 추출완료. 누적1235개
# 49번째 종목 좋은사람들 추출중...
# 0개 추출완료. 누적1235개
# 50번째 종목 블레이드 Ent 추출중...
# 14개 추출완료. 누적1249개
# 51번째 종목 샘씨엔에스 추출중...
# 16개 추출완료. 누적1265개
# 52번째 종목 SCI평가정보 추출중...
# 32개 추출완료. 누적1297개
# 53번째 종목 하림 추출중...
# 43개 추출완료. 누적1340개
# 54번째 종목 한국정보인증 추출중...
# 24개 추출완료. 누적1364개
# 55번째 종목 매커스 추출중...
# 24개 추출완료. 누적1388개
# 56번째 종목 SGC이테크건설 추출중...
# 44개 추출완료. 누적1432개
# 57번째 종목 감성코퍼레이션 추출중...
# 38개 추출완료. 누적1470개
# 58번째 종목 지아이텍 추출중...
# 18개 추출완료. 누적1488개
# 59번째 종목 뉴프렉스 추출중...
# 42개 추출완료. 누적1530개
# 60번째 종목 카카오게임즈 추출중...
# 42개 추출완료. 누적1572개
# 61번째 종목 투비소프트 추출중...
# 6개 추출완료. 누적1578개
# 62번째 종목 큐라클 추출중...
# 32개 추출완료. 누적1610개
# 63번째 종목 장원테크 추출중...
# 2개 추출완료. 누적1612개
# 64번째 종목 제로투세븐 추출중...
# 31개 추출완료. 누적1643개
# 65번째 종목 경남제약 추출중...
# 41개 추출완료. 누적1684개
# 66번째 종목 세동 추출중...
# 27개 추출완료. 누적1711개
# 67번째 종목 액트로 추출중...
# 11개 추출완료. 누적1722개
# 68번째 종목 제너셈 추출중...
# 36개 추출완료. 누적1758개
# 69번째 종목 한스바이오메드 추출중...
# 29개 추출완료. 누적1787개
# 70번째 종목 원익QnC 추출중...
# 39개 추출완료. 누적1826개
# 71번째 종목 동구바이오제약 추출중...
# 32개 추출완료. 누적1858개
# 72번째 종목 라파스 추출중...
# 32개 추출완료. 누적1890개
# 73번째 종목 남화산업 추출중...
# 45개 추출완료. 누적1935개
# 74번째 종목 하나기술 추출중...
# 19개 추출완료. 누적1954개
# 75번째 종목 에이비엘바이오 추출중...
# 43개 추출완료. 누적1997개
# 76번째 종목 에코플라스틱 추출중...
# 19개 추출완료. 누적2016개
# 77번째 종목 웹케시 추출중...
# 40개 추출완료. 누적2056개
# 78번째 종목 비에이치아이 추출중...
# 37개 추출완료. 누적2093개
# 79번째 종목 블루콤 추출중...
# 16개 추출완료. 누적2109개
# 80번째 종목 대유 추출중...
# 10개 추출완료. 누적2119개
# 81번째 종목 웹젠 추출중...
# 40개 추출완료. 누적2159개
# 82번째 종목 KCC건설 추출중...
# 36개 추출완료. 누적2195개
# 83번째 종목 에이피티씨 추출중...
# 36개 추출완료. 누적2231개
# 84번째 종목 한국컴퓨터 추출중...
# 30개 추출완료. 누적2261개
# 85번째 종목 디에스케이 추출중...
# 43개 추출완료. 누적2304개
# 86번째 종목 핌스 추출중...
# 30개 추출완료. 누적2334개
# 87번째 종목 이오플로우 추출중...
# 37개 추출완료. 누적2371개
# 88번째 종목 옵티시스 추출중...
# 40개 추출완료. 누적2411개
# 89번째 종목 이퓨쳐 추출중...
# 30개 추출완료. 누적2441개
# 90번째 종목 한주라이트메탈 추출중...
# 8개 추출완료. 누적2449개
# 91번째 종목 동화기업 추출중...
# 39개 추출완료. 누적2488개
# 92번째 종목 이지케어텍 추출중...
# 25개 추출완료. 누적2513개
# 93번째 종목 중앙백신 추출중...
# 20개 추출완료. 누적2533개
# 94번째 종목 에스피시스템스 추출중...
# 17개 추출완료. 누적2550개
# 95번째 종목 동일철강 추출중...
# 27개 추출완료. 누적2577개
# 96번째 종목 초록뱀컴퍼니 추출중...
# 16개 추출완료. 누적2593개
# 97번째 종목 이엔코퍼레이션 추출중...
# 32개 추출완료. 누적2625개
# 98번째 종목 파이버프로 추출중...
# 13개 추출완료. 누적2638개
# 99번째 종목 가온칩스 추출중...
# 24개 추출완료. 누적2662개
# 100번째 종목 원익피앤이 추출중...
# 26개 추출완료. 누적2688개
# 101번째 종목 엘엠에스 추출중...
# 25개 추출완료. 누적2713개
# 102번째 종목 켐트로스 추출중...
# 25개 추출완료. 누적2738개
# 103번째 종목 가비아 추출중...
# 23개 추출완료. 누적2761개
# 104번째 종목 파나케이아 추출중...
# 0개 추출완료. 누적2761개
# 105번째 종목 엠브레인 추출중...
# 29개 추출완료. 누적2790개
# 106번째 종목 에스맥 추출중...
# 16개 추출완료. 누적2806개
# 107번째 종목 우주일렉트로 추출중...
# 26개 추출완료. 누적2832개
# 108번째 종목 제일테크노스 추출중...
# 34개 추출완료. 누적2866개
# 109번째 종목 엠아이텍 추출중...
# 46개 추출완료. 누적2912개
# 110번째 종목 우리벤처파트너스 추출중...
# 31개 추출완료. 누적2943개
# 111번째 종목 비덴트 추출중...
# 4개 추출완료. 누적2947개
# 112번째 종목 마이크로디지탈 추출중...
# 48개 추출완료. 누적2995개
# 113번째 종목 싸이버원 추출중...
# 26개 추출완료. 누적3021개
# 114번째 종목 네오이뮨텍 추출중...
# 40개 추출완료. 누적3061개
# 115번째 종목 현대무벡스 추출중...
# 21개 추출완료. 누적3082개
# 116번째 종목 신스틸 추출중...
# 8개 추출완료. 누적3090개
# 117번째 종목 비스토스 추출중...
# 16개 추출완료. 누적3106개
# 118번째 종목 파워넷 추출중...
# 23개 추출완료. 누적3129개
# 119번째 종목 윙스풋 추출중...
# 37개 추출완료. 누적3166개
# 120번째 종목 파인엠텍 추출중...
# 43개 추출완료. 누적3209개
# 121번째 종목 삼륭물산 추출중...
# 42개 추출완료. 누적3251개
# 122번째 종목 제이스텍 추출중...
# 31개 추출완료. 누적3282개
# 123번째 종목 바이넥스 추출중...
# 44개 추출완료. 누적3326개
# 124번째 종목 와토스코리아 추출중...
# 44개 추출완료. 누적3370개
# 125번째 종목 필옵틱스 추출중...
# 19개 추출완료. 누적3389개
# 126번째 종목 모베이스전자 추출중...
# 19개 추출완료. 누적3408개
# 127번째 종목 제넥신 추출중...
# 43개 추출완료. 누적3451개
# 128번째 종목 샤페론 추출중...
# 35개 추출완료. 누적3486개
# 129번째 종목 래몽래인 추출중...
# 28개 추출완료. 누적3514개
# 130번째 종목 에코앤드림 추출중...
# 33개 추출완료. 누적3547개
# 131번째 종목 피코그램 추출중...
# 3개 추출완료. 누적3550개
# 132번째 종목 엠투엔 추출중...
# 40개 추출완료. 누적3590개
# 133번째 종목 풍강 추출중...
# 50개 추출완료. 누적3640개
# 134번째 종목 휴온스 추출중...
# 37개 추출완료. 누적3677개
# 135번째 종목 리튬포어스 추출중...
# 34개 추출완료. 누적3711개
# 136번째 종목 인산가 추출중...
# 24개 추출완료. 누적3735개
# 137번째 종목 플라즈맵 추출중...
# 42개 추출완료. 누적3777개
# 138번째 종목 예스티 추출중...
# 43개 추출완료. 누적3820개
# 139번째 종목 HLB 추출중...
# 42개 추출완료. 누적3862개
# 140번째 종목 흥국 추출중...
# 32개 추출완료. 누적3894개
# 141번째 종목 에스엠코어 추출중...
# 22개 추출완료. 누적3916개
# 142번째 종목 티사이언티픽 추출중...
# 45개 추출완료. 누적3961개
# 143번째 종목 국순당 추출중...
# 25개 추출완료. 누적3986개
# 144번째 종목 이건홀딩스 추출중...
# 26개 추출완료. 누적4012개
# 145번째 종목 피델릭스 추출중...
# 19개 추출완료. 누적4031개
# 146번째 종목 오상자이엘 추출중...
# 5개 추출완료. 누적4036개
# 147번째 종목 대한뉴팜 추출중...
# 34개 추출완료. 누적4070개
# 148번째 종목 골프존 추출중...
# 38개 추출완료. 누적4108개
# 149번째 종목 씨티씨바이오 추출중...
# 32개 추출완료. 누적4140개
# 150번째 종목 신일제약 추출중...
# 44개 추출완료. 누적4184개
# 151번째 종목 바이오스마트 추출중...
# 39개 추출완료. 누적4223개
# 152번째 종목 동국알앤에스 추출중...
# 4개 추출완료. 누적4227개
# 153번째 종목 에이텍모빌리티 추출중...
# 18개 추출완료. 누적4245개
# 154번째 종목 바이오니아 추출중...
# 43개 추출완료. 누적4288개
# 155번째 종목 흥국에프엔비 추출중...
# 38개 추출완료. 누적4326개
# 156번째 종목 올릭스 추출중...
# 39개 추출완료. 누적4365개
# 157번째 종목 에이에프더블류 추출중...
# 0개 추출완료. 누적4365개
# 158번째 종목 리노공업 추출중...
# 37개 추출완료. 누적4402개
# 159번째 종목 에이디엠코리아 추출중...
# 27개 추출완료. 누적4429개
# 160번째 종목 핑거 추출중...
# 31개 추출완료. 누적4460개
# 161번째 종목 신흥에스이씨 추출중...
# 47개 추출완료. 누적4507개
# 162번째 종목 프럼파스트 추출중...
# 36개 추출완료. 누적4543개
# 163번째 종목 팬스타엔터프라이즈 추출중...
# 41개 추출완료. 누적4584개
# 164번째 종목 하츠 추출중...
# 13개 추출완료. 누적4597개
# 165번째 종목 올리패스 추출중...
# 31개 추출완료. 누적4628개
# 166번째 종목 희림 추출중...
# 37개 추출완료. 누적4665개
# 167번째 종목 SBW생명과학 추출중...
# 27개 추출완료. 누적4692개
# 168번째 종목 플레이위드 추출중...
# 26개 추출완료. 누적4718개
# 169번째 종목 상보 추출중...
# 15개 추출완료. 누적4733개
# 170번째 종목 덕신하우징 추출중...
# 26개 추출완료. 누적4759개
# 171번째 종목 디이엔티 추출중...
# 40개 추출완료. 누적4799개
# 172번째 종목 미투젠 추출중...
# 37개 추출완료. 누적4836개
# 173번째 종목 뉴트리 추출중...
# 42개 추출완료. 누적4878개
# 174번째 종목 스튜디오미르 추출중...
# 10개 추출완료. 누적4888개
# 175번째 종목 정원엔시스 추출중...
# 33개 추출완료. 누적4921개
# 176번째 종목 DGP 추출중...
# 30개 추출완료. 누적4951개
# 177번째 종목 에코마케팅 추출중...
# 39개 추출완료. 누적4990개
# 178번째 종목 코데즈컴바인 추출중...
# 8개 추출완료. 누적4998개
# 179번째 종목 아이티센 추출중...
# 6개 추출완료. 누적5004개
# 180번째 종목 에프알텍 추출중...
# 32개 추출완료. 누적5036개
# 181번째 종목 인지소프트 추출중...
# 34개 추출완료. 누적5070개
# 182번째 종목 동우팜투테이블 추출중...
# 44개 추출완료. 누적5114개
# 183번째 종목 인카금융서비스 추출중...
# 27개 추출완료. 누적5141개
# 184번째 종목 아모그린텍 추출중...
# 22개 추출완료. 누적5163개
# 185번째 종목 삼천리자전거 추출중...
# 33개 추출완료. 누적5196개
# 186번째 종목 세진티에스 추출중...
# 18개 추출완료. 누적5214개
# 187번째 종목 에이치피오 추출중...
# 30개 추출완료. 누적5244개
# 188번째 종목 경창산업 추출중...
# 11개 추출완료. 누적5255개
# 189번째 종목 아우딘퓨쳐스 추출중...
# 27개 추출완료. 누적5282개
# 190번째 종목 솔고바이오 추출중...
# 32개 추출완료. 누적5314개
# 191번째 종목 에스제이그룹 추출중...
# 42개 추출완료. 누적5356개
# 192번째 종목 더블유씨피 추출중...
# 46개 추출완료. 누적5402개
# 193번째 종목 MIT 추출중...
# 0개 추출완료. 누적5402개
# 194번째 종목 와이지-원 추출중...
# 38개 추출완료. 누적5440개
# 195번째 종목 창해에탄올 추출중...
# 31개 추출완료. 누적5471개
# 196번째 종목 엔텔스 추출중...
# 15개 추출완료. 누적5486개
# 197번째 종목 코아시아씨엠 추출중...
# 39개 추출완료. 누적5525개
# 198번째 종목 와이아이케이 추출중...
# 14개 추출완료. 누적5539개
# 199번째 종목 시큐센 추출중...
# 8개 추출완료. 누적5547개
# 200번째 종목 아스트 추출중...
# 34개 추출완료. 누적5581개
# 201번째 종목 EDGC 추출중...
# 9개 추출완료. 누적5590개
# 202번째 종목 브이티 추출중...
# 21개 추출완료. 누적5611개
# 203번째 종목 드래곤플라이 추출중...
# 37개 추출완료. 누적5648개
# 204번째 종목 KH바텍 추출중...
# 45개 추출완료. 누적5693개
# 205번째 종목 우진비앤지 추출중...
# 25개 추출완료. 누적5718개
# 206번째 종목 윌링스 추출중...
# 17개 추출완료. 누적5735개
# 207번째 종목 육일씨엔에쓰 추출중...
# 31개 추출완료. 누적5766개
# 208번째 종목 클리오 추출중...
# 41개 추출완료. 누적5807개
# 209번째 종목 메가엠디 추출중...
# 13개 추출완료. 누적5820개
# 210번째 종목 ISC 추출중...
# 46개 추출완료. 누적5866개
# 211번째 종목 한국파마 추출중...
# 37개 추출완료. 누적5903개
# 212번째 종목 모비릭스 추출중...
# 35개 추출완료. 누적5938개
# 213번째 종목 아이윈 추출중...
# 20개 추출완료. 누적5958개
# 214번째 종목 성광벤드 추출중...
# 49개 추출완료. 누적6007개
# 215번째 종목 아시아종묘 추출중...
# 24개 추출완료. 누적6031개
# 216번째 종목 알티캐스트 추출중...
# 10개 추출완료. 누적6041개
# 217번째 종목 팅크웨어 추출중...
# 20개 추출완료. 누적6061개
# 218번째 종목 큐로홀딩스 추출중...
# 2개 추출완료. 누적6063개
# 219번째 종목 인성정보 추출중...
# 10개 추출완료. 누적6073개
# 220번째 종목 중앙에너비스 추출중...
# 13개 추출완료. 누적6086개
# 221번째 종목 본느 추출중...
# 18개 추출완료. 누적6104개
# 222번째 종목 케이프 추출중...
# 17개 추출완료. 누적6121개
# 223번째 종목 이노와이어리스 추출중...
# 39개 추출완료. 누적6160개
# 224번째 종목 케이엠제약 추출중...
# 28개 추출완료. 누적6188개
# 225번째 종목 제이엔케이히터 추출중...
# 33개 추출완료. 누적6221개
# 226번째 종목 플레이디 추출중...
# 23개 추출완료. 누적6244개
# 227번째 종목 엔젯 추출중...
# 26개 추출완료. 누적6270개
# 228번째 종목 오에스피 추출중...
# 43개 추출완료. 누적6313개
# 229번째 종목 삼천당제약 추출중...
# 46개 추출완료. 누적6359개
# 230번째 종목 크루셜텍 추출중...
# 0개 추출완료. 누적6359개
# 231번째 종목 SG&G 추출중...
# 30개 추출완료. 누적6389개
# 232번째 종목 레몬 추출중...
# 14개 추출완료. 누적6403개
# 233번째 종목 꿈비 추출중...
# 2개 추출완료. 누적6405개
# 234번째 종목 오이솔루션 추출중...
# 24개 추출완료. 누적6429개
# 235번째 종목 아이톡시 추출중...
# 0개 추출완료. 누적6429개
# 236번째 종목 지에스이 추출중...
# 11개 추출완료. 누적6440개
# 237번째 종목 서울바이오시스 추출중...
# 26개 추출완료. 누적6466개
# 238번째 종목 포바이포 추출중...
# 49개 추출완료. 누적6515개
# 239번째 종목 우리산업홀딩스 추출중...
# 17개 추출완료. 누적6532개
# 240번째 종목 유바이오로직스 추출중...
# 48개 추출완료. 누적6580개
# 241번째 종목 쎄노텍 추출중...
# 5개 추출완료. 누적6585개
# 242번째 종목 메쎄이상 추출중...
# 0개 추출완료. 누적6585개
# 243번째 종목 베스파 추출중...
# 0개 추출완료. 누적6585개
# 244번째 종목 피에이치씨 추출중...
# 0개 추출완료. 누적6585개
# 245번째 종목 이글루 추출중...
# 13개 추출완료. 누적6598개
# 246번째 종목 비케이홀딩스 추출중...
# 7개 추출완료. 누적6605개
# 247번째 종목 케어젠 추출중...
# 38개 추출완료. 누적6643개
# 248번째 종목 시너지이노베이션 추출중...
# 37개 추출완료. 누적6680개
# 249번째 종목 밸로프 추출중...
# 29개 추출완료. 누적6709개
# 250번째 종목 코렌텍 추출중...
# 25개 추출완료. 누적6734개
# 251번째 종목 제주맥주 추출중...
# 18개 추출완료. 누적6752개
# 252번째 종목 파인테크닉스 추출중...
# 27개 추출완료. 누적6779개
# 253번째 종목 한국큐빅 추출중...
# 37개 추출완료. 누적6816개
# 254번째 종목 바이옵트로 추출중...
# 19개 추출완료. 누적6835개
# 255번째 종목 미디어젠 추출중...
# 28개 추출완료. 누적6863개
# 256번째 종목 휴맥스홀딩스 추출중...
# 0개 추출완료. 누적6863개
# 257번째 종목 신도기연 추출중...
# 10개 추출완료. 누적6873개
# 258번째 종목 와이엠씨 추출중...
# 33개 추출완료. 누적6906개
# 259번째 종목 텔레필드 추출중...
# 18개 추출완료. 누적6924개
# 260번째 종목 고영 추출중...
# 45개 추출완료. 누적6969개
# 261번째 종목 티피씨글로벌 추출중...
# 17개 추출완료. 누적6986개
# 262번째 종목 아진엑스텍 추출중...
# 10개 추출완료. 누적6996개
# 263번째 종목 이엠앤아이 추출중...
# 30개 추출완료. 누적7026개
# 264번째 종목 윙입푸드 추출중...
# 11개 추출완료. 누적7037개
# 265번째 종목 아이윈플러스 추출중...
# 38개 추출완료. 누적7075개
# 266번째 종목 유성티엔에스 추출중...
# 38개 추출완료. 누적7113개
# 267번째 종목 GRT 추출중...
# 21개 추출완료. 누적7134개
# 268번째 종목 아이진 추출중...
# 30개 추출완료. 누적7164개
# 269번째 종목 오션브릿지 추출중...
# 35개 추출완료. 누적7199개
# 270번째 종목 듀오백 추출중...
# 28개 추출완료. 누적7227개
# 271번째 종목 핸디소프트 추출중...
# 14개 추출완료. 누적7241개
# 272번째 종목 수성샐바시온 추출중...
# 17개 추출완료. 누적7258개
# 273번째 종목 DSEN 추출중...
# 12개 추출완료. 누적7270개
# 274번째 종목 케이엔솔 추출중...
# 25개 추출완료. 누적7295개
# 275번째 종목 코아시아 추출중...
# 21개 추출완료. 누적7316개
# 276번째 종목 HB테크놀러지 추출중...
# 21개 추출완료. 누적7337개
# 277번째 종목 오비고 추출중...
# 23개 추출완료. 누적7360개
# 278번째 종목 디딤이앤에프 추출중...
# 29개 추출완료. 누적7389개
# 279번째 종목 캠시스 추출중...
# 40개 추출완료. 누적7429개
# 280번째 종목 나인테크 추출중...
# 30개 추출완료. 누적7459개
# 281번째 종목 코디 추출중...
# 30개 추출완료. 누적7489개
# 282번째 종목 에이디테크놀로지 추출중...
# 33개 추출완료. 누적7522개
# 283번째 종목 피에이치에이 추출중...
# 43개 추출완료. 누적7565개
# 284번째 종목 오로스테크놀로지 추출중...
# 15개 추출완료. 누적7580개
# 285번째 종목 메타바이오메드 추출중...
# 11개 추출완료. 누적7591개
# 286번째 종목 제이아이테크 추출중...
# 18개 추출완료. 누적7609개
# 287번째 종목 딜리 추출중...
# 42개 추출완료. 누적7651개
# 288번째 종목 이씨에스 추출중...
# 33개 추출완료. 누적7684개
# 289번째 종목 유니테스트 추출중...
# 41개 추출완료. 누적7725개
# 290번째 종목 베뉴지 추출중...
# 32개 추출완료. 누적7757개
# 291번째 종목 큐에스아이 추출중...
# 21개 추출완료. 누적7778개
# 292번째 종목 코리아에프티 추출중...
# 8개 추출완료. 누적7786개
# 293번째 종목 와이솔 추출중...
# 41개 추출완료. 누적7827개
# 294번째 종목 심텍 추출중...
# 39개 추출완료. 누적7866개
# 295번째 종목 엔에프씨 추출중...
# 21개 추출완료. 누적7887개
# 296번째 종목 이큐셀 추출중...
# 0개 추출완료. 누적7887개
# 297번째 종목 신테카바이오 추출중...
# 23개 추출완료. 누적7910개
# 298번째 종목 CMG제약 추출중...
# 44개 추출완료. 누적7954개
# 299번째 종목 셀트리온헬스케어 추출중...
# 40개 추출완료. 누적7994개
# 300번째 종목 조광ILI 추출중...
# 9개 추출완료. 누적8003개
# 301번째 종목 에스유홀딩스 추출중...
# 23개 추출완료. 누적8026개
# 302번째 종목 에이텍 추출중...
# 26개 추출완료. 누적8052개
# 303번째 종목 디와이씨 추출중...
# 38개 추출완료. 누적8090개
# 304번째 종목 잉크테크 추출중...
# 6개 추출완료. 누적8096개
# 305번째 종목 태양 추출중...
# 34개 추출완료. 누적8130개
# 306번째 종목 테스 추출중...
# 38개 추출완료. 누적8168개
# 307번째 종목 보광산업 추출중...
# 32개 추출완료. 누적8200개
# 308번째 종목 세명전기 추출중...
# 28개 추출완료. 누적8228개
# 309번째 종목 엑셈 추출중...
# 40개 추출완료. 누적8268개
# 310번째 종목 진로발효 추출중...
# 41개 추출완료. 누적8309개
# 311번째 종목 압타바이오 추출중...
# 24개 추출완료. 누적8333개
# 312번째 종목 세경하이테크 추출중...
# 23개 추출완료. 누적8356개
# 313번째 종목 스카이문스테크놀로지 추출중...
# 0개 추출완료. 누적8356개
# 314번째 종목 테고사이언스 추출중...
# 38개 추출완료. 누적8394개
# 315번째 종목 한국비엔씨 추출중...
# 41개 추출완료. 누적8435개
# 316번째 종목 이스트아시아홀딩스 추출중...
# 31개 추출완료. 누적8466개
# 317번째 종목 로보로보 추출중...
# 42개 추출완료. 누적8508개
# 318번째 종목 케이엠 추출중...
# 43개 추출완료. 누적8551개
# 319번째 종목 세림B&G 추출중...
# 21개 추출완료. 누적8572개
# 320번째 종목 엔터파트너즈 추출중...
# 11개 추출완료. 누적8583개
# 321번째 종목 정상제이엘에스 추출중...
# 41개 추출완료. 누적8624개
# 322번째 종목 디지틀조선 추출중...
# 39개 추출완료. 누적8663개
# 323번째 종목 코스텍시스 추출중...
# 20개 추출완료. 누적8683개
# 324번째 종목 오텍 추출중...
# 27개 추출완료. 누적8710개
# 325번째 종목 KCI 추출중...
# 42개 추출완료. 누적8752개
# 326번째 종목 대림제지 추출중...
# 33개 추출완료. 누적8785개
# 327번째 종목 씨아이에스 추출중...
# 28개 추출완료. 누적8813개
# 328번째 종목 제넨바이오 추출중...
# 4개 추출완료. 누적8817개
# 329번째 종목 알체라 추출중...
# 39개 추출완료. 누적8856개
# 330번째 종목 디지털대성 추출중...
# 42개 추출완료. 누적8898개
# 331번째 종목 대동기어 추출중...
# 29개 추출완료. 누적8927개
# 332번째 종목 세종메디칼 추출중...
# 21개 추출완료. 누적8948개
# 333번째 종목 티쓰리 추출중...
# 31개 추출완료. 누적8979개
# 334번째 종목 티에스이 추출중...
# 38개 추출완료. 누적9017개
# 335번째 종목 인트론바이오 추출중...
# 45개 추출완료. 누적9062개
# 336번째 종목 브이원텍 추출중...
# 32개 추출완료. 누적9094개
# 337번째 종목 케이아이엔엑스 추출중...
# 35개 추출완료. 누적9129개
# 338번째 종목 주성엔지니어링 추출중...
# 22개 추출완료. 누적9151개
# 339번째 종목 제이에스티나 추출중...
# 34개 추출완료. 누적9185개
# 340번째 종목 삼목에스폼 추출중...
# 30개 추출완료. 누적9215개
# 341번째 종목 잉글우드랩 추출중...
# 24개 추출완료. 누적9239개
# 342번째 종목 아이크래프트 추출중...
# 17개 추출완료. 누적9256개
# 343번째 종목 웨이버스 추출중...
# 16개 추출완료. 누적9272개
# 344번째 종목 유니테크노 추출중...
# 31개 추출완료. 누적9303개
# 345번째 종목 KT서브마린 추출중...
# 30개 추출완료. 누적9333개
# 346번째 종목 아이엠 추출중...
# 38개 추출완료. 누적9371개
# 347번째 종목 와이지엔터테인먼트 추출중...
# 41개 추출완료. 누적9412개
# 348번째 종목 씨엔알리서치 추출중...
# 28개 추출완료. 누적9440개
# 349번째 종목 남화토건 추출중...
# 26개 추출완료. 누적9466개
# 350번째 종목 레인보우로보틱스 추출중...
# 46개 추출완료. 누적9512개
# 351번째 종목 파워로직스 추출중...
# 27개 추출완료. 누적9539개
# 352번째 종목 크린앤사이언스 추출중...
# 46개 추출완료. 누적9585개
# 353번째 종목 대성하이텍 추출중...
# 25개 추출완료. 누적9610개
# 354번째 종목 한일단조 추출중...
# 30개 추출완료. 누적9640개
# 355번째 종목 피에스케이홀딩스 추출중...
# 34개 추출완료. 누적9674개
# 356번째 종목 중앙디앤엠 추출중...
# 44개 추출완료. 누적9718개
# 357번째 종목 스톤브릿지벤처스 추출중...
# 34개 추출완료. 누적9752개
# 358번째 종목 상상인 추출중...
# 46개 추출완료. 누적9798개
# 359번째 종목 예스24 추출중...
# 24개 추출완료. 누적9822개
# 360번째 종목 엔피케이 추출중...
# 18개 추출완료. 누적9840개
# 361번째 종목 대원 추출중...
# 28개 추출완료. 누적9868개
# 362번째 종목 위닉스 추출중...
# 27개 추출완료. 누적9895개
# 363번째 종목 미코 추출중...
# 19개 추출완료. 누적9914개
# 364번째 종목 인트로메딕 추출중...
# 0개 추출완료. 누적9914개
# 365번째 종목 팜스빌 추출중...
# 21개 추출완료. 누적9935개
# 366번째 종목 파라다이스 추출중...
# 42개 추출완료. 누적9977개
# 367번째 종목 시공테크 추출중...
# 18개 추출완료. 누적9995개
# 368번째 종목 휴먼엔 추출중...
# 0개 추출완료. 누적9995개
# 369번째 종목 아스타 추출중...
# 24개 추출완료. 누적10019개
# 370번째 종목 이오테크닉스 추출중...
# 41개 추출완료. 누적10060개
# 371번째 종목 셀리버리 추출중...
# 0개 추출완료. 누적10060개
# 372번째 종목 디아이티 추출중...
# 26개 추출완료. 누적10086개
# 373번째 종목 대주산업 추출중...
# 15개 추출완료. 누적10101개
# 374번째 종목 iMBC 추출중...
# 21개 추출완료. 누적10122개
# 375번째 종목 데이타솔루션 추출중...
# 26개 추출완료. 누적10148개
# 376번째 종목 더블유에스아이 추출중...
# 23개 추출완료. 누적10171개
# 377번째 종목 케이피에프 추출중...
# 18개 추출완료. 누적10189개
# 378번째 종목 한탑 추출중...
# 4개 추출완료. 누적10193개
# 379번째 종목 헬릭스미스 추출중...
# 38개 추출완료. 누적10231개
# 380번째 종목 테크윙 추출중...
# 29개 추출완료. 누적10260개
# 381번째 종목 세토피아 추출중...
# 29개 추출완료. 누적10289개
# 382번째 종목 프로텍 추출중...
# 21개 추출완료. 누적10310개
# 383번째 종목 SGA 추출중...
# 15개 추출완료. 누적10325개
# 384번째 종목 화신정공 추출중...
# 16개 추출완료. 누적10341개
# 385번째 종목 코윈테크 추출중...
# 24개 추출완료. 누적10365개
# 386번째 종목 제놀루션 추출중...
# 22개 추출완료. 누적10387개
# 387번째 종목 솔트웨어 추출중...
# 12개 추출완료. 누적10399개
# 388번째 종목 초록뱀미디어 추출중...
# 26개 추출완료. 누적10425개
# 389번째 종목 이즈미디어 추출중...
# 0개 추출완료. 누적10425개
# 390번째 종목 파인텍 추출중...
# 39개 추출완료. 누적10464개
# 391번째 종목 NE능률 추출중...
# 5개 추출완료. 누적10469개
# 392번째 종목 엔투텍 추출중...
# 16개 추출완료. 누적10485개
# 393번째 종목 케이피에스 추출중...
# 33개 추출완료. 누적10518개
# 394번째 종목 효성오앤비 추출중...
# 16개 추출완료. 누적10534개
# 395번째 종목 강스템바이오텍 추출중...
# 42개 추출완료. 누적10576개
# 396번째 종목 홈센타홀딩스 추출중...
# 17개 추출완료. 누적10593개
# 397번째 종목 에이프릴바이오 추출중...
# 40개 추출완료. 누적10633개
# 398번째 종목 라이트론 추출중...
# 33개 추출완료. 누적10666개
# 399번째 종목 성우하이텍 추출중...
# 29개 추출완료. 누적10695개
# 400번째 종목 아이엘사이언스 추출중...
# 46개 추출완료. 누적10741개
# 401번째 종목 에스씨엠생명과학 추출중...
# 30개 추출완료. 누적10771개
# 402번째 종목 제이엘케이 추출중...
# 20개 추출완료. 누적10791개
# 403번째 종목 삼일기업공사 추출중...
# 42개 추출완료. 누적10833개
# 404번째 종목 천보 추출중...
# 45개 추출완료. 누적10878개
# 405번째 종목 이랜시스 추출중...
# 10개 추출완료. 누적10888개
# 406번째 종목 큐렉소 추출중...
# 15개 추출완료. 누적10903개
# 407번째 종목 진매트릭스 추출중...
# 9개 추출완료. 누적10912개
# 408번째 종목 SM C&C 추출중...
# 33개 추출완료. 누적10945개
# 409번째 종목 한솔인티큐브 추출중...
# 24개 추출완료. 누적10969개
# 410번째 종목 유비쿼스홀딩스 추출중...
# 42개 추출완료. 누적11011개
# 411번째 종목 티앤엘 추출중...
# 43개 추출완료. 누적11054개
# 412번째 종목 퓨런티어 추출중...
# 31개 추출완료. 누적11085개
# 413번째 종목 씨유메디칼 추출중...
# 28개 추출완료. 누적11113개
# 414번째 종목 다원시스 추출중...
# 49개 추출완료. 누적11162개
# 415번째 종목 씨앤씨인터내셔널 추출중...
# 40개 추출완료. 누적11202개
# 416번째 종목 삼양옵틱스 추출중...
# 45개 추출완료. 누적11247개
# 417번째 종목 코스맥스엔비티 추출중...
# 46개 추출완료. 누적11293개
# 418번째 종목 JTC 추출중...
# 44개 추출완료. 누적11337개
# 419번째 종목 CNT85 추출중...
# 0개 추출완료. 누적11337개
# 420번째 종목 마녀공장 추출중...
# 0개 추출완료. 누적11337개
# 421번째 종목 덕산하이메탈 추출중...
# 23개 추출완료. 누적11360개
# 422번째 종목 원텍 추출중...
# 41개 추출완료. 누적11401개
# 423번째 종목 에스티아이 추출중...
# 32개 추출완료. 누적11433개
# 424번째 종목 에스트래픽 추출중...
# 11개 추출완료. 누적11444개
# 425번째 종목 유진로봇 추출중...
# 31개 추출완료. 누적11475개
# 426번째 종목 지아이이노베이션 추출중...
# 0개 추출완료. 누적11475개
# 427번째 종목 지니뮤직 추출중...
# 21개 추출완료. 누적11496개
# 428번째 종목 에프앤가이드 추출중...
# 37개 추출완료. 누적11533개
# 429번째 종목 멕아이씨에스 추출중...
# 20개 추출완료. 누적11553개
# 430번째 종목 퀀타매트릭스 추출중...
# 22개 추출완료. 누적11575개
# 431번째 종목 휴림네트웍스 추출중...
# 28개 추출완료. 누적11603개
# 432번째 종목 SDN 추출중...
# 16개 추출완료. 누적11619개
# 433번째 종목 포스코DX 추출중...
# 26개 추출완료. 누적11645개
# 434번째 종목 그린플러스 추출중...
# 26개 추출완료. 누적11671개
# 435번째 종목 탑코미디어 추출중...
# 28개 추출완료. 누적11699개
# 436번째 종목 씨큐브 추출중...
# 21개 추출완료. 누적11720개
# 437번째 종목 뷰노 추출중...
# 36개 추출완료. 누적11756개
# 438번째 종목 쇼박스 추출중...
# 22개 추출완료. 누적11778개
# 439번째 종목 엠에프엠코리아 추출중...
# 27개 추출완료. 누적11805개
# 440번째 종목 동운아나텍 추출중...
# 30개 추출완료. 누적11835개
# 441번째 종목 에스앤디 추출중...
# 38개 추출완료. 누적11873개
# 442번째 종목 아모텍 추출중...
# 44개 추출완료. 누적11917개
# 443번째 종목 성창오토텍 추출중...
# 31개 추출완료. 누적11948개
# 444번째 종목 새빗켐 추출중...
# 30개 추출완료. 누적11978개
# 445번째 종목 윈팩 추출중...
# 19개 추출완료. 누적11997개
# 446번째 종목 티이엠씨 추출중...
# 16개 추출완료. 누적12013개
# 447번째 종목 오리엔트정공 추출중...
# 17개 추출완료. 누적12030개
# 448번째 종목 딥노이드 추출중...
# 14개 추출완료. 누적12044개
# 449번째 종목 디앤씨미디어 추출중...
# 33개 추출완료. 누적12077개
# 450번째 종목 알에프텍 추출중...
# 30개 추출완료. 누적12107개
# 451번째 종목 모트렉스 추출중...
# 46개 추출완료. 누적12153개
# 452번째 종목 테라젠이텍스 추출중...
# 10개 추출완료. 누적12163개
# 453번째 종목 이엔에프테크놀로지 추출중...
# 45개 추출완료. 누적12208개
# 454번째 종목 한네트 추출중...
# 8개 추출완료. 누적12216개
# 455번째 종목 경동제약 추출중...
# 42개 추출완료. 누적12258개
# 456번째 종목 슈프리마 추출중...
# 30개 추출완료. 누적12288개
# 457번째 종목 엔시스 추출중...
# 7개 추출완료. 누적12295개
# 458번째 종목 서울반도체 추출중...
# 30개 추출완료. 누적12325개
# 459번째 종목 에이디칩스 추출중...
# 19개 추출완료. 누적12344개
# 460번째 종목 코메론 추출중...
# 41개 추출완료. 누적12385개
# 461번째 종목 AP시스템 추출중...
# 41개 추출완료. 누적12426개
# 462번째 종목 자연과환경 추출중...
# 31개 추출완료. 누적12457개
# 463번째 종목 티씨케이 추출중...
# 42개 추출완료. 누적12499개
# 464번째 종목 유틸렉스 추출중...
# 46개 추출완료. 누적12545개
# 465번째 종목 하이로닉 추출중...
# 30개 추출완료. 누적12575개
# 466번째 종목 카이노스메드 추출중...
# 29개 추출완료. 누적12604개
# 467번째 종목 금강철강 추출중...
# 8개 추출완료. 누적12612개
# 468번째 종목 삼보모터스 추출중...
# 30개 추출완료. 누적12642개
# 469번째 종목 프로이천 추출중...
# 2개 추출완료. 누적12644개
# 470번째 종목 카스 추출중...
# 42개 추출완료. 누적12686개
# 471번째 종목 제이씨케미칼 추출중...
# 45개 추출완료. 누적12731개
# 472번째 종목 아가방컴퍼니 추출중...
# 46개 추출완료. 누적12777개
# 473번째 종목 형지I&C 추출중...
# 14개 추출완료. 누적12791개
# 474번째 종목 디오 추출중...
# 37개 추출완료. 누적12828개
# 475번째 종목 대주전자재료 추출중...
# 42개 추출완료. 누적12870개
# 476번째 종목 펩트론 추출중...
# 30개 추출완료. 누적12900개
# 477번째 종목 현대공업 추출중...
# 19개 추출완료. 누적12919개
# 478번째 종목 셀레믹스 추출중...
# 6개 추출완료. 누적12925개
# 479번째 종목 신원종합개발 추출중...
# 12개 추출완료. 누적12937개
# 480번째 종목 HLB생명과학 추출중...
# 42개 추출완료. 누적12979개
# 481번째 종목 알테오젠 추출중...
# 39개 추출완료. 누적13018개
# 482번째 종목 삼진엘앤디 추출중...
# 27개 추출완료. 누적13045개
# 483번째 종목 광진실업 추출중...
# 25개 추출완료. 누적13070개
# 484번째 종목 YBM넷 추출중...
# 10개 추출완료. 누적13080개
# 485번째 종목 린드먼아시아 추출중...
# 5개 추출완료. 누적13085개
# 486번째 종목 인터엠 추출중...
# 47개 추출완료. 누적13132개
# 487번째 종목 원익머트리얼즈 추출중...
# 42개 추출완료. 누적13174개
# 488번째 종목 케이엔제이 추출중...
# 38개 추출완료. 누적13212개
# 489번째 종목 동양이엔피 추출중...
# 17개 추출완료. 누적13229개
# 490번째 종목 제노레이 추출중...
# 40개 추출완료. 누적13269개
# 491번째 종목 상신이디피 추출중...
# 31개 추출완료. 누적13300개
# 492번째 종목 네온테크 추출중...
# 26개 추출완료. 누적13326개
# 493번째 종목 아이큐어 추출중...
# 23개 추출완료. 누적13349개
# 494번째 종목 국전약품 추출중...
# 32개 추출완료. 누적13381개
# 495번째 종목 펨트론 추출중...
# 30개 추출완료. 누적13411개
# 496번째 종목 다날 추출중...
# 43개 추출완료. 누적13454개
# 497번째 종목 토비스 추출중...
# 42개 추출완료. 누적13496개
# 498번째 종목 캐스텍코리아 추출중...
# 25개 추출완료. 누적13521개
# 499번째 종목 아톤 추출중...
# 37개 추출완료. 누적13558개
# 500번째 종목 대동스틸 추출중...
# 13개 추출완료. 누적13571개

# %%
print(len(test_result))
print(sum([low[1] for low in test_result]))
# Out:
# 13571
# 5951

# %%
test_result = get_same_labelnum(test_result, 5000)
test_images, test_labels = zip(*test_result)
print(sum(test_labels))
np.save('test_images.npy', test_images)
np.save('test_labels.npy', test_labels)
# Out:
# 5000

# %%
train_images = np.load('train_images.npy')
train_labels = np.load('train_labels.npy')
# test_images = np.load('test_images.npy')
# test_labels = np.load('test_labels.npy')

train_images = train_images[:, :, :, :3]
# test_images = test_images[:, :, :, :3]

np.save('train_images.npy', train_images)
np.save('train_labels.npy', train_labels)
# np.save('test_images.npy', test_images)
# np.save('test_labels.npy', test_labels)

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# 이미지 개수와 그리드 크기 설정
num_images = len(train_images)
num_to_display = 100
grid_size = int(np.sqrt(num_to_display))

# 랜덤으로 이미지 인덱스 선택
random_indices = np.random.choice(num_images, num_to_display, replace=False)

fig, axes = plt.subplots(grid_size, grid_size, figsize=(16, 16))
for i in range(grid_size):
    for j in range(grid_size):
        img_idx = random_indices[i * grid_size + j]
        img = Image.fromarray(train_images[img_idx])
        axes[i, j].imshow(img)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        axes[i, j].set_xlabel(f'Img {img_idx + 1}', fontsize=9)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10, 10, figsize=(16, 16))
for i in range(10):
    for j in range(10):
        img_idx = i * 10 + j
        img = Image.fromarray(train_images[img_idx])
        axes[i, j].imshow(img)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        axes[i, j].set_xlabel(f'Img {img_idx + 1}', fontsize=9)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.show()
